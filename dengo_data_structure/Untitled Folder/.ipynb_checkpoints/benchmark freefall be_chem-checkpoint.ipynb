# %%
from dengo_freefall import *
# Out:
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#  using cli
#  using CLI for selections

# %%
def Init_values(temperature, density, n_species = 9, cooling=True, size=10):
    """ Create a initial value dictionary,
        for a given temperature, density, number of species
    Args:
        temperature -- in Kelvin
        density     -- in amu / cm**3
        n_species   -- number of species (6/9)
        cooling

    Returns:
        init_values: initial value dictionary with
                     self-consistent energy/ electron density
        primordial : chemical_network classes

    """

    # initialize and setup the network
    dengo.primordial_rates.setup_primordial()
    primordial = ChemicalNetwork()
    primordial.threebody = 4

    if n_species == 9:
        for i in range(22):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass
    else:
        for i in range(6):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass

    # the temperature array required to interpolates the rates
    primordial.init_temperature((1e0, 1e5))

    tiny = 1.0e-20

    # init_array are is in fractional abundances
    init_values = dict()
    density = numpy.array([density])*numpy.ones((size))
    if n_species == 6:
        # 6-species model
        init_values["He_1"]    = density * (1.0 - 0.76)
        init_values["He_2"]    = np.array([tiny])
        init_values["He_3"]    = np.array([tiny])
        init_values["H_1"]     = density *  (0.76)
        init_values['H_2']     = np.array([tiny]) 
    else:
        # 9-species model
        init_values["He_1"]    = density * (1.0 - 0.76) 
        init_values["He_2"]    = density *np.array([tiny])
        init_values["He_3"]    = density *np.array([tiny])
        init_values["H_1"]     = density *  (0.76)
        init_values['H_2']     = density *np.array([tiny])

        init_values["H_m0"]    = density *np.array([tiny])
        init_values["H2_1"]    = density *np.array([tiny])
        init_values["H2_2"]    = density *np.array([tiny])

    # now everything in mass density
    init_values['de'] = primordial.calculate_free_electrons(init_values)
    # one signle value: again mass density
    init_values['density'] = primordial.calculate_total_density(init_values)

    num_den = {}
    for sp in primordial.required_species:
        try:
            num_den[sp.name] = init_values[sp.name]/ sp.weight
        except:
            pass

    # set up initial temperatures values used to define ge
    init_values['T'] = numpy.array([temperature])*numpy.ones((size))
    ge_array = numpy.ones((size))
    init_values['ge'] = ge_array
    
    # calculate gammaH2
    
    for i in range(size):
        
        temperature = init_values['T'][i]
        x = 6100.0/temperature
        expx = numpy.exp(x)
        gammaH2 = 2.0 / (5.0 + 2.0*x*x*expx / (expx - 1 )**2.0 ) + 1

        rs = primordial.required_species
        H2_1_sp = list(rs)[0]
        gammaH2 = primordial.species_gamma(H2_1_sp,name=False, temp=True).subs({'T':temperature})

        new_num_den = {}
        for ele in num_den.keys():
            new_num_den[ele] = num_den[ele][i]
        
        gamma_factor = primordial.gamma_factor().subs(new_num_den).subs({'gammaH2': gammaH2 , 'gamma': 5./3.,'T': temperature })

        ge  = ((temperature *  kboltz) *gamma_factor
                             / (init_values['density'][i] * mh  ))

        
        T = init_values['density']*ge*mh / kboltz / gamma_factor
        init_values['ge'][i] = numpy.float64(ge)
    print(ge)
    if cooling:
        for cooling_action in cooling_registry:
            k = cooling_registry[cooling_action]
            if (k.species).issubset( primordial.required_species ):
                if k.name != "cie_cooling":                    
                    print("adding cooling: {}".format(k.name) )
                    primordial.add_cooling(cooling_action)
    return init_values, primordial

# %%
density = 1e10
initial_temperature = 2000.0
final_time = 1e10

final_time_Myr = u.second.in_units('Myr').v * final_time

init, primordial = Init_values(initial_temperature, 
                               density, n_species = 9, 
                               cooling=True, size=1)
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# 201787598961.116
# adding cooling: brem
# adding cooling: reHII
# adding cooling: reHeIII
# adding cooling: gloverabel08
# adding cooling: ceHI
# adding cooling: compton
# adding cooling: h2formation
# adding cooling: reHeII2
# adding cooling: reHeII1
# adding cooling: ciHeIS
# adding cooling: ceHeII
# adding cooling: ciHI
# adding cooling: ceHeI
# adding cooling: gammah
# adding cooling: ciHeI
# adding cooling: ciHeII

# %%
solver_name = 'test_bechem_cvdls'
pyximport.install(setup_args={"include_dirs":np.get_include()},
                  reload_support=True, inplace=True)

primordial.stop_time = 1.0e10
# write the network

# primordial.write_solver(solver_name, output_dir = ".",
#     solver_template = "be_chem_solve/rates_and_rate_tables",
#     ode_solver_source = "BE_chem_solve.C",
#     init_values=init,
#     input_is_number=False)

# import the pyx module
bechem_cvdls_run = pyximport.load_module("{}_run".format(solver_name),
                "{}_solver_run.pyx".format(solver_name),
                 build_inplace = True, pyxbuild_dir = "_dengo_temp")

# %%
temperature = 50000.0# K
density = 1.0e-1*1.007947 # cm^-3


init, primordial = Init_values(temperature, 
                               density, n_species = 9, 
                               cooling=True, size=1)
tic = time.time()
rv, rv_int = bechem_cvdls_run.run_test_bechem_cvdls(init, 1e18,niter=1e3);
toc = time.time()
print('time taken: %0.3e' %(toc-tic) )
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# 5044689974027.89
# adding cooling: brem
# adding cooling: reHII
# adding cooling: reHeIII
# adding cooling: gloverabel08
# adding cooling: ceHI
# adding cooling: compton
# adding cooling: h2formation
# adding cooling: reHeII2
# adding cooling: reHeII1
# adding cooling: ciHeIS
# adding cooling: ceHeII
# adding cooling: ciHI
# adding cooling: ceHeI
# adding cooling: gammah
# adding cooling: ciHeI
# adding cooling: ciHeII
# End in 914 iterations: 1.00000e+18 / 1.00000e+18 (0.00000e+00)
# time taken: 4.660e-02

# %%
flag = rv_int['successful']
# plt.loglog(rv_int['t'][flag],rv_int['H2_1'][0][flag],'-o')
# plt.loglog(rv_int['t'][flag],rv_int['H_1'][0][flag],'-o')
plt.loglog(rv_int['t'][flag],rv_int['T'][0][flag],'-o')
rv_int['T'][0][flag][-1]
# Out:
# 88.93863741162428

# %%
flag = rv_int['successful']

t = rv_int['t'][flag]
for key in rv_int.keys():
    if key not in ['ge','de','successful','t','dt']:
        print(key)
        vals = rv_int[key][0][flag]
        plt.loglog(t, vals,label=key)
plt.legend()
plt.show()
# Out:
# H_2
# H_1
# He_1
# He_2
# He_3
# H2_2
# H2_1
# H_m0
# T

# %%
total_t = 0.0
final_density = 1.0e14*1.007947
density_array = numpy.array([ init['density'] ])
pressure_array = numpy.array([])
ttt = []
run_time = []
current_density = density_array[-1]

all_data = {}
for key in init.keys():
    all_data[key] = []
all_data['force_factor'] = []

# %%
dir_ff_grackle = "/home/kwoksun2/grackle/src/python/examples/freefall.h5"
import h5py
f = h5py.File(dir_ff_grackle)
fdata = f['data']
grackle_init = convert_from_grackle_to_dengo(fdata)


init, primordial = Init_values( temperature , density , n_species = 9, size=1)
for i in new_init.keys():
    if i not in ['density','ge']:
        print(i, grackle_init[i]) 
        init[i] = numpy.array([grackle_init[i]])

init['de'] = primordial.calculate_free_electrons(init)
init['ge'] =  calculate_energy(init, primordial)
rv, rv_int = bechem_cvdls_run.run_test_bechem_cvdls(init, 1e-5,niter=1e0)
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# 5044689974027.89
# adding cooling: brem
# adding cooling: reHII
# adding cooling: reHeIII
# adding cooling: gloverabel08
# adding cooling: ceHI
# adding cooling: compton
# adding cooling: h2formation
# adding cooling: reHeII2
# adding cooling: reHeII1
# adding cooling: ciHeIS
# adding cooling: ceHeII
# adding cooling: ciHI
# adding cooling: ceHeI
# adding cooling: gammah
# adding cooling: ciHeI
# adding cooling: ciHeII
# ('H_2', 2.037048519859754e-07)
# ('H_1', 0.07640481321249512)
# ('de', 2.0388464478882167e-07)
# ('He_1', 0.024190727280809784)
# ('He_2', 7.191902135742953e-10)
# ('He_3', 1.0079469999999966e-25)
# ('H2_2', 5.381147020325274e-17)
# ('H2_1', 0.00019895508264805535)
# ('H_m0', 4.7774530481217236e-15)
# ('T', array(99.9955172))
# [-2.84217094304040e-14]
# Successful iteration[    0]: (1.000e-05) 1.000e-05 / 1.000e-05
# End in 1 iterations: 1.00000e-05 / 1.00000e-05 (0.00000e+00)

# %%
iterrr = 0
while current_density < final_density:

    # keep track of time in here
    
    new_init = generate_init_from_results(rv_int, primordial, init)
    init, pressure_array, density_array, dt, force_factor = update_initial_condition(new_init, primordial, pressure_array
                                                             , density_array, safety_factor=0.01)
    
    tic = time.time()
    rv, rv_int = bechem_cvdls_run.run_test_bechem_cvdls(init, dt)
    toc = time.time()
    total_t += dt
    ttt.append(float(total_t))
    run_time.append(toc-tic)
    
    flag = rv_int['successful']
    for key in init.keys():
        if key not in ['density']:
            data = rv_int[key][0][flag][-1]
            all_data[key].append(data)
    all_data['force_factor'].append( float(force_factor))
    current_density = density_array[-1]
    
    
    t_ends = rv_int['t'][flag][-1]
    if t_ends < dt:
        print('##########cannot finish the run....####################3')
        break
#     iterrr += 1
#     if iterrr > 0:
#         break
# Out:
# force_factor: 0.0
# gammma - 1: 0.666075661696
# Successful iteration[    0]: (1.451e+09) 1.451e+09 / 1.451e+13
# End in 73 iterations: 1.45083e+13 / 1.45083e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666076044082
# Successful iteration[    0]: (1.444e+09) 1.444e+09 / 1.444e+13
# End in 73 iterations: 1.44358e+13 / 1.44358e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666076442726
# Successful iteration[    0]: (1.436e+09) 1.436e+09 / 1.436e+13
# End in 73 iterations: 1.43636e+13 / 1.43636e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666076857425
# Successful iteration[    0]: (1.429e+09) 1.429e+09 / 1.429e+13
# End in 73 iterations: 1.42918e+13 / 1.42918e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666077287976
# Successful iteration[    0]: (1.422e+09) 1.422e+09 / 1.422e+13
# End in 73 iterations: 1.42203e+13 / 1.42203e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666077734172
# Successful iteration[    0]: (1.415e+09) 1.415e+09 / 1.415e+13
# End in 73 iterations: 1.41492e+13 / 1.41492e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666078195805
# Successful iteration[    0]: (1.408e+09) 1.408e+09 / 1.408e+13
# End in 73 iterations: 1.40785e+13 / 1.40785e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666078672661
# Successful iteration[    0]: (1.401e+09) 1.401e+09 / 1.401e+13
# End in 73 iterations: 1.40081e+13 / 1.40081e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666079164528
# Successful iteration[    0]: (1.394e+09) 1.394e+09 / 1.394e+13
# End in 73 iterations: 1.39380e+13 / 1.39380e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666079671187
# Successful iteration[    0]: (1.387e+09) 1.387e+09 / 1.387e+13
# End in 73 iterations: 1.38683e+13 / 1.38683e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66608019242
# Successful iteration[    0]: (1.380e+09) 1.380e+09 / 1.380e+13
# End in 73 iterations: 1.37990e+13 / 1.37990e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666080728005
# Successful iteration[    0]: (1.373e+09) 1.373e+09 / 1.373e+13
# End in 73 iterations: 1.37300e+13 / 1.37300e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666081277719
# Successful iteration[    0]: (1.366e+09) 1.366e+09 / 1.366e+13
# End in 73 iterations: 1.36614e+13 / 1.36614e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666081841335
# Successful iteration[    0]: (1.359e+09) 1.359e+09 / 1.359e+13
# End in 73 iterations: 1.35931e+13 / 1.35931e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666082418626
# Successful iteration[    0]: (1.353e+09) 1.353e+09 / 1.353e+13
# End in 73 iterations: 1.35251e+13 / 1.35251e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666083009359
# Successful iteration[    0]: (1.346e+09) 1.346e+09 / 1.346e+13
# End in 73 iterations: 1.34575e+13 / 1.34575e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666083613305
# Successful iteration[    0]: (1.339e+09) 1.339e+09 / 1.339e+13
# End in 73 iterations: 1.33902e+13 / 1.33902e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666084230227
# Successful iteration[    0]: (1.332e+09) 1.332e+09 / 1.332e+13
# End in 73 iterations: 1.33232e+13 / 1.33232e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.6660848599
# Successful iteration[    0]: (1.326e+09) 1.326e+09 / 1.326e+13
# End in 73 iterations: 1.32566e+13 / 1.32566e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666085502091
# Successful iteration[    0]: (1.319e+09) 1.319e+09 / 1.319e+13
# End in 73 iterations: 1.31903e+13 / 1.31903e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666086156544
# Successful iteration[    0]: (1.312e+09) 1.312e+09 / 1.312e+13
# End in 73 iterations: 1.31244e+13 / 1.31244e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666086823016
# Successful iteration[    0]: (1.306e+09) 1.306e+09 / 1.306e+13
# End in 73 iterations: 1.30587e+13 / 1.30587e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666087501263
# Successful iteration[    0]: (1.299e+09) 1.299e+09 / 1.299e+13
# End in 73 iterations: 1.29935e+13 / 1.29935e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666088191041
# Successful iteration[    0]: (1.293e+09) 1.293e+09 / 1.293e+13
# End in 73 iterations: 1.29285e+13 / 1.29285e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666088892103
# Successful iteration[    0]: (1.286e+09) 1.286e+09 / 1.286e+13
# End in 73 iterations: 1.28638e+13 / 1.28638e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666089604198
# Successful iteration[    0]: (1.280e+09) 1.280e+09 / 1.280e+13
# End in 73 iterations: 1.27995e+13 / 1.27995e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666090327079
# Successful iteration[    0]: (1.274e+09) 1.274e+09 / 1.274e+13
# End in 73 iterations: 1.27355e+13 / 1.27355e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666091060493
# Successful iteration[    0]: (1.267e+09) 1.267e+09 / 1.267e+13
# End in 73 iterations: 1.26719e+13 / 1.26719e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666091804188
# Successful iteration[    0]: (1.261e+09) 1.261e+09 / 1.261e+13
# End in 73 iterations: 1.26085e+13 / 1.26085e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66609255791
# Successful iteration[    0]: (1.255e+09) 1.255e+09 / 1.255e+13
# End in 73 iterations: 1.25454e+13 / 1.25454e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666093321403
# Successful iteration[    0]: (1.248e+09) 1.248e+09 / 1.248e+13
# End in 73 iterations: 1.24827e+13 / 1.24827e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666094094412
# Successful iteration[    0]: (1.242e+09) 1.242e+09 / 1.242e+13
# End in 73 iterations: 1.24203e+13 / 1.24203e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666094876679
# Successful iteration[    0]: (1.236e+09) 1.236e+09 / 1.236e+13
# End in 73 iterations: 1.23582e+13 / 1.23582e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666095667946
# Successful iteration[    0]: (1.230e+09) 1.230e+09 / 1.230e+13
# End in 73 iterations: 1.22964e+13 / 1.22964e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666096467954
# Successful iteration[    0]: (1.223e+09) 1.223e+09 / 1.223e+13
# End in 73 iterations: 1.22349e+13 / 1.22349e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666097276442
# Successful iteration[    0]: (1.217e+09) 1.217e+09 / 1.217e+13
# End in 73 iterations: 1.21738e+13 / 1.21738e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666098093151
# Successful iteration[    0]: (1.211e+09) 1.211e+09 / 1.211e+13
# End in 73 iterations: 1.21129e+13 / 1.21129e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666098917818
# Successful iteration[    0]: (1.205e+09) 1.205e+09 / 1.205e+13
# End in 73 iterations: 1.20523e+13 / 1.20523e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666099750181
# Successful iteration[    0]: (1.199e+09) 1.199e+09 / 1.199e+13
# End in 73 iterations: 1.19921e+13 / 1.19921e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666100589979
# Successful iteration[    0]: (1.193e+09) 1.193e+09 / 1.193e+13
# End in 73 iterations: 1.19321e+13 / 1.19321e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666101436947
# Successful iteration[    0]: (1.187e+09) 1.187e+09 / 1.187e+13
# End in 73 iterations: 1.18724e+13 / 1.18724e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666102290822
# Successful iteration[    0]: (1.181e+09) 1.181e+09 / 1.181e+13
# End in 73 iterations: 1.18131e+13 / 1.18131e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66610315134
# Successful iteration[    0]: (1.175e+09) 1.175e+09 / 1.175e+13
# End in 73 iterations: 1.17540e+13 / 1.17540e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666104018237
# Successful iteration[    0]: (1.170e+09) 1.170e+09 / 1.170e+13
# End in 73 iterations: 1.16952e+13 / 1.16952e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666104891248
# Successful iteration[    0]: (1.164e+09) 1.164e+09 / 1.164e+13
# End in 73 iterations: 1.16368e+13 / 1.16368e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666105770109
# Successful iteration[    0]: (1.158e+09) 1.158e+09 / 1.158e+13
# End in 73 iterations: 1.15786e+13 / 1.15786e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666106654556
# Successful iteration[    0]: (1.152e+09) 1.152e+09 / 1.152e+13
# End in 73 iterations: 1.15207e+13 / 1.15207e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666107544324
# Successful iteration[    0]: (1.146e+09) 1.146e+09 / 1.146e+13
# End in 73 iterations: 1.14631e+13 / 1.14631e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666108439148
# Successful iteration[    0]: (1.141e+09) 1.141e+09 / 1.141e+13
# End in 73 iterations: 1.14058e+13 / 1.14058e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666109338763
# Successful iteration[    0]: (1.135e+09) 1.135e+09 / 1.135e+13
# End in 73 iterations: 1.13487e+13 / 1.13487e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666110242907
# Successful iteration[    0]: (1.129e+09) 1.129e+09 / 1.129e+13
# End in 73 iterations: 1.12920e+13 / 1.12920e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666111151314
# Successful iteration[    0]: (1.124e+09) 1.124e+09 / 1.124e+13
# End in 73 iterations: 1.12355e+13 / 1.12355e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666112063722
# Successful iteration[    0]: (1.118e+09) 1.118e+09 / 1.118e+13
# End in 73 iterations: 1.11794e+13 / 1.11794e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666112979867
# Successful iteration[    0]: (1.112e+09) 1.112e+09 / 1.112e+13
# End in 73 iterations: 1.11235e+13 / 1.11235e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666113899487
# Successful iteration[    0]: (1.107e+09) 1.107e+09 / 1.107e+13
# End in 73 iterations: 1.10678e+13 / 1.10678e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66611482232
# Successful iteration[    0]: (1.101e+09) 1.101e+09 / 1.101e+13
# End in 73 iterations: 1.10125e+13 / 1.10125e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666115748105
# Successful iteration[    0]: (1.096e+09) 1.096e+09 / 1.096e+13
# End in 73 iterations: 1.09574e+13 / 1.09574e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66611667658
# Successful iteration[    0]: (1.090e+09) 1.090e+09 / 1.090e+13
# End in 73 iterations: 1.09027e+13 / 1.09027e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666117607487
# Successful iteration[    0]: (1.085e+09) 1.085e+09 / 1.085e+13
# End in 73 iterations: 1.08481e+13 / 1.08481e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666118540566
# Successful iteration[    0]: (1.079e+09) 1.079e+09 / 1.079e+13
# End in 73 iterations: 1.07939e+13 / 1.07939e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666119475558
# Successful iteration[    0]: (1.074e+09) 1.074e+09 / 1.074e+13
# End in 73 iterations: 1.07399e+13 / 1.07399e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666120412208
# Successful iteration[    0]: (1.069e+09) 1.069e+09 / 1.069e+13
# End in 73 iterations: 1.06862e+13 / 1.06862e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666121350259
# Successful iteration[    0]: (1.063e+09) 1.063e+09 / 1.063e+13
# End in 73 iterations: 1.06328e+13 / 1.06328e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666122289457
# Successful iteration[    0]: (1.058e+09) 1.058e+09 / 1.058e+13
# End in 73 iterations: 1.05796e+13 / 1.05796e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666123229546
# Successful iteration[    0]: (1.053e+09) 1.053e+09 / 1.053e+13
# End in 73 iterations: 1.05267e+13 / 1.05267e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666124170276
# Successful iteration[    0]: (1.047e+09) 1.047e+09 / 1.047e+13
# End in 73 iterations: 1.04741e+13 / 1.04741e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666125111394
# Successful iteration[    0]: (1.042e+09) 1.042e+09 / 1.042e+13
# End in 73 iterations: 1.04217e+13 / 1.04217e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666126052652
# Successful iteration[    0]: (1.037e+09) 1.037e+09 / 1.037e+13
# End in 73 iterations: 1.03696e+13 / 1.03696e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666126993801
# Successful iteration[    0]: (1.032e+09) 1.032e+09 / 1.032e+13
# End in 73 iterations: 1.03178e+13 / 1.03178e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666127934594
# Successful iteration[    0]: (1.027e+09) 1.027e+09 / 1.027e+13
# End in 73 iterations: 1.02662e+13 / 1.02662e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666128874786
# Successful iteration[    0]: (1.021e+09) 1.021e+09 / 1.021e+13
# End in 73 iterations: 1.02149e+13 / 1.02149e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666129814134
# Successful iteration[    0]: (1.016e+09) 1.016e+09 / 1.016e+13
# End in 73 iterations: 1.01638e+13 / 1.01638e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666130752395
# Successful iteration[    0]: (1.011e+09) 1.011e+09 / 1.011e+13
# End in 73 iterations: 1.01130e+13 / 1.01130e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666131689331
# Successful iteration[    0]: (1.006e+09) 1.006e+09 / 1.006e+13
# End in 73 iterations: 1.00624e+13 / 1.00624e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666132624701
# Successful iteration[    0]: (1.001e+09) 1.001e+09 / 1.001e+13
# End in 73 iterations: 1.00121e+13 / 1.00121e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666133558271
# Successful iteration[    0]: (9.962e+08) 9.962e+08 / 9.962e+12
# End in 73 iterations: 9.96203e+12 / 9.96203e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666134489805
# Successful iteration[    0]: (9.912e+08) 9.912e+08 / 9.912e+12
# End in 73 iterations: 9.91222e+12 / 9.91222e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666135419072
# Successful iteration[    0]: (9.863e+08) 9.863e+08 / 9.863e+12
# End in 73 iterations: 9.86266e+12 / 9.86266e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666136345842
# Successful iteration[    0]: (9.813e+08) 9.813e+08 / 9.813e+12
# End in 73 iterations: 9.81335e+12 / 9.81335e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666137269885
# Successful iteration[    0]: (9.764e+08) 9.764e+08 / 9.764e+12
# End in 73 iterations: 9.76428e+12 / 9.76428e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666138190978
# Successful iteration[    0]: (9.715e+08) 9.715e+08 / 9.715e+12
# End in 73 iterations: 9.71546e+12 / 9.71546e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666139108893
# Successful iteration[    0]: (9.667e+08) 9.667e+08 / 9.667e+12
# End in 73 iterations: 9.66688e+12 / 9.66688e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666140023412
# Successful iteration[    0]: (9.619e+08) 9.619e+08 / 9.619e+12
# End in 73 iterations: 9.61855e+12 / 9.61855e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666140934316
# Successful iteration[    0]: (9.570e+08) 9.570e+08 / 9.570e+12
# End in 73 iterations: 9.57046e+12 / 9.57046e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666141841386
# Successful iteration[    0]: (9.523e+08) 9.523e+08 / 9.523e+12
# End in 73 iterations: 9.52260e+12 / 9.52260e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66614274441
# Successful iteration[    0]: (9.475e+08) 9.475e+08 / 9.475e+12
# End in 73 iterations: 9.47499e+12 / 9.47499e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666143643175
# Successful iteration[    0]: (9.428e+08) 9.428e+08 / 9.428e+12
# End in 73 iterations: 9.42761e+12 / 9.42761e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666144537472
# Successful iteration[    0]: (9.380e+08) 9.380e+08 / 9.380e+12
# End in 73 iterations: 9.38048e+12 / 9.38048e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666145427095
# Successful iteration[    0]: (9.334e+08) 9.334e+08 / 9.334e+12
# End in 73 iterations: 9.33357e+12 / 9.33357e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66614631184
# Successful iteration[    0]: (9.287e+08) 9.287e+08 / 9.287e+12
# End in 73 iterations: 9.28691e+12 / 9.28691e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666147191507
# Successful iteration[    0]: (9.240e+08) 9.240e+08 / 9.240e+12
# End in 73 iterations: 9.24047e+12 / 9.24047e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666148065895
# Successful iteration[    0]: (9.194e+08) 9.194e+08 / 9.194e+12
# End in 73 iterations: 9.19427e+12 / 9.19427e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666148934811
# Successful iteration[    0]: (9.148e+08) 9.148e+08 / 9.148e+12
# End in 73 iterations: 9.14830e+12 / 9.14830e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666149798061
# Successful iteration[    0]: (9.103e+08) 9.103e+08 / 9.103e+12
# End in 73 iterations: 9.10256e+12 / 9.10256e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666150655456
# Successful iteration[    0]: (9.057e+08) 9.057e+08 / 9.057e+12
# End in 73 iterations: 9.05704e+12 / 9.05704e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66615150681
# Successful iteration[    0]: (9.012e+08) 9.012e+08 / 9.012e+12
# End in 73 iterations: 9.01176e+12 / 9.01176e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666152351936
# Successful iteration[    0]: (8.967e+08) 8.967e+08 / 8.967e+12
# End in 73 iterations: 8.96670e+12 / 8.96670e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666153190657
# Successful iteration[    0]: (8.922e+08) 8.922e+08 / 8.922e+12
# End in 73 iterations: 8.92187e+12 / 8.92187e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666154022793
# Successful iteration[    0]: (8.877e+08) 8.877e+08 / 8.877e+12
# End in 73 iterations: 8.87726e+12 / 8.87726e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66615484817
# Successful iteration[    0]: (8.833e+08) 8.833e+08 / 8.833e+12
# End in 73 iterations: 8.83287e+12 / 8.83287e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666155666618
# Successful iteration[    0]: (8.789e+08) 8.789e+08 / 8.789e+12
# End in 73 iterations: 8.78871e+12 / 8.78871e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666156477966
# Successful iteration[    0]: (8.745e+08) 8.745e+08 / 8.745e+12
# End in 73 iterations: 8.74476e+12 / 8.74476e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666157282053
# Successful iteration[    0]: (8.701e+08) 8.701e+08 / 8.701e+12
# End in 73 iterations: 8.70104e+12 / 8.70104e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666158078714
# Successful iteration[    0]: (8.658e+08) 8.658e+08 / 8.658e+12
# End in 73 iterations: 8.65753e+12 / 8.65753e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666158867792
# Successful iteration[    0]: (8.614e+08) 8.614e+08 / 8.614e+12
# End in 73 iterations: 8.61425e+12 / 8.61425e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666159649131
# Successful iteration[    0]: (8.571e+08) 8.571e+08 / 8.571e+12
# End in 73 iterations: 8.57118e+12 / 8.57118e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666160422581
# Successful iteration[    0]: (8.528e+08) 8.528e+08 / 8.528e+12
# End in 73 iterations: 8.52832e+12 / 8.52832e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666161187994
# Successful iteration[    0]: (8.486e+08) 8.486e+08 / 8.486e+12
# End in 73 iterations: 8.48568e+12 / 8.48568e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666161945223
# Successful iteration[    0]: (8.443e+08) 8.443e+08 / 8.443e+12
# End in 73 iterations: 8.44325e+12 / 8.44325e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666162694131
# Successful iteration[    0]: (8.401e+08) 8.401e+08 / 8.401e+12
# End in 73 iterations: 8.40103e+12 / 8.40103e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666163434576
# Successful iteration[    0]: (8.359e+08) 8.359e+08 / 8.359e+12
# End in 73 iterations: 8.35903e+12 / 8.35903e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666164166426
# Successful iteration[    0]: (8.317e+08) 8.317e+08 / 8.317e+12
# End in 73 iterations: 8.31723e+12 / 8.31723e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666164889551
# Successful iteration[    0]: (8.276e+08) 8.276e+08 / 8.276e+12
# End in 73 iterations: 8.27565e+12 / 8.27565e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666165603822
# Successful iteration[    0]: (8.234e+08) 8.234e+08 / 8.234e+12
# End in 73 iterations: 8.23427e+12 / 8.23427e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66616630912
# Successful iteration[    0]: (8.193e+08) 8.193e+08 / 8.193e+12
# End in 73 iterations: 8.19310e+12 / 8.19310e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666167005321
# Successful iteration[    0]: (8.152e+08) 8.152e+08 / 8.152e+12
# End in 73 iterations: 8.15213e+12 / 8.15213e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666167692311
# Successful iteration[    0]: (8.111e+08) 8.111e+08 / 8.111e+12
# End in 73 iterations: 8.11137e+12 / 8.11137e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666168369978
# Successful iteration[    0]: (8.071e+08) 8.071e+08 / 8.071e+12
# End in 73 iterations: 8.07081e+12 / 8.07081e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666169038212
# Successful iteration[    0]: (8.030e+08) 8.030e+08 / 8.030e+12
# End in 73 iterations: 8.03046e+12 / 8.03046e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666169696912
# Successful iteration[    0]: (7.990e+08) 7.990e+08 / 7.990e+12
# End in 73 iterations: 7.99031e+12 / 7.99031e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666170345973
# Successful iteration[    0]: (7.950e+08) 7.950e+08 / 7.950e+12
# End in 73 iterations: 7.95036e+12 / 7.95036e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666170985302
# Successful iteration[    0]: (7.911e+08) 7.911e+08 / 7.911e+12
# End in 73 iterations: 7.91060e+12 / 7.91060e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666171614802
# Successful iteration[    0]: (7.871e+08) 7.871e+08 / 7.871e+12
# End in 73 iterations: 7.87105e+12 / 7.87105e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666172234386
# Successful iteration[    0]: (7.832e+08) 7.832e+08 / 7.832e+12
# End in 73 iterations: 7.83170e+12 / 7.83170e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666172843968
# Successful iteration[    0]: (7.793e+08) 7.793e+08 / 7.793e+12
# End in 73 iterations: 7.79254e+12 / 7.79254e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666173443466
# Successful iteration[    0]: (7.754e+08) 7.754e+08 / 7.754e+12
# End in 73 iterations: 7.75357e+12 / 7.75357e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666174032804
# Successful iteration[    0]: (7.715e+08) 7.715e+08 / 7.715e+12
# End in 73 iterations: 7.71481e+12 / 7.71481e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666174611905
# Successful iteration[    0]: (7.676e+08) 7.676e+08 / 7.676e+12
# End in 73 iterations: 7.67623e+12 / 7.67623e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666175180702
# Successful iteration[    0]: (7.638e+08) 7.638e+08 / 7.638e+12
# End in 73 iterations: 7.63785e+12 / 7.63785e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666175739126
# Successful iteration[    0]: (7.600e+08) 7.600e+08 / 7.600e+12
# End in 73 iterations: 7.59966e+12 / 7.59966e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176287118
# Successful iteration[    0]: (7.562e+08) 7.562e+08 / 7.562e+12
# End in 73 iterations: 7.56166e+12 / 7.56166e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66617682462
# Successful iteration[    0]: (7.524e+08) 7.524e+08 / 7.524e+12
# End in 73 iterations: 7.52386e+12 / 7.52386e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177351574
# Successful iteration[    0]: (7.486e+08) 7.486e+08 / 7.486e+12
# End in 73 iterations: 7.48624e+12 / 7.48624e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177867936
# Successful iteration[    0]: (7.449e+08) 7.449e+08 / 7.449e+12
# End in 73 iterations: 7.44881e+12 / 7.44881e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178373653
# Successful iteration[    0]: (7.412e+08) 7.412e+08 / 7.412e+12
# End in 73 iterations: 7.41156e+12 / 7.41156e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178868687
# Successful iteration[    0]: (7.375e+08) 7.375e+08 / 7.375e+12
# End in 73 iterations: 7.37450e+12 / 7.37450e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179352999
# Successful iteration[    0]: (7.338e+08) 7.338e+08 / 7.338e+12
# End in 73 iterations: 7.33763e+12 / 7.33763e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179826553
# Successful iteration[    0]: (7.301e+08) 7.301e+08 / 7.301e+12
# End in 73 iterations: 7.30094e+12 / 7.30094e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180289322
# Successful iteration[    0]: (7.264e+08) 7.264e+08 / 7.264e+12
# End in 73 iterations: 7.26444e+12 / 7.26444e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180741275
# Successful iteration[    0]: (7.228e+08) 7.228e+08 / 7.228e+12
# End in 73 iterations: 7.22812e+12 / 7.22812e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181182395
# Successful iteration[    0]: (7.192e+08) 7.192e+08 / 7.192e+12
# End in 73 iterations: 7.19198e+12 / 7.19198e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181612658
# Successful iteration[    0]: (7.156e+08) 7.156e+08 / 7.156e+12
# End in 73 iterations: 7.15602e+12 / 7.15602e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182032053
# Successful iteration[    0]: (7.120e+08) 7.120e+08 / 7.120e+12
# End in 73 iterations: 7.12024e+12 / 7.12024e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182440568
# Successful iteration[    0]: (7.085e+08) 7.085e+08 / 7.085e+12
# End in 73 iterations: 7.08463e+12 / 7.08463e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182838196
# Successful iteration[    0]: (7.049e+08) 7.049e+08 / 7.049e+12
# End in 73 iterations: 7.04921e+12 / 7.04921e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183224937
# Successful iteration[    0]: (7.014e+08) 7.014e+08 / 7.014e+12
# End in 73 iterations: 7.01396e+12 / 7.01396e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183600788
# Successful iteration[    0]: (6.979e+08) 6.979e+08 / 6.979e+12
# End in 73 iterations: 6.97890e+12 / 6.97890e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183965758
# Successful iteration[    0]: (6.944e+08) 6.944e+08 / 6.944e+12
# End in 73 iterations: 6.94400e+12 / 6.94400e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184319853
# Successful iteration[    0]: (6.909e+08) 6.909e+08 / 6.909e+12
# End in 73 iterations: 6.90928e+12 / 6.90928e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184663086
# Successful iteration[    0]: (6.875e+08) 6.875e+08 / 6.875e+12
# End in 73 iterations: 6.87473e+12 / 6.87473e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184995475
# Successful iteration[    0]: (6.840e+08) 6.840e+08 / 6.840e+12
# End in 73 iterations: 6.84036e+12 / 6.84036e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618531704
# Successful iteration[    0]: (6.806e+08) 6.806e+08 / 6.806e+12
# End in 73 iterations: 6.80616e+12 / 6.80616e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185627805
# Successful iteration[    0]: (6.772e+08) 6.772e+08 / 6.772e+12
# End in 73 iterations: 6.77213e+12 / 6.77213e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185927797
# Successful iteration[    0]: (6.738e+08) 6.738e+08 / 6.738e+12
# End in 73 iterations: 6.73827e+12 / 6.73827e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186217051
# Successful iteration[    0]: (6.705e+08) 6.705e+08 / 6.705e+12
# End in 73 iterations: 6.70458e+12 / 6.70458e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186495598
# Successful iteration[    0]: (6.671e+08) 6.671e+08 / 6.671e+12
# End in 73 iterations: 6.67105e+12 / 6.67105e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618676348
# Successful iteration[    0]: (6.638e+08) 6.638e+08 / 6.638e+12
# End in 73 iterations: 6.63770e+12 / 6.63770e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187020739
# Successful iteration[    0]: (6.605e+08) 6.605e+08 / 6.605e+12
# End in 73 iterations: 6.60451e+12 / 6.60451e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187267421
# Successful iteration[    0]: (6.571e+08) 6.571e+08 / 6.571e+12
# End in 73 iterations: 6.57149e+12 / 6.57149e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187503577
# Successful iteration[    0]: (6.539e+08) 6.539e+08 / 6.539e+12
# End in 73 iterations: 6.53863e+12 / 6.53863e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618772926
# Successful iteration[    0]: (6.506e+08) 6.506e+08 / 6.506e+12
# End in 73 iterations: 6.50594e+12 / 6.50594e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187944529
# Successful iteration[    0]: (6.473e+08) 6.473e+08 / 6.473e+12
# End in 73 iterations: 6.47341e+12 / 6.47341e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188149441
# Successful iteration[    0]: (6.441e+08) 6.441e+08 / 6.441e+12
# End in 73 iterations: 6.44104e+12 / 6.44104e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188344062
# Successful iteration[    0]: (6.409e+08) 6.409e+08 / 6.409e+12
# End in 73 iterations: 6.40883e+12 / 6.40883e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618852846
# Successful iteration[    0]: (6.377e+08) 6.377e+08 / 6.377e+12
# End in 73 iterations: 6.37679e+12 / 6.37679e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188702705
# Successful iteration[    0]: (6.345e+08) 6.345e+08 / 6.345e+12
# End in 73 iterations: 6.34491e+12 / 6.34491e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188866872
# Successful iteration[    0]: (6.313e+08) 6.313e+08 / 6.313e+12
# End in 73 iterations: 6.31318e+12 / 6.31318e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189021037
# Successful iteration[    0]: (6.282e+08) 6.282e+08 / 6.282e+12
# End in 73 iterations: 6.28162e+12 / 6.28162e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189165283
# Successful iteration[    0]: (6.250e+08) 6.250e+08 / 6.250e+12
# End in 73 iterations: 6.25021e+12 / 6.25021e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189299691
# Successful iteration[    0]: (6.219e+08) 6.219e+08 / 6.219e+12
# End in 73 iterations: 6.21896e+12 / 6.21896e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189424351
# Successful iteration[    0]: (6.188e+08) 6.188e+08 / 6.188e+12
# End in 73 iterations: 6.18786e+12 / 6.18786e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189539349
# Successful iteration[    0]: (6.157e+08) 6.157e+08 / 6.157e+12
# End in 73 iterations: 6.15692e+12 / 6.15692e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189644782
# Successful iteration[    0]: (6.126e+08) 6.126e+08 / 6.126e+12
# End in 73 iterations: 6.12614e+12 / 6.12614e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189740744
# Successful iteration[    0]: (6.096e+08) 6.096e+08 / 6.096e+12
# End in 73 iterations: 6.09551e+12 / 6.09551e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189827333
# Successful iteration[    0]: (6.065e+08) 6.065e+08 / 6.065e+12
# End in 73 iterations: 6.06503e+12 / 6.06503e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189904654
# Successful iteration[    0]: (6.035e+08) 6.035e+08 / 6.035e+12
# End in 73 iterations: 6.03470e+12 / 6.03470e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189972808
# Successful iteration[    0]: (6.005e+08) 6.005e+08 / 6.005e+12
# End in 73 iterations: 6.00453e+12 / 6.00453e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190031904
# Successful iteration[    0]: (5.975e+08) 5.975e+08 / 5.975e+12
# End in 73 iterations: 5.97451e+12 / 5.97451e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190082052
# Successful iteration[    0]: (5.945e+08) 5.945e+08 / 5.945e+12
# End in 73 iterations: 5.94464e+12 / 5.94464e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190123363
# Successful iteration[    0]: (5.915e+08) 5.915e+08 / 5.915e+12
# End in 73 iterations: 5.91491e+12 / 5.91491e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190155954
# Successful iteration[    0]: (5.885e+08) 5.885e+08 / 5.885e+12
# End in 73 iterations: 5.88534e+12 / 5.88534e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190179941
# Successful iteration[    0]: (5.856e+08) 5.856e+08 / 5.856e+12
# End in 73 iterations: 5.85591e+12 / 5.85591e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190195444
# Successful iteration[    0]: (5.827e+08) 5.827e+08 / 5.827e+12
# End in 73 iterations: 5.82663e+12 / 5.82663e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190202585
# Successful iteration[    0]: (5.797e+08) 5.797e+08 / 5.797e+12
# End in 73 iterations: 5.79750e+12 / 5.79750e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190201489
# Successful iteration[    0]: (5.769e+08) 5.769e+08 / 5.769e+12
# End in 73 iterations: 5.76851e+12 / 5.76851e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190192282
# Successful iteration[    0]: (5.740e+08) 5.740e+08 / 5.740e+12
# End in 73 iterations: 5.73967e+12 / 5.73967e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190175092
# Successful iteration[    0]: (5.711e+08) 5.711e+08 / 5.711e+12
# End in 73 iterations: 5.71097e+12 / 5.71097e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190150051
# Successful iteration[    0]: (5.682e+08) 5.682e+08 / 5.682e+12
# End in 73 iterations: 5.68242e+12 / 5.68242e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190117291
# Successful iteration[    0]: (5.654e+08) 5.654e+08 / 5.654e+12
# End in 73 iterations: 5.65400e+12 / 5.65400e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190076945
# Successful iteration[    0]: (5.626e+08) 5.626e+08 / 5.626e+12
# End in 73 iterations: 5.62573e+12 / 5.62573e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666190029151
# Successful iteration[    0]: (5.598e+08) 5.598e+08 / 5.598e+12
# End in 73 iterations: 5.59760e+12 / 5.59760e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189974046
# Successful iteration[    0]: (5.570e+08) 5.570e+08 / 5.570e+12
# End in 73 iterations: 5.56962e+12 / 5.56962e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189911769
# Successful iteration[    0]: (5.542e+08) 5.542e+08 / 5.542e+12
# End in 73 iterations: 5.54177e+12 / 5.54177e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189842462
# Successful iteration[    0]: (5.514e+08) 5.514e+08 / 5.514e+12
# End in 73 iterations: 5.51406e+12 / 5.51406e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189766267
# Successful iteration[    0]: (5.486e+08) 5.486e+08 / 5.486e+12
# End in 73 iterations: 5.48649e+12 / 5.48649e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189683327
# Successful iteration[    0]: (5.459e+08) 5.459e+08 / 5.459e+12
# End in 73 iterations: 5.45906e+12 / 5.45906e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189593788
# Successful iteration[    0]: (5.432e+08) 5.432e+08 / 5.432e+12
# End in 73 iterations: 5.43176e+12 / 5.43176e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189497796
# Successful iteration[    0]: (5.405e+08) 5.405e+08 / 5.405e+12
# End in 73 iterations: 5.40460e+12 / 5.40460e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189395497
# Successful iteration[    0]: (5.378e+08) 5.378e+08 / 5.378e+12
# End in 73 iterations: 5.37758e+12 / 5.37758e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618928704
# Successful iteration[    0]: (5.351e+08) 5.351e+08 / 5.351e+12
# End in 73 iterations: 5.35069e+12 / 5.35069e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189172576
# Successful iteration[    0]: (5.324e+08) 5.324e+08 / 5.324e+12
# End in 73 iterations: 5.32394e+12 / 5.32394e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189052252
# Successful iteration[    0]: (5.297e+08) 5.297e+08 / 5.297e+12
# End in 73 iterations: 5.29732e+12 / 5.29732e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188926221
# Successful iteration[    0]: (5.271e+08) 5.271e+08 / 5.271e+12
# End in 73 iterations: 5.27083e+12 / 5.27083e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188794632
# Successful iteration[    0]: (5.244e+08) 5.244e+08 / 5.244e+12
# End in 73 iterations: 5.24448e+12 / 5.24448e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188657641
# Successful iteration[    0]: (5.218e+08) 5.218e+08 / 5.218e+12
# End in 73 iterations: 5.21826e+12 / 5.21826e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188515395
# Successful iteration[    0]: (5.192e+08) 5.192e+08 / 5.192e+12
# End in 73 iterations: 5.19216e+12 / 5.19216e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188368053
# Successful iteration[    0]: (5.166e+08) 5.166e+08 / 5.166e+12
# End in 73 iterations: 5.16620e+12 / 5.16620e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188215762
# Successful iteration[    0]: (5.140e+08) 5.140e+08 / 5.140e+12
# End in 73 iterations: 5.14037e+12 / 5.14037e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188058681
# Successful iteration[    0]: (5.115e+08) 5.115e+08 / 5.115e+12
# End in 73 iterations: 5.11467e+12 / 5.11467e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187896959
# Successful iteration[    0]: (5.089e+08) 5.089e+08 / 5.089e+12
# End in 73 iterations: 5.08910e+12 / 5.08910e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187730753
# Successful iteration[    0]: (5.064e+08) 5.064e+08 / 5.064e+12
# End in 73 iterations: 5.06365e+12 / 5.06365e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187560213
# Successful iteration[    0]: (5.038e+08) 5.038e+08 / 5.038e+12
# End in 73 iterations: 5.03833e+12 / 5.03833e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187385495
# Successful iteration[    0]: (5.013e+08) 5.013e+08 / 5.013e+12
# End in 73 iterations: 5.01314e+12 / 5.01314e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187206749
# Successful iteration[    0]: (4.988e+08) 4.988e+08 / 4.988e+12
# End in 73 iterations: 4.98808e+12 / 4.98808e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187024131
# Successful iteration[    0]: (4.963e+08) 4.963e+08 / 4.963e+12
# End in 73 iterations: 4.96314e+12 / 4.96314e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618683779
# Successful iteration[    0]: (4.938e+08) 4.938e+08 / 4.938e+12
# End in 73 iterations: 4.93832e+12 / 4.93832e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618664788
# Successful iteration[    0]: (4.914e+08) 4.914e+08 / 4.914e+12
# End in 73 iterations: 4.91363e+12 / 4.91363e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186454552
# Successful iteration[    0]: (4.889e+08) 4.889e+08 / 4.889e+12
# End in 73 iterations: 4.88906e+12 / 4.88906e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186257955
# Successful iteration[    0]: (4.865e+08) 4.865e+08 / 4.865e+12
# End in 73 iterations: 4.86462e+12 / 4.86462e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618605824
# Successful iteration[    0]: (4.840e+08) 4.840e+08 / 4.840e+12
# End in 73 iterations: 4.84029e+12 / 4.84029e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185855555
# Successful iteration[    0]: (4.816e+08) 4.816e+08 / 4.816e+12
# End in 73 iterations: 4.81609e+12 / 4.81609e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185650048
# Successful iteration[    0]: (4.792e+08) 4.792e+08 / 4.792e+12
# End in 73 iterations: 4.79201e+12 / 4.79201e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185441867
# Successful iteration[    0]: (4.768e+08) 4.768e+08 / 4.768e+12
# End in 73 iterations: 4.76805e+12 / 4.76805e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185231156
# Successful iteration[    0]: (4.744e+08) 4.744e+08 / 4.744e+12
# End in 73 iterations: 4.74421e+12 / 4.74421e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185018061
# Successful iteration[    0]: (4.720e+08) 4.720e+08 / 4.720e+12
# End in 73 iterations: 4.72049e+12 / 4.72049e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184802725
# Successful iteration[    0]: (4.697e+08) 4.697e+08 / 4.697e+12
# End in 73 iterations: 4.69689e+12 / 4.69689e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184585291
# Successful iteration[    0]: (4.673e+08) 4.673e+08 / 4.673e+12
# End in 73 iterations: 4.67340e+12 / 4.67340e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184365898
# Successful iteration[    0]: (4.650e+08) 4.650e+08 / 4.650e+12
# End in 73 iterations: 4.65003e+12 / 4.65003e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184144687
# Successful iteration[    0]: (4.627e+08) 4.627e+08 / 4.627e+12
# End in 73 iterations: 4.62678e+12 / 4.62678e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183921794
# Successful iteration[    0]: (4.604e+08) 4.604e+08 / 4.604e+12
# End in 73 iterations: 4.60365e+12 / 4.60365e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183697357
# Successful iteration[    0]: (4.581e+08) 4.581e+08 / 4.581e+12
# End in 73 iterations: 4.58063e+12 / 4.58063e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183471508
# Successful iteration[    0]: (4.558e+08) 4.558e+08 / 4.558e+12
# End in 73 iterations: 4.55773e+12 / 4.55773e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183244385
# Successful iteration[    0]: (4.535e+08) 4.535e+08 / 4.535e+12
# End in 73 iterations: 4.53494e+12 / 4.53494e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618301611
# Successful iteration[    0]: (4.512e+08) 4.512e+08 / 4.512e+12
# End in 73 iterations: 4.51227e+12 / 4.51227e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182786823
# Successful iteration[    0]: (4.490e+08) 4.490e+08 / 4.490e+12
# End in 73 iterations: 4.48970e+12 / 4.48970e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618255664
# Successful iteration[    0]: (4.467e+08) 4.467e+08 / 4.467e+12
# End in 73 iterations: 4.46726e+12 / 4.46726e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182325698
# Successful iteration[    0]: (4.445e+08) 4.445e+08 / 4.445e+12
# End in 73 iterations: 4.44492e+12 / 4.44492e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182094106
# Successful iteration[    0]: (4.423e+08) 4.423e+08 / 4.423e+12
# End in 73 iterations: 4.42270e+12 / 4.42270e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181862004
# Successful iteration[    0]: (4.401e+08) 4.401e+08 / 4.401e+12
# End in 73 iterations: 4.40058e+12 / 4.40058e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618162949
# Successful iteration[    0]: (4.379e+08) 4.379e+08 / 4.379e+12
# End in 73 iterations: 4.37858e+12 / 4.37858e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181396702
# Successful iteration[    0]: (4.357e+08) 4.357e+08 / 4.357e+12
# End in 73 iterations: 4.35669e+12 / 4.35669e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181163738
# Successful iteration[    0]: (4.335e+08) 4.335e+08 / 4.335e+12
# End in 73 iterations: 4.33490e+12 / 4.33490e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180930723
# Successful iteration[    0]: (4.313e+08) 4.313e+08 / 4.313e+12
# End in 73 iterations: 4.31323e+12 / 4.31323e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180697758
# Successful iteration[    0]: (4.292e+08) 4.292e+08 / 4.292e+12
# End in 73 iterations: 4.29166e+12 / 4.29166e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180464956
# Successful iteration[    0]: (4.270e+08) 4.270e+08 / 4.270e+12
# End in 73 iterations: 4.27020e+12 / 4.27020e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180232422
# Successful iteration[    0]: (4.249e+08) 4.249e+08 / 4.249e+12
# End in 73 iterations: 4.24885e+12 / 4.24885e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180000254
# Successful iteration[    0]: (4.228e+08) 4.228e+08 / 4.228e+12
# End in 73 iterations: 4.22761e+12 / 4.22761e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179768563
# Successful iteration[    0]: (4.206e+08) 4.206e+08 / 4.206e+12
# End in 73 iterations: 4.20647e+12 / 4.20647e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179537431
# Successful iteration[    0]: (4.185e+08) 4.185e+08 / 4.185e+12
# End in 73 iterations: 4.18544e+12 / 4.18544e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179306975
# Successful iteration[    0]: (4.165e+08) 4.165e+08 / 4.165e+12
# End in 73 iterations: 4.16451e+12 / 4.16451e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179077266
# Successful iteration[    0]: (4.144e+08) 4.144e+08 / 4.144e+12
# End in 73 iterations: 4.14369e+12 / 4.14369e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178848418
# Successful iteration[    0]: (4.123e+08) 4.123e+08 / 4.123e+12
# End in 73 iterations: 4.12297e+12 / 4.12297e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178620503
# Successful iteration[    0]: (4.102e+08) 4.102e+08 / 4.102e+12
# End in 73 iterations: 4.10235e+12 / 4.10235e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178393614
# Successful iteration[    0]: (4.082e+08) 4.082e+08 / 4.082e+12
# End in 73 iterations: 4.08184e+12 / 4.08184e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178167834
# Successful iteration[    0]: (4.061e+08) 4.061e+08 / 4.061e+12
# End in 73 iterations: 4.06143e+12 / 4.06143e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177943234
# Successful iteration[    0]: (4.041e+08) 4.041e+08 / 4.041e+12
# End in 73 iterations: 4.04113e+12 / 4.04113e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66617771991
# Successful iteration[    0]: (4.021e+08) 4.021e+08 / 4.021e+12
# End in 73 iterations: 4.02092e+12 / 4.02092e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177497916
# Successful iteration[    0]: (4.001e+08) 4.001e+08 / 4.001e+12
# End in 73 iterations: 4.00082e+12 / 4.00082e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177277349
# Successful iteration[    0]: (3.981e+08) 3.981e+08 / 3.981e+12
# End in 73 iterations: 3.98081e+12 / 3.98081e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177058262
# Successful iteration[    0]: (3.961e+08) 3.961e+08 / 3.961e+12
# End in 73 iterations: 3.96091e+12 / 3.96091e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176840729
# Successful iteration[    0]: (3.941e+08) 3.941e+08 / 3.941e+12
# End in 73 iterations: 3.94110e+12 / 3.94110e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176624821
# Successful iteration[    0]: (3.921e+08) 3.921e+08 / 3.921e+12
# End in 73 iterations: 3.92140e+12 / 3.92140e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176410581
# Successful iteration[    0]: (3.902e+08) 3.902e+08 / 3.902e+12
# End in 73 iterations: 3.90179e+12 / 3.90179e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176198099
# Successful iteration[    0]: (3.882e+08) 3.882e+08 / 3.882e+12
# End in 73 iterations: 3.88228e+12 / 3.88228e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666175987409
# Successful iteration[    0]: (3.863e+08) 3.863e+08 / 3.863e+12
# End in 73 iterations: 3.86287e+12 / 3.86287e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666175778577
# Successful iteration[    0]: (3.844e+08) 3.844e+08 / 3.844e+12
# End in 73 iterations: 3.84356e+12 / 3.84356e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66617557166
# Successful iteration[    0]: (3.824e+08) 3.824e+08 / 3.824e+12
# End in 73 iterations: 3.82434e+12 / 3.82434e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666175366686
# Successful iteration[    0]: (3.805e+08) 3.805e+08 / 3.805e+12
# End in 73 iterations: 3.80522e+12 / 3.80522e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666175163736
# Successful iteration[    0]: (3.786e+08) 3.786e+08 / 3.786e+12
# End in 73 iterations: 3.78619e+12 / 3.78619e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666174962833
# Successful iteration[    0]: (3.767e+08) 3.767e+08 / 3.767e+12
# End in 73 iterations: 3.76726e+12 / 3.76726e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666174764023
# Successful iteration[    0]: (3.748e+08) 3.748e+08 / 3.748e+12
# End in 73 iterations: 3.74842e+12 / 3.74842e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666174567361
# Successful iteration[    0]: (3.730e+08) 3.730e+08 / 3.730e+12
# End in 73 iterations: 3.72968e+12 / 3.72968e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666174372859
# Successful iteration[    0]: (3.711e+08) 3.711e+08 / 3.711e+12
# End in 73 iterations: 3.71103e+12 / 3.71103e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666174180582
# Successful iteration[    0]: (3.692e+08) 3.692e+08 / 3.692e+12
# End in 73 iterations: 3.69248e+12 / 3.69248e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666173990552
# Successful iteration[    0]: (3.674e+08) 3.674e+08 / 3.674e+12
# End in 73 iterations: 3.67402e+12 / 3.67402e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666173802785
# Successful iteration[    0]: (3.656e+08) 3.656e+08 / 3.656e+12
# End in 73 iterations: 3.65565e+12 / 3.65565e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666173617344
# Successful iteration[    0]: (3.637e+08) 3.637e+08 / 3.637e+12
# End in 73 iterations: 3.63737e+12 / 3.63737e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666173434233
# Successful iteration[    0]: (3.619e+08) 3.619e+08 / 3.619e+12
# End in 73 iterations: 3.61918e+12 / 3.61918e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666173253472
# Successful iteration[    0]: (3.601e+08) 3.601e+08 / 3.601e+12
# End in 73 iterations: 3.60108e+12 / 3.60108e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666173075112
# Successful iteration[    0]: (3.583e+08) 3.583e+08 / 3.583e+12
# End in 73 iterations: 3.58308e+12 / 3.58308e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666172899149
# Successful iteration[    0]: (3.565e+08) 3.565e+08 / 3.565e+12
# End in 73 iterations: 3.56516e+12 / 3.56516e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666172725606
# Successful iteration[    0]: (3.547e+08) 3.547e+08 / 3.547e+12
# End in 73 iterations: 3.54734e+12 / 3.54734e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666172554519
# ...
# force_factor: 0.0
# gammma - 1: 0.43231671075
# Successful iteration[    0]: (7.321e+01) 7.321e+01 / 7.321e+05
# End in 73 iterations: 7.32122e+05 / 7.32122e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432298908334
# Successful iteration[    0]: (7.285e+01) 7.285e+01 / 7.285e+05
# End in 73 iterations: 7.28462e+05 / 7.28462e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432281253887
# Successful iteration[    0]: (7.248e+01) 7.248e+01 / 7.248e+05
# End in 73 iterations: 7.24819e+05 / 7.24819e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432263745458
# Successful iteration[    0]: (7.212e+01) 7.212e+01 / 7.212e+05
# End in 73 iterations: 7.21195e+05 / 7.21195e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432246381116
# Successful iteration[    0]: (7.176e+01) 7.176e+01 / 7.176e+05
# End in 73 iterations: 7.17589e+05 / 7.17589e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432229158948
# Successful iteration[    0]: (7.140e+01) 7.140e+01 / 7.140e+05
# End in 73 iterations: 7.14001e+05 / 7.14001e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432212077062
# Successful iteration[    0]: (7.104e+01) 7.104e+01 / 7.104e+05
# End in 73 iterations: 7.10431e+05 / 7.10431e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432195133916
# Successful iteration[    0]: (7.069e+01) 7.069e+01 / 7.069e+05
# End in 73 iterations: 7.06879e+05 / 7.06879e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432178328519
# Successful iteration[    0]: (7.033e+01) 7.033e+01 / 7.033e+05
# End in 73 iterations: 7.03345e+05 / 7.03345e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432161659893
# Successful iteration[    0]: (6.998e+01) 6.998e+01 / 6.998e+05
# End in 73 iterations: 6.99828e+05 / 6.99828e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432145127089
# Successful iteration[    0]: (6.963e+01) 6.963e+01 / 6.963e+05
# End in 73 iterations: 6.96329e+05 / 6.96329e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432128729176
# Successful iteration[    0]: (6.928e+01) 6.928e+01 / 6.928e+05
# End in 73 iterations: 6.92847e+05 / 6.92847e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432112464831
# Successful iteration[    0]: (6.894e+01) 6.894e+01 / 6.894e+05
# End in 73 iterations: 6.89383e+05 / 6.89383e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432096332181
# Successful iteration[    0]: (6.859e+01) 6.859e+01 / 6.859e+05
# End in 73 iterations: 6.85936e+05 / 6.85936e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432080329371
# Successful iteration[    0]: (6.825e+01) 6.825e+01 / 6.825e+05
# End in 73 iterations: 6.82506e+05 / 6.82506e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432064454565
# Successful iteration[    0]: (6.791e+01) 6.791e+01 / 6.791e+05
# End in 73 iterations: 6.79094e+05 / 6.79094e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432048705947
# Successful iteration[    0]: (6.757e+01) 6.757e+01 / 6.757e+05
# End in 73 iterations: 6.75698e+05 / 6.75698e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432033081719
# Successful iteration[    0]: (6.723e+01) 6.723e+01 / 6.723e+05
# End in 73 iterations: 6.72320e+05 / 6.72320e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432017580101
# Successful iteration[    0]: (6.690e+01) 6.690e+01 / 6.690e+05
# End in 73 iterations: 6.68958e+05 / 6.68958e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.432002199333
# Successful iteration[    0]: (6.656e+01) 6.656e+01 / 6.656e+05
# End in 73 iterations: 6.65613e+05 / 6.65613e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431986937669
# Successful iteration[    0]: (6.623e+01) 6.623e+01 / 6.623e+05
# End in 73 iterations: 6.62285e+05 / 6.62285e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431971793423
# Successful iteration[    0]: (6.590e+01) 6.590e+01 / 6.590e+05
# End in 73 iterations: 6.58974e+05 / 6.58974e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43195676564
# Successful iteration[    0]: (6.557e+01) 6.557e+01 / 6.557e+05
# End in 73 iterations: 6.55679e+05 / 6.55679e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431941853642
# Successful iteration[    0]: (6.524e+01) 6.524e+01 / 6.524e+05
# End in 73 iterations: 6.52401e+05 / 6.52401e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431927056762
# Successful iteration[    0]: (6.491e+01) 6.491e+01 / 6.491e+05
# End in 73 iterations: 6.49139e+05 / 6.49139e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431912374339
# Successful iteration[    0]: (6.459e+01) 6.459e+01 / 6.459e+05
# End in 73 iterations: 6.45893e+05 / 6.45893e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431897805424
# Successful iteration[    0]: (6.427e+01) 6.427e+01 / 6.427e+05
# End in 73 iterations: 6.42664e+05 / 6.42664e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43188334829
# Successful iteration[    0]: (6.395e+01) 6.395e+01 / 6.395e+05
# End in 73 iterations: 6.39450e+05 / 6.39450e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431869001221
# Successful iteration[    0]: (6.363e+01) 6.363e+01 / 6.363e+05
# End in 73 iterations: 6.36253e+05 / 6.36253e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431854762519
# Successful iteration[    0]: (6.331e+01) 6.331e+01 / 6.331e+05
# End in 73 iterations: 6.33072e+05 / 6.33072e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431840630507
# Successful iteration[    0]: (6.299e+01) 6.299e+01 / 6.299e+05
# End in 73 iterations: 6.29906e+05 / 6.29906e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431826603523
# Successful iteration[    0]: (6.268e+01) 6.268e+01 / 6.268e+05
# End in 73 iterations: 6.26757e+05 / 6.26757e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431812679925
# Successful iteration[    0]: (6.236e+01) 6.236e+01 / 6.236e+05
# End in 73 iterations: 6.23623e+05 / 6.23623e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431798858088
# Successful iteration[    0]: (6.205e+01) 6.205e+01 / 6.205e+05
# End in 73 iterations: 6.20505e+05 / 6.20505e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431785136403
# Successful iteration[    0]: (6.174e+01) 6.174e+01 / 6.174e+05
# End in 73 iterations: 6.17402e+05 / 6.17402e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431771513599
# Successful iteration[    0]: (6.143e+01) 6.143e+01 / 6.143e+05
# End in 73 iterations: 6.14315e+05 / 6.14315e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431757989205
# Successful iteration[    0]: (6.112e+01) 6.112e+01 / 6.112e+05
# End in 73 iterations: 6.11244e+05 / 6.11244e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431744562798
# Successful iteration[    0]: (6.082e+01) 6.082e+01 / 6.082e+05
# End in 73 iterations: 6.08188e+05 / 6.08188e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431731233949
# Successful iteration[    0]: (6.051e+01) 6.051e+01 / 6.051e+05
# End in 73 iterations: 6.05147e+05 / 6.05147e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431718002079
# Successful iteration[    0]: (6.021e+01) 6.021e+01 / 6.021e+05
# End in 73 iterations: 6.02121e+05 / 6.02121e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431704865646
# Successful iteration[    0]: (5.991e+01) 5.991e+01 / 5.991e+05
# End in 73 iterations: 5.99110e+05 / 5.99110e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431691823044
# Successful iteration[    0]: (5.961e+01) 5.961e+01 / 5.961e+05
# End in 73 iterations: 5.96115e+05 / 5.96115e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431678872687
# Successful iteration[    0]: (5.931e+01) 5.931e+01 / 5.931e+05
# End in 73 iterations: 5.93134e+05 / 5.93134e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431666013006
# Successful iteration[    0]: (5.902e+01) 5.902e+01 / 5.902e+05
# End in 73 iterations: 5.90168e+05 / 5.90168e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431653242449
# Successful iteration[    0]: (5.872e+01) 5.872e+01 / 5.872e+05
# End in 73 iterations: 5.87218e+05 / 5.87218e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431640559482
# Successful iteration[    0]: (5.843e+01) 5.843e+01 / 5.843e+05
# End in 73 iterations: 5.84282e+05 / 5.84282e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43162796259
# Successful iteration[    0]: (5.814e+01) 5.814e+01 / 5.814e+05
# End in 73 iterations: 5.81360e+05 / 5.81360e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431615450271
# Successful iteration[    0]: (5.785e+01) 5.785e+01 / 5.785e+05
# End in 73 iterations: 5.78453e+05 / 5.78453e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431603021643
# Successful iteration[    0]: (5.756e+01) 5.756e+01 / 5.756e+05
# End in 73 iterations: 5.75561e+05 / 5.75561e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431590676486
# Successful iteration[    0]: (5.727e+01) 5.727e+01 / 5.727e+05
# End in 73 iterations: 5.72683e+05 / 5.72683e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431578414575
# Successful iteration[    0]: (5.698e+01) 5.698e+01 / 5.698e+05
# End in 73 iterations: 5.69820e+05 / 5.69820e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431566235729
# Successful iteration[    0]: (5.670e+01) 5.670e+01 / 5.670e+05
# End in 73 iterations: 5.66971e+05 / 5.66971e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431554138972
# Successful iteration[    0]: (5.641e+01) 5.641e+01 / 5.641e+05
# End in 73 iterations: 5.64136e+05 / 5.64136e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43154212278
# Successful iteration[    0]: (5.613e+01) 5.613e+01 / 5.613e+05
# End in 73 iterations: 5.61315e+05 / 5.61315e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431530185652
# Successful iteration[    0]: (5.585e+01) 5.585e+01 / 5.585e+05
# End in 73 iterations: 5.58509e+05 / 5.58509e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431518326104
# Successful iteration[    0]: (5.557e+01) 5.557e+01 / 5.557e+05
# End in 73 iterations: 5.55716e+05 / 5.55716e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431506542667
# Successful iteration[    0]: (5.529e+01) 5.529e+01 / 5.529e+05
# End in 73 iterations: 5.52938e+05 / 5.52938e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431494833893
# Successful iteration[    0]: (5.502e+01) 5.502e+01 / 5.502e+05
# End in 73 iterations: 5.50173e+05 / 5.50173e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431483198347
# Successful iteration[    0]: (5.474e+01) 5.474e+01 / 5.474e+05
# End in 73 iterations: 5.47422e+05 / 5.47422e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431471634613
# Successful iteration[    0]: (5.447e+01) 5.447e+01 / 5.447e+05
# End in 73 iterations: 5.44685e+05 / 5.44685e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431460141709
# Successful iteration[    0]: (5.420e+01) 5.420e+01 / 5.420e+05
# End in 73 iterations: 5.41961e+05 / 5.41961e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431448719563
# Successful iteration[    0]: (5.393e+01) 5.393e+01 / 5.393e+05
# End in 73 iterations: 5.39252e+05 / 5.39252e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43143736813
# Successful iteration[    0]: (5.366e+01) 5.366e+01 / 5.366e+05
# End in 73 iterations: 5.36555e+05 / 5.36555e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.4314260874
# Successful iteration[    0]: (5.339e+01) 5.339e+01 / 5.339e+05
# End in 73 iterations: 5.33873e+05 / 5.33873e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431414876514
# Successful iteration[    0]: (5.312e+01) 5.312e+01 / 5.312e+05
# End in 73 iterations: 5.31203e+05 / 5.31203e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431403734028
# Successful iteration[    0]: (5.285e+01) 5.285e+01 / 5.285e+05
# End in 73 iterations: 5.28547e+05 / 5.28547e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431392658521
# Successful iteration[    0]: (5.259e+01) 5.259e+01 / 5.259e+05
# End in 73 iterations: 5.25904e+05 / 5.25904e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431381648585
# Successful iteration[    0]: (5.233e+01) 5.233e+01 / 5.233e+05
# End in 73 iterations: 5.23275e+05 / 5.23275e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431370702832
# Successful iteration[    0]: (5.207e+01) 5.207e+01 / 5.207e+05
# End in 73 iterations: 5.20659e+05 / 5.20659e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431359819889
# Successful iteration[    0]: (5.181e+01) 5.181e+01 / 5.181e+05
# End in 73 iterations: 5.18055e+05 / 5.18055e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431348998399
# Successful iteration[    0]: (5.155e+01) 5.155e+01 / 5.155e+05
# End in 73 iterations: 5.15465e+05 / 5.15465e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431338237022
# Successful iteration[    0]: (5.129e+01) 5.129e+01 / 5.129e+05
# End in 73 iterations: 5.12888e+05 / 5.12888e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431327535212
# Successful iteration[    0]: (5.103e+01) 5.103e+01 / 5.103e+05
# End in 73 iterations: 5.10323e+05 / 5.10323e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431316893083
# Successful iteration[    0]: (5.078e+01) 5.078e+01 / 5.078e+05
# End in 73 iterations: 5.07772e+05 / 5.07772e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431306310754
# Successful iteration[    0]: (5.052e+01) 5.052e+01 / 5.052e+05
# End in 73 iterations: 5.05233e+05 / 5.05233e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431295788187
# Successful iteration[    0]: (5.027e+01) 5.027e+01 / 5.027e+05
# End in 73 iterations: 5.02707e+05 / 5.02707e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431285324187
# Successful iteration[    0]: (5.002e+01) 5.002e+01 / 5.002e+05
# End in 73 iterations: 5.00193e+05 / 5.00193e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431274917387
# Successful iteration[    0]: (4.977e+01) 4.977e+01 / 4.977e+05
# End in 73 iterations: 4.97692e+05 / 4.97692e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431264566436
# Successful iteration[    0]: (4.952e+01) 4.952e+01 / 4.952e+05
# End in 73 iterations: 4.95204e+05 / 4.95204e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431254270001
# Successful iteration[    0]: (4.927e+01) 4.927e+01 / 4.927e+05
# End in 73 iterations: 4.92728e+05 / 4.92728e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431244026765
# Successful iteration[    0]: (4.903e+01) 4.903e+01 / 4.903e+05
# End in 73 iterations: 4.90264e+05 / 4.90264e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431233835426
# Successful iteration[    0]: (4.878e+01) 4.878e+01 / 4.878e+05
# End in 73 iterations: 4.87813e+05 / 4.87813e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.4312236947
# Successful iteration[    0]: (4.854e+01) 4.854e+01 / 4.854e+05
# End in 73 iterations: 4.85374e+05 / 4.85374e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431213603639
# Successful iteration[    0]: (4.829e+01) 4.829e+01 / 4.829e+05
# End in 73 iterations: 4.82947e+05 / 4.82947e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431203562406
# Successful iteration[    0]: (4.805e+01) 4.805e+01 / 4.805e+05
# End in 73 iterations: 4.80532e+05 / 4.80532e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43119357125
# Successful iteration[    0]: (4.781e+01) 4.781e+01 / 4.781e+05
# End in 73 iterations: 4.78129e+05 / 4.78129e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431183630408
# Successful iteration[    0]: (4.757e+01) 4.757e+01 / 4.757e+05
# End in 73 iterations: 4.75739e+05 / 4.75739e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431173739024
# Successful iteration[    0]: (4.734e+01) 4.734e+01 / 4.734e+05
# End in 73 iterations: 4.73360e+05 / 4.73360e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431163895783
# Successful iteration[    0]: (4.710e+01) 4.710e+01 / 4.710e+05
# End in 73 iterations: 4.70993e+05 / 4.70993e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431154099388
# Successful iteration[    0]: (4.686e+01) 4.686e+01 / 4.686e+05
# End in 73 iterations: 4.68638e+05 / 4.68638e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431144348555
# Successful iteration[    0]: (4.663e+01) 4.663e+01 / 4.663e+05
# End in 73 iterations: 4.66295e+05 / 4.66295e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431134642019
# Successful iteration[    0]: (4.640e+01) 4.640e+01 / 4.640e+05
# End in 73 iterations: 4.63964e+05 / 4.63964e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431124978528
# Successful iteration[    0]: (4.616e+01) 4.616e+01 / 4.616e+05
# End in 73 iterations: 4.61644e+05 / 4.61644e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431115356847
# Successful iteration[    0]: (4.593e+01) 4.593e+01 / 4.593e+05
# End in 73 iterations: 4.59336e+05 / 4.59336e+05 (0.00000e+00)

# %%
dir_ff_grackle = "/home/kwoksun2/grackle/src/python/examples/freefall.h5"
import h5py
f = h5py.File(dir_ff_grackle)
fdata = f['data']
grackle_T = fdata['temperature'].value
grackle_rho = fdata['density'].value
grackle_data = convert_from_grackle_to_dengo_all(fdata)
f.close()

# %%
plt.figure(dpi=100)
plt.loglog(density_array[1:]* u.amu.v, all_data['T'] ,label='dengo   freefall')
plt.loglog(grackle_rho, grackle_T, label='grackle freefall')
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel('temperature (K)')
plt.legend()

# %%
def get_e_from_all_data(all_data):
    l = len(all_data['de'])
    q = np.zeros((l))
    for sp in primordial.required_species:
        if sp.name not in ['ge', 'de']:
            q += numpy.array(all_data[sp.name])/ sp.weight * sp.free_electrons
    return q

def get_mu_from_all_data(all_data, density_array):
    l = len(all_data['de'])
    n = np.zeros((l))    
    # mass density / number density
    for sp in primordial.required_species:
        if sp.name not in ['ge', 'de']:
            n += numpy.array(all_data[sp.name])/ sp.weight
            
    mu = density_array/ n / 1.00794
    return mu

def get_gamma_from_all_data( all_data ):
    l = len(all_data['de'])
    total_n = np.zeros((l))    
    # mass density / number density
    for sp in primordial.required_species:
        if sp.name not in ['ge', 'de']:
            total_n += numpy.array(all_data[sp.name])/ sp.weight    

    rs = primordial.required_species
    H2_1_sp = list(rs)[0]
    
    gamma_array = np.zeros((l))
    for n in range(l):
        
        temperature = all_data['T'][n]
        num_den = {}
        for sp in primordial.required_species:
            if sp.name != 'ge':
                num_den[sp.name] = numpy.array(all_data[sp.name][n])/ sp.weight   

        gammaH2 = primordial.species_gamma(H2_1_sp,name=False, temp=True).subs({'T':temperature})    
        gamma_factor = primordial.gamma_factor().subs(num_den).subs({'gammaH2': gammaH2 , 
                                                                         'gamma': 5./3.,'T': temperature })
        # gamma_factor = n / (gamma - 1)
        
        gamma = total_n[n] / gamma_factor + 1.0
        gamma_array[n] = gamma
    return gamma_array

# %%
# check conservation of stuff
plt.figure(dpi = 100)
yerr = 1e-5
plt.ylim( 1- yerr ,  1+ yerr)
plt.title('Dengo conservation of mass/charge density')
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(r'$\rho_x / \rho_0$   /    $ q / de $')


all_H = numpy.array(all_data['H_1']) + numpy.array(all_data['H2_1']) + numpy.array(all_data['H2_2'])
plt.semilogx( density_array[1:]*u.amu, (all_H / density_array[1:]) / (all_H / density_array[1:])[0], label='Hydrogen' )



all_He = numpy.array(all_data['He_1']) + numpy.array(all_data['He_2']) + numpy.array(all_data['He_3'])
plt.semilogx( density_array[1:]*u.amu, (all_He / density_array[1:]) / (all_H / density_array[1:])[0], label='Helium' )




q = get_e_from_all_data(all_data)
de = numpy.array(all_data['de'])

plt.semilogx(density_array[1:]*u.amu, de /q, label='charge ratios' )

plt.legend()
plt.show()

# %%
# check conservation of stuff
plt.figure(dpi = 100)
yerr = 1e-5
plt.ylim( 1- yerr ,  1+ yerr)
plt.title('Conservation of mass/charge density')
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(r'$\rho_x / \rho_0$')

plt.gca().set_prop_cycle(None)

all_H_gra = numpy.array(grackle_data['H_1']) + numpy.array(grackle_data['H2_1']) + numpy.array(grackle_data['H2_2'])
plt.semilogx( density_array[1:]*u.amu, (all_H_gra / density_array[1:]) / (all_H_gra / density_array[1:])[0], 
             label='Hydrogen', ls = '--' )



all_He_gra = numpy.array(grackle_data['He_1']) + numpy.array(grackle_data['He_2']) + numpy.array(grackle_data['He_3'])
plt.semilogx( density_array[1:]*u.amu, (all_He_gra/ density_array[1:]) / (all_He_gra / density_array[1:])[0], 
             label='Helium', ls = '--' )



def get_e_from_all_data(all_data):
    l = len(all_data['de'])
    q = np.zeros((l))
    for sp in primordial.required_species:
        if sp.name not in ['ge', 'de']:
            q += numpy.array(all_data[sp.name])/ sp.weight * sp.free_electrons
    return q

q = get_e_from_all_data(grackle_data)
de = numpy.array(grackle_data['de'])

plt.semilogx(density_array[1:]*u.amu, de /q / 1.00794, label='charge ratios', ls= '--' )

plt.legend()
plt.show()

# %%
### get fractional abundances of H2
plt.figure(dpi =100)

fig, ax1 = plt.subplots(dpi =100)

ax2 = ax1.twinx()

ax1.loglog(density_array[1:]* u.amu.v, all_data['T'], label='dengo   freefall', color='k', ls='--')
ax1.loglog(grackle_rho, grackle_T, label='grackle freefall',color='r')
ax1.set_xlabel('density ($g$ $cm^{-3}$)')
ax1.set_ylabel('Temperature (K)')


ax2.set_ylabel('fractional abundances of $H_2$: $f_{H_2}$ ')
ax2.plot(density_array[1:]* u.amu.v, all_data['H2_1'] / all_H, label='dengo   freefall' ,color='k', ls='--')
ax2.loglog(density_array[1:]* u.amu.v, grackle_data['H2_1'] / all_H_gra, label='grackle  freefall' ,color='r')

ax1.legend()

# %%
plt.figure(dpi=100)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel('fractional abundances of $H_2$: $f_{H_2}$ ')
plt.plot(density_array[1:]* u.amu.v, all_data['H2_1'] / all_H, label='dengo   freefall' )
plt.loglog(density_array[1:]* u.amu.v, grackle_data['H2_1'] / all_H_gra, label='grackle  freefall')
plt.legend()

# %%
plt.figure(dpi =100)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(' mean molecular mass ($\mu$) ')

mu_dengo = get_mu_from_all_data(all_data, density_array[1:])
mu_grackle = get_mu_from_all_data(grackle_data, density_array[:-1])


plt.plot(density_array[1:]* u.amu.v, mu_dengo, label='dengo   freefall' )
plt.semilogx(density_array[1:]* u.amu.v, mu_grackle , label='grackle   freefall' )
plt.legend()
plt.show()

# %%
gamma_dengo = get_gamma_from_all_data( all_data )
gamma_grackle = get_gamma_from_all_data( grackle_data )

# %%
plt.figure(dpi =100)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(' adiabatic index ($\gamma$) ')

plt.plot(density_array[1:]* u.amu.v, gamma_dengo, label='dengo   freefall' )
plt.semilogx(density_array[:-1]* u.amu.v, gamma_grackle , label='grackle   freefall' )

plt.legend()
plt.show()

# %%
plt.figure(dpi=100)
for key in primordial.required_species:
    if key.name not in ['ge'] :
        plt.loglog(density_array[2:-1]*u.amu, numpy.array(all_data[key.name][:-1] ),label=key.name )

plt.ylim(0, 2)
plt.ylim(1e-28,1e0)
# plt.xlim(1e-24,1e-22)
plt.legend( loc = 0)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(r'Fractional Abundance $\rho_{x, dengo} / \rho_{x, grackle})$')
plt.title('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-53095223b25b> in <module>()
#       2 for key in primordial.required_species:
#       3     if key.name not in ['ge'] :
# ----> 4         plt.loglog(density_array[2:-1]*u.amu, numpy.array(all_data[key.name][:-1] ),label=key.name )
#       5
#       6 plt.ylim(0, 2)
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in loglog(*args, **kwargs)
#    3223                       mplDeprecation)
#    3224     try:
# -> 3225         ret = ax.loglog(*args, **kwargs)
#    3226     finally:
#    3227         ax._hold = washold
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in loglog(self, *args, **kwargs)
#    1670         b = self._hold
#    1671         self._hold = True  # we've already processed the hold
# -> 1672         l = self.plot(*args, **kwargs)
#    1673         self._hold = b  # restore the hold
#    1674
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1525         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1526
# -> 1527         for line in self._get_lines(*args, **kwargs):
#    1528             self.add_line(line)
#    1529             lines.append(line)
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (3444,) and (3445,)

# %%
plt.loglog(density_array[2:-1]*u.amu, numpy.array(all_data['ge'][:-1] ),label='ge' )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-8e405efac2eb> in <module>()
#       1 plt.loglog(density_array[2:-1]*u.amu, numpy.array(all_data['ge'][:-1] ),label='ge' )
# ----> 2 plt.loglog(density_array[2:-1]*u.amu, numpy.array(grackle_data['ge'][:-1] ),label='ge' )
#
# KeyError: 'ge'

# %%
plt.figure(dpi = 100)
plt.semilogx(density_array[1:]* u.amu, run_time)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel('runtime (s)')
plt.title('dengo runtime (evolve freefall)')
plt.show()

# %%
f = h5py.File('test_bechem_cvdls_tables.h5')
f.keys()
f.close()

# %% [markdown]
# # Performance with N strips

# %%
# %%writefile bechem_runfile
# #!/bin/bash
# rm -f a.out
# g++ test_bechem_cvdls_solver.C test_bechem_cvdls_solver_main.C BE_chem_solve.C -I. -lm -lstdc++ -lhdf5 -lhdf5_hl -O3
# Out:
# Overwriting bechem_runfile

# %%
# !bash bechem_runfile

# %%
# !./a.out
# Out:
# Successfully read in rate tables.
# Successfully read in cooling rate tables.
# Successfully read in gamma tables.
# Getting dimensionality from ge:
#   ncells =   1
# Reading I.C. for /H2_1
# H2_1[0] = 1e-10, atol =>  1e-19
# Reading I.C. for /H2_2
# H2_2[0] = 1e-10, atol =>  1e-19
# Reading I.C. for /H_1
# H_1[0] = 7.6e+09, atol =>  1e-19
# Reading I.C. for /H_2
# H_2[0] = 1e-10, atol =>  1e-19
# Reading I.C. for /H_m0
# H_m0[0] = 1e-10, atol =>  1e-19
# Reading I.C. for /He_1
# He_1[0] = 2.4e+09, atol =>  1e-19
# Reading I.C. for /He_2
# He_2[0] = 1e-10, atol =>  1e-19
# Reading I.C. for /He_3
# He_3[0] = 1e-10, atol =>  1e-19
# Reading I.C. for /de
# de[0] = 1.25e-10, atol =>  1e-19
# Reading I.C. for /ge
# ge[0] = 2.02e+11, atol =>  1e-19
# dt 0.76294, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.38147, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.19073, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.095367, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.047684, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.023842, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.011921, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.0059605, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.0029802, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.0014901, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.00074506, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.00037253, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 0.00018626, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 9.3132e-05, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 4.6566e-05, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 2.3283e-05, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# dt 1.1642e-05, Sweep 0, Unsolved[0]: nchem: 0 change:  4.7592827e+36 sum tol:  4.7593e+27 atol:  1e-09 rtol:  1e-09 value: -4.7593e+36
# Dying! dt/dtf = 5.8208e-16
# Writing solution for /H2_1
# Writing solution for /H2_2
# Writing solution for /H_1
# Writing solution for /H_2
# Writing solution for /H_m0
# Writing solution for /He_1
# Writing solution for /He_2
# Writing solution for /He_3
# Writing solution for /de
# Writing solution for /ge

# %%
def cooling_rate_from_temp(T):
    cooling_rates = {}
    for action in primordial.cooling_actions.values():
        actionname = action.name
        for tab in action.tables:
            name = "{}_{}[i]".format(actionname, tab)
            
            temp_array = primordial.T
            
            cooling = numpy.interp(T, temp_array, action.tables[tab](primordial))
            cooling_rates[name] = cooling
    cooling_rates['T'] = T
    cooling_rates['z'] = numpy.zeros((len(T)))
#     cooling_rates = sorted(cooling_rates)
    return cooling_rates

def cooling_from_results(results, primordial, cooling_rates, T):
    
    cooling_results = {}

    for action in primordial.cooling_actions:
        cool_action = cooling_registry[action].equation
        cool_sym = cool_action.free_symbols
        
        cool_sym_name = [str(i) for i in cool_sym]
        func = lambdify(cool_sym, cool_action,'numpy') # returns a numpy-ready function
        
        
        num_var = len(cool_sym)
        len_T   = len(T)
        
        input_array = numpy.zeros(( num_var, len_T ))       
        for iii, sym_name in enumerate(cool_sym_name):
            try:
                input_array[iii, :] = results[sym_name]
            except:
                input_array[iii, :] = cooling_rates[sym_name]
        
        
        cooling_results[action] = func(*input_array)
    return cooling_results

# %%
T_array = all_data['T']

cooling_rates = cooling_rate_from_temp(T_array)
cooling_rates['mdensity'] = density_array[1:]
cooling_rates['mh'] = numpy.ones((len(T_array)))* u.mass_hydrogen_cgs.v

cooling_results = cooling_from_results(all_data, primordial, cooling_rates, T_array)


T_array_gra = grackle_data['T']

cooling_rates_gra = cooling_rate_from_temp(T_array_gra)
cooling_rates_gra['mdensity'] = density_array[1:]
cooling_rates_gra['mh'] = numpy.ones((len(T_array_gra)))* u.mass_hydrogen_cgs.v

cooling_results_gra = cooling_from_results(grackle_data, primordial, cooling_rates_gra, T_array_gra)

# %%
plt.figure(dpi=100, figsize=(10,10))
from matplotlib.pyplot import cm
color=cm.tab20(np.linspace(0,1,len(cooling_results.keys()) ))
net_cooling = numpy.zeros((len(T_array)))

iii = 0
for i in cooling_results.keys():
    d = cooling_results[i]
    
    net_cooling = d + net_cooling
    if i not in ['gammah']:
        if d[0] < 0:
            plt.semilogx(density_array[1:]*u.amu, numpy.abs(d)/density_array[1:]/ u.amu_cgs.v, label=i,c=color[iii])
        else:
            plt.loglog(density_array[1:]*u.amu, numpy.abs(d)/density_array[1:]/ u.amu_cgs.v, label=i,  c=color[iii])
            
    iii += 1
    
net_cooling_gra = numpy.zeros((len(T_array_gra)))

iii = 0
for i in cooling_results_gra.keys():
    d = cooling_results_gra[i]
    
    net_cooling_gra = d + net_cooling_gra
    if i not in ['gammah']:
        if d[0] < 0:
            plt.semilogx(density_array[1:]*u.amu, numpy.abs(d)/density_array[1:]/ u.amu_cgs.v, ls= '--', c=color[iii])
        else:
            plt.loglog(density_array[1:]*u.amu, numpy.abs(d)/density_array[1:]/ u.amu_cgs.v, ls= '--', c=color[iii])
            
    iii += 1    

plt.legend()
plt.xlabel('density (g / $cm^{-3}$)')
plt.ylabel(r'cooling rate per unit mass (erg / g /s)')
# plt.ylim(1e-5,1e5)
plt.gca().set_prop_cycle(None)


plt.show()

plt.figure(dpi=100, figsize=(10,10))
plt.loglog(density_array[1:]*u.amu, numpy.abs(net_cooling)/density_array[1:]/ u.amu_cgs.v, label='dengo freefall')
plt.loglog(density_array[1:]*u.amu, numpy.abs(net_cooling_gra)/density_array[1:]/ u.amu_cgs.v,ls= '--',label='grackle freefall')
# plt.ylim(1e-5,1e5)
plt.legend()
plt.xlabel('density (g / $cm^{-3}$)')
plt.ylabel(r'cooling rate per unit mass (erg / g /s)')
plt.show()
