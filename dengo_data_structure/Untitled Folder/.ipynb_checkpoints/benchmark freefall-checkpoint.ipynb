# %%
from dengo_freefall import *
# Out:
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#  using cli
#  using CLI for selections

# %%
def Init_values(temperature, density, n_species = 9, cooling=True, size=10):
    """ Create a initial value dictionary,
        for a given temperature, density, number of species
    Args:
        temperature -- in Kelvin
        density     -- in amu / cm**3
        n_species   -- number of species (6/9)
        cooling

    Returns:
        init_values: initial value dictionary with
                     self-consistent energy/ electron density
        primordial : chemical_network classes

    """

    # initialize and setup the network
    dengo.primordial_rates.setup_primordial()
    primordial = ChemicalNetwork()
    primordial.threebody = 4

    if n_species == 9:
        for i in range(22):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass
    else:
        for i in range(6):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass

    # the temperature array required to interpolates the rates
    primordial.init_temperature((1e0, 1e5))

    tiny = 1.0e-20

    # init_array are is in fractional abundances
    init_values = dict()
    density = numpy.array([density])*numpy.ones((size))
    if n_species == 6:
        # 6-species model
        init_values["He_1"]    = density * (1.0 - 0.76)
        init_values["He_2"]    = np.array([tiny])
        init_values["He_3"]    = np.array([tiny])
        init_values["H_1"]     = density *  (0.76)
        init_values['H_2']     = np.array([tiny]) 
    else:
        # 9-species model
        init_values["He_1"]    = density * (1.0 - 0.76) 
        init_values["He_2"]    = density *np.array([tiny])
        init_values["He_3"]    = density *np.array([tiny])
        init_values["H_1"]     = density *  (0.76)
        init_values['H_2']     = density *np.array([tiny])

        init_values["H_m0"]    = density *np.array([tiny])
        init_values["H2_1"]    = density *np.array([tiny])
        init_values["H2_2"]    = density *np.array([tiny])

    # now everything in mass density
    init_values['de'] = primordial.calculate_free_electrons(init_values)
    # one signle value: again mass density
    init_values['density'] = primordial.calculate_total_density(init_values)

    num_den = {}
    for sp in primordial.required_species:
        try:
            num_den[sp.name] = init_values[sp.name]/ sp.weight
        except:
            pass

    # set up initial temperatures values used to define ge
    init_values['T'] = numpy.array([temperature])*numpy.ones((size))
    ge_array = numpy.ones((size))
    init_values['ge'] = ge_array
    
    # calculate gammaH2
    
    for i in range(size):
        
        temperature = init_values['T'][i]
        x = 6100.0/temperature
        expx = numpy.exp(x)
        gammaH2 = 2.0 / (5.0 + 2.0*x*x*expx / (expx - 1 )**2.0 ) + 1

        rs = primordial.required_species
        H2_1_sp = list(rs)[0]
        gammaH2 = primordial.species_gamma(H2_1_sp,name=False, temp=True).subs({'T':temperature})

        new_num_den = {}
        for ele in num_den.keys():
            new_num_den[ele] = num_den[ele][i]
        
        gamma_factor = primordial.gamma_factor().subs(new_num_den).subs({'gammaH2': gammaH2 , 'gamma': 5./3.,'T': temperature })

        ge  = ((temperature *  kboltz) *gamma_factor
                             / (init_values['density'][i] * mh  ))

        
        T = init_values['density']*ge*mh / kboltz / gamma_factor
        init_values['ge'][i] = numpy.float64(ge)
    print(ge)
    if cooling:
        for cooling_action in cooling_registry:
            k = cooling_registry[cooling_action]
            if (k.species).issubset( primordial.required_species ):
                if k.name != "cie_cooling":                    
                    print("adding cooling: {}".format(k.name) )
                    primordial.add_cooling(cooling_action)
    return init_values, primordial

# %%
density = 1e10
initial_temperature = 2000.0
final_time = 1e10

final_time_Myr = u.second.in_units('Myr').v * final_time

init, primordial = Init_values(initial_temperature, 
                               density, n_species = 9, 
                               cooling=True, size=1)
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# 201787598961.116
# adding cooling: brem
# adding cooling: reHII
# adding cooling: reHeIII
# adding cooling: gloverabel08
# adding cooling: ceHI
# adding cooling: compton
# adding cooling: h2formation
# adding cooling: reHeII2
# adding cooling: reHeII1
# adding cooling: ciHeIS
# adding cooling: ceHeII
# adding cooling: ciHI
# adding cooling: ceHeI
# adding cooling: gammah
# adding cooling: ciHeI
# adding cooling: ciHeII

# %%
solver_name = 'test_cvdls'
pyximport.install(setup_args={"include_dirs":np.get_include()},
                  reload_support=True, inplace=True)

primordial.stop_time = 1.0e10
# write the network

primordial.write_solver(solver_name, output_dir = ".",
    solver_template = "cvdls_n/sundials_CVDls",
    ode_solver_source = "initialize_cvode_solver.C",
    init_values=init,
    input_is_number=False)

# import the pyx module
sundials_cvdls_run = pyximport.load_module("{}_run".format(solver_name),
                "{}_solver_run.pyx".format(solver_name),
                 build_inplace = True, pyxbuild_dir = "_dengo_temp")
# Out:
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/dengo-0.1-py2.7.egg/dengo/primordial_cooling.py:326: RuntimeWarning: overflow encountered in power
#   + 70.609154 * lt3[_i2] **8)
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/dengo-0.1-py2.7.egg/dengo/primordial_cooling.py:350: RuntimeWarning: overflow encountered in power
#   + 1.8161874 * lt3**8)

# %%
temperature = 50000.0# K
density = 1.0e-1*1.007947 # cm^-3


init, primordial = Init_values(temperature, 
                               density, n_species = 9, 
                               cooling=True, size=1)
tic = time.time()
rv, rv_int = sundials_cvdls_run.run_test_cvdls(init, 1e18,niter=1e3);
toc = time.time()
print('time taken: %0.3e' %(toc-tic) )
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# 5044689974027.89
# adding cooling: brem
# adding cooling: reHII
# adding cooling: reHeIII
# adding cooling: gloverabel08
# adding cooling: ceHI
# adding cooling: compton
# adding cooling: h2formation
# adding cooling: reHeII2
# adding cooling: reHeII1
# adding cooling: ciHeIS
# adding cooling: ceHeII
# adding cooling: ciHI
# adding cooling: ceHeI
# adding cooling: gammah
# adding cooling: ciHeI
# adding cooling: ciHeII
# initial  temperature: 5.000E+04
# Successful iteration[    0]: (1.000e+15) 1.000e+15 / 1.000e+18
# End in 49 iterations: 1.00000e+18 / 1.00000e+18 (0.00000e+00)
# time taken: 2.964e-01

# %%
flag = rv_int['successful']
# plt.loglog(rv_int['t'][flag],rv_int['H2_1'][0][flag],'-o')
# plt.loglog(rv_int['t'][flag],rv_int['H_1'][0][flag],'-o')
plt.loglog(rv_int['t'][flag],rv_int['T'][0][flag],'-o')
rv_int['T'][0][flag][-1]
# Out:
# 93.39729688828172

# %%
total_t = 0.0
final_density = 1.0e14*1.007947
density_array = numpy.array([ init['density'] ])
pressure_array = numpy.array([])
ttt = []
run_time = []
current_density = density_array[-1]

all_data = {}
for key in init.keys():
    all_data[key] = []
all_data['force_factor'] = []

# %%
dir_ff_grackle = "/home/kwoksun2/grackle/src/python/examples/freefall.h5"
import h5py
f = h5py.File(dir_ff_grackle)
fdata = f['data']
grackle_init = convert_from_grackle_to_dengo(fdata)


new_init, primordial = Init_values( temperature , density , n_species = 9, size=1)
for i in new_init.keys():
    if i not in ['density','ge']:
        print(i, grackle_init[i]) 
        new_init[i] = numpy.array([grackle_init[i]])

new_init['de'] = primordial.calculate_free_electrons(new_init)
new_init['ge'] =  calculate_energy(new_init, primordial)
rv, rv_int = sundials_cvdls_run.run_test_cvdls(new_init, 1e-5,niter=1e0)
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# 5044689974027.89
# adding cooling: brem
# adding cooling: reHII
# adding cooling: reHeIII
# adding cooling: gloverabel08
# adding cooling: ceHI
# adding cooling: compton
# adding cooling: h2formation
# adding cooling: reHeII2
# adding cooling: reHeII1
# adding cooling: ciHeIS
# adding cooling: ceHeII
# adding cooling: ciHI
# adding cooling: ceHeI
# adding cooling: gammah
# adding cooling: ciHeI
# adding cooling: ciHeII
# ('H_2', 2.037048519859754e-07)
# ('H_1', 0.07640481321249512)
# ('de', 2.0388464478882167e-07)
# ('He_1', 0.024190727280809784)
# ('He_2', 7.191902135742953e-10)
# ('He_3', 1.0079469999999966e-25)
# ('H2_2', 5.381147020325274e-17)
# ('H2_1', 0.00019895508264805535)
# ('H_m0', 4.7774530481217236e-15)
# ('T', array(99.9955172))
# [-2.84217094304040e-14]
# initial  temperature: 1.000E+02
# Successful iteration[    0]: (1.000e-05) 1.000e-05 / 1.000e-05
# End in 1 iterations: 1.00000e-05 / 1.00000e-05 (0.00000e+00)

# %%
iterrr = 0
while current_density < final_density:

    # keep track of time in here
    
    new_init = generate_init_from_results(rv_int, primordial, init)
    init, pressure_array, density_array, dt, force_factor = update_initial_condition(new_init, primordial, pressure_array
                                                             , density_array, safety_factor=0.01)
    
    tic = time.time()
    rv, rv_int = sundials_cvdls_run.run_test_cvdls(init, dt,niter=1e0)
    toc = time.time()
    total_t += dt
    ttt.append(float(total_t))
    run_time.append(toc-tic)
    
    flag = rv_int['successful']
    for key in init.keys():
        if key not in ['density']:
            data = rv_int[key][0][flag][-1]
            all_data[key].append(data)
    all_data['force_factor'].append( float(force_factor))
    current_density = density_array[-1]
    
    
    t_ends = rv_int['t'][flag][-1]
    if t_ends < dt:
        print('##########cannot finish the run....####################3')
        break
#     iterrr += 1
#     if iterrr > 0:
#         break
# Out:
# force_factor: 0.0
# gammma - 1: 0.666084054979
# initial  temperature: 1.007E+02
# Successful iteration[    0]: (1.451e+13) 1.451e+13 / 1.451e+13
# End in 1 iterations: 1.45083e+13 / 1.45083e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666084691618
# initial  temperature: 1.013E+02
# Successful iteration[    0]: (1.444e+13) 1.444e+13 / 1.444e+13
# End in 1 iterations: 1.44358e+13 / 1.44358e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666085340474
# initial  temperature: 1.020E+02
# Successful iteration[    0]: (1.436e+13) 1.436e+13 / 1.436e+13
# End in 1 iterations: 1.43636e+13 / 1.43636e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666086001744
# initial  temperature: 1.027E+02
# Successful iteration[    0]: (1.429e+13) 1.429e+13 / 1.429e+13
# End in 1 iterations: 1.42918e+13 / 1.42918e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666086674619
# initial  temperature: 1.034E+02
# Successful iteration[    0]: (1.422e+13) 1.422e+13 / 1.422e+13
# End in 1 iterations: 1.42203e+13 / 1.42203e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666087358795
# initial  temperature: 1.041E+02
# Successful iteration[    0]: (1.415e+13) 1.415e+13 / 1.415e+13
# End in 1 iterations: 1.41492e+13 / 1.41492e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66608805594
# initial  temperature: 1.048E+02
# Successful iteration[    0]: (1.408e+13) 1.408e+13 / 1.408e+13
# End in 1 iterations: 1.40785e+13 / 1.40785e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66608876346
# initial  temperature: 1.055E+02
# Successful iteration[    0]: (1.401e+13) 1.401e+13 / 1.401e+13
# End in 1 iterations: 1.40081e+13 / 1.40081e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666089481588
# initial  temperature: 1.062E+02
# Successful iteration[    0]: (1.394e+13) 1.394e+13 / 1.394e+13
# End in 1 iterations: 1.39380e+13 / 1.39380e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666090210644
# initial  temperature: 1.069E+02
# Successful iteration[    0]: (1.387e+13) 1.387e+13 / 1.387e+13
# End in 1 iterations: 1.38683e+13 / 1.38683e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666090950166
# initial  temperature: 1.076E+02
# Successful iteration[    0]: (1.380e+13) 1.380e+13 / 1.380e+13
# End in 1 iterations: 1.37990e+13 / 1.37990e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666091699806
# initial  temperature: 1.083E+02
# Successful iteration[    0]: (1.373e+13) 1.373e+13 / 1.373e+13
# End in 1 iterations: 1.37300e+13 / 1.37300e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66609245993
# initial  temperature: 1.090E+02
# Successful iteration[    0]: (1.366e+13) 1.366e+13 / 1.366e+13
# End in 1 iterations: 1.36614e+13 / 1.36614e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666093229361
# initial  temperature: 1.098E+02
# Successful iteration[    0]: (1.359e+13) 1.359e+13 / 1.359e+13
# End in 1 iterations: 1.35931e+13 / 1.35931e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666094008148
# initial  temperature: 1.105E+02
# Successful iteration[    0]: (1.353e+13) 1.353e+13 / 1.353e+13
# End in 1 iterations: 1.35251e+13 / 1.35251e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666094795481
# initial  temperature: 1.112E+02
# Successful iteration[    0]: (1.346e+13) 1.346e+13 / 1.346e+13
# End in 1 iterations: 1.34575e+13 / 1.34575e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666095592124
# initial  temperature: 1.120E+02
# Successful iteration[    0]: (1.339e+13) 1.339e+13 / 1.339e+13
# End in 1 iterations: 1.33902e+13 / 1.33902e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666096397653
# initial  temperature: 1.127E+02
# Successful iteration[    0]: (1.332e+13) 1.332e+13 / 1.332e+13
# End in 1 iterations: 1.33232e+13 / 1.33232e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666097211327
# initial  temperature: 1.135E+02
# Successful iteration[    0]: (1.326e+13) 1.326e+13 / 1.326e+13
# End in 1 iterations: 1.32566e+13 / 1.32566e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66609803329
# initial  temperature: 1.142E+02
# Successful iteration[    0]: (1.319e+13) 1.319e+13 / 1.319e+13
# End in 1 iterations: 1.31903e+13 / 1.31903e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666098863374
# initial  temperature: 1.150E+02
# Successful iteration[    0]: (1.312e+13) 1.312e+13 / 1.312e+13
# End in 1 iterations: 1.31244e+13 / 1.31244e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666099700818
# initial  temperature: 1.158E+02
# Successful iteration[    0]: (1.306e+13) 1.306e+13 / 1.306e+13
# End in 1 iterations: 1.30587e+13 / 1.30587e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666100545914
# initial  temperature: 1.166E+02
# Successful iteration[    0]: (1.299e+13) 1.299e+13 / 1.299e+13
# End in 1 iterations: 1.29935e+13 / 1.29935e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666101397701
# initial  temperature: 1.173E+02
# Successful iteration[    0]: (1.293e+13) 1.293e+13 / 1.293e+13
# End in 1 iterations: 1.29285e+13 / 1.29285e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666102255463
# initial  temperature: 1.181E+02
# Successful iteration[    0]: (1.286e+13) 1.286e+13 / 1.286e+13
# End in 1 iterations: 1.28638e+13 / 1.28638e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666103121257
# initial  temperature: 1.189E+02
# Successful iteration[    0]: (1.280e+13) 1.280e+13 / 1.280e+13
# End in 1 iterations: 1.27995e+13 / 1.27995e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666103992653
# initial  temperature: 1.197E+02
# Successful iteration[    0]: (1.274e+13) 1.274e+13 / 1.274e+13
# End in 1 iterations: 1.27355e+13 / 1.27355e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666104870063
# initial  temperature: 1.205E+02
# Successful iteration[    0]: (1.267e+13) 1.267e+13 / 1.267e+13
# End in 1 iterations: 1.26719e+13 / 1.26719e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666105753174
# initial  temperature: 1.213E+02
# Successful iteration[    0]: (1.261e+13) 1.261e+13 / 1.261e+13
# End in 1 iterations: 1.26085e+13 / 1.26085e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666106642305
# initial  temperature: 1.221E+02
# Successful iteration[    0]: (1.255e+13) 1.255e+13 / 1.255e+13
# End in 1 iterations: 1.25454e+13 / 1.25454e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666107535214
# initial  temperature: 1.229E+02
# Successful iteration[    0]: (1.248e+13) 1.248e+13 / 1.248e+13
# End in 1 iterations: 1.24827e+13 / 1.24827e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666108433947
# initial  temperature: 1.238E+02
# Successful iteration[    0]: (1.242e+13) 1.242e+13 / 1.242e+13
# End in 1 iterations: 1.24203e+13 / 1.24203e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666109338841
# initial  temperature: 1.246E+02
# Successful iteration[    0]: (1.236e+13) 1.236e+13 / 1.236e+13
# End in 1 iterations: 1.23582e+13 / 1.23582e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666110246659
# initial  temperature: 1.254E+02
# Successful iteration[    0]: (1.230e+13) 1.230e+13 / 1.230e+13
# End in 1 iterations: 1.22964e+13 / 1.22964e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666111158744
# initial  temperature: 1.263E+02
# Successful iteration[    0]: (1.223e+13) 1.223e+13 / 1.223e+13
# End in 1 iterations: 1.22349e+13 / 1.22349e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666112074203
# initial  temperature: 1.271E+02
# Successful iteration[    0]: (1.217e+13) 1.217e+13 / 1.217e+13
# End in 1 iterations: 1.21738e+13 / 1.21738e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666112994885
# initial  temperature: 1.279E+02
# Successful iteration[    0]: (1.211e+13) 1.211e+13 / 1.211e+13
# End in 1 iterations: 1.21129e+13 / 1.21129e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666113917735
# initial  temperature: 1.288E+02
# Successful iteration[    0]: (1.205e+13) 1.205e+13 / 1.205e+13
# End in 1 iterations: 1.20523e+13 / 1.20523e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666114844007
# initial  temperature: 1.297E+02
# Successful iteration[    0]: (1.199e+13) 1.199e+13 / 1.199e+13
# End in 1 iterations: 1.19921e+13 / 1.19921e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666115772756
# initial  temperature: 1.305E+02
# Successful iteration[    0]: (1.193e+13) 1.193e+13 / 1.193e+13
# End in 1 iterations: 1.19321e+13 / 1.19321e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666116703693
# initial  temperature: 1.314E+02
# Successful iteration[    0]: (1.187e+13) 1.187e+13 / 1.187e+13
# End in 1 iterations: 1.18724e+13 / 1.18724e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666117637881
# initial  temperature: 1.323E+02
# Successful iteration[    0]: (1.181e+13) 1.181e+13 / 1.181e+13
# End in 1 iterations: 1.18131e+13 / 1.18131e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666118574209
# initial  temperature: 1.332E+02
# Successful iteration[    0]: (1.175e+13) 1.175e+13 / 1.175e+13
# End in 1 iterations: 1.17540e+13 / 1.17540e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666119512249
# initial  temperature: 1.340E+02
# Successful iteration[    0]: (1.170e+13) 1.170e+13 / 1.170e+13
# End in 1 iterations: 1.16952e+13 / 1.16952e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666120450453
# initial  temperature: 1.349E+02
# Successful iteration[    0]: (1.164e+13) 1.164e+13 / 1.164e+13
# End in 1 iterations: 1.16368e+13 / 1.16368e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666121392752
# initial  temperature: 1.358E+02
# Successful iteration[    0]: (1.158e+13) 1.158e+13 / 1.158e+13
# End in 1 iterations: 1.15786e+13 / 1.15786e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666122333022
# initial  temperature: 1.367E+02
# Successful iteration[    0]: (1.152e+13) 1.152e+13 / 1.152e+13
# End in 1 iterations: 1.15207e+13 / 1.15207e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666123276618
# initial  temperature: 1.377E+02
# Successful iteration[    0]: (1.146e+13) 1.146e+13 / 1.146e+13
# End in 1 iterations: 1.14631e+13 / 1.14631e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666124219762
# initial  temperature: 1.386E+02
# Successful iteration[    0]: (1.141e+13) 1.141e+13 / 1.141e+13
# End in 1 iterations: 1.14058e+13 / 1.14058e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66612516287
# initial  temperature: 1.395E+02
# Successful iteration[    0]: (1.135e+13) 1.135e+13 / 1.135e+13
# End in 1 iterations: 1.13487e+13 / 1.13487e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666126106182
# initial  temperature: 1.404E+02
# Successful iteration[    0]: (1.129e+13) 1.129e+13 / 1.129e+13
# End in 1 iterations: 1.12920e+13 / 1.12920e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66612704787
# initial  temperature: 1.414E+02
# Successful iteration[    0]: (1.124e+13) 1.124e+13 / 1.124e+13
# End in 1 iterations: 1.12355e+13 / 1.12355e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666127992057
# initial  temperature: 1.423E+02
# Successful iteration[    0]: (1.118e+13) 1.118e+13 / 1.118e+13
# End in 1 iterations: 1.11794e+13 / 1.11794e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666128931574
# initial  temperature: 1.433E+02
# Successful iteration[    0]: (1.112e+13) 1.112e+13 / 1.112e+13
# End in 1 iterations: 1.11235e+13 / 1.11235e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666129876263
# initial  temperature: 1.442E+02
# Successful iteration[    0]: (1.107e+13) 1.107e+13 / 1.107e+13
# End in 1 iterations: 1.10678e+13 / 1.10678e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666130814993
# initial  temperature: 1.452E+02
# Successful iteration[    0]: (1.101e+13) 1.101e+13 / 1.101e+13
# End in 1 iterations: 1.10125e+13 / 1.10125e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666131754851
# initial  temperature: 1.461E+02
# Successful iteration[    0]: (1.096e+13) 1.096e+13 / 1.096e+13
# End in 1 iterations: 1.09574e+13 / 1.09574e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66613268978
# initial  temperature: 1.471E+02
# Successful iteration[    0]: (1.090e+13) 1.090e+13 / 1.090e+13
# End in 1 iterations: 1.09027e+13 / 1.09027e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666133624995
# initial  temperature: 1.481E+02
# Successful iteration[    0]: (1.085e+13) 1.085e+13 / 1.085e+13
# End in 1 iterations: 1.08481e+13 / 1.08481e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666134559595
# initial  temperature: 1.491E+02
# Successful iteration[    0]: (1.079e+13) 1.079e+13 / 1.079e+13
# End in 1 iterations: 1.07939e+13 / 1.07939e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666135489965
# initial  temperature: 1.501E+02
# Successful iteration[    0]: (1.074e+13) 1.074e+13 / 1.074e+13
# End in 1 iterations: 1.07399e+13 / 1.07399e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666136416687
# initial  temperature: 1.511E+02
# Successful iteration[    0]: (1.069e+13) 1.069e+13 / 1.069e+13
# End in 1 iterations: 1.06862e+13 / 1.06862e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666137342606
# initial  temperature: 1.521E+02
# Successful iteration[    0]: (1.063e+13) 1.063e+13 / 1.063e+13
# End in 1 iterations: 1.06328e+13 / 1.06328e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666138264607
# initial  temperature: 1.531E+02
# Successful iteration[    0]: (1.058e+13) 1.058e+13 / 1.058e+13
# End in 1 iterations: 1.05796e+13 / 1.05796e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666139175286
# initial  temperature: 1.541E+02
# Successful iteration[    0]: (1.053e+13) 1.053e+13 / 1.053e+13
# End in 1 iterations: 1.05267e+13 / 1.05267e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666140097958
# initial  temperature: 1.551E+02
# Successful iteration[    0]: (1.047e+13) 1.047e+13 / 1.047e+13
# End in 1 iterations: 1.04741e+13 / 1.04741e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666141009461
# initial  temperature: 1.562E+02
# Successful iteration[    0]: (1.042e+13) 1.042e+13 / 1.042e+13
# End in 1 iterations: 1.04217e+13 / 1.04217e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666141917903
# initial  temperature: 1.572E+02
# Successful iteration[    0]: (1.037e+13) 1.037e+13 / 1.037e+13
# End in 1 iterations: 1.03696e+13 / 1.03696e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666142816255
# initial  temperature: 1.583E+02
# Successful iteration[    0]: (1.032e+13) 1.032e+13 / 1.032e+13
# End in 1 iterations: 1.03178e+13 / 1.03178e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666143720572
# initial  temperature: 1.593E+02
# Successful iteration[    0]: (1.027e+13) 1.027e+13 / 1.027e+13
# End in 1 iterations: 1.02662e+13 / 1.02662e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666144614616
# initial  temperature: 1.604E+02
# Successful iteration[    0]: (1.021e+13) 1.021e+13 / 1.021e+13
# End in 1 iterations: 1.02149e+13 / 1.02149e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666145505249
# initial  temperature: 1.614E+02
# Successful iteration[    0]: (1.016e+13) 1.016e+13 / 1.016e+13
# End in 1 iterations: 1.01638e+13 / 1.01638e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666146387042
# initial  temperature: 1.625E+02
# Successful iteration[    0]: (1.011e+13) 1.011e+13 / 1.011e+13
# End in 1 iterations: 1.01130e+13 / 1.01130e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666147268919
# initial  temperature: 1.636E+02
# Successful iteration[    0]: (1.006e+13) 1.006e+13 / 1.006e+13
# End in 1 iterations: 1.00624e+13 / 1.00624e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666148142596
# initial  temperature: 1.647E+02
# Successful iteration[    0]: (1.001e+13) 1.001e+13 / 1.001e+13
# End in 1 iterations: 1.00121e+13 / 1.00121e+13 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666149012575
# initial  temperature: 1.658E+02
# Successful iteration[    0]: (9.962e+12) 9.962e+12 / 9.962e+12
# End in 1 iterations: 9.96203e+12 / 9.96203e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666149870338
# initial  temperature: 1.669E+02
# Successful iteration[    0]: (9.912e+12) 9.912e+12 / 9.912e+12
# End in 1 iterations: 9.91222e+12 / 9.91222e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666150732485
# initial  temperature: 1.680E+02
# Successful iteration[    0]: (9.863e+12) 9.863e+12 / 9.863e+12
# End in 1 iterations: 9.86266e+12 / 9.86266e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666151583194
# initial  temperature: 1.691E+02
# Successful iteration[    0]: (9.813e+12) 9.813e+12 / 9.813e+12
# End in 1 iterations: 9.81335e+12 / 9.81335e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666152421368
# initial  temperature: 1.702E+02
# Successful iteration[    0]: (9.764e+12) 9.764e+12 / 9.764e+12
# End in 1 iterations: 9.76428e+12 / 9.76428e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666153248034
# initial  temperature: 1.713E+02
# Successful iteration[    0]: (9.715e+12) 9.715e+12 / 9.715e+12
# End in 1 iterations: 9.71546e+12 / 9.71546e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666154097088
# initial  temperature: 1.725E+02
# Successful iteration[    0]: (9.667e+12) 9.667e+12 / 9.667e+12
# End in 1 iterations: 9.66688e+12 / 9.66688e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666154921964
# initial  temperature: 1.736E+02
# Successful iteration[    0]: (9.619e+12) 9.619e+12 / 9.619e+12
# End in 1 iterations: 9.61855e+12 / 9.61855e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666155739059
# initial  temperature: 1.748E+02
# Successful iteration[    0]: (9.570e+12) 9.570e+12 / 9.570e+12
# End in 1 iterations: 9.57046e+12 / 9.57046e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666156547763
# initial  temperature: 1.759E+02
# Successful iteration[    0]: (9.523e+12) 9.523e+12 / 9.523e+12
# End in 1 iterations: 9.52260e+12 / 9.52260e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666157351019
# initial  temperature: 1.771E+02
# Successful iteration[    0]: (9.475e+12) 9.475e+12 / 9.475e+12
# End in 1 iterations: 9.47499e+12 / 9.47499e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666158147204
# initial  temperature: 1.783E+02
# Successful iteration[    0]: (9.428e+12) 9.428e+12 / 9.428e+12
# End in 1 iterations: 9.42761e+12 / 9.42761e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666158935906
# initial  temperature: 1.795E+02
# Successful iteration[    0]: (9.380e+12) 9.380e+12 / 9.380e+12
# End in 1 iterations: 9.38048e+12 / 9.38048e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666159715553
# initial  temperature: 1.806E+02
# Successful iteration[    0]: (9.334e+12) 9.334e+12 / 9.334e+12
# End in 1 iterations: 9.33357e+12 / 9.33357e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666160487135
# initial  temperature: 1.818E+02
# Successful iteration[    0]: (9.287e+12) 9.287e+12 / 9.287e+12
# End in 1 iterations: 9.28691e+12 / 9.28691e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666161248005
# initial  temperature: 1.830E+02
# Successful iteration[    0]: (9.240e+12) 9.240e+12 / 9.240e+12
# End in 1 iterations: 9.24047e+12 / 9.24047e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666162006385
# initial  temperature: 1.843E+02
# Successful iteration[    0]: (9.194e+12) 9.194e+12 / 9.194e+12
# End in 1 iterations: 9.19427e+12 / 9.19427e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666162753396
# initial  temperature: 1.855E+02
# Successful iteration[    0]: (9.148e+12) 9.148e+12 / 9.148e+12
# End in 1 iterations: 9.14830e+12 / 9.14830e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666163491642
# initial  temperature: 1.867E+02
# Successful iteration[    0]: (9.103e+12) 9.103e+12 / 9.103e+12
# End in 1 iterations: 9.10256e+12 / 9.10256e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66616422015
# initial  temperature: 1.879E+02
# Successful iteration[    0]: (9.057e+12) 9.057e+12 / 9.057e+12
# End in 1 iterations: 9.05704e+12 / 9.05704e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666164943473
# initial  temperature: 1.892E+02
# Successful iteration[    0]: (9.012e+12) 9.012e+12 / 9.012e+12
# End in 1 iterations: 9.01176e+12 / 9.01176e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666165648122
# initial  temperature: 1.904E+02
# Successful iteration[    0]: (8.967e+12) 8.967e+12 / 8.967e+12
# End in 1 iterations: 8.96670e+12 / 8.96670e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666166351772
# initial  temperature: 1.917E+02
# Successful iteration[    0]: (8.922e+12) 8.922e+12 / 8.922e+12
# End in 1 iterations: 8.92187e+12 / 8.92187e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666167051906
# initial  temperature: 1.930E+02
# Successful iteration[    0]: (8.877e+12) 8.877e+12 / 8.877e+12
# End in 1 iterations: 8.87726e+12 / 8.87726e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666167735697
# initial  temperature: 1.942E+02
# Successful iteration[    0]: (8.833e+12) 8.833e+12 / 8.833e+12
# End in 1 iterations: 8.83287e+12 / 8.83287e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666168411756
# initial  temperature: 1.955E+02
# Successful iteration[    0]: (8.789e+12) 8.789e+12 / 8.789e+12
# End in 1 iterations: 8.78871e+12 / 8.78871e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666169071754
# initial  temperature: 1.968E+02
# Successful iteration[    0]: (8.745e+12) 8.745e+12 / 8.745e+12
# End in 1 iterations: 8.74476e+12 / 8.74476e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666169733232
# initial  temperature: 1.981E+02
# Successful iteration[    0]: (8.701e+12) 8.701e+12 / 8.701e+12
# End in 1 iterations: 8.70104e+12 / 8.70104e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666170379337
# initial  temperature: 1.994E+02
# Successful iteration[    0]: (8.658e+12) 8.658e+12 / 8.658e+12
# End in 1 iterations: 8.65753e+12 / 8.65753e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666171009168
# initial  temperature: 2.007E+02
# Successful iteration[    0]: (8.614e+12) 8.614e+12 / 8.614e+12
# End in 1 iterations: 8.61425e+12 / 8.61425e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666171642322
# initial  temperature: 2.020E+02
# Successful iteration[    0]: (8.571e+12) 8.571e+12 / 8.571e+12
# End in 1 iterations: 8.57118e+12 / 8.57118e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666172251492
# initial  temperature: 2.034E+02
# Successful iteration[    0]: (8.528e+12) 8.528e+12 / 8.528e+12
# End in 1 iterations: 8.52832e+12 / 8.52832e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666172861479
# initial  temperature: 2.047E+02
# Successful iteration[    0]: (8.486e+12) 8.486e+12 / 8.486e+12
# End in 1 iterations: 8.48568e+12 / 8.48568e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666173451865
# initial  temperature: 2.061E+02
# Successful iteration[    0]: (8.443e+12) 8.443e+12 / 8.443e+12
# End in 1 iterations: 8.44325e+12 / 8.44325e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666174043569
# initial  temperature: 2.074E+02
# Successful iteration[    0]: (8.401e+12) 8.401e+12 / 8.401e+12
# End in 1 iterations: 8.40103e+12 / 8.40103e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666174619746
# initial  temperature: 2.088E+02
# Successful iteration[    0]: (8.359e+12) 8.359e+12 / 8.359e+12
# End in 1 iterations: 8.35903e+12 / 8.35903e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66617517746
# initial  temperature: 2.102E+02
# Successful iteration[    0]: (8.317e+12) 8.317e+12 / 8.317e+12
# End in 1 iterations: 8.31723e+12 / 8.31723e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666175737681
# initial  temperature: 2.115E+02
# Successful iteration[    0]: (8.276e+12) 8.276e+12 / 8.276e+12
# End in 1 iterations: 8.27565e+12 / 8.27565e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176283677
# initial  temperature: 2.129E+02
# Successful iteration[    0]: (8.234e+12) 8.234e+12 / 8.234e+12
# End in 1 iterations: 8.23427e+12 / 8.23427e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176817723
# initial  temperature: 2.143E+02
# Successful iteration[    0]: (8.193e+12) 8.193e+12 / 8.193e+12
# End in 1 iterations: 8.19310e+12 / 8.19310e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177342065
# initial  temperature: 2.157E+02
# Successful iteration[    0]: (8.152e+12) 8.152e+12 / 8.152e+12
# End in 1 iterations: 8.15213e+12 / 8.15213e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177854268
# initial  temperature: 2.171E+02
# Successful iteration[    0]: (8.111e+12) 8.111e+12 / 8.111e+12
# End in 1 iterations: 8.11137e+12 / 8.11137e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66617835155
# initial  temperature: 2.186E+02
# Successful iteration[    0]: (8.071e+12) 8.071e+12 / 8.071e+12
# End in 1 iterations: 8.07081e+12 / 8.07081e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178837042
# initial  temperature: 2.200E+02
# Successful iteration[    0]: (8.030e+12) 8.030e+12 / 8.030e+12
# End in 1 iterations: 8.03046e+12 / 8.03046e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179325101
# initial  temperature: 2.214E+02
# Successful iteration[    0]: (7.990e+12) 7.990e+12 / 7.990e+12
# End in 1 iterations: 7.99031e+12 / 7.99031e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179793331
# initial  temperature: 2.229E+02
# Successful iteration[    0]: (7.950e+12) 7.950e+12 / 7.950e+12
# End in 1 iterations: 7.95036e+12 / 7.95036e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180251649
# initial  temperature: 2.244E+02
# Successful iteration[    0]: (7.911e+12) 7.911e+12 / 7.911e+12
# End in 1 iterations: 7.91060e+12 / 7.91060e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180698481
# initial  temperature: 2.258E+02
# Successful iteration[    0]: (7.871e+12) 7.871e+12 / 7.871e+12
# End in 1 iterations: 7.87105e+12 / 7.87105e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181131991
# initial  temperature: 2.273E+02
# Successful iteration[    0]: (7.832e+12) 7.832e+12 / 7.832e+12
# End in 1 iterations: 7.83170e+12 / 7.83170e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181559814
# initial  temperature: 2.288E+02
# Successful iteration[    0]: (7.793e+12) 7.793e+12 / 7.793e+12
# End in 1 iterations: 7.79254e+12 / 7.79254e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181972835
# initial  temperature: 2.303E+02
# Successful iteration[    0]: (7.754e+12) 7.754e+12 / 7.754e+12
# End in 1 iterations: 7.75357e+12 / 7.75357e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182371254
# initial  temperature: 2.318E+02
# Successful iteration[    0]: (7.715e+12) 7.715e+12 / 7.715e+12
# End in 1 iterations: 7.71481e+12 / 7.71481e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182768105
# initial  temperature: 2.333E+02
# Successful iteration[    0]: (7.676e+12) 7.676e+12 / 7.676e+12
# End in 1 iterations: 7.67623e+12 / 7.67623e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183143592
# initial  temperature: 2.348E+02
# Successful iteration[    0]: (7.638e+12) 7.638e+12 / 7.638e+12
# End in 1 iterations: 7.63785e+12 / 7.63785e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618351858
# initial  temperature: 2.363E+02
# Successful iteration[    0]: (7.600e+12) 7.600e+12 / 7.600e+12
# End in 1 iterations: 7.59966e+12 / 7.59966e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183878203
# initial  temperature: 2.379E+02
# Successful iteration[    0]: (7.562e+12) 7.562e+12 / 7.562e+12
# End in 1 iterations: 7.56166e+12 / 7.56166e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184220976
# initial  temperature: 2.394E+02
# Successful iteration[    0]: (7.524e+12) 7.524e+12 / 7.524e+12
# End in 1 iterations: 7.52386e+12 / 7.52386e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184555731
# initial  temperature: 2.410E+02
# Successful iteration[    0]: (7.486e+12) 7.486e+12 / 7.486e+12
# End in 1 iterations: 7.48624e+12 / 7.48624e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184882075
# initial  temperature: 2.425E+02
# Successful iteration[    0]: (7.449e+12) 7.449e+12 / 7.449e+12
# End in 1 iterations: 7.44881e+12 / 7.44881e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185196275
# initial  temperature: 2.441E+02
# Successful iteration[    0]: (7.412e+12) 7.412e+12 / 7.412e+12
# End in 1 iterations: 7.41156e+12 / 7.41156e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185507138
# initial  temperature: 2.457E+02
# Successful iteration[    0]: (7.375e+12) 7.375e+12 / 7.375e+12
# End in 1 iterations: 7.37450e+12 / 7.37450e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185794137
# initial  temperature: 2.473E+02
# Successful iteration[    0]: (7.338e+12) 7.338e+12 / 7.338e+12
# End in 1 iterations: 7.33763e+12 / 7.33763e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186078011
# initial  temperature: 2.489E+02
# Successful iteration[    0]: (7.301e+12) 7.301e+12 / 7.301e+12
# End in 1 iterations: 7.30094e+12 / 7.30094e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186352988
# initial  temperature: 2.505E+02
# Successful iteration[    0]: (7.264e+12) 7.264e+12 / 7.264e+12
# End in 1 iterations: 7.26444e+12 / 7.26444e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186613511
# initial  temperature: 2.521E+02
# Successful iteration[    0]: (7.228e+12) 7.228e+12 / 7.228e+12
# End in 1 iterations: 7.22812e+12 / 7.22812e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186861811
# initial  temperature: 2.538E+02
# Successful iteration[    0]: (7.192e+12) 7.192e+12 / 7.192e+12
# End in 1 iterations: 7.19198e+12 / 7.19198e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187093548
# initial  temperature: 2.554E+02
# Successful iteration[    0]: (7.156e+12) 7.156e+12 / 7.156e+12
# End in 1 iterations: 7.15602e+12 / 7.15602e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.6661873281
# initial  temperature: 2.571E+02
# Successful iteration[    0]: (7.120e+12) 7.120e+12 / 7.120e+12
# End in 1 iterations: 7.12024e+12 / 7.12024e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618754759
# initial  temperature: 2.587E+02
# Successful iteration[    0]: (7.085e+12) 7.085e+12 / 7.085e+12
# End in 1 iterations: 7.08463e+12 / 7.08463e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187754081
# initial  temperature: 2.604E+02
# Successful iteration[    0]: (7.049e+12) 7.049e+12 / 7.049e+12
# End in 1 iterations: 7.04921e+12 / 7.04921e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187950628
# initial  temperature: 2.621E+02
# Successful iteration[    0]: (7.014e+12) 7.014e+12 / 7.014e+12
# End in 1 iterations: 7.01396e+12 / 7.01396e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188132308
# initial  temperature: 2.637E+02
# Successful iteration[    0]: (6.979e+12) 6.979e+12 / 6.979e+12
# End in 1 iterations: 6.97890e+12 / 6.97890e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188313458
# initial  temperature: 2.654E+02
# Successful iteration[    0]: (6.944e+12) 6.944e+12 / 6.944e+12
# End in 1 iterations: 6.94400e+12 / 6.94400e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188478533
# initial  temperature: 2.671E+02
# Successful iteration[    0]: (6.909e+12) 6.909e+12 / 6.909e+12
# End in 1 iterations: 6.90928e+12 / 6.90928e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188632909
# initial  temperature: 2.689E+02
# Successful iteration[    0]: (6.875e+12) 6.875e+12 / 6.875e+12
# End in 1 iterations: 6.87473e+12 / 6.87473e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188779188
# initial  temperature: 2.706E+02
# Successful iteration[    0]: (6.840e+12) 6.840e+12 / 6.840e+12
# End in 1 iterations: 6.84036e+12 / 6.84036e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188912304
# initial  temperature: 2.723E+02
# Successful iteration[    0]: (6.806e+12) 6.806e+12 / 6.806e+12
# End in 1 iterations: 6.80616e+12 / 6.80616e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189038528
# initial  temperature: 2.741E+02
# Successful iteration[    0]: (6.772e+12) 6.772e+12 / 6.772e+12
# End in 1 iterations: 6.77213e+12 / 6.77213e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189151885
# initial  temperature: 2.758E+02
# Successful iteration[    0]: (6.738e+12) 6.738e+12 / 6.738e+12
# End in 1 iterations: 6.73827e+12 / 6.73827e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189257178
# initial  temperature: 2.776E+02
# Successful iteration[    0]: (6.705e+12) 6.705e+12 / 6.705e+12
# End in 1 iterations: 6.70458e+12 / 6.70458e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189349256
# initial  temperature: 2.793E+02
# Successful iteration[    0]: (6.671e+12) 6.671e+12 / 6.671e+12
# End in 1 iterations: 6.67105e+12 / 6.67105e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189439482
# initial  temperature: 2.811E+02
# Successful iteration[    0]: (6.638e+12) 6.638e+12 / 6.638e+12
# End in 1 iterations: 6.63770e+12 / 6.63770e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189515818
# initial  temperature: 2.829E+02
# Successful iteration[    0]: (6.605e+12) 6.605e+12 / 6.605e+12
# End in 1 iterations: 6.60451e+12 / 6.60451e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189581664
# initial  temperature: 2.847E+02
# Successful iteration[    0]: (6.571e+12) 6.571e+12 / 6.571e+12
# End in 1 iterations: 6.57149e+12 / 6.57149e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189639405
# initial  temperature: 2.865E+02
# Successful iteration[    0]: (6.539e+12) 6.539e+12 / 6.539e+12
# End in 1 iterations: 6.53863e+12 / 6.53863e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189687501
# initial  temperature: 2.883E+02
# Successful iteration[    0]: (6.506e+12) 6.506e+12 / 6.506e+12
# End in 1 iterations: 6.50594e+12 / 6.50594e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189725685
# initial  temperature: 2.902E+02
# Successful iteration[    0]: (6.473e+12) 6.473e+12 / 6.473e+12
# End in 1 iterations: 6.47341e+12 / 6.47341e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189755657
# initial  temperature: 2.920E+02
# Successful iteration[    0]: (6.441e+12) 6.441e+12 / 6.441e+12
# End in 1 iterations: 6.44104e+12 / 6.44104e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189777646
# initial  temperature: 2.939E+02
# Successful iteration[    0]: (6.409e+12) 6.409e+12 / 6.409e+12
# End in 1 iterations: 6.40883e+12 / 6.40883e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189789841
# initial  temperature: 2.957E+02
# Successful iteration[    0]: (6.377e+12) 6.377e+12 / 6.377e+12
# End in 1 iterations: 6.37679e+12 / 6.37679e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189793424
# initial  temperature: 2.976E+02
# Successful iteration[    0]: (6.345e+12) 6.345e+12 / 6.345e+12
# End in 1 iterations: 6.34491e+12 / 6.34491e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189788665
# initial  temperature: 2.995E+02
# Successful iteration[    0]: (6.313e+12) 6.313e+12 / 6.313e+12
# End in 1 iterations: 6.31318e+12 / 6.31318e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189775663
# initial  temperature: 3.013E+02
# Successful iteration[    0]: (6.282e+12) 6.282e+12 / 6.282e+12
# End in 1 iterations: 6.28162e+12 / 6.28162e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618975387
# initial  temperature: 3.032E+02
# Successful iteration[    0]: (6.250e+12) 6.250e+12 / 6.250e+12
# End in 1 iterations: 6.25021e+12 / 6.25021e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189723895
# initial  temperature: 3.051E+02
# Successful iteration[    0]: (6.219e+12) 6.219e+12 / 6.219e+12
# End in 1 iterations: 6.21896e+12 / 6.21896e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189686229
# initial  temperature: 3.071E+02
# Successful iteration[    0]: (6.188e+12) 6.188e+12 / 6.188e+12
# End in 1 iterations: 6.18786e+12 / 6.18786e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189642085
# initial  temperature: 3.090E+02
# Successful iteration[    0]: (6.157e+12) 6.157e+12 / 6.157e+12
# End in 1 iterations: 6.15692e+12 / 6.15692e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189586083
# initial  temperature: 3.109E+02
# Successful iteration[    0]: (6.126e+12) 6.126e+12 / 6.126e+12
# End in 1 iterations: 6.12614e+12 / 6.12614e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189525006
# initial  temperature: 3.129E+02
# Successful iteration[    0]: (6.096e+12) 6.096e+12 / 6.096e+12
# End in 1 iterations: 6.09551e+12 / 6.09551e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189456922
# initial  temperature: 3.148E+02
# Successful iteration[    0]: (6.065e+12) 6.065e+12 / 6.065e+12
# End in 1 iterations: 6.06503e+12 / 6.06503e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189380322
# initial  temperature: 3.168E+02
# Successful iteration[    0]: (6.035e+12) 6.035e+12 / 6.035e+12
# End in 1 iterations: 6.03470e+12 / 6.03470e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189297157
# initial  temperature: 3.187E+02
# Successful iteration[    0]: (6.005e+12) 6.005e+12 / 6.005e+12
# End in 1 iterations: 6.00453e+12 / 6.00453e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189207081
# initial  temperature: 3.207E+02
# Successful iteration[    0]: (5.975e+12) 5.975e+12 / 5.975e+12
# End in 1 iterations: 5.97451e+12 / 5.97451e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189112596
# initial  temperature: 3.227E+02
# Successful iteration[    0]: (5.945e+12) 5.945e+12 / 5.945e+12
# End in 1 iterations: 5.94464e+12 / 5.94464e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666189006877
# initial  temperature: 3.247E+02
# Successful iteration[    0]: (5.915e+12) 5.915e+12 / 5.915e+12
# End in 1 iterations: 5.91491e+12 / 5.91491e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188894969
# initial  temperature: 3.267E+02
# Successful iteration[    0]: (5.885e+12) 5.885e+12 / 5.885e+12
# End in 1 iterations: 5.88534e+12 / 5.88534e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188776982
# initial  temperature: 3.287E+02
# Successful iteration[    0]: (5.856e+12) 5.856e+12 / 5.856e+12
# End in 1 iterations: 5.85591e+12 / 5.85591e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188654021
# initial  temperature: 3.308E+02
# Successful iteration[    0]: (5.827e+12) 5.827e+12 / 5.827e+12
# End in 1 iterations: 5.82663e+12 / 5.82663e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188540332
# initial  temperature: 3.328E+02
# Successful iteration[    0]: (5.797e+12) 5.797e+12 / 5.797e+12
# End in 1 iterations: 5.79750e+12 / 5.79750e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188390441
# initial  temperature: 3.348E+02
# Successful iteration[    0]: (5.769e+12) 5.769e+12 / 5.769e+12
# End in 1 iterations: 5.76851e+12 / 5.76851e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188247944
# initial  temperature: 3.369E+02
# Successful iteration[    0]: (5.740e+12) 5.740e+12 / 5.740e+12
# End in 1 iterations: 5.73967e+12 / 5.73967e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666188105564
# initial  temperature: 3.389E+02
# Successful iteration[    0]: (5.711e+12) 5.711e+12 / 5.711e+12
# End in 1 iterations: 5.71097e+12 / 5.71097e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187948256
# initial  temperature: 3.410E+02
# Successful iteration[    0]: (5.682e+12) 5.682e+12 / 5.682e+12
# End in 1 iterations: 5.68242e+12 / 5.68242e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187791063
# initial  temperature: 3.431E+02
# Successful iteration[    0]: (5.654e+12) 5.654e+12 / 5.654e+12
# End in 1 iterations: 5.65400e+12 / 5.65400e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618763223
# initial  temperature: 3.452E+02
# Successful iteration[    0]: (5.626e+12) 5.626e+12 / 5.626e+12
# End in 1 iterations: 5.62573e+12 / 5.62573e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187468909
# initial  temperature: 3.473E+02
# Successful iteration[    0]: (5.598e+12) 5.598e+12 / 5.598e+12
# End in 1 iterations: 5.59760e+12 / 5.59760e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187283421
# initial  temperature: 3.494E+02
# Successful iteration[    0]: (5.570e+12) 5.570e+12 / 5.570e+12
# End in 1 iterations: 5.56962e+12 / 5.56962e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666187105818
# initial  temperature: 3.515E+02
# Successful iteration[    0]: (5.542e+12) 5.542e+12 / 5.542e+12
# End in 1 iterations: 5.54177e+12 / 5.54177e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186931285
# initial  temperature: 3.536E+02
# Successful iteration[    0]: (5.514e+12) 5.514e+12 / 5.514e+12
# End in 1 iterations: 5.51406e+12 / 5.51406e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186732069
# initial  temperature: 3.557E+02
# Successful iteration[    0]: (5.486e+12) 5.486e+12 / 5.486e+12
# End in 1 iterations: 5.48649e+12 / 5.48649e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186559987
# initial  temperature: 3.579E+02
# Successful iteration[    0]: (5.459e+12) 5.459e+12 / 5.459e+12
# End in 1 iterations: 5.45906e+12 / 5.45906e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186358225
# initial  temperature: 3.600E+02
# Successful iteration[    0]: (5.432e+12) 5.432e+12 / 5.432e+12
# End in 1 iterations: 5.43176e+12 / 5.43176e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666186149777
# initial  temperature: 3.622E+02
# Successful iteration[    0]: (5.405e+12) 5.405e+12 / 5.405e+12
# End in 1 iterations: 5.40460e+12 / 5.40460e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185955231
# initial  temperature: 3.643E+02
# Successful iteration[    0]: (5.378e+12) 5.378e+12 / 5.378e+12
# End in 1 iterations: 5.37758e+12 / 5.37758e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185732463
# initial  temperature: 3.665E+02
# Successful iteration[    0]: (5.351e+12) 5.351e+12 / 5.351e+12
# End in 1 iterations: 5.35069e+12 / 5.35069e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185530939
# initial  temperature: 3.687E+02
# Successful iteration[    0]: (5.324e+12) 5.324e+12 / 5.324e+12
# End in 1 iterations: 5.32394e+12 / 5.32394e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185307848
# initial  temperature: 3.709E+02
# Successful iteration[    0]: (5.297e+12) 5.297e+12 / 5.297e+12
# End in 1 iterations: 5.29732e+12 / 5.29732e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666185108829
# initial  temperature: 3.731E+02
# Successful iteration[    0]: (5.271e+12) 5.271e+12 / 5.271e+12
# End in 1 iterations: 5.27083e+12 / 5.27083e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184890461
# initial  temperature: 3.753E+02
# Successful iteration[    0]: (5.244e+12) 5.244e+12 / 5.244e+12
# End in 1 iterations: 5.24448e+12 / 5.24448e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184670612
# initial  temperature: 3.775E+02
# Successful iteration[    0]: (5.218e+12) 5.218e+12 / 5.218e+12
# End in 1 iterations: 5.21826e+12 / 5.21826e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184437506
# initial  temperature: 3.797E+02
# Successful iteration[    0]: (5.192e+12) 5.192e+12 / 5.192e+12
# End in 1 iterations: 5.19216e+12 / 5.19216e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666184191566
# initial  temperature: 3.819E+02
# Successful iteration[    0]: (5.166e+12) 5.166e+12 / 5.166e+12
# End in 1 iterations: 5.16620e+12 / 5.16620e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183956004
# initial  temperature: 3.841E+02
# Successful iteration[    0]: (5.140e+12) 5.140e+12 / 5.140e+12
# End in 1 iterations: 5.14037e+12 / 5.14037e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183722118
# initial  temperature: 3.864E+02
# Successful iteration[    0]: (5.115e+12) 5.115e+12 / 5.115e+12
# End in 1 iterations: 5.11467e+12 / 5.11467e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183519753
# initial  temperature: 3.886E+02
# Successful iteration[    0]: (5.089e+12) 5.089e+12 / 5.089e+12
# End in 1 iterations: 5.08910e+12 / 5.08910e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183248943
# initial  temperature: 3.909E+02
# Successful iteration[    0]: (5.064e+12) 5.064e+12 / 5.064e+12
# End in 1 iterations: 5.06365e+12 / 5.06365e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666183014254
# initial  temperature: 3.931E+02
# Successful iteration[    0]: (5.038e+12) 5.038e+12 / 5.038e+12
# End in 1 iterations: 5.03833e+12 / 5.03833e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182777109
# initial  temperature: 3.954E+02
# Successful iteration[    0]: (5.013e+12) 5.013e+12 / 5.013e+12
# End in 1 iterations: 5.01314e+12 / 5.01314e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182539062
# initial  temperature: 3.976E+02
# Successful iteration[    0]: (4.988e+12) 4.988e+12 / 4.988e+12
# End in 1 iterations: 4.98808e+12 / 4.98808e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182288023
# initial  temperature: 3.999E+02
# Successful iteration[    0]: (4.963e+12) 4.963e+12 / 4.963e+12
# End in 1 iterations: 4.96314e+12 / 4.96314e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666182059177
# initial  temperature: 4.022E+02
# Successful iteration[    0]: (4.938e+12) 4.938e+12 / 4.938e+12
# End in 1 iterations: 4.93832e+12 / 4.93832e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181796078
# initial  temperature: 4.045E+02
# Successful iteration[    0]: (4.914e+12) 4.914e+12 / 4.914e+12
# End in 1 iterations: 4.91363e+12 / 4.91363e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181554133
# initial  temperature: 4.068E+02
# Successful iteration[    0]: (4.889e+12) 4.889e+12 / 4.889e+12
# End in 1 iterations: 4.88906e+12 / 4.88906e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181302165
# initial  temperature: 4.091E+02
# Successful iteration[    0]: (4.865e+12) 4.865e+12 / 4.865e+12
# End in 1 iterations: 4.86462e+12 / 4.86462e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666181057357
# initial  temperature: 4.114E+02
# Successful iteration[    0]: (4.840e+12) 4.840e+12 / 4.840e+12
# End in 1 iterations: 4.84029e+12 / 4.84029e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180798547
# initial  temperature: 4.137E+02
# Successful iteration[    0]: (4.816e+12) 4.816e+12 / 4.816e+12
# End in 1 iterations: 4.81609e+12 / 4.81609e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180552396
# initial  temperature: 4.160E+02
# Successful iteration[    0]: (4.792e+12) 4.792e+12 / 4.792e+12
# End in 1 iterations: 4.79201e+12 / 4.79201e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666180287868
# initial  temperature: 4.183E+02
# Successful iteration[    0]: (4.768e+12) 4.768e+12 / 4.768e+12
# End in 1 iterations: 4.76805e+12 / 4.76805e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66618004066
# initial  temperature: 4.206E+02
# Successful iteration[    0]: (4.744e+12) 4.744e+12 / 4.744e+12
# End in 1 iterations: 4.74421e+12 / 4.74421e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66617980754
# initial  temperature: 4.229E+02
# Successful iteration[    0]: (4.720e+12) 4.720e+12 / 4.720e+12
# End in 1 iterations: 4.72049e+12 / 4.72049e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179541488
# initial  temperature: 4.253E+02
# Successful iteration[    0]: (4.697e+12) 4.697e+12 / 4.697e+12
# End in 1 iterations: 4.69689e+12 / 4.69689e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179275725
# initial  temperature: 4.276E+02
# Successful iteration[    0]: (4.673e+12) 4.673e+12 / 4.673e+12
# End in 1 iterations: 4.67340e+12 / 4.67340e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666179022633
# initial  temperature: 4.299E+02
# Successful iteration[    0]: (4.650e+12) 4.650e+12 / 4.650e+12
# End in 1 iterations: 4.65003e+12 / 4.65003e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178771306
# initial  temperature: 4.323E+02
# Successful iteration[    0]: (4.627e+12) 4.627e+12 / 4.627e+12
# End in 1 iterations: 4.62678e+12 / 4.62678e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.66617852929
# initial  temperature: 4.346E+02
# Successful iteration[    0]: (4.604e+12) 4.604e+12 / 4.604e+12
# End in 1 iterations: 4.60365e+12 / 4.60365e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178266605
# initial  temperature: 4.369E+02
# Successful iteration[    0]: (4.581e+12) 4.581e+12 / 4.581e+12
# End in 1 iterations: 4.58063e+12 / 4.58063e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666178015052
# initial  temperature: 4.393E+02
# Successful iteration[    0]: (4.558e+12) 4.558e+12 / 4.558e+12
# End in 1 iterations: 4.55773e+12 / 4.55773e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177766991
# initial  temperature: 4.416E+02
# Successful iteration[    0]: (4.535e+12) 4.535e+12 / 4.535e+12
# End in 1 iterations: 4.53494e+12 / 4.53494e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177516572
# initial  temperature: 4.440E+02
# Successful iteration[    0]: (4.512e+12) 4.512e+12 / 4.512e+12
# End in 1 iterations: 4.51227e+12 / 4.51227e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177298435
# initial  temperature: 4.463E+02
# Successful iteration[    0]: (4.490e+12) 4.490e+12 / 4.490e+12
# End in 1 iterations: 4.48970e+12 / 4.48970e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666177053416
# initial  temperature: 4.487E+02
# Successful iteration[    0]: (4.467e+12) 4.467e+12 / 4.467e+12
# End in 1 iterations: 4.46726e+12 / 4.46726e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176785591
# initial  temperature: 4.510E+02
# Successful iteration[    0]: (4.445e+12) 4.445e+12 / 4.445e+12
# End in 1 iterations: 4.44492e+12 / 4.44492e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176549158
# initial  temperature: 4.534E+02
# Successful iteration[    0]: (4.423e+12) 4.423e+12 / 4.423e+12
# End in 1 iterations: 4.42270e+12 / 4.42270e+12 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.666176360557
# initial  temperature: 4.557E+02
# Successful iteration[    0]: (4.401e+12) 4.401e+12 / 4.401e+12
# ...
# Successful iteration[    0]: (6.825e+05) 6.825e+05 / 6.825e+05
# End in 1 iterations: 6.82506e+05 / 6.82506e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431130891053
# initial  temperature: 9.236E+02
# Successful iteration[    0]: (6.791e+05) 6.791e+05 / 6.791e+05
# End in 1 iterations: 6.79094e+05 / 6.79094e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431113813233
# initial  temperature: 9.245E+02
# Successful iteration[    0]: (6.757e+05) 6.757e+05 / 6.757e+05
# End in 1 iterations: 6.75698e+05 / 6.75698e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431093930292
# initial  temperature: 9.253E+02
# Successful iteration[    0]: (6.723e+05) 6.723e+05 / 6.723e+05
# End in 1 iterations: 6.72320e+05 / 6.72320e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431076993539
# initial  temperature: 9.262E+02
# Successful iteration[    0]: (6.690e+05) 6.690e+05 / 6.690e+05
# End in 1 iterations: 6.68958e+05 / 6.68958e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431059913487
# initial  temperature: 9.271E+02
# Successful iteration[    0]: (6.656e+05) 6.656e+05 / 6.656e+05
# End in 1 iterations: 6.65613e+05 / 6.65613e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431043104084
# initial  temperature: 9.280E+02
# Successful iteration[    0]: (6.623e+05) 6.623e+05 / 6.623e+05
# End in 1 iterations: 6.62285e+05 / 6.62285e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431022964024
# initial  temperature: 9.289E+02
# Successful iteration[    0]: (6.590e+05) 6.590e+05 / 6.590e+05
# End in 1 iterations: 6.58974e+05 / 6.58974e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.431005757625
# initial  temperature: 9.297E+02
# Successful iteration[    0]: (6.557e+05) 6.557e+05 / 6.557e+05
# End in 1 iterations: 6.55679e+05 / 6.55679e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43098745913
# initial  temperature: 9.306E+02
# Successful iteration[    0]: (6.524e+05) 6.524e+05 / 6.524e+05
# End in 1 iterations: 6.52401e+05 / 6.52401e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430974039175
# initial  temperature: 9.315E+02
# Successful iteration[    0]: (6.491e+05) 6.491e+05 / 6.491e+05
# End in 1 iterations: 6.49139e+05 / 6.49139e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430961428911
# initial  temperature: 9.324E+02
# Successful iteration[    0]: (6.459e+05) 6.459e+05 / 6.459e+05
# End in 1 iterations: 6.45893e+05 / 6.45893e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430938485694
# initial  temperature: 9.333E+02
# Successful iteration[    0]: (6.427e+05) 6.427e+05 / 6.427e+05
# End in 1 iterations: 6.42664e+05 / 6.42664e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430919373724
# initial  temperature: 9.342E+02
# Successful iteration[    0]: (6.395e+05) 6.395e+05 / 6.395e+05
# End in 1 iterations: 6.39450e+05 / 6.39450e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430903871192
# initial  temperature: 9.351E+02
# Successful iteration[    0]: (6.363e+05) 6.363e+05 / 6.363e+05
# End in 1 iterations: 6.36253e+05 / 6.36253e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430886601893
# initial  temperature: 9.361E+02
# Successful iteration[    0]: (6.331e+05) 6.331e+05 / 6.331e+05
# End in 1 iterations: 6.33072e+05 / 6.33072e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430872428707
# initial  temperature: 9.370E+02
# Successful iteration[    0]: (6.299e+05) 6.299e+05 / 6.299e+05
# End in 1 iterations: 6.29906e+05 / 6.29906e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430854120121
# initial  temperature: 9.379E+02
# Successful iteration[    0]: (6.268e+05) 6.268e+05 / 6.268e+05
# End in 1 iterations: 6.26757e+05 / 6.26757e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430835223181
# initial  temperature: 9.388E+02
# Successful iteration[    0]: (6.236e+05) 6.236e+05 / 6.236e+05
# End in 1 iterations: 6.23623e+05 / 6.23623e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43082021178
# initial  temperature: 9.397E+02
# Successful iteration[    0]: (6.205e+05) 6.205e+05 / 6.205e+05
# End in 1 iterations: 6.20505e+05 / 6.20505e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43080292585
# initial  temperature: 9.407E+02
# Successful iteration[    0]: (6.174e+05) 6.174e+05 / 6.174e+05
# End in 1 iterations: 6.17402e+05 / 6.17402e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430786572967
# initial  temperature: 9.416E+02
# Successful iteration[    0]: (6.143e+05) 6.143e+05 / 6.143e+05
# End in 1 iterations: 6.14315e+05 / 6.14315e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430775250951
# initial  temperature: 9.425E+02
# Successful iteration[    0]: (6.112e+05) 6.112e+05 / 6.112e+05
# End in 1 iterations: 6.11244e+05 / 6.11244e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430754367267
# initial  temperature: 9.435E+02
# Successful iteration[    0]: (6.082e+05) 6.082e+05 / 6.082e+05
# End in 1 iterations: 6.08188e+05 / 6.08188e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43074176471
# initial  temperature: 9.444E+02
# Successful iteration[    0]: (6.051e+05) 6.051e+05 / 6.051e+05
# End in 1 iterations: 6.05147e+05 / 6.05147e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43072656154
# initial  temperature: 9.453E+02
# Successful iteration[    0]: (6.021e+05) 6.021e+05 / 6.021e+05
# End in 1 iterations: 6.02121e+05 / 6.02121e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430709438431
# initial  temperature: 9.463E+02
# Successful iteration[    0]: (5.991e+05) 5.991e+05 / 5.991e+05
# End in 1 iterations: 5.99110e+05 / 5.99110e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430692777561
# initial  temperature: 9.472E+02
# Successful iteration[    0]: (5.961e+05) 5.961e+05 / 5.961e+05
# End in 1 iterations: 5.96115e+05 / 5.96115e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430679181128
# initial  temperature: 9.482E+02
# Successful iteration[    0]: (5.931e+05) 5.931e+05 / 5.931e+05
# End in 1 iterations: 5.93134e+05 / 5.93134e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430660552878
# initial  temperature: 9.492E+02
# Successful iteration[    0]: (5.902e+05) 5.902e+05 / 5.902e+05
# End in 1 iterations: 5.90168e+05 / 5.90168e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430646282753
# initial  temperature: 9.501E+02
# Successful iteration[    0]: (5.872e+05) 5.872e+05 / 5.872e+05
# End in 1 iterations: 5.87218e+05 / 5.87218e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430629450172
# initial  temperature: 9.511E+02
# Successful iteration[    0]: (5.843e+05) 5.843e+05 / 5.843e+05
# End in 1 iterations: 5.84282e+05 / 5.84282e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43061217948
# initial  temperature: 9.520E+02
# Successful iteration[    0]: (5.814e+05) 5.814e+05 / 5.814e+05
# End in 1 iterations: 5.81360e+05 / 5.81360e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430601056387
# initial  temperature: 9.530E+02
# Successful iteration[    0]: (5.785e+05) 5.785e+05 / 5.785e+05
# End in 1 iterations: 5.78453e+05 / 5.78453e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430583044759
# initial  temperature: 9.540E+02
# Successful iteration[    0]: (5.756e+05) 5.756e+05 / 5.756e+05
# End in 1 iterations: 5.75561e+05 / 5.75561e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430570630866
# initial  temperature: 9.550E+02
# Successful iteration[    0]: (5.727e+05) 5.727e+05 / 5.727e+05
# End in 1 iterations: 5.72683e+05 / 5.72683e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430553477353
# initial  temperature: 9.559E+02
# Successful iteration[    0]: (5.698e+05) 5.698e+05 / 5.698e+05
# End in 1 iterations: 5.69820e+05 / 5.69820e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430537317961
# initial  temperature: 9.569E+02
# Successful iteration[    0]: (5.670e+05) 5.670e+05 / 5.670e+05
# End in 1 iterations: 5.66971e+05 / 5.66971e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430524638322
# initial  temperature: 9.579E+02
# Successful iteration[    0]: (5.641e+05) 5.641e+05 / 5.641e+05
# End in 1 iterations: 5.64136e+05 / 5.64136e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430509950951
# initial  temperature: 9.589E+02
# Successful iteration[    0]: (5.613e+05) 5.613e+05 / 5.613e+05
# End in 1 iterations: 5.61315e+05 / 5.61315e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430491658361
# initial  temperature: 9.599E+02
# Successful iteration[    0]: (5.585e+05) 5.585e+05 / 5.585e+05
# End in 1 iterations: 5.58509e+05 / 5.58509e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430476444641
# initial  temperature: 9.609E+02
# Successful iteration[    0]: (5.557e+05) 5.557e+05 / 5.557e+05
# End in 1 iterations: 5.55716e+05 / 5.55716e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.4304635464
# initial  temperature: 9.619E+02
# Successful iteration[    0]: (5.529e+05) 5.529e+05 / 5.529e+05
# End in 1 iterations: 5.52938e+05 / 5.52938e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430447429221
# initial  temperature: 9.629E+02
# Successful iteration[    0]: (5.502e+05) 5.502e+05 / 5.502e+05
# End in 1 iterations: 5.50173e+05 / 5.50173e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43043662922
# initial  temperature: 9.639E+02
# Successful iteration[    0]: (5.474e+05) 5.474e+05 / 5.474e+05
# End in 1 iterations: 5.47422e+05 / 5.47422e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430420489894
# initial  temperature: 9.649E+02
# Successful iteration[    0]: (5.447e+05) 5.447e+05 / 5.447e+05
# End in 1 iterations: 5.44685e+05 / 5.44685e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430403062135
# initial  temperature: 9.659E+02
# Successful iteration[    0]: (5.420e+05) 5.420e+05 / 5.420e+05
# End in 1 iterations: 5.41961e+05 / 5.41961e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430389042947
# initial  temperature: 9.669E+02
# Successful iteration[    0]: (5.393e+05) 5.393e+05 / 5.393e+05
# End in 1 iterations: 5.39252e+05 / 5.39252e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430374239701
# initial  temperature: 9.679E+02
# Successful iteration[    0]: (5.366e+05) 5.366e+05 / 5.366e+05
# End in 1 iterations: 5.36555e+05 / 5.36555e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430362905375
# initial  temperature: 9.689E+02
# Successful iteration[    0]: (5.339e+05) 5.339e+05 / 5.339e+05
# End in 1 iterations: 5.33873e+05 / 5.33873e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430347235772
# initial  temperature: 9.700E+02
# Successful iteration[    0]: (5.312e+05) 5.312e+05 / 5.312e+05
# End in 1 iterations: 5.31203e+05 / 5.31203e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430331988952
# initial  temperature: 9.710E+02
# Successful iteration[    0]: (5.285e+05) 5.285e+05 / 5.285e+05
# End in 1 iterations: 5.28547e+05 / 5.28547e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430317382047
# initial  temperature: 9.720E+02
# Successful iteration[    0]: (5.259e+05) 5.259e+05 / 5.259e+05
# End in 1 iterations: 5.25904e+05 / 5.25904e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43030428141
# initial  temperature: 9.730E+02
# Successful iteration[    0]: (5.233e+05) 5.233e+05 / 5.233e+05
# End in 1 iterations: 5.23275e+05 / 5.23275e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430290872384
# initial  temperature: 9.741E+02
# Successful iteration[    0]: (5.207e+05) 5.207e+05 / 5.207e+05
# End in 1 iterations: 5.20659e+05 / 5.20659e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.43027432705
# initial  temperature: 9.751E+02
# Successful iteration[    0]: (5.181e+05) 5.181e+05 / 5.181e+05
# End in 1 iterations: 5.18055e+05 / 5.18055e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430262722182
# initial  temperature: 9.761E+02
# Successful iteration[    0]: (5.155e+05) 5.155e+05 / 5.155e+05
# End in 1 iterations: 5.15465e+05 / 5.15465e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430249129267
# initial  temperature: 9.772E+02
# Successful iteration[    0]: (5.129e+05) 5.129e+05 / 5.129e+05
# End in 1 iterations: 5.12888e+05 / 5.12888e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430233712648
# initial  temperature: 9.782E+02
# Successful iteration[    0]: (5.103e+05) 5.103e+05 / 5.103e+05
# End in 1 iterations: 5.10323e+05 / 5.10323e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430218331923
# initial  temperature: 9.793E+02
# Successful iteration[    0]: (5.078e+05) 5.078e+05 / 5.078e+05
# End in 1 iterations: 5.07772e+05 / 5.07772e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430208328943
# initial  temperature: 9.803E+02
# Successful iteration[    0]: (5.052e+05) 5.052e+05 / 5.052e+05
# End in 1 iterations: 5.05233e+05 / 5.05233e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430191034082
# initial  temperature: 9.814E+02
# Successful iteration[    0]: (5.027e+05) 5.027e+05 / 5.027e+05
# End in 1 iterations: 5.02707e+05 / 5.02707e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430176541864
# initial  temperature: 9.824E+02
# Successful iteration[    0]: (5.002e+05) 5.002e+05 / 5.002e+05
# End in 1 iterations: 5.00193e+05 / 5.00193e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430163109059
# initial  temperature: 9.835E+02
# Successful iteration[    0]: (4.977e+05) 4.977e+05 / 4.977e+05
# End in 1 iterations: 4.97692e+05 / 4.97692e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430148535274
# initial  temperature: 9.845E+02
# Successful iteration[    0]: (4.952e+05) 4.952e+05 / 4.952e+05
# End in 1 iterations: 4.95204e+05 / 4.95204e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430137399539
# initial  temperature: 9.856E+02
# Successful iteration[    0]: (4.927e+05) 4.927e+05 / 4.927e+05
# End in 1 iterations: 4.92728e+05 / 4.92728e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430121432731
# initial  temperature: 9.867E+02
# Successful iteration[    0]: (4.903e+05) 4.903e+05 / 4.903e+05
# End in 1 iterations: 4.90264e+05 / 4.90264e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430108242882
# initial  temperature: 9.877E+02
# Successful iteration[    0]: (4.878e+05) 4.878e+05 / 4.878e+05
# End in 1 iterations: 4.87813e+05 / 4.87813e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430093855645
# initial  temperature: 9.888E+02
# Successful iteration[    0]: (4.854e+05) 4.854e+05 / 4.854e+05
# End in 1 iterations: 4.85374e+05 / 4.85374e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430084867274
# initial  temperature: 9.899E+02
# Successful iteration[    0]: (4.829e+05) 4.829e+05 / 4.829e+05
# End in 1 iterations: 4.82947e+05 / 4.82947e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430067446764
# initial  temperature: 9.910E+02
# Successful iteration[    0]: (4.805e+05) 4.805e+05 / 4.805e+05
# End in 1 iterations: 4.80532e+05 / 4.80532e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430055979271
# initial  temperature: 9.920E+02
# Successful iteration[    0]: (4.781e+05) 4.781e+05 / 4.781e+05
# End in 1 iterations: 4.78129e+05 / 4.78129e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430042168943
# initial  temperature: 9.931E+02
# Successful iteration[    0]: (4.757e+05) 4.757e+05 / 4.757e+05
# End in 1 iterations: 4.75739e+05 / 4.75739e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430026619679
# initial  temperature: 9.942E+02
# Successful iteration[    0]: (4.734e+05) 4.734e+05 / 4.734e+05
# End in 1 iterations: 4.73360e+05 / 4.73360e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.430012311591
# initial  temperature: 9.953E+02
# Successful iteration[    0]: (4.710e+05) 4.710e+05 / 4.710e+05
# End in 1 iterations: 4.70993e+05 / 4.70993e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.429999243538
# initial  temperature: 9.964E+02
# Successful iteration[    0]: (4.686e+05) 4.686e+05 / 4.686e+05
# End in 1 iterations: 4.68638e+05 / 4.68638e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.42998816611
# initial  temperature: 9.975E+02
# Successful iteration[    0]: (4.663e+05) 4.663e+05 / 4.663e+05
# End in 1 iterations: 4.66295e+05 / 4.66295e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.429974645471
# initial  temperature: 9.986E+02
# Successful iteration[    0]: (4.640e+05) 4.640e+05 / 4.640e+05
# End in 1 iterations: 4.63964e+05 / 4.63964e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.429959225259
# initial  temperature: 9.997E+02
# Successful iteration[    0]: (4.616e+05) 4.616e+05 / 4.616e+05
# End in 1 iterations: 4.61644e+05 / 4.61644e+05 (0.00000e+00)
# force_factor: 0.0
# gammma - 1: 0.429945645009
# initial  temperature: 1.001E+03
# Successful iteration[    0]: (4.593e+05) 4.593e+05 / 4.593e+05
# End in 1 iterations: 4.59336e+05 / 4.59336e+05 (0.00000e+00)

# %%
dir_ff_grackle = "/home/kwoksun2/grackle/src/python/examples/freefall.h5"
import h5py
f = h5py.File(dir_ff_grackle)
fdata = f['data']
grackle_T = fdata['temperature'].value
grackle_rho = fdata['density'].value
grackle_data = convert_from_grackle_to_dengo_all(fdata)
f.close()

# %%
plt.figure(dpi=200)
plt.loglog(density_array[1:]* u.amu.v, all_data['T'], label='dengo   freefall')
plt.loglog(grackle_rho, grackle_T, label='grackle freefall')
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel('temperature (K)')
plt.legend()

# %%
def get_e_from_all_data(all_data):
    l = len(all_data['de'])
    q = np.zeros((l))
    for sp in primordial.required_species:
        if sp.name not in ['ge', 'de']:
            q += numpy.array(all_data[sp.name])/ sp.weight * sp.free_electrons
    return q

def get_mu_from_all_data(all_data, density_array):
    l = len(all_data['de'])
    n = np.zeros((l))    
    # mass density / number density
    for sp in primordial.required_species:
        if sp.name not in ['ge', 'de']:
            n += numpy.array(all_data[sp.name])/ sp.weight
            
    mu = density_array/ n / 1.00794
    return mu

def get_gamma_from_all_data( all_data ):
    l = len(all_data['de'])
    total_n = np.zeros((l))    
    # mass density / number density
    for sp in primordial.required_species:
        if sp.name not in ['ge', 'de']:
            total_n += numpy.array(all_data[sp.name])/ sp.weight    

    rs = primordial.required_species
    H2_1_sp = list(rs)[0]
    
    gamma_array = np.zeros((l))
    for n in range(l):
        
        temperature = all_data['T'][n]
        num_den = {}
        for sp in primordial.required_species:
            if sp.name != 'ge':
                num_den[sp.name] = numpy.array(all_data[sp.name][n])/ sp.weight   

        gammaH2 = primordial.species_gamma(H2_1_sp,name=False, temp=True).subs({'T':temperature})    
        gamma_factor = primordial.gamma_factor().subs(num_den).subs({'gammaH2': gammaH2 , 
                                                                         'gamma': 5./3.,'T': temperature })
        # gamma_factor = n / (gamma - 1)
        
        gamma = total_n[n] / gamma_factor + 1.0
        gamma_array[n] = gamma
    return gamma_array

# %%
# check conservation of stuff
plt.figure(dpi = 200)
# yerr = 1e-5
# plt.ylim( 1- yerr ,  1+ yerr)
plt.title('conservation of mass/charge density')
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(r'$\rho_x / \rho_0$   /    $ q / de $')


all_H = numpy.array(all_data['H_1']) + all_data['H_2'] + numpy.array(all_data['H2_1']) + numpy.array(all_data['H2_2'])
plt.semilogx( density_array[1:]*u.amu, (all_H / density_array[1:]) / 0.76 , label='Hydrogen' )



all_He = numpy.array(all_data['He_1']) + numpy.array(all_data['He_2']) + numpy.array(all_data['He_3'])
plt.semilogx( density_array[1:]*u.amu, (all_He /density_array[1:]) / 0.24, label='Helium' )




q = get_e_from_all_data(all_data)
de = numpy.array(all_data['de'])

plt.semilogx(density_array[1:]*u.amu, de /q, label='charge ratios' )

plt.legend()
plt.show()

# %%
# check conservation of stuff
plt.figure(dpi = 100)
yerr = 1e-5
plt.ylim( 1- yerr ,  1+ yerr)
plt.title('Conservation of mass/charge density')
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(r'$\rho_x / \rho_0$')

plt.gca().set_prop_cycle(None)

all_H_gra = numpy.array(grackle_data['H_1']) + numpy.array(grackle_data['H2_1']) + numpy.array(grackle_data['H2_2'])
plt.semilogx( density_array[1:]*u.amu, (all_H_gra / density_array[1:]) / (all_H_gra / density_array[1:])[0], 
             label='Hydrogen', ls = '--' )



all_He_gra = numpy.array(grackle_data['He_1']) + numpy.array(grackle_data['He_2']) + numpy.array(grackle_data['He_3'])
plt.semilogx( density_array[1:]*u.amu, (all_He_gra/ density_array[1:]) / (all_He_gra / density_array[1:])[0], 
             label='Helium', ls = '--' )



def get_e_from_all_data(all_data):
    l = len(all_data['de'])
    q = np.zeros((l))
    for sp in primordial.required_species:
        if sp.name not in ['ge', 'de']:
            q += numpy.array(all_data[sp.name])/ sp.weight * sp.free_electrons
    return q

q = get_e_from_all_data(grackle_data)
de = numpy.array(grackle_data['de'])

plt.semilogx(density_array[1:]*u.amu, de /q / 1.00794, label='charge ratios', ls= '--' )

plt.legend()
plt.show()

# %%
### get fractional abundances of H2
plt.figure(dpi =200)

fig, ax1 = plt.subplots(dpi =200)

ax2 = ax1.twinx()

ax1.loglog(density_array[1:]* u.amu.v, all_data['T'], label='dengo   freefall', color='k', ls='--')
ax1.loglog(grackle_rho, grackle_T, label='grackle freefall',color='r')
ax1.set_xlabel('density ($g$ $cm^{-3}$)')
ax1.set_ylabel('Temperature (K)')


ax2.set_ylabel('fractional abundances of $H_2$: $f_{H_2}$ ')
ax2.plot(density_array[1:]* u.amu.v, all_data['H2_1'] / all_H, label='dengo   freefall' ,color='k', ls='--')
ax2.loglog(density_array[1:]* u.amu.v, grackle_data['H2_1'] / all_H_gra, label='grackle  freefall' ,color='r')

ax1.legend()

# %%
plt.figure(dpi=200)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel('fractional abundances of $H_2$: $f_{H_2}$ ')
plt.plot(density_array[1:]* u.amu.v, all_data['H2_1'] / all_H, label='dengo   freefall' )
plt.loglog(density_array[1:]* u.amu.v, grackle_data['H2_1'] / all_H_gra, label='grackle  freefall')
plt.legend()

# %%
plt.figure(dpi =200)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(' mean molecular mass ($\mu$) ')

mu_dengo = get_mu_from_all_data(all_data, density_array[1:])
mu_grackle = get_mu_from_all_data(grackle_data, density_array[:-1])


plt.plot(density_array[1:]* u.amu.v, mu_dengo, label='dengo   freefall' )
plt.semilogx(density_array[1:]* u.amu.v, mu_grackle , label='grackle   freefall' )
plt.legend()
plt.show()

# %%
gamma_dengo = get_gamma_from_all_data( all_data )
gamma_grackle = get_gamma_from_all_data( grackle_data )

# %%
plt.figure(dpi =100)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(' adiabatic index ($\gamma$) ')

plt.plot(density_array[1:]* u.amu.v, gamma_dengo, label='dengo   freefall' )
plt.semilogx(density_array[:-1]* u.amu.v, gamma_grackle , label='grackle   freefall' )

plt.legend()
plt.show()

# %%
plt.figure(dpi=200)
for key in primordial.required_species:
    if key.name not in ['ge'] :
        plt.semilogx(density_array[1:-1]*u.amu, numpy.array(all_data[key.name][:-1] )/ grackle_data[ key.name ][1:],label=key.name )

plt.ylim(0, 2)
# plt.ylim(0.8,1.1)
# plt.xlim(1e-24,1e-22)
plt.legend( loc = 2)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel(r'Fractional Abundance $\rho_{x, dengo} / \rho_{x, grackle})$')
plt.title('')
plt.show()

# %%
plt.figure(dpi = 200)
plt.semilogx(density_array[1:]* u.amu, run_time)
plt.xlabel('density ($g$ $cm^{-3}$)')
plt.ylabel('runtime (s)')
plt.title('dengo runtime (evolve freefall)')
plt.show()

# %%
for cool in primo

# %% [markdown]
# # Performance with N strips

# %%
numpy.sum(run_time)

# %%
plt.gca().set_prop_cycle(None)

# %%
def cooling_rate_from_temp(T):
    cooling_rates = {}
    for action in primordial.cooling_actions.values():
        actionname = action.name
        for tab in action.tables:
            name = "{}_{}[i]".format(actionname, tab)
            
            temp_array = primordial.T
            
            cooling = numpy.interp(T, temp_array, action.tables[tab](primordial))
            cooling_rates[name] = cooling
    cooling_rates['T'] = T
    cooling_rates['z'] = numpy.zeros((len(T)))
#     cooling_rates = sorted(cooling_rates)
    return cooling_rates

def cooling_from_results(results, primordial, cooling_rates, T):
    
    cooling_results = {}

    for action in primordial.cooling_actions:
        cool_action = cooling_registry[action].equation
        cool_sym = cool_action.free_symbols
        
        cool_sym_name = [str(i) for i in cool_sym]
        func = lambdify(cool_sym, cool_action,'numpy') # returns a numpy-ready function
        
        
        num_var = len(cool_sym)
        len_T   = len(T)
        
        input_array = numpy.zeros(( num_var, len_T ))       
        for iii, sym_name in enumerate(cool_sym_name):
            try:
                input_array[iii, :] = results[sym_name]
            except:
                input_array[iii, :] = cooling_rates[sym_name]
        
        
        cooling_results[action] = func(*input_array)
    return cooling_results

# %%
T_array = all_data['T']

cooling_rates = cooling_rate_from_temp(T_array)
cooling_rates['mdensity'] = density_array[1:]
cooling_rates['mh'] = numpy.ones((len(T_array)))* u.mass_hydrogen_cgs.v

cooling_results = cooling_from_results(all_data, primordial, cooling_rates, T_array)


T_array_gra = grackle_data['T']

cooling_rates_gra = cooling_rate_from_temp(T_array_gra)
cooling_rates_gra['mdensity'] = density_array[1:]
cooling_rates_gra['mh'] = numpy.ones((len(T_array_gra)))* u.mass_hydrogen_cgs.v

cooling_results_gra = cooling_from_results(grackle_data, primordial, cooling_rates_gra, T_array_gra)

# %%
f = plt.figure(dpi=200)
ax = plt.subplot(111)

from matplotlib.pyplot import cm
color=cm.tab20(np.linspace(0,1,len(cooling_results.keys()) ))
net_cooling = numpy.zeros((len(T_array)))

iii = 0
for i in sorted(cooling_results.keys()):
    d = cooling_results[i]
    
    net_cooling = d + net_cooling
    if i not in ['gammah']:
        if d[0] < 0:
            ax.semilogx(density_array[1:]*u.amu, numpy.abs(d)/density_array[1:]/ u.amu_cgs.v, label=i,c=color[iii])
        else:
            ax.loglog(density_array[1:]*u.amu, numpy.abs(d)/density_array[1:]/ u.amu_cgs.v, label=i,  c=color[iii])
            
    iii += 1
    
net_cooling_gra = numpy.zeros((len(T_array_gra)))

iii = 0
for i in sorted(cooling_results_gra.keys()):
    d = cooling_results_gra[i]
    
    net_cooling_gra = d + net_cooling_gra
    if i not in ['gammah']:
        if d[0] < 0:
            ax.semilogx(density_array[1:]*u.amu, numpy.abs(d)/density_array[1:]/ u.amu_cgs.v, ls= '--', c=color[iii])
        else:
            ax.loglog(density_array[1:]*u.amu, numpy.abs(d)/density_array[1:]/ u.amu_cgs.v, ls= '--', c=color[iii])
            
    iii += 1    

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
ax.set_xlabel('density (g / $cm^{-3}$)')
ax.set_ylabel(r'cooling rate per gram (erg / g /s)')
# plt.ylim(1e-5,1e5)
plt.gca().set_prop_cycle(None)


plt.show()

plt.figure(dpi=200)
plt.loglog(density_array[1:]*u.amu, numpy.abs(net_cooling)/density_array[1:]/ u.amu_cgs.v, label='dengo freefall')
plt.loglog(density_array[1:]*u.amu, numpy.abs(net_cooling_gra)/density_array[1:]/ u.amu_cgs.v,ls= '--',label='grackle freefall')
# plt.ylim(1e-5,1e5)
plt.legend()
plt.xlabel('density (g / $cm^{-3}$)')
plt.ylabel(r'cooling rate per unit mass (erg / g /s)')
plt.show()
