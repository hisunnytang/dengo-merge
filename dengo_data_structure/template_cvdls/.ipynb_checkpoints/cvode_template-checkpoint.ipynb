# %%
import sys
import yt.units as u
import numpy
import numpy as np
import matplotlib.pyplot as plt
import pyximport

from dengo.chemical_network import \
    ChemicalNetwork, \
    reaction_registry, \
    cooling_registry, species_registry
import dengo.primordial_rates, dengo.primordial_cooling
from dengo.chemistry_constants import tiny, kboltz, mh
import h5py
import os
os.environ['HDF5_DIR'] = '/home/kwoksun2/anaconda2/'
# Out:
#  using cli
#  using CLI for selections

# %%
def Init_values(temperature, density, n_species = 9, cooling=True, size=10):
    """ Create a initial value dictionary,
        for a given temperature, density, number of species
    Args:
        temperature -- in Kelvin
        density     -- in amu / cm**3
        n_species   -- number of species (6/9)
        cooling

    Returns:
        init_values: initial value dictionary with
                     self-consistent energy/ electron density
        primordial : chemical_network classes

    """

    # initialize and setup the network
    dengo.primordial_rates.setup_primordial()
    primordial = ChemicalNetwork()
    primordial.threebody = 4

    if n_species == 9:
        for i in range(22):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass
    else:
        for i in range(6):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass

    # the temperature array required to interpolates the rates
    primordial.init_temperature((1e0, 1e5))

    tiny = 1.0e-20

    # init_array are is in fractional abundances
    init_values = dict()
    density = numpy.array([density])*numpy.ones((size))
    if n_species == 6:
        # 6-species model
        init_values["He_1"]    = density * (1.0 - 0.76)
        init_values["He_2"]    = np.array([tiny])
        init_values["He_3"]    = np.array([tiny])
        init_values["H_1"]     = density *  (0.76)
        init_values['H_2']     = np.array([tiny]) 
    else:
        # 9-species model
        init_values["He_1"]    = density * (1.0 - 0.76) 
        init_values["He_2"]    = density *np.array([tiny])
        init_values["He_3"]    = density *np.array([tiny])
        init_values["H_1"]     = density *  (0.76) /2.0
        init_values['H_2']     = density *np.array([tiny])

        init_values["H_m0"]    = density *np.array([tiny])
        init_values["H2_1"]    = density *  (0.76) /2.0
        init_values["H2_2"]    = density *np.array([tiny])

    # now everything in mass density
    init_values['de'] = primordial.calculate_free_electrons(init_values)
    # one signle value: again mass density
    init_values['density'] = primordial.calculate_total_density(init_values)

    num_den = {}
    for sp in primordial.required_species:
        try:
            num_den[sp.name] = init_values[sp.name]/ sp.weight
        except:
            pass

    # set up initial temperatures values used to define ge
    init_values['T'] = numpy.array([temperature])*numpy.ones((size))
    ge_array = numpy.ones((size))
    init_values['ge'] = ge_array
    
    # calculate gammaH2
    
    for i in range(size):
        
        temperature = init_values['T'][i]
        x = 6100.0/temperature
        expx = numpy.exp(x)
        gammaH2 = 2.0 / (5.0 + 2.0*x*x*expx / (expx - 1 )**2.0 ) + 1

        rs = primordial.required_species
        H2_1_sp = list(rs)[0]
        gammaH2 = primordial.species_gamma(H2_1_sp,name=False, temp=True).subs({'T':temperature})

        new_num_den = {}
        for ele in num_den.keys():
            new_num_den[ele] = num_den[ele][i]
        
        gamma_factor = primordial.gamma_factor().subs(new_num_den).subs({'gammaH2': gammaH2 , 'gamma': 5./3.,'T': temperature })

        ge  = ((temperature *  kboltz) *gamma_factor
                             / (init_values['density'][i] * mh  ))

        
        T = init_values['density']*ge*mh / kboltz / gamma_factor
        init_values['ge'][i] = numpy.float64(ge)

    if cooling:
        for cooling_action in cooling_registry:
            k = cooling_registry[cooling_action]
            if (k.species).issubset( primordial.required_species ):                                    
                print("adding:", k.name, k.equation)
                primordial.add_cooling(cooling_action)
                print('---------------------------')
    return init_values, primordial

# %%
density = 1e14
initial_temperature = 3000.0
final_time = (1.0 / (u.G * u.mass_hydrogen * u.cm**-3 * density)**0.5).in_cgs().v



init, primordial = Init_values(initial_temperature, 
                               density, n_species = 9, 
                               cooling=True,size=1)
primordial.stop_time = final_time
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# ('adding:', 'brem', -brem_brem[i]*de*(H_2 + He_2 + 4.0*He_3))
# ---------------------------
# ('adding:', 'reHII', -H_2*de*reHII_reHII[i])
# ---------------------------
# ('adding:', 'reHeIII', -He_3*de*reHeIII_reHeIII[i])
# ---------------------------
# ('adding:', 'gloverabel08', -H2_1*gloverabel08_h2lte[i]/(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0))
# ---------------------------
# ('adding:', 'ceHI', -H_1*ceHI_ceHI[i]*de)
# ---------------------------
# ('adding:', 'compton', -compton_comp_[i]*de*(z + 1.0)**4*(T - 2.73*z - 2.73))
# ---------------------------
# ('adding:', 'h2formation', 0.5*(h2formation_ncrn[i]/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0)**(-1.0)*(-H2_1*H_1*h2formation_h2mcool[i] + H_1**3*h2formation_h2mheat[i]))
# ---------------------------
# ('adding:', 'reHeII2', -He_2*de*reHeII2_reHeII2[i])
# ---------------------------
# ('adding:', 'reHeII1', -He_2*de*reHeII1_reHeII1[i])
# ---------------------------
# ('adding:', 'ciHeIS', -He_2*ciHeIS_ciHeIS[i]*de**2)
# ---------------------------
# ('adding:', 'ceHeII', -He_2*ceHeII_ceHeII[i]*de)
# ---------------------------
# ('adding:', 'ciHI', -H_1*ciHI_ciHI[i]*de)
# ---------------------------
# ('adding:', 'ceHeI', -He_2*ceHeI_ceHeI[i]*de**2)
# ---------------------------
# ('adding:', 'gammah', 0)
# ---------------------------
# ('adding:', 'cie_cooling', -H2_1*cie_cooling_cieco[i]*mdensity*mh)
# ---------------------------
# ('adding:', 'ciHeI', -He_1*ciHeI_ciHeI[i]*de)
# ---------------------------
# ('adding:', 'ciHeII', -He_2*ciHeII_ciHeII[i]*de)
# ---------------------------

# %%
primordial.species_gamma(H2_1,name=False, temp=True).subs({'T':2000})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-360331a13b66> in <module>()
# ----> 1 primordial.species_gamma(H2_1,name=False, temp=True).subs({'T':2000})
#
# NameError: name 'primordial' is not defined

# %%
mh

# %%
init
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-19f3d006bcd3> in <module>()
# ----> 1 init
#
# NameError: name 'init' is not defined

# %%
f = h5py.File("dlsmem_solution.h5")

qh = f['H_2'].value / 1.00794  - f['H_m0'].value/ 1.00794 + f['H2_2'].value/ 2.01588
qhe = f['He_2'].value / 4.002602  + 2.0*f['He_3'].value / 4.002602
qde = f['de'].value
f.close()
numpy.abs(qh + qhe - qde)/qde
# Out:
# array([1.13726282e-11, 9.70038193e-12, 4.04844243e-12, ...,
#        3.01028268e-12, 3.41886976e-12, 3.82722584e-12])

# %%
f = h5py.File("dlsmem_solution.h5")
print(f['H2_1'].value)
f.close()
# Out:
# [72243218.82079278 72263703.44603842 72269701.24657468 ...
#  72245706.70880678 72267311.692342   72263448.28718175]

# %%
(qh+qhe - qde) / qde

# %%
import h5py

# %%
qde/(qh+qhe)

# %%
init
# Out:
# {'H2_1': array([3.8e+13, 3.8e+13, 3.8e+13, 3.8e+13, 3.8e+13, 3.8e+13, 3.8e+13,
#         3.8e+13, 3.8e+13, 3.8e+13]),
#  'H2_2': array([1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06,
#         1.e-06, 1.e-06]),
#  'H_1': array([3.8e+13, 3.8e+13, 3.8e+13, 3.8e+13, 3.8e+13, 3.8e+13, 3.8e+13,
#         3.8e+13, 3.8e+13, 3.8e+13]),
#  'H_2': array([1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06,
#         1.e-06, 1.e-06]),
#  'H_m0': array([1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06,
#         1.e-06, 1.e-06]),
#  'He_1': array([2.4e+13, 2.4e+13, 2.4e+13, 2.4e+13, 2.4e+13, 2.4e+13, 2.4e+13,
#         2.4e+13, 2.4e+13, 2.4e+13]),
#  'He_2': array([1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06,
#         1.e-06, 1.e-06]),
#  'He_3': array([1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06, 1.e-06,
#         1.e-06, 1.e-06]),
#  'T': array([3000., 3000., 3000., 3000., 3000., 3000., 3000., 3000., 3000.,
#         3000.]),
#  'de': array([1.24557372e-06, 1.24557372e-06, 1.24557372e-06, 1.24557372e-06,
#         1.24557372e-06, 1.24557372e-06, 1.24557372e-06, 1.24557372e-06,
#         1.24557372e-06, 1.24557372e-06]),
#  'density': array([1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14,
#         1.e+14, 1.e+14]),
#  'ge': array([2.89870372e+11, 2.89870372e+11, 2.89870372e+11, 2.89870372e+11,
#         2.89870372e+11, 2.89870372e+11, 2.89870372e+11, 2.89870372e+11,
#         2.89870372e+11, 2.89870372e+11])}

# %%
solver_name = "dlsmem"

primordial.write_solver(solver_name, output_dir = ".",
    solver_template = "cvdls_n/sundials_CVDls",
    ode_solver_source = "initialize_cvode_solver.C",
    init_values=init,
    input_is_number=False)

# %%
pyximport.install(setup_args={"include_dirs":np.get_include()},
                  reload_support=True, inplace=True)

solver_name = "dlsmem"
# import the pyx module
sundials_cvdls_run = pyximport.load_module("{}_run".format(solver_name),
                "{}_solver_run.pyx".format(solver_name),
                 build_inplace = True, pyxbuild_dir = "_dengo_temp")

# %%
rv,rv_int = sundials_cvdls_run.run_dlsmem(init, 1e10, niter=1000)
# Out:
# initial  temperature: 3.000E+03
# Successful iteration[    0]: (1.000e+07) 1.000e+07 / 1.000e+10
# End in 49 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)

# %%
flag = rv_int['successful']
t = rv_int['t'][flag]

element = rv_int['T'][0][flag]
plt.semilogx(t, element, label=k)

# for k in rv_int.keys():
#     if k not in ['successful','t','dt']:
#         element = rv_int[k][0][flag]
#         plt.loglog(t, element, label=k)
plt.legend()
plt.show()

# %%
# %%timeit
sundials_cvdls_run.run_dlsmem(init, 1e10, niter=1)
# Out:
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# initial  temperature: 2.000E+03
# ttt: 10000000000.0, dt: 10000000000.0, after 0 iteration
# 1076075110.36
# 1076139658.31
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# 1076139396.44
# 1076139688.12
# 1076139397.31
# Successful iteration[    0]: (1.000e+10) 1.000e+10 / 1.000e+10
# End in 1 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# 10 loops, best of 3: 112 ms per loop

# %%
solution
# Out:
# {u'H2_1': array([7.59915656e+13, 7.59915656e+13, 7.59915656e+13, 7.59915656e+13,
#         7.59915656e+13, 7.59915656e+13, 7.59915656e+13, 7.59915656e+13,
#         7.59915656e+13, 7.59915656e+13]),
#  u'H2_2': array([9.18447097e-15, 9.18446574e-15, 9.18446713e-15, 9.18446871e-15,
#         9.18447090e-15, 9.18446623e-15, 9.18446752e-15, 9.18447575e-15,
#         9.18446634e-15, 9.18446507e-15]),
#  u'H_1': array([8.43435595e+09, 8.43435221e+09, 8.43435335e+09, 8.43435416e+09,
#         8.43435601e+09, 8.43435269e+09, 8.43435383e+09, 8.43435744e+09,
#         8.43435292e+09, 8.43435227e+09]),
#  u'H_2': array([1.49999999e-06, 1.49999999e-06, 1.49999999e-06, 1.49999999e-06,
#         1.49999999e-06, 1.49999999e-06, 1.49999999e-06, 1.49999999e-06,
#         1.49999999e-06, 1.49999999e-06]),
#  u'H_m0': array([3.93910995e-13, 3.93910852e-13, 3.93910890e-13, 3.93910933e-13,
#         3.93910993e-13, 3.93910865e-13, 3.93910901e-13, 3.93911126e-13,
#         3.93910868e-13, 3.93910834e-13]),
#  u'He_1': array([2.4e+13, 2.4e+13, 2.4e+13, 2.4e+13, 2.4e+13, 2.4e+13, 2.4e+13,
#         2.4e+13, 2.4e+13, 2.4e+13]),
#  u'He_2': array([1.00000001e-06, 1.00000001e-06, 1.00000001e-06, 1.00000001e-06,
#         1.00000001e-06, 1.00000001e-06, 1.00000001e-06, 1.00000001e-06,
#         1.00000001e-06, 1.00000001e-06]),
#  u'He_3': array([9.99999991e-07, 9.99999991e-07, 9.99999991e-07, 9.99999991e-07,
#         9.99999991e-07, 9.99999991e-07, 9.99999991e-07, 9.99999991e-07,
#         9.99999991e-07, 9.99999991e-07]),
#  u'T': array([596.90187052, 596.90142235, 596.94981791, 596.8410128 ,
#         596.94847029, 596.85396857, 596.91536891, 596.88620993,
#         596.94504996, 596.84139601]),
#  u'de': array([2.23769587e-06, 2.23769587e-06, 2.23769587e-06, 2.23769587e-06,
#         2.23769587e-06, 2.23769587e-06, 2.23769587e-06, 2.23769587e-06,
#         2.23769587e-06, 2.23769587e-06]),
#  u'ge': array([4.98002574e+10, 4.98002422e+10, 4.98002462e+10, 4.98002508e+10,
#         4.98002572e+10, 4.98002436e+10, 4.98002474e+10, 4.98002712e+10,
#         4.98002439e+10, 4.98002403e+10])}

# %%
# !bash runfile

# %%
# !./a.out
# Out:
# Successfully read in rate tables.
# Successfully read in cooling rate tables.
# Successfully read in gamma tables.
# Getting dimensionality from ge:
#   ncells =   1
# Reading I.C. for /H2_1
# H2_1[0] = 3.8e+09, atol =>  3.8
# Reading I.C. for /H2_2
# H2_2[0] = 1e-10, atol =>  3.8
# Reading I.C. for /H_1
# H_1[0] = 3.8e+09, atol =>  3.8
# Reading I.C. for /H_2
# H_2[0] = 1e-10, atol =>  3.8
# Reading I.C. for /H_m0
# H_m0[0] = 1e-10, atol =>  3.8
# Reading I.C. for /He_1
# He_1[0] = 2.4e+09, atol =>  3.8
# Reading I.C. for /He_2
# He_2[0] = 1e-10, atol =>  3.8
# Reading I.C. for /He_3
# He_3[0] = 1e-10, atol =>  3.8
# Reading I.C. for /de
# de[0] = 1.25e-10, atol =>  3.8
# Reading I.C. for /ge
# ge[0] = 2.01e+11, atol =>  3.8
# input dt: 1e+10
ge: 2.0133e+11
# INTERP: 0, bin_id = 675, dT =  0.01125408158843655, T =  1997.170276675992, logT =  7.599486596018208
# H2_1: 3.7053e+07
# T: 1997.2 ; Tnew: 1996.9; dge_dT: 1.009e+08, dge: 2.2734e+07, ge: 2.0133e+11
# T: 1996.9 ; Tnew: 1996.9; dge_dT: 1.009e+08, dge: 18818, ge: 2.0133e+11
# INTERP: 0, bin_id = 675, dT =  0.01125408158843655, T =  1996.944787860275, logT =  7.599373685492441
# H2_1: 3.3846e+07
# T: 1996.9 ; Tnew: 1996.9; dge_dT: 1.009e+08, dge: 87130, ge: 2.0133e+11
# INTERP: 0, bin_id = 675, dT =  0.01125408158843655, T =  1996.943924368573, logT =  7.599373253085949
# H2_1: 3.3831e+07
# dtf: 1e+10; dt_now: 1e+10
# data->scale[0] = 3.5837e+07, y[] = 0.019011
# data->scale[1] = 4.5533e-18, y[] = 9.179e-08
# data->scale[2] = 7.4685e+09, y[] = 1.981
# data->scale[3] = 1.4882e-10, y[] = 1.5
# data->scale[4] = 1.553e-16, y[] = 1.5653e-06
# data->scale[5] = 5.9961e+08, y[] = 1
# data->scale[6] = 2.4984e-11, y[] = 1
# data->scale[7] = 2.4984e-11, y[] = 1
# data->scale[8] = 2.2377e-10, y[] = 1.7965
# data->scale[9] = 2.0133e+11, y[] = 1
# Writing solution for /H2_1
# Writing solution for /H2_2
# Writing solution for /H_1
# Writing solution for /H_2
# Writing solution for /H_m0
# Writing solution for /He_1
# Writing solution for /He_2
# Writing solution for /He_3
# Writing solution for /de
# Writing solution for /ge

# %%
f = h5py.File("_new_solver_solution.h5")

qh = f['H_2'].value / 1.00794  - f['H_m0'].value/ 1.00794 + f['H2_2'].value/ 2.01588
qhe = f['He_2'].value / 4.002602  + 2.0*f['He_3'].value / 4.002602
qde = f['de'].value

solution = {}
for k in f.keys():
    solution[k] = f[k].value
    

f.close()
k = numpy.abs( (qh + qhe - qde ) / qde )

# %%
f = h5py.File("_new_solver_solution.h5")

mh0 = f['H_2'].value + f['H_1'].value   + f['H_m0'].value + f['H2_2'].value + f['H2_1'].value
mhe0 = f['He_2'].value   +  f['He_3'].value + f['He_1'].value 
f.close()
m_all0 = ( mh0 + mhe0 )

# %%
f = h5py.File("_new_solver_solution.h5")

mh = f['H_2'].value + f['H_1'].value   + f['H_m0'].value + f['H2_2'].value + f['H2_1'].value
mhe = f['He_2'].value   +  f['He_3'].value + f['He_1'].value 
T = f['T'].value
f.close()
m_all = ( mh + mhe )

# %%
k
# Out:
# array([1.27034358e-12, 1.71397965e-12, 1.05988141e-13, 2.48258294e-12,
#        3.29320295e-13, 3.38726720e-12, 4.67294143e-13, 1.54420937e-12,
#        3.20803391e-13, 4.26034474e-13])

# %%
m_all
# Out:
# array([1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14,
#        1.e+14, 1.e+14])

# %%
m_all0
# Out:
# array([1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14, 1.e+14,
#        1.e+14, 1.e+14])

# %%
# %%writefile _new_runfile
# #!/bin/bash
# rm -f a.out
# g++ _new_solver_solver.C _new_solver_solver_main.C initialize_cvode_solver.C -I. -I/home/kwoksun2/cvode-3.1.0/instdir/include/ -lm -lstdc++ -lhdf5 -lhdf5_hl /home/kwoksun2/cvode-3.1.0/instdir/lib/libsundials_cvode.a /home/kwoksun2/cvode-3.1.0/instdir/lib/libsundials_nvecserial.a -pg
# Out:
# Writing _new_runfile

# %%
# !bash _new_runfile

# %%
# %%time
# !./a.out
# Out:
# Successfully read in rate tables.
# Successfully read in cooling rate tables.
# Successfully read in gamma tables.
# Getting dimensionality from ge:
#   ncells =  10
# Reading I.C. for /H2_1
# H2_1[0] = 3.8e+13, atol =>  38000
# Reading I.C. for /H2_2
# H2_2[0] = 1e-06, atol =>  38000
# Reading I.C. for /H_1
# H_1[0] = 3.8e+13, atol =>  38000
# Reading I.C. for /H_2
# H_2[0] = 1e-06, atol =>  38000
# Reading I.C. for /H_m0
# H_m0[0] = 1e-06, atol =>  38000
# Reading I.C. for /He_1
# He_1[0] = 2.4e+13, atol =>  38000
# Reading I.C. for /He_2
# He_2[0] = 1e-06, atol =>  38000
# Reading I.C. for /He_3
# He_3[0] = 1e-06, atol =>  38000
# Reading I.C. for /de
# de[0] = 1.25e-06, atol =>  38000
# Reading I.C. for /ge
# ge[0] = 2.9e+11, atol =>  38000
# data->scale[0] = 1.9996
# data->scale[1] = 3.6536e-07
# data->scale[2] = 0.00043953
# data->scale[3] = 1.5
# data->scale[4] = 2.4436e-07
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.19959
# data->scale[0] = 1.0001
# data->scale[1] = 0.025143
# data->scale[2] = 0.50508
# data->scale[3] = 1
# data->scale[4] = 1.6122
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.86085
# 0 the strip = 2.992e+08
# data->scale[0] = 1.9996
# data->scale[1] = 2.6585e-08
# data->scale[2] = 0.0004394
# data->scale[3] = 1.5
# data->scale[4] = 4.8471e-07
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.19958
# data->scale[0] = 1.0001
# data->scale[1] = 0.34553
# data->scale[2] = 0.50513
# data->scale[3] = 1
# data->scale[4] = 0.81275
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.86087
# 1 the strip = 2.992e+08
#
# [CVODE ERROR]  CVode
#   At t = 1.34358e+08 and h = 71.2385, the error test failed repeatedly or with |h| = hmin.
#
# data->scale[0] = 1.9994
# data->scale[1] = 2.2432e-06
# data->scale[2] = 0.00055388
# data->scale[3] = 1.5
# data->scale[4] = 5.0092e-05
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.21003
# data->scale[0] = 1.0002
# data->scale[1] = 0.0042108
# data->scale[2] = 0.42856
# data->scale[3] = 1
# data->scale[4] = 0.0080048
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.83024
# data->scale[0] = 1
# data->scale[1] = 0.97258
# data->scale[2] = 0.93511
# data->scale[3] = 1
# data->scale[4] = 0.98254
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.98536
# 2 the strip = 2.992e+08
#
# [CVODE ERROR]  CVode
#   At t = 3.16392e+07 and h = 14.9072, the error test failed repeatedly or with |h| = hmin.
#
# data->scale[0] = 1.9971
# data->scale[1] = 3.86e-06
# data->scale[2] = 0.0028511
# data->scale[3] = 1.5
# data->scale[4] = 6.1118e-05
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.30684
# data->scale[0] = 1.0008
# data->scale[1] = 0.0049199
# data->scale[2] = 0.43285
# data->scale[3] = 1
# data->scale[4] = 0.010185
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.81969
# data->scale[0] = 1.0002
# data->scale[1] = 0.79916
# data->scale[2] = 0.59615
# data->scale[3] = 1
# data->scale[4] = 0.86912
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.88933
# data->scale[0] = 1.0001
# data->scale[1] = 0.84939
# data->scale[2] = 0.68025
# data->scale[3] = 1
# data->scale[4] = 0.90233
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.91811
# data->scale[0] = 1.0001
# data->scale[1] = 0.8772
# data->scale[2] = 0.73126
# data->scale[3] = 1
# data->scale[4] = 0.92056
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.93357
# data->scale[0] = 1
# data->scale[1] = 0.89468
# data->scale[2] = 0.76532
# data->scale[3] = 1
# data->scale[4] = 0.93195
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.94309
# data->scale[0] = 1
# data->scale[1] = 0.90789
# data->scale[2] = 0.79248
# data->scale[3] = 1
# data->scale[4] = 0.94056
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.95023
# 3 the strip = 2.992e+08
# data->scale[0] = 1.9991
# data->scale[1] = 1.7959e-08
# data->scale[2] = 0.00086839
# data->scale[3] = 1.5
# data->scale[4] = 5.8881e-07
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.23218
# data->scale[0] = 1.0002
# data->scale[1] = 0.63451
# data->scale[2] = 0.42922
# data->scale[3] = 1
# data->scale[4] = 0.76697
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.82909
# data->scale[0] = 1.0001
# data->scale[1] = 0.80607
# data->scale[2] = 0.59546
# data->scale[3] = 1
# data->scale[4] = 0.87231
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.89254
# 4 the strip = 2.992e+08
# data->scale[0] = 1.9998
# data->scale[1] = 9.7545e-09
# data->scale[2] = 0.00022187
# data->scale[3] = 1.5
# data->scale[4] = 2.4192e-07
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.17182
# 5 the strip = 2.992e+08
# data->scale[0] = 1.9998
# data->scale[1] = 2.6268e-08
# data->scale[2] = 0.00022203
# data->scale[3] = 1.5
# data->scale[4] = 3.9373e-07
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.17184
# 6 the strip = 2.992e+08
# data->scale[0] = 1.9998
# data->scale[1] = 9.83e-08
# data->scale[2] = 0.00022179
# data->scale[3] = 1.5
# data->scale[4] = 4.0338e-07
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.17182
# 7 the strip = 2.992e+08
#
# [CVODE ERROR]  CVode
#   At t = 9.30724e+07 and h = 70.2912, the error test failed repeatedly or with |h| = hmin.
#
# data->scale[0] = 1.9992
# data->scale[1] = 0.00015977
# data->scale[2] = 0.0008416
# data->scale[3] = 1.4999
# data->scale[4] = 1.0768e-05
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.23052
# data->scale[0] = 1.0002
# data->scale[1] = 7.038e-05
# data->scale[2] = 0.42907
# data->scale[3] = 1.0001
# data->scale[4] = 0.041587
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.82925
# data->scale[0] = 1.0001
# data->scale[1] = 0.81688
# data->scale[2] = 0.6147
# data->scale[3] = 1
# data->scale[4] = 0.87973
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1
# data->scale[9] = 0.8988
# 8 the strip = 2.992e+08
# data->scale[0] = 1.9998
# data->scale[1] = 1.0869e-08
# data->scale[2] = 0.00022198
# data->scale[3] = 1.5
# data->scale[4] = 3.9289e-07
# data->scale[5] = 1
# data->scale[6] = 1
# data->scale[7] = 1
# data->scale[8] = 1.7965
# data->scale[9] = 0.17183
# 9 the strip = 2.992e+08
# Writing solution for /H2_1
# Writing solution for /H2_2
# Writing solution for /H_1
# Writing solution for /H_2
# Writing solution for /H_m0
# Writing solution for /He_1
# Writing solution for /He_2
# Writing solution for /He_3
# Writing solution for /de
# Writing solution for /ge
# CPU times: user 15.6 ms, sys: 31.2 ms, total: 46.9 ms
# Wall time: 429 ms

# %%
73/1024.
# Out:
# 0.0712890625

# %%
import h5py
# Out:
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
f =h5py.File(' ')
