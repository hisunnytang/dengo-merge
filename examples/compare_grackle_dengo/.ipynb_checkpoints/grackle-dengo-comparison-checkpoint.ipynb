# %%
import matplotlib.pyplot as plt
from IPython.display import Image
import pickle
import time
import numpy
import yt.units as u
import numpy
loc_pwd = ""
def save_obj(obj, name ):
    with open(loc_pwd+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(loc_pwd + name + '.pkl', 'rb') as f:
        return pickle.load(f)
    
import sys
sys.path.append("../cvdls_examples/9species_cooling") 
sys.path.append("../cvspils_examples/9species_cooling") 
sys.path.append("../be_chem_solve_examples/9species_cooling/") 

from generate_dls_cooling_network import run_cvdls
from generate_cvspils_cooling_network import run_cvspils
from generate_bechem_cooling_network import run_bechem
# %matplotlib inline

import os
os.environ['YT_DEST'] = '/home/kwoksun2/anaconda2/pkgs/yt-3.3.5-np111py27_2/'
import numpy as np
from dengo.chemical_network import \
    ChemicalNetwork, \
    reaction_registry, \
    cooling_registry, species_registry
import dengo.primordial_rates, dengo.primordial_cooling
from dengo.chemistry_constants import tiny, kboltz, mh
import time
# Out:
#  using cli
#  using CLI for selections

# %%
def Init_values(temperature, density, n_species = 9, cooling=True):
    """ Create a initial value dictionary,
        for a given temperature, density, number of species
    Args:
        temperature -- in Kelvin
        density     -- in amu / cm**3
        n_species   -- number of species (6/9)
        cooling

    Returns:
        init_values: initial value dictionary with
                     self-consistent energy/ electron density
        primordial : chemical_network classes

    """

    # initialize and setup the network
    dengo.primordial_rates.setup_primordial()
    primordial = ChemicalNetwork()
    primordial.threebody = 4

    if n_species == 9:
        for i in range(22):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass
    else:
        for i in range(6):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass

    # the temperature array required to interpolates the rates
    primordial.init_temperature((1e0, 1e5))

    tiny = 1.0e-20

    # init_array are is in fractional abundances
    init_values = dict()
    density = numpy.array([density])
    if n_species == 6:
        # 6-species model
        init_values["He_1"]    = density * (1.0 - 0.76)
        init_values["He_2"]    = np.array([tiny])
        init_values["He_3"]    = np.array([tiny])
        init_values["H_1"]     = density *  (0.76)
        init_values['H_2']     = np.array([tiny]) 
    else:
        # 9-species model
        init_values["He_1"]    = density * (1.0 - 0.76) 
        init_values["He_2"]    = density *np.array([tiny])
        init_values["He_3"]    = density *np.array([tiny])
        init_values["H_1"]     = density *  (0.76)
        init_values['H_2']     = density *np.array([tiny])

        init_values["H_m0"]    = density *np.array([tiny])
        init_values["H2_1"]    = density *np.array([tiny])
        init_values["H2_2"]    = density *np.array([tiny])

    # now everything in mass density
    init_values['de'] = primordial.calculate_free_electrons(init_values)
    # one signle value: again mass density
    init_values['density'] = primordial.calculate_total_density(init_values)

    num_den = {}
    for sp in primordial.required_species:
        try:
            num_den[sp.name] = init_values[sp.name]/ sp.weight
        except:
            pass

    # set up initial temperatures values used to define ge
    init_values['T'] = numpy.array([temperature])

    # calculate gammaH2
    x = 6100.0/temperature
    expx = numpy.exp(x)
    gammaH2 = 2.0 / (5.0 + 2.0*x*x*expx / (expx - 1 )**2.0 ) + 1

    gamma_factor = primordial.gamma_factor().subs(num_den).subs({'gammaH2': gammaH2 , 'gamma': 5./3.,'T': temperature })

    ge  = ((temperature *  kboltz) *gamma_factor
                         / (init_values['density'] * mh  ))

    T = init_values['density']*ge*mh / kboltz / gamma_factor
    print(T-temperature)
    init_values['ge'] = numpy.array( [numpy.float64(ge)] )

    if cooling:
        for cooling_action in cooling_registry:
            k = cooling_registry[cooling_action]
            if (k.species).issubset( primordial.required_species ):
                if k.name != "cie_cooling":                    
                    print("adding:", k.name, k.equation)
                    primordial.add_cooling(cooling_action)
                    print('---------------------------')
    return init_values, primordial

# %%
from pygrackle import \
    FluidContainer, \
    chemistry_data, \
    evolve_constant_density

from pygrackle.utilities.physical_constants import \
    mass_hydrogen_cgs, \
    sec_per_Myr, \
    cm_per_mpc, \
    mass_electron_cgs

tiny_number = 1e-20
import sys

def run_grackle(density, initial_temperature, final_time):
    current_redshift = 0.

    # Set initial values


    # Set solver parameters
    my_chemistry = chemistry_data()
    my_chemistry.use_grackle = 1
    my_chemistry.with_radiative_cooling = 1
    my_chemistry.primordial_chemistry = 2
    my_chemistry.three_body_rate = 4
    my_chemistry.metal_cooling = 0
    my_chemistry.UVbackground = 0
    my_chemistry.self_shielding_method = 0
    my_chemistry.H2_self_shielding = 0
    grackle_dir = "/home/kwoksun2/grackle_install/"
    my_chemistry.grackle_data_file = os.sep.join(
        [grackle_dir, "input", "CloudyData_UVB=HM2012.h5"])

    # Set units
    my_chemistry.comoving_coordinates = 0 # proper units
    my_chemistry.a_units = 1.0
    my_chemistry.a_value = 1. / (1. + current_redshift) / \
        my_chemistry.a_units
    my_chemistry.density_units = 1.66053904e-24 #mass_hydrogen_cgs # rho = 1.0 is 1.67e-24 g
    my_chemistry.length_units = cm_per_mpc         # 1 Mpc in cm
    my_chemistry.time_units = sec_per_Myr          # 1 Myr in s
    my_chemistry.velocity_units = my_chemistry.a_units * \
        (my_chemistry.length_units / my_chemistry.a_value) / \
        my_chemistry.time_units

    rval = my_chemistry.initialize()

    fc = FluidContainer(my_chemistry, 1)
    fc["density"][:] = density
    if my_chemistry.primordial_chemistry > 0:
        fc["HI"][:] = 0.76 * fc["density"]
        fc["HII"][:] = tiny_number * fc["density"]
        fc["HeI"][:] = (1.0 - 0.76) * fc["density"]
        fc["HeII"][:] = tiny_number * fc["density"]
        fc["HeIII"][:] = tiny_number * fc["density"]
    if my_chemistry.primordial_chemistry > 1:
        fc["H2I"][:] = tiny_number * fc["density"] 
        fc["H2II"][:] = tiny_number * fc["density"]
        fc["HM"][:] = tiny_number * fc["density"]
        fc["de"][:] = 2e-4 * mass_electron_cgs / mass_hydrogen_cgs * fc["density"]
            # tiny_number * fc["density"]
    if my_chemistry.primordial_chemistry > 2:
        fc["DI"][:] = 2.0 * 3.4e-5 * fc["density"]
        fc["DII"][:] = tiny_number * fc["density"]
        fc["HDI"][:] = tiny_number * fc["density"]
    if my_chemistry.metal_cooling == 1:
        fc["metal"][:] = 0.1 * fc["density"] * \
          my_chemistry.SolarMetalFractionByMass

    fc["x-velocity"][:] = 0.0
    fc["y-velocity"][:] = 0.0
    fc["z-velocity"][:] = 0.0

    fc["energy"][:] = initial_temperature / \
        fc.chemistry_data.temperature_units
    fc.calculate_temperature()
    fc["energy"][:] *= initial_temperature / fc["temperature"]

    # timestepping safety factor
    safety_factor = 0.001
    
    tic = time.time()
    # let gas cool at constant density
    data = evolve_constant_density(
        fc, final_time=final_time,
        safety_factor=safety_factor)
    toc = time.time()

    # convert grackle language to dengo language
    name_map_dict = { 'HI':'H_1',
              'HII':'H_2',
              'HeI':'He_1',
              'HeII':'He_2',
              'HeIII':'He_3',
              'H2I' : 'H2_1',
              'H2II': 'H2_2',
              'HM' : 'H_m0',
                'de':'de',
                'temperature':'T',
                'time': 't',
                'energy':'ge'}

    weight_map_dict = { 'HI':1.00794,
              'HII':1.00794,
              'HeI':4.002602,
              'HeII':4.002602,
              'HeIII':4.002602,
               'H2II': 2.01588,
               'H2I' : 2.01588,
               'HM' : 1.00794,
                'de':1.00794,
                  'time': 1.0,
                  'temperature': 1.0,
                  'energy': 1.0}

    data_grackle = {}


    for key in name_map_dict.keys():
        key_dengo = name_map_dict[key]
        if key_dengo in ["t","T"]:
            data_grackle[key_dengo] = data[key].value
        else:
            data_grackle[key_dengo] = data[key].value / weight_map_dict[key] / u.amu_cgs.value
    
    return data_grackle, toc-tic

# %%
def calc_fftime(den):
    mu = 1.0
    rho = mu* u.mass_hydrogen *den *(u.cm**-3)
    tff = numpy.sqrt(1.0 / u.G / rho).in_units('s')
    return tff.v

# %%
density = 1e10
initial_temperature = 3000.0
final_time = calc_fftime(density)
final_time = 3.15e-3
init, primordial = Init_values(initial_temperature, 
                               density, n_species = 9, 
                               cooling=True);
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# [0]
# ('adding:', 'brem', -brem_brem[i]*de*(H_2 + He_2 + 4.0*He_3))
# ---------------------------
# ('adding:', 'reHII', -H_2*de*reHII_reHII[i])
# ---------------------------
# ('adding:', 'reHeIII', -He_3*de*reHeIII_reHeIII[i])
# ---------------------------
# ('adding:', 'gloverabel08', -H2_1*gloverabel08_h2lte[i]/(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0))
# ---------------------------
# ('adding:', 'ceHI', -H_1*ceHI_ceHI[i]*de)
# ---------------------------
# ('adding:', 'compton', -compton_comp_[i]*de*(z + 1.0)**4*(T - 2.73*z - 2.73))
# ---------------------------
# ('adding:', 'h2formation', 0.5*(h2formation_ncrn[i]/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0)**(-1.0)*(-H2_1*H_1*h2formation_h2mcool[i] + H_1**3*h2formation_h2mheat[i]))
# ---------------------------
# ('adding:', 'reHeII2', -He_2*de*reHeII2_reHeII2[i])
# ---------------------------
# ('adding:', 'reHeII1', -He_2*de*reHeII1_reHeII1[i])
# ---------------------------
# ('adding:', 'ciHeIS', -He_2*ciHeIS_ciHeIS[i]*de**2)
# ---------------------------
# ('adding:', 'ceHeII', -He_2*ceHeII_ceHeII[i]*de)
# ---------------------------
# ('adding:', 'ciHI', -H_1*ciHI_ciHI[i]*de)
# ---------------------------
# ('adding:', 'ceHeI', -He_2*ceHeI_ceHeI[i]*de**2)
# ---------------------------
# ('adding:', 'gammah', 0)
# ---------------------------
# ('adding:', 'ciHeI', -He_1*ciHeI_ciHeI[i]*de)
# ---------------------------
# ('adding:', 'ciHeII', -He_2*ciHeII_ciHeII[i]*de)
# ---------------------------

# %%
density = 1e10
initial_temperature = 3000.0
final_time = calc_fftime(density)
final_time = 3.15e-3

final_time_Myr = u.second.in_units('Myr').v * final_time

# run grackle
grackle_data, run_time_grackle = run_grackle(density, initial_temperature, final_time_Myr)

init, primordial = Init_values(initial_temperature, 
                               density, n_species = 9, 
                               cooling=False);

# # run our solver
_, cvdls_data, run_time_cvdls = run_cvdls( initial_temperature, 
                                          density, final_time, 
                                          init=init, primordial=primordial)
# _, bechem_data, run_time_bechem = run_bechem( initial_temperature, 
#                                              density, final_time, 
#                                             init=init, primordial=primordial)
# _, cvspils_data, run_time_cvspils = run_cvspils( initial_temperature, 
#                                                 density, final_time, 
#                                                init=init, primordial=primordial)
# Out:
# Evolve constant density - t: 0.000000e+00 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.981748e-14 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.996350e-13 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.994524e-13 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.992699e-13 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.990874e-13 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.989049e-13 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.987223e-13 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.985398e-13 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.983573e-13 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.981748e-13 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.097992e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.197810e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.297627e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.397445e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.497262e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.597080e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.696897e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.796715e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.896532e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.996350e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.096167e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.195984e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.295802e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.395619e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.495437e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.595254e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.695072e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.794889e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.894707e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.994524e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.094342e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.194159e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.293977e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.393794e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.493612e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.593429e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.693247e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.793064e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.892882e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.992699e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.092517e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.192334e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.292151e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.391969e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.491786e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.591604e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.691421e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.791239e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.891056e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.990874e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.090691e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.190509e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.290326e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.390144e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.489961e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.589779e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.689596e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.789414e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.889231e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.989049e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.088866e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.188684e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.288501e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.388319e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.488136e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.587953e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.687771e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.787588e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.887406e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 6.987223e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.087041e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.186858e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.286676e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.386493e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.486311e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.586128e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.685946e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.785763e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.885581e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 7.985398e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.085216e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.185033e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.284851e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.384668e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.484486e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.584303e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.684120e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.783938e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.883755e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.983573e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.083390e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.183208e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.283025e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.382843e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.482660e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.582478e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.682295e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.782113e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.881930e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.981748e-12 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.008157e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.018138e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.028120e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.038102e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.048084e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.058065e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.068047e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.078029e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.088010e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.097992e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.107974e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.117956e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.127937e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.137919e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.147901e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.157883e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.167864e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.177846e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.187828e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.197810e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.207791e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.217773e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.227755e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.237737e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.247718e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.257700e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.267682e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.277664e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.287645e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.297627e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.307609e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.317591e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.327572e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.337554e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.347536e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.357518e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.367499e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.377481e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.387463e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.397445e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.407426e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.417408e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.427390e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.437372e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.447353e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.457335e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.467317e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.477299e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.487280e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.497262e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.507244e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.517226e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.527207e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.537189e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.547171e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.557153e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.567134e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.577116e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.587098e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.597080e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.607061e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.617043e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.627025e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.637007e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.646988e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.656970e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.666952e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.676934e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.686915e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.696897e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.706879e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.716861e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.726842e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.736824e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.746806e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.756788e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.766769e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.776751e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.786733e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.796715e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.806696e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.816678e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.826660e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.836642e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.846623e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.856605e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.866587e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.876569e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.886550e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.896532e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.906514e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.916496e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.926477e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.936459e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.946441e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.956423e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.966404e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.976386e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.986368e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.996350e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.006331e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.016313e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.026295e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.036277e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.046258e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.056240e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.066222e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.076204e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.086185e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.096167e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.106149e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.116131e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.126112e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.136094e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.146076e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.156057e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.166039e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.176021e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.186003e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.195984e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.205966e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.215948e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.225930e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.235911e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.245893e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.255875e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.265857e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.275838e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.285820e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.295802e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.305784e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.315765e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.325747e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.335729e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.345711e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.355692e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.365674e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.375656e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.385638e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.395619e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.405601e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.415583e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.425565e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.435546e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.445528e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.455510e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.465492e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.475473e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.485455e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.495437e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.505419e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.515400e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.525382e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.535364e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.545346e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.555327e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.565309e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.575291e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.585273e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.595254e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.605236e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.615218e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.625200e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.635181e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.645163e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.655145e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.665127e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.675108e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.685090e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.695072e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.705054e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.715035e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.725017e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.734999e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.744981e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.754962e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.764944e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.774926e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.784908e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.794889e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.804871e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.814853e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.824835e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.834816e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.844798e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.854780e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.864762e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.874743e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.884725e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.894707e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.904689e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.914670e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.924652e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.934634e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.944616e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.954597e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.964579e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.974561e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.984543e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.994524e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.004506e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.014488e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.024470e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.034451e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.044433e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.054415e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.064397e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.074378e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.084360e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.094342e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.104324e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.114305e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.124287e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.134269e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.144251e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.154232e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.164214e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.174196e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.184178e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.194159e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.204141e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.214123e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.224104e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.234086e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.244068e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.254050e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.264031e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.274013e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.283995e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.293977e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.303958e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.313940e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.323922e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.333904e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.343885e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.353867e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.363849e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.373831e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.383812e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.393794e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.403776e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.413758e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.423739e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.433721e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.443703e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.453685e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.463666e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.473648e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.483630e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.493612e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.503593e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.513575e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.523557e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.533539e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.543520e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.553502e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.563484e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.573466e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.583447e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.593429e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.603411e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.613393e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.623374e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.633356e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.643338e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.653320e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.663301e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.673283e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.683265e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.693247e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.703228e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.713210e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.723192e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.733174e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.743155e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.753137e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.763119e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.773101e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.783082e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.793064e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.803046e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.813028e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.823009e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.832991e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.842973e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.852955e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.862936e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.872918e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.882900e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.892882e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.902863e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.912845e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.922827e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.932809e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.942790e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.952772e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.962754e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.972736e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.982717e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 3.992699e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.002681e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.012663e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.022644e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.032626e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.042608e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.052590e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.062571e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.072553e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.082535e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.092517e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.102498e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.112480e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.122462e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.132444e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.142425e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.152407e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.162389e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.172371e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.182352e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.192334e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.202316e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.212298e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.222279e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.232261e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.242243e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.252225e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.262206e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.272188e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.282170e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.292151e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.302133e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.312115e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.322097e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.332078e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.342060e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.352042e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.362024e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.372005e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.381987e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.391969e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.401951e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.411932e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.421914e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.431896e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.441878e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.451859e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.461841e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.471823e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.481805e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.491786e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.501768e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.511750e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.521732e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.531713e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.541695e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.551677e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.561659e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.571640e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.581622e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.591604e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.601586e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.611567e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.621549e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.631531e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.641513e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.651494e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.661476e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.671458e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.681440e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.691421e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.701403e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.711385e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.721367e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.731348e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.741330e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.751312e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.761294e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.771275e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.781257e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.791239e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.801221e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.811202e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.821184e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.831166e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.841148e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.851129e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.861111e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.871093e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.881075e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.891056e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.901038e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.911020e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.921002e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.930983e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.940965e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.950947e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.960929e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.970910e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.980892e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 4.990874e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.000856e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.010837e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.020819e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.030801e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.040783e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.050764e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.060746e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.070728e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.080710e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.090691e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.100673e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.110655e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.120637e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.130618e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.140600e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.150582e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.160564e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.170545e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.180527e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.190509e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.200491e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.210472e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.220454e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.230436e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.240418e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.250399e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# ...
# Evolve constant density - t: 8.364705e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.374686e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.384668e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.394650e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.404632e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.414613e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.424595e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.434577e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.444559e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.454540e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.464522e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.474504e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.484486e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.494467e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.504449e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.514431e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.524413e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.534394e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.544376e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.554358e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.564339e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.574321e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.584303e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.594285e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.604266e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.614248e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.624230e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.634212e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.644193e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.654175e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.664157e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.674139e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.684120e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.694102e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.704084e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.714066e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.724047e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.734029e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.744011e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.753993e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.763974e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.773956e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.783938e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.793920e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.803901e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.813883e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.823865e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.833847e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.843828e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.853810e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.863792e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.873774e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.883755e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.893737e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.903719e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.913701e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.923682e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.933664e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.943646e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.953628e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.963609e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.973591e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.983573e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.993555e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.003536e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.013518e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.023500e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.033482e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.043463e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.053445e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.063427e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.073409e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.083390e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.093372e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.103354e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.113336e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.123317e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.133299e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.143281e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.153263e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.163244e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.173226e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.183208e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.193190e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.203171e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.213153e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.223135e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.233117e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.243098e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.253080e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.263062e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.273044e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.283025e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.293007e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.302989e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.312971e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.322952e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.332934e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.342916e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.352898e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.362879e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.372861e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.382843e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.392825e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.402806e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.412788e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.422770e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.432752e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.442733e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.452715e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.462697e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.472679e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.482660e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.492642e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.502624e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.512606e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.522587e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.532569e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.542551e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.552533e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.562514e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.572496e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.582478e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.592460e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.602441e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.612423e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.622405e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.632386e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.642368e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.652350e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.662332e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.672313e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.682295e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.692277e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.702259e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.712240e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.722222e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.732204e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.742186e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.752167e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.762149e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.772131e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.782113e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.792094e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.802076e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.812058e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.822040e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.832021e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.842003e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.851985e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.861967e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.871948e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.881930e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.891912e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.901894e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.911875e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.921857e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.931839e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.941821e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.951802e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.961784e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 9.971766e-11 yr, rho: 1.660539e-14 g/cm^3, T: 3.000000e+03 K.
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# [0]
# three body rate: 4
# initial  temperature: 3.000E+03
# Successful iteration[    0]: (3.150e-07) 3.150e-07 / 3.150e-03
# End in 73 iterations: 3.15000e-03 / 3.15000e-03 (0.00000e+00)

# %%
flag_cvdls = cvdls_data['successful']
t_cvdls = cvdls_data['t'][flag_cvdls]


# flag_bechem = bechem_data['successful']
# t_bechem = bechem_data['t'][flag_bechem]

# flag_cvspils = cvspils_data['successful']
# t_cvspils = cvspils_data['t'][flag_cvspils]

t_grackle = grackle_data['t']
flag_grackle = (t_grackle > 1e0)

plt.figure(figsize=(8,8))
for key in cvdls_data.keys():
    if key not in ['t', 'successful','dt','ge']:
        print(key)
        cvdls_d = cvdls_data[key][0][flag_cvdls]
        plt.semilogx( t_cvdls, cvdls_d,label=key)

#plt.gca().set_color_cycle(None)    
# for key in cvdls_data.keys():
#     if key not in ['t','successful','dt','ge']:
        
#         bechem_d = bechem_data[key][0][flag_bechem]
#         plt.semilogx( t_bechem, bechem_d, ls ='--')

# plt.gca().set_color_cycle(None)        
# for key in cvdls_data.keys():
#     if key not in ['t', 'successful','dt','ge']:
        
#         cvspils_d = cvspils_data[key][0][flag_cvspils]
#         plt.semilogx( t_cvspils, cvspils_d, ls= ':')
        
for key in cvdls_data.keys():
    if key not in ['t', 'successful','dt','ge']:
        
        grack_d = grackle_data[key]
        plt.loglog( t_grackle, grack_d, ls='-.')

plt.title('cvdls( - {})  \n grackle ( -. {})  '.format(run_time_cvdls, run_time_grackle) )

plt.legend()
plt.show()
# Out:
# H_2
# H_1
# de
# He_1
# He_2
# He_3
# H2_2
# H2_1
# H_m0
# T

# %%
flag_cvdls = cvdls_data['successful']
grack_d = grackle_data['T']
# bechem_d = bechem_data['T'][0][flag_bechem]
cvdls_d = cvdls_data['T'][0][flag_cvdls]   
plt.semilogx(t_grackle,grack_d)
plt.semilogx(t_cvdls, cvdls_d, label='cvdls')
plt.legend()
plt.show()

# %%
flag_cvdls = cvdls_data['successful']
t_cvdls = cvdls_data['t'][flag_cvdls]
t_grackle = grackle_data['t']

flag_grackle = (t_grackle > min(t_cvdls))

plt.figure(figsize=(8,8))
for key in grackle_data.keys():
    if key not in ['t','de','ge']:
        grack_d = grackle_data[key][flag_grackle]
        cvdls_d = cvdls_data[key][0][flag_cvdls]
        interp_cvdls_data = numpy.interp( t_grackle[flag_grackle], t_cvdls, cvdls_d )
        plt.semilogx( t_grackle[flag_grackle], grack_d/interp_cvdls_data,label=key)

plt.title('grackle (run_time = {}) / cvdls (run_time : {}) '.format(run_time_grackle,run_time_cvdls) )
plt.ylim(-0.1,10)
plt.legend()
plt.show()

# %%
plt.loglog( t_cvdls, cvdls_data['ge'][0][flag_cvdls] )
plt.semilogx( t_grackle, grackle_data['ge'], ls='-.')
plt.show()

# %%
def conservation_of_M_e(data, flag_input=False):
    
    if flag_input:        
        flag = data['successful']
        size = len(data['t'][flag])
    else:
        flag = (data['t'] >= 0)
        size = len(data['t'])

        
    zeros = numpy.zeros((size))
    conserv_dict = {'H': zeros, 
                    'H2':zeros,
                    'He':zeros, 
                    'de':zeros, 
                    't': zeros, 
                    'de_':zeros}

    for key in data.keys():
        ele_charge = key.split('_')
        if ele_charge[0] in ['H', 'He']:

            name = ele_charge[0]
            if flag_input:
                conserv_dict[name] += data[key][0][flag]
            else:
                conserv_dict[name] += data[key][flag]
            try:
                charge = eval(ele_charge[1]) - 1
                if flag_input:
                    conserv_dict['de'] += charge*data[key][0][flag]
                else:
                    conserv_dict['de'] += charge*data[key][flag]
            except:
                if ele_charge[1][0] == 'm':             
                    charge = eval(ele_charge[1][1]) - 1
                    if flag_input:
                        conserv_dict['de'] += charge*data[key][0][flag]
                    else:
                        conserv_dict['de'] += charge*data[key][flag]
    
    conserv_dict['t'] = data['t'][flag]
    if flag_input:
        conserv_dict['de_'] = data['de'][0][flag]
    else:
        conserv_dict['de_'] = data['de'][flag]
    return conserv_dict

# %%
conserv_dict_grackle = conservation_of_M_e(grackle_data)
conserv_dict_cvdls = conservation_of_M_e(cvdls_data, flag_input=True)

# %%
t_gra = conserv_dict_grackle['t']
t_cvdls = conserv_dict_cvdls['t']

H_gra = conserv_dict_grackle['H']
H_cvdls = conserv_dict_cvdls['H']

H2_gra = conserv_dict_grackle['H2']
H2_cvdls = conserv_dict_cvdls['H2']

He_gra = conserv_dict_grackle['He']
He_cvdls = conserv_dict_cvdls['He']

de_gra = conserv_dict_grackle['de']
de_cvdls = conserv_dict_cvdls['de']

de__gra = conserv_dict_grackle['de_']
de__cvdls = conserv_dict_cvdls['de_']

plt.clf()
plt.plot( t_gra, (H_gra + 2.0*H2_gra)/(H_gra + 2.0*H2_gra)[0] ,color= 'r',ls='--')
plt.plot( t_cvdls, (H_cvdls + 2.0*H2_cvdls)/(H_cvdls + 2.0*H2_cvdls)[0] ,color= 'r',label='H')

plt.plot( t_gra, He_gra/He_gra[0]  ,color= 'b',ls='--')
plt.plot( t_cvdls, He_cvdls/He_cvdls[0] ,color= 'b',label='He')


net_charge_cvdls = (cvdls_data['H2_2'] + cvdls_data['H_2'] - cvdls_data['H_m0'] + cvdls_data["He_2"] + \
                2.0*cvdls_data["He_3"])/ cvdls_data["de"]

net_charge_gra = (grackle_data['H2_2'] + grackle_data['H_2'] - grackle_data['H_m0'] + grackle_data["He_2"] + \
                2.0*grackle_data["He_3"])/ grackle_data["de"]

t_cvdls = cvdls_data['t']
plt.plot( t_gra, net_charge_gra,color='g' ,ls='--')
plt.plot( t_cvdls, net_charge_cvdls[0],color='g',label='de')
plt.title('conservation')
plt.xlabel('time (s)')
plt.ylabel('fractional abundance')
plt.legend()
# plt.ylim(0.9,1.1)
plt.show()

# %%
temperature = 100.0

# %%
x = 6100.0/temperature
expx = numpy.exp(x)
gammaH2 = 2.0 / (5.0 + 2.0*x*x*expx / (expx - 1 )**2.0 ) + 1

# %%
gammaH2

# %%
temperature = numpy.logspace(0,5,100)
x = 6100.0/temperature
expx = numpy.exp(x)
gammaH2 = 2.0 / (5.0 + 2.0*x*x*expx / (expx - 1 )**2.0 ) + 1
plt.semilogx(temperature,1.0 / (gammaH2-1) )

# %%
mh
# Out:
# 1.67e-24

# %%
sp = species_registry['H2_1']

# %%
expr = primordial.species_gamma(sp, temp=True)

# %%
from sympy.utilities import lambdify

# %%
fH2 = lambdify('T', expr)

# %%
plt.plot(T, fH2(T))

# %%
T = numpy.logspace(0,5,100)

# %%
fH2(T)
# Out:
# array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,  1.4       ,
#         1.4       ,  1.4       ,  1.4       ,  1.4       ,  1.4       ,
#         1.4       ,  1.4       ,  1.4       ,  1.4       ,  1.4       ,
#         1.4       ,  1.4       ,  1.4       ,  1.4       ,  1.4       ,
#         1.4       ,  1.4       ,  1.4       ,  1.4       ,  1.4       ,
#         1.4       ,  1.4       ,  1.4       ,  1.4       ,  1.4       ,
#         1.4       ,  1.4       ,  1.4       ,  1.39999999,  1.39999991,
#         1.39999934,  1.39999614,  1.39998188,  1.39993004,  1.39977307,
#         1.39936985,  1.39847705,  1.39675023,  1.39379895,  1.38929658,
#         1.38310621,  1.37535964,  1.36644361,  1.35690009,  1.34729322,
#         1.33810032,  1.3296564 ,  1.32214863,  1.31564151,  1.31011273,
#         1.3054871 ,  1.30166305,  1.29853079,  1.29598352,  1.29392351,
#         1.29226479,  1.2909337 ,  1.28986838,  1.28901754,  1.2883391 ,
#         1.28779884,  1.28736905,  1.28702741,  1.28675601,  1.28654053,
#         1.2863695 ,  1.28623381,  1.28612617,  1.2860408 ,  1.28597311,
#         1.28591944,  1.2858769 ,  1.28584317,  1.28581643,  1.28579524,
#         1.28577845,  1.28576514,  1.28575458,  1.28574622,  1.2857396 ])

# %%
T
# Out:
# array([  1.00000000e+00,   1.12332403e+00,   1.26185688e+00,
#          1.41747416e+00,   1.59228279e+00,   1.78864953e+00,
#          2.00923300e+00,   2.25701972e+00,   2.53536449e+00,
#          2.84803587e+00,   3.19926714e+00,   3.59381366e+00,
#          4.03701726e+00,   4.53487851e+00,   5.09413801e+00,
#          5.72236766e+00,   6.42807312e+00,   7.22080902e+00,
#          8.11130831e+00,   9.11162756e+00,   1.02353102e+01,
#          1.14975700e+01,   1.29154967e+01,   1.45082878e+01,
#          1.62975083e+01,   1.83073828e+01,   2.05651231e+01,
#          2.31012970e+01,   2.59502421e+01,   2.91505306e+01,
#          3.27454916e+01,   3.67837977e+01,   4.13201240e+01,
#          4.64158883e+01,   5.21400829e+01,   5.85702082e+01,
#          6.57933225e+01,   7.39072203e+01,   8.30217568e+01,
#          9.32603347e+01,   1.04761575e+02,   1.17681195e+02,
#          1.32194115e+02,   1.48496826e+02,   1.66810054e+02,
#          1.87381742e+02,   2.10490414e+02,   2.36448941e+02,
#          2.65608778e+02,   2.98364724e+02,   3.35160265e+02,
#          3.76493581e+02,   4.22924287e+02,   4.75081016e+02,
#          5.33669923e+02,   5.99484250e+02,   6.73415066e+02,
#          7.56463328e+02,   8.49753436e+02,   9.54548457e+02,
#          1.07226722e+03,   1.20450354e+03,   1.35304777e+03,
#          1.51991108e+03,   1.70735265e+03,   1.91791026e+03,
#          2.15443469e+03,   2.42012826e+03,   2.71858824e+03,
#          3.05385551e+03,   3.43046929e+03,   3.85352859e+03,
#          4.32876128e+03,   4.86260158e+03,   5.46227722e+03,
#          6.13590727e+03,   6.89261210e+03,   7.74263683e+03,
#          8.69749003e+03,   9.77009957e+03,   1.09749877e+04,
#          1.23284674e+04,   1.38488637e+04,   1.55567614e+04,
#          1.74752840e+04,   1.96304065e+04,   2.20513074e+04,
#          2.47707636e+04,   2.78255940e+04,   3.12571585e+04,
#          3.51119173e+04,   3.94420606e+04,   4.43062146e+04,
#          4.97702356e+04,   5.59081018e+04,   6.28029144e+04,
#          7.05480231e+04,   7.92482898e+04,   8.90215085e+04,
#          1.00000000e+05])

# %%
a0 = 64.2416
a1 = -9.36334
a2 = -0.377266
a3 = 69.8091
a4 = 0.0493452
a5 = 2.28021
a6 = 0.115357
a7 = 0.114188
a8 = 2.90778
a9 = 0.689708

T0 = numpy.logspace(0,1,1024)

gamma_T = sympy.exp(-a0*T**a1)*(a2+T**-a3) \
            + a4*sympy.exp( - (T-a5)**2 / a6)\
            + a7*sympy.exp( -(T-a8)**2 / a9) \
            + 5./3.
T_array = numpy.logspace(0,6.5,1024)

# %%
plt.semilogx(T_array, gamma_T)

T = primordial.T
plt.semilogx(primordial.T, gammaH2)
plt.ylim(1.2,1.7)
# Out:
# (1.2, 1.7)

# %%
T0 = numpy.logspace(0,6.5,1024)

gamma_T = numpy.exp(-a0*T0**a1)*(a2+T0**-a3) \
            + a4*numpy.exp( - (T0-a5)**2 / a6)\
            + a7*numpy.exp( -(T0-a8)**2 / a9) \
            + 5./3.
T_array = numpy.logspace(0,6.5,1024)

plt.semilogx(T_array, gamma_T)

T = primordial.T
plt.semilogx(primordial.T, gammaH2)
plt.ylim(1.2,1.7)
# Out:
# (1.2, 1.7)

# %%
gammaH2 = primordial.interpolate_species_gamma(sp)
dgammaH2_dT = primordial.interpolate_species_gamma(sp, deriv=True)
# Out:
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/numpy/__init__.py:1: RuntimeWarning: invalid value encountered in multiply
#   """
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/numpy/__init__.py:1: RuntimeWarning: invalid value encountered in multiply
#   """

# %%
plt.semilogx(T,gammaH2)
plt.semilogx(T,dgammaH2_dT)
plt.show()

# %%
gammaH2
# Out:
# array([ 1.4,  1.4,  1.4, ...,  1.4,  1.4,  1.4])

# %%
expr = primordial.species_gamma(sp, temp=True, name=False)
expr
# Out:
# 1 + 2.0/(5.0 + 74420000.0*(exp(6100.0/T) - 1)**(-2.0)*exp(6100.0/T)/T**2)

# %%
from sympy.utilities import lambdify
f = lambdify('T',expr)

# %%
T = primordial.T

# %%
(5.0 + 74420000.0*(numpy.exp(6100.0/T) - 1)**(-2.0)/T/T)
# Out:
# array([ 5.        ,  5.        ,  5.        , ...,  6.87842613,
#         6.87975166,  6.88106312])

# %%
x = 6100.0/T

expx = numpy.exp(x)

gammaH2 = 2.0/(5.0+ 2.0*x*x*expx/(expx-1)/(expx-1)) + 1
gammaH2[numpy.isnan(gammaH2)] = 1.4
gammaH2[gammaH2<1.2] = 1.4
# Out:
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in divide
#   """

# %%
len(gammaH2)
# Out:
# 1024

# %%
gammaH2 = sympy.Function('gammaH2T')(T)

# %%
sym_dgammaH2_dT = diff(gammaH2,T)

# %%
kkk = sympy.Symbol('dgH2_dT')

# %%
gammaH2
# Out:
# gammaH2T(T)

# %%
ddd = diff(gammaH2 + expr,T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-43a532de78a8> in <module>()
# ----> 1 ddd = diff(gammaH2 + expr,T)
#
# NameError: name 'diff' is not defined

# %%
ddd.subs({sym_dgammaH2_dT: kkk})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-edc22abe6527> in <module>()
# ----> 1 ddd.subs({sym_dgammaH2_dT: kkk})
#
# NameError: name 'ddd' is not defined

# %%
primordial.species_gamma(sp, temp=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a88baee6bf97> in <module>()
# ----> 1 primordial.species_gamma(sp, temp=False)
#
# NameError: name 'sp' is not defined
