# %%
import matplotlib.pyplot as plt
from IPython.display import Image
import pickle
import time
import numpy
import yt.units as u
import numpy
loc_pwd = ""
def save_obj(obj, name ):
    with open(loc_pwd+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(loc_pwd + name + '.pkl', 'rb') as f:
        return pickle.load(f)
    
import sys
sys.path.append("../cvdls_examples/9species_cooling") 
sys.path.append("../cvspils_examples/9species_cooling") 
sys.path.append("../be_chem_solve_examples/9species_cooling/") 

from generate_dls_cooling_network import run_cvdls
from generate_cvspils_cooling_network import run_cvspils
from generate_bechem_cooling_network import run_bechem
# %matplotlib inline

import os
os.environ['YT_DEST'] = '/home/kwoksun2/anaconda2/pkgs/yt-3.3.5-np111py27_2/'
import numpy as np
from dengo.chemical_network import \
    ChemicalNetwork, \
    reaction_registry, \
    cooling_registry, species_registry
import dengo.primordial_rates, dengo.primordial_cooling
from dengo.chemistry_constants import tiny, kboltz, mh
import time
# Out:
#  using cli
#  using CLI for selections

# %%
def Init_values(temperature, density, n_species = 9, cooling=True):
    """ Create a initial value dictionary,
        for a given temperature, density, number of species
    Args:
        temperature -- in Kelvin
        density     -- in amu / cm**3
        n_species   -- number of species (6/9)
        cooling

    Returns:
        init_values: initial value dictionary with
                     self-consistent energy/ electron density
        primordial : chemical_network classes

    """

    # initialize and setup the network
    dengo.primordial_rates.setup_primordial()
    primordial = ChemicalNetwork()
    primordial.threebody = 4

    if n_species == 9:
        for i in range(22):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass
    else:
        for i in range(6):
            try:
                primordial.add_reaction("k{0:02d}".format(i+1))
            except:
                pass

    # the temperature array required to interpolates the rates
    primordial.init_temperature((1e0, 1e5))

    tiny = 1.0e-20

    # init_array are is in fractional abundances
    init_values = dict()
    density = numpy.array([density])
    if n_species == 6:
        # 6-species model
        init_values["He_1"]    = density * (1.0 - 0.76)
        init_values["He_2"]    = np.array([tiny])
        init_values["He_3"]    = np.array([tiny])
        init_values["H_1"]     = density *  (0.76)
        init_values['H_2']     = np.array([tiny]) 
    else:
        # 9-species model
        init_values["He_1"]    = density * (1.0 - 0.76) 
        init_values["He_2"]    = density *np.array([tiny])
        init_values["He_3"]    = density *np.array([tiny])
        init_values["H_1"]     = density *  (0.76)
        init_values['H_2']     = density *np.array([tiny])

        init_values["H_m0"]    = density *np.array([tiny])
        init_values["H2_1"]    = density *np.array([tiny])
        init_values["H2_2"]    = density *np.array([tiny])

    # now everything in mass density
    init_values['de'] = primordial.calculate_free_electrons(init_values)
    # one signle value: again mass density
    init_values['density'] = primordial.calculate_total_density(init_values)

    num_den = {}
    for sp in primordial.required_species:
        try:
            num_den[sp.name] = init_values[sp.name]/ sp.weight
        except:
            pass

    # set up initial temperatures values used to define ge
    init_values['T'] = numpy.array([temperature])

    # calculate gammaH2
    x = 6100.0/temperature
    expx = numpy.exp(x)
    gammaH2 = 2.0 / (5.0 + 2.0*x*x*expx / (expx - 1 )**2.0 ) + 1

    gamma_factor = primordial.gamma_factor().subs(num_den).subs({'gammaH2': gammaH2 , 'gamma': 5./3.,'T': temperature })
    print(gamma_factor)
    ge  = ((temperature *  kboltz) *gamma_factor
                         / (init_values['density'] * mh  ))

    T = init_values['density']*ge*mh / kboltz / gamma_factor
    print(T-temperature)
    init_values['ge'] = numpy.array( [numpy.float64(ge)] )

    if cooling:
        for cooling_action in cooling_registry:
            k = cooling_registry[cooling_action]
            if (k.species).issubset( primordial.required_species ):
                print("adding:", k.name, k.equation)
                primordial.add_cooling(cooling_action)
                print('---------------------------')
    return init_values, primordial

# %%
from pygrackle import \
    FluidContainer, \
    chemistry_data, \
    evolve_constant_density

from pygrackle.utilities.physical_constants import \
    mass_hydrogen_cgs, \
    sec_per_Myr, \
    cm_per_mpc, \
    mass_electron_cgs

tiny_number = 1e-20
import sys

def run_grackle(density, initial_temperature, final_time):
    current_redshift = 0.

    # Set initial values


    # Set solver parameters
    my_chemistry = chemistry_data()
    my_chemistry.use_grackle = 1
    my_chemistry.with_radiative_cooling = 1
    my_chemistry.primordial_chemistry = 2
    my_chemistry.three_body_rate = 4
    my_chemistry.metal_cooling = 0
    my_chemistry.UVbackground = 0
    my_chemistry.self_shielding_method = 0
    my_chemistry.H2_self_shielding = 0
    grackle_dir = "/home/kwoksun2/grackle_install/"
    my_chemistry.grackle_data_file = os.sep.join(
        [grackle_dir, "input", "CloudyData_UVB=HM2012.h5"])
    
    my_chemistry.cie_cooling = 1
    # Set units
    my_chemistry.comoving_coordinates = 0 # proper units
    my_chemistry.a_units = 1.0
    my_chemistry.a_value = 1. / (1. + current_redshift) / \
        my_chemistry.a_units
    my_chemistry.density_units = 1.66053904e-24 #mass_hydrogen_cgs # rho = 1.0 is 1.67e-24 g
    my_chemistry.length_units = cm_per_mpc         # 1 Mpc in cm
    my_chemistry.time_units = sec_per_Myr          # 1 Myr in s
    my_chemistry.velocity_units = my_chemistry.a_units * \
        (my_chemistry.length_units / my_chemistry.a_value) / \
        my_chemistry.time_units

    rval = my_chemistry.initialize()

    fc = FluidContainer(my_chemistry, 1)
    fc["density"][:] = density
    if my_chemistry.primordial_chemistry > 0:
        fc["HI"][:] = 0.76 * fc["density"]
        fc["HII"][:] = tiny_number * fc["density"]
        fc["HeI"][:] = (1.0 - 0.76) * fc["density"]
        fc["HeII"][:] = tiny_number * fc["density"]
        fc["HeIII"][:] = tiny_number * fc["density"]
    if my_chemistry.primordial_chemistry > 1:
        fc["H2I"][:] = tiny_number * fc["density"] 
        fc["H2II"][:] = tiny_number * fc["density"]
        fc["HM"][:] = tiny_number * fc["density"]
        fc["de"][:] = 2e-4 * mass_electron_cgs / mass_hydrogen_cgs * fc["density"]
            # tiny_number * fc["density"]
    if my_chemistry.primordial_chemistry > 2:
        fc["DI"][:] = 2.0 * 3.4e-5 * fc["density"]
        fc["DII"][:] = tiny_number * fc["density"]
        fc["HDI"][:] = tiny_number * fc["density"]
    if my_chemistry.metal_cooling == 1:
        fc["metal"][:] = 0.1 * fc["density"] * \
          my_chemistry.SolarMetalFractionByMass

    fc["x-velocity"][:] = 0.0
    fc["y-velocity"][:] = 0.0
    fc["z-velocity"][:] = 0.0

    fc["energy"][:] = initial_temperature / \
        fc.chemistry_data.temperature_units
    fc.calculate_temperature()
    fc["energy"][:] *= initial_temperature / fc["temperature"]

    # timestepping safety factor
    safety_factor = 0.001
    
    tic = time.time()
    # let gas cool at constant density
    data = evolve_constant_density(
        fc, final_time=final_time,
        safety_factor=safety_factor)
    toc = time.time()

    # convert grackle language to dengo language
    name_map_dict = { 'HI':'H_1',
              'HII':'H_2',
              'HeI':'He_1',
              'HeII':'He_2',
              'HeIII':'He_3',
              'H2I' : 'H2_1',
              'H2II': 'H2_2',
              'HM' : 'H_m0',
                'de':'de',
                'temperature':'T',
                'time': 't',
                'energy':'ge'}

    weight_map_dict = { 'HI':1.00794,
              'HII':1.00794,
              'HeI':4.002602,
              'HeII':4.002602,
              'HeIII':4.002602,
               'H2II': 2.01588,
               'H2I' : 2.01588,
               'HM' : 1.00794,
                'de':1.00794,
                  'time': 1.0,
                  'temperature': 1.0,
                  'energy': 1.0}

    data_grackle = {}


    for key in name_map_dict.keys():
        key_dengo = name_map_dict[key]
        if key_dengo in ["t","T"]:
            data_grackle[key_dengo] = data[key].value
        else:
            data_grackle[key_dengo] = data[key].value / weight_map_dict[key] / u.amu_cgs.value
    
    return data_grackle, toc-tic

# %%
def calc_fftime(den):
    mu = 1.0
    rho = mu* u.mass_hydrogen *den *(u.cm**-3)
    tff = numpy.sqrt(1.0 / u.G / rho).in_units('s')
    return tff.v

# %%
density = 1e10
initial_temperature = 3000.0
final_time = calc_fftime(density)
final_time = 3.15e-3
init, primordial = Init_values(initial_temperature, 
                               density, n_species = 9, 
                               cooling=True);
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# 12209611966.1255
# [0]
# ('adding:', 'brem', -brem_brem[i]*de*(H_2 + He_2 + 4.0*He_3))
# ---------------------------
# ('adding:', 'reHII', -H_2*de*reHII_reHII[i])
# ---------------------------
# ('adding:', 'reHeIII', -He_3*de*reHeIII_reHeIII[i])
# ---------------------------
# ('adding:', 'gloverabel08', -H2_1*gloverabel08_h2lte[i]/(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0))
# ---------------------------
# ('adding:', 'ceHI', -H_1*ceHI_ceHI[i]*de)
# ---------------------------
# ('adding:', 'compton', -compton_comp_[i]*de*(z + 1.0)**4*(T - 2.73*z - 2.73))
# ---------------------------
# ('adding:', 'h2formation', 0.5*(h2formation_ncrn[i]/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0)**(-1.0)*(-H2_1*H_1*h2formation_h2mcool[i] + H_1**3*h2formation_h2mheat[i]))
# ---------------------------
# ('adding:', 'reHeII2', -He_2*de*reHeII2_reHeII2[i])
# ---------------------------
# ('adding:', 'reHeII1', -He_2*de*reHeII1_reHeII1[i])
# ---------------------------
# ('adding:', 'ciHeIS', -He_2*ciHeIS_ciHeIS[i]*de**2)
# ---------------------------
# ('adding:', 'ceHeII', -He_2*ceHeII_ceHeII[i]*de)
# ---------------------------
# ('adding:', 'ciHI', -H_1*ciHI_ciHI[i]*de)
# ---------------------------
# ('adding:', 'ceHeI', -He_2*ceHeI_ceHeI[i]*de**2)
# ---------------------------
# ('adding:', 'gammah', 0)
# ---------------------------
# ('adding:', 'cie_cooling', -H2_1*cie_cooling_cieco[i]*mdensity)
# ---------------------------
# ('adding:', 'ciHeI', -He_1*ciHeI_ciHeI[i]*de)
# ---------------------------
# ('adding:', 'ciHeII', -He_2*ciHeII_ciHeII[i]*de)
# ---------------------------

# %%
density = 1e13
initial_temperature = 3000.0
final_time = calc_fftime(density)*1e-9

final_time_Myr = u.second.in_units('Myr').v * final_time

# run grackle
grackle_data, run_time_grackle = run_grackle(density, initial_temperature, final_time_Myr)

init, primordial = Init_values(initial_temperature, 
                               density, n_species = 9, 
                               cooling=True);

# # run our solver
_, cvdls_data, run_time_cvdls = run_cvdls( initial_temperature, 
                                          density, final_time, 
                                          init=init, primordial=primordial)
# _, bechem_data, run_time_bechem = run_bechem( initial_temperature, 
#                                              density, final_time, 
#                                             init=init, primordial=primordial)
# _, cvspils_data, run_time_cvspils = run_cvspils( initial_temperature, 
#                                                 density, final_time, 
#                                                init=init, primordial=primordial)
# Out:
# Evolve constant density - t: 0.000000e+00 yr, rho: 1.660539e-11 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 2.998229e-11 yr, rho: 1.660539e-11 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 5.996457e-11 yr, rho: 1.660539e-11 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 8.994686e-11 yr, rho: 1.660539e-11 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.199291e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.499114e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000000e+03 K.
# Evolve constant density - t: 1.798937e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 2.098760e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 2.398583e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 2.698406e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 2.998229e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 3.298052e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 3.597874e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 3.897697e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 4.197520e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 4.497343e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 4.797166e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 5.096989e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 5.396812e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 5.696635e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 5.996457e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 6.296280e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 6.596103e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 6.895926e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 7.195749e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 7.495572e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 7.795395e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 8.095218e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 8.395040e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 8.694863e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 8.994686e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 9.294509e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 9.594332e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 9.894155e-10 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.019398e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.049380e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.079362e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.109345e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.139327e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.169309e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.199291e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.229274e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.259256e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.289238e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.319221e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.349203e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.379185e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.409167e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.439150e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.469132e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.499114e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.529097e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.559079e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.589061e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.619044e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.649026e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.679008e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.708990e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.738973e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.768955e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.798937e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.828920e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.858902e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.888884e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.918866e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000001e+03 K.
# Evolve constant density - t: 1.948849e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 1.978831e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.008813e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.038796e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.068778e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.098760e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.128742e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.158725e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.188707e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.218689e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.248672e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.278654e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.308636e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.338618e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.368601e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.398583e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.428565e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.458548e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.488530e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.518512e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.548494e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.578477e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.608459e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.638441e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.668424e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.698406e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.728388e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.758370e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.788353e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.818335e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.848317e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.878300e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.908282e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.938264e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.968246e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 2.998229e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.028211e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.058193e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.088176e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.118158e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.148140e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.178122e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.208105e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.238087e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.268069e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.298052e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.328034e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.358016e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.387998e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.417981e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.447963e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.477945e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.507928e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.537910e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.567892e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.597874e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.627857e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.657839e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000002e+03 K.
# Evolve constant density - t: 3.687821e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.717804e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.747786e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.777768e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.807750e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.837733e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.867715e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.897697e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.927680e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.957662e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 3.987644e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.017626e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.047609e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.077591e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.107573e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.137556e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.167538e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.197520e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.227502e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.257485e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.287467e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.317449e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.347432e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.377414e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.407396e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.437379e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.467361e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.497343e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.527325e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.557308e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.587290e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.617272e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.647255e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.677237e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.707219e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.737201e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.767184e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.797166e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.827148e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.857131e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.887113e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.917095e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.947077e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 4.977060e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.007042e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.037024e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.067007e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.096989e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.126971e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.156953e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.186936e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.216918e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.246900e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.276883e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.306865e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.336847e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.366829e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.396812e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000003e+03 K.
# Evolve constant density - t: 5.426794e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.456776e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.486759e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.516741e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.546723e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.576705e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.606688e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.636670e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.666652e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.696635e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.726617e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.756599e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.786581e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.816564e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.846546e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.876528e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.906511e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.936493e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.966475e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 5.996457e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.026440e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.056422e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.086404e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.116387e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.146369e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.176351e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.206333e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.236316e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.266298e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.296280e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.326263e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.356245e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.386227e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.416209e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.446192e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.476174e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.506156e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.536139e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.566121e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.596103e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.626085e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.656068e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.686050e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.716032e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.746015e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.775997e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.805979e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.835961e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.865944e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.895926e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.925908e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.955891e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 6.985873e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 7.015855e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 7.045837e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 7.075820e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 7.105802e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 7.135784e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 7.165767e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000004e+03 K.
# Evolve constant density - t: 7.195749e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.225731e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.255713e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.285696e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.315678e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.345660e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.375643e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.405625e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.435607e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.465590e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.495572e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.525554e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.555536e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.585519e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.615501e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.645483e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.675466e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.705448e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.735430e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.765412e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.795395e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.825377e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.855359e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.885342e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.915324e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.945306e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 7.975288e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.005271e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.035253e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.065235e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.095218e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.125200e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.155182e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.185164e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.215147e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.245129e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.275111e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.305094e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.335076e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.365058e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.395040e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.425023e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.455005e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.484987e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.514970e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.544952e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.574934e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.604916e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.634899e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.664881e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.694863e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.724846e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.754828e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.784810e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.814792e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.844775e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.874757e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.904739e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000005e+03 K.
# Evolve constant density - t: 8.934722e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 8.964704e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 8.994686e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.024668e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.054651e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.084633e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.114615e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.144598e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.174580e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.204562e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.234544e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.264527e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.294509e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.324491e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.354474e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.384456e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.414438e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.444420e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.474403e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.504385e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.534367e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.564350e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.594332e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.624314e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.654296e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.684279e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.714261e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.744243e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.774226e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.804208e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.834190e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.864172e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.894155e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.924137e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.954119e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 9.984102e-09 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.001408e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.004407e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.007405e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.010403e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.013401e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.016400e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.019398e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.022396e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.025394e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.028392e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.031391e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.034389e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.037387e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.040385e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.043384e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.046382e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.049380e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.052378e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.055377e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.058375e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.061373e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.064371e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000006e+03 K.
# Evolve constant density - t: 1.067369e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.070368e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.073366e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.076364e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.079362e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.082361e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.085359e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.088357e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.091355e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.094353e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.097352e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.100350e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.103348e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.106346e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.109345e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.112343e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.115341e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.118339e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.121338e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.124336e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.127334e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.130332e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.133330e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.136329e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.139327e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.142325e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.145323e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.148322e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.151320e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.154318e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.157316e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.160315e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.163313e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.166311e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.169309e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.172307e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.175306e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.178304e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.181302e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.184300e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.187299e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.190297e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.193295e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.196293e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.199291e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.202290e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.205288e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.208286e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.211284e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.214283e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.217281e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.220279e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.223277e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.226276e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.229274e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.232272e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.235270e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.238268e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.241267e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000007e+03 K.
# Evolve constant density - t: 1.244265e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.247263e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.250261e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.253260e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.256258e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.259256e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.262254e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.265253e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.268251e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.271249e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.274247e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.277245e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.280244e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.283242e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.286240e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.289238e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.292237e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.295235e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.298233e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.301231e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.304229e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.307228e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.310226e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.313224e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.316222e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.319221e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.322219e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.325217e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.328215e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.331214e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.334212e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.337210e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.340208e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.343206e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.346205e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.349203e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.352201e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.355199e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.358198e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.361196e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.364194e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.367192e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.370191e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.373189e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.376187e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.379185e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.382183e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.385182e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.388180e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.391178e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.394176e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.397175e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.400173e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.403171e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.406169e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.409167e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.412166e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.415164e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000008e+03 K.
# Evolve constant density - t: 1.418162e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.421160e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.424159e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.427157e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.430155e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.433153e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.436152e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.439150e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.442148e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.445146e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.448144e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.451143e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.454141e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.457139e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.460137e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.463136e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.466134e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.469132e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.472130e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.475129e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.478127e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.481125e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.484123e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.487121e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.490120e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.493118e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.496116e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.499114e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.502113e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.505111e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.508109e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.511107e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.514106e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.517104e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.520102e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.523100e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.526098e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.529097e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.532095e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.535093e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.538091e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.541090e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.544088e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.547086e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.550084e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.553082e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.556081e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.559079e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.562077e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.565075e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.568074e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.571072e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.574070e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# Evolve constant density - t: 1.577068e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000009e+03 K.
# ...
# Evolve constant density - t: 2.572480e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.575478e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.578477e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.581475e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.584473e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.587471e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.590470e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.593468e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.596466e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.599464e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.602463e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.605461e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.608459e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.611457e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.614455e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.617454e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.620452e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.623450e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.626448e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.629447e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.632445e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.635443e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.638441e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000015e+03 K.
# Evolve constant density - t: 2.641440e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.644438e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.647436e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.650434e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.653432e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.656431e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.659429e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.662427e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.665425e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.668424e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.671422e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.674420e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.677418e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.680416e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.683415e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.686413e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.689411e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.692409e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.695408e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.698406e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.701404e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.704402e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.707401e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.710399e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.713397e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.716395e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.719393e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.722392e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.725390e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.728388e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.731386e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.734385e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.737383e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.740381e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.743379e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.746378e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.749376e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.752374e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.755372e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.758370e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.761369e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.764367e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.767365e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.770363e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.773362e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.776360e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.779358e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.782356e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.785354e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.788353e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.791351e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.794349e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.797347e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.800346e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.803344e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.806342e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.809340e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.812339e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.815337e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000016e+03 K.
# Evolve constant density - t: 2.818335e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.821333e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.824331e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.827330e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.830328e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.833326e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.836324e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.839323e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.842321e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.845319e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.848317e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.851316e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.854314e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.857312e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.860310e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.863308e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.866307e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.869305e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.872303e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.875301e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.878300e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.881298e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.884296e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.887294e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.890292e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.893291e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.896289e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.899287e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.902285e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.905284e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.908282e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.911280e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.914278e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.917277e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.920275e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.923273e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.926271e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.929269e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.932268e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.935266e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.938264e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.941262e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.944261e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.947259e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.950257e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.953255e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.956254e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.959252e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.962250e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.965248e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.968246e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.971245e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.974243e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.977241e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.980239e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.983238e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.986236e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.989234e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000017e+03 K.
# Evolve constant density - t: 2.992232e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000018e+03 K.
# Evolve constant density - t: 2.995230e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000018e+03 K.
# Evolve constant density - t: 2.998229e-08 yr, rho: 1.660539e-11 g/cm^3, T: 3.000018e+03 K.
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# 12209611966125.5
# [4.54747350886464e-13]
# ('adding:', 'brem', -brem_brem[i]*de*(H_2 + He_2 + 4.0*He_3))
# ---------------------------
# ('adding:', 'reHII', -H_2*de*reHII_reHII[i])
# ---------------------------
# ('adding:', 'reHeIII', -He_3*de*reHeIII_reHeIII[i])
# ---------------------------
# ('adding:', 'gloverabel08', -H2_1*gloverabel08_h2lte[i]/(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0))
# ---------------------------
# ('adding:', 'ceHI', -H_1*ceHI_ceHI[i]*de)
# ---------------------------
# ('adding:', 'compton', -compton_comp_[i]*de*(z + 1.0)**4*(T - 2.73*z - 2.73))
# ---------------------------
# ('adding:', 'h2formation', 0.5*(h2formation_ncrn[i]/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0)**(-1.0)*(-H2_1*H_1*h2formation_h2mcool[i] + H_1**3*h2formation_h2mheat[i]))
# ---------------------------
# ('adding:', 'reHeII2', -He_2*de*reHeII2_reHeII2[i])
# ---------------------------
# ('adding:', 'reHeII1', -He_2*de*reHeII1_reHeII1[i])
# ---------------------------
# ('adding:', 'ciHeIS', -He_2*ciHeIS_ciHeIS[i]*de**2)
# ---------------------------
# ('adding:', 'ceHeII', -He_2*ceHeII_ceHeII[i]*de)
# ---------------------------
# ('adding:', 'ciHI', -H_1*ciHI_ciHI[i]*de)
# ---------------------------
# ('adding:', 'ceHeI', -He_2*ceHeI_ceHeI[i]*de**2)
# ---------------------------
# ('adding:', 'gammah', 0)
# ---------------------------
# ('adding:', 'cie_cooling', -H2_1*cie_cooling_cieco[i]*mdensity)
# ---------------------------
# ('adding:', 'ciHeI', -He_1*ciHeI_ciHeI[i]*de)
# ---------------------------
# ('adding:', 'ciHeII', -He_2*ciHeII_ciHeII[i]*de)
# ---------------------------
# three body rate: 4
# initial  temperature: 3.000E+03
# Successful iteration[    0]: (9.462e-05) 9.462e-05 / 9.462e-01
# End in 73 iterations: 9.46169e-01 / 9.46169e-01 (0.00000e+00)

# %%
flag_cvdls = cvdls_data['successful']
t_cvdls = cvdls_data['t'][flag_cvdls]


# flag_bechem = bechem_data['successful']
# t_bechem = bechem_data['t'][flag_bechem]

# flag_cvspils = cvspils_data['successful']
# t_cvspils = cvspils_data['t'][flag_cvspils]

t_grackle = grackle_data['t']
flag_grackle = (t_grackle > 1e0)

plt.figure(figsize=(8,8))
for key in cvdls_data.keys():
    if key not in ['t', 'successful','dt','ge']:
        print(key)
        cvdls_d = cvdls_data[key][0][flag_cvdls]
        plt.semilogx( t_cvdls, cvdls_d,label=key)

#plt.gca().set_color_cycle(None)    
# for key in cvdls_data.keys():
#     if key not in ['t','successful','dt','ge']:
        
#         bechem_d = bechem_data[key][0][flag_bechem]
#         plt.semilogx( t_bechem, bechem_d, ls ='--')

# plt.gca().set_color_cycle(None)        
# for key in cvdls_data.keys():
#     if key not in ['t', 'successful','dt','ge']:
        
#         cvspils_d = cvspils_data[key][0][flag_cvspils]
#         plt.semilogx( t_cvspils, cvspils_d, ls= ':')
        
for key in cvdls_data.keys():
    if key not in ['t', 'successful','dt','ge']:
        
        grack_d = grackle_data[key]
        plt.loglog( t_grackle, grack_d, ls='-.')

plt.title('cvdls( - {})  \n grackle ( -. {})  '.format(run_time_cvdls, run_time_grackle) )

plt.legend()
plt.show()
# Out:
# H_2
# H_1
# de
# He_1
# He_2
# He_3
# H2_2
# H2_1
# H_m0
# T

# %%
cvdls_d = cvdls_data['T'][0][flag_cvdls]   
3000.0/cvdls_d

# %%
flag_cvdls = cvdls_data['successful']
grack_d = grackle_data['T']
# bechem_d = bechem_data['T'][0][flag_bechem]
cvdls_d = cvdls_data['T'][0][flag_cvdls]   
plt.semilogx(t_grackle,grack_d)
plt.semilogx(t_cvdls, cvdls_d, label='cvdls')
plt.legend()
plt.show()

# %%
flag_cvdls = cvdls_data['successful']
t_cvdls = cvdls_data['t'][flag_cvdls]
t_grackle = grackle_data['t']

flag_grackle = (t_grackle > min(t_cvdls))

plt.figure(figsize=(8,8))
for key in grackle_data.keys():
    if key not in ['t','de','ge']:
        grack_d = grackle_data[key][flag_grackle]
        cvdls_d = cvdls_data[key][0][flag_cvdls]
        interp_cvdls_data = numpy.interp( t_grackle[flag_grackle], t_cvdls, cvdls_d )
        plt.semilogx( t_grackle[flag_grackle], grack_d/interp_cvdls_data,label=key)

plt.title('grackle (run_time = {}) / cvdls (run_time : {}) '.format(run_time_grackle,run_time_cvdls) )
plt.ylim(0.9,1.1)
plt.legend()
plt.show()

# %%
plt.loglog( t_cvdls, cvdls_data['ge'][0][flag_cvdls] )
plt.semilogx( t_grackle, grackle_data['ge'], ls='-.')
plt.show()

# %%
def conservation_of_M_e(data, flag_input=False):
    
    if flag_input:        
        flag = data['successful']
        size = len(data['t'][flag])
    else:
        flag = (data['t'] >= 0)
        size = len(data['t'])

        
    zeros = numpy.zeros((size))
    conserv_dict = {'H': zeros, 
                    'H2':zeros,
                    'He':zeros, 
                    'de':zeros, 
                    't': zeros, 
                    'de_':zeros}

    for key in data.keys():
        ele_charge = key.split('_')
        if ele_charge[0] in ['H', 'He']:

            name = ele_charge[0]
            if flag_input:
                conserv_dict[name] += data[key][0][flag]
            else:
                conserv_dict[name] += data[key][flag]
            try:
                charge = eval(ele_charge[1]) - 1
                if flag_input:
                    conserv_dict['de'] += charge*data[key][0][flag]
                else:
                    conserv_dict['de'] += charge*data[key][flag]
            except:
                if ele_charge[1][0] == 'm':             
                    charge = eval(ele_charge[1][1]) - 1
                    if flag_input:
                        conserv_dict['de'] += charge*data[key][0][flag]
                    else:
                        conserv_dict['de'] += charge*data[key][flag]
    
    conserv_dict['t'] = data['t'][flag]
    if flag_input:
        conserv_dict['de_'] = data['de'][0][flag]
    else:
        conserv_dict['de_'] = data['de'][flag]
    return conserv_dict

# %%
conserv_dict_grackle = conservation_of_M_e(grackle_data)
conserv_dict_cvdls = conservation_of_M_e(cvdls_data, flag_input=True)

# %%
t_gra = conserv_dict_grackle['t']
t_cvdls = conserv_dict_cvdls['t']

H_gra = conserv_dict_grackle['H']
H_cvdls = conserv_dict_cvdls['H']

H2_gra = conserv_dict_grackle['H2']
H2_cvdls = conserv_dict_cvdls['H2']

He_gra = conserv_dict_grackle['He']
He_cvdls = conserv_dict_cvdls['He']

de_gra = conserv_dict_grackle['de']
de_cvdls = conserv_dict_cvdls['de']

de__gra = conserv_dict_grackle['de_']
de__cvdls = conserv_dict_cvdls['de_']

plt.clf()
plt.plot( t_gra, (H_gra + 2.0*H2_gra)/(H_gra + 2.0*H2_gra)[0] ,color= 'r',ls='--')
plt.plot( t_cvdls, (H_cvdls + 2.0*H2_cvdls)/(H_cvdls + 2.0*H2_cvdls)[0] ,color= 'r',label='H')

plt.plot( t_gra, He_gra/He_gra[0]  ,color= 'b',ls='--')
plt.plot( t_cvdls, He_cvdls/He_cvdls[0] ,color= 'b',label='He')


net_charge_cvdls = (cvdls_data['H2_2'] + cvdls_data['H_2'] - cvdls_data['H_m0'] + cvdls_data["He_2"] + \
                2.0*cvdls_data["He_3"])/ cvdls_data["de"]

net_charge_gra = (grackle_data['H2_2'] + grackle_data['H_2'] - grackle_data['H_m0'] + grackle_data["He_2"] + \
                2.0*grackle_data["He_3"])/ grackle_data["de"]

t_cvdls = cvdls_data['t']
plt.plot( t_gra, net_charge_gra,color='g' ,ls='--')
plt.plot( t_cvdls, net_charge_cvdls[0],color='g',label='de')
plt.title('conservation')
plt.xlabel('time (s)')
plt.ylabel('fractional abundance')
plt.legend()
# plt.ylim(0.9,1.1)
plt.show()

# %%
temperature = 100.0

# %%
x = 6100.0/temperature
expx = numpy.exp(x)
gammaH2 = 2.0 / (5.0 + 2.0*x*x*expx / (expx - 1 )**2.0 ) + 1

# %%
gammaH2

# %%
temperature = numpy.logspace(0,5,100)
x = 6100.0/temperature
expx = numpy.exp(x)
gammaH2 = 2.0 / (5.0 + 2.0*x*x*expx / (expx - 1 )**2.0 ) + 1
plt.semilogx(temperature,1.0 / (gammaH2-1) )

# %%
mh

# %%
sp = species_registry['H2_1']

# %%
expr = primordial.species_gamma(sp, temp=True)

# %%
from sympy.utilities import lambdify

# %%
fH2 = lambdify('T', expr)

# %%
plt.plot(T, fH2(T))

# %%
T = numpy.logspace(0,5,100)

# %%
fH2(T)

# %%
T

# %%
a0 = 64.2416
a1 = -9.36334
a2 = -0.377266
a3 = 69.8091
a4 = 0.0493452
a5 = 2.28021
a6 = 0.115357
a7 = 0.114188
a8 = 2.90778
a9 = 0.689708

T0 = numpy.logspace(0,1,1024)

gamma_T = sympy.exp(-a0*T**a1)*(a2+T**-a3) \
            + a4*sympy.exp( - (T-a5)**2 / a6)\
            + a7*sympy.exp( -(T-a8)**2 / a9) \
            + 5./3.
T_array = numpy.logspace(0,6.5,1024)

# %%
print(T_array)
plt.plot(T0, T_array)
plt.plot(T_array**(1./6.5), T_array ) 
plt.show()

# %%
import sympy

# %%
plt.semilogx(T_array, gamma_T)

T = primordial.T
plt.semilogx(primordial.T, gammaH2)
plt.ylim(1.2,1.7)

# %%
T0 = numpy.logspace(0,6.5,1024)

gamma_T = numpy.exp(-a0*T0**a1)*(a2+T0**-a3) \
            + a4*numpy.exp( - (T0-a5)**2 / a6)\
            + a7*numpy.exp( -(T0-a8)**2 / a9) \
            + 5./3.
T_array = numpy.logspace(0,6.5,1024)

plt.semilogx(T_array, gamma_T)

T = primordial.T
plt.semilogx(primordial.T, gammaH2)
plt.ylim(1.2,1.7)

# %%
gammaH2 = primordial.interpolate_species_gamma(sp)
dgammaH2_dT = primordial.interpolate_species_gamma(sp, deriv=True)

# %%
# plt.semilogx(primordial.T,gammaH2)
plt.semilogx(primordial.T,dgammaH2_dT)
plt.show()

# %%
primordial.temperature_calculation(derivative_dge_dT=True)

# %%
import sympy

sp = species_registry['H2_1']
T = sympy.Symbol('T')

T = sympy.Symbol('T')
f = primordial.gamma_factor(temp=True) * sympy.Symbol('kb') * sympy.Symbol('T') \
        / sympy.Symbol('mh') / sympy.Symbol('density')
dge_dT = sympy.diff(f, T)


sym_fgamma = sympy.Function('gamma%s' %sp.name)(T)
sym_dfgamma = sympy.diff(sym_fgamma, T)
sym_gamma = sympy.Function('gamma%s' %sp.name)
dgamma = sympy.Symbol('dgamma%s_dT' %sp.name)
dge_dT = dge_dT.subs({sym_dfgamma: dgamma}).subs({sym_fgamma:sym_gamma})

# %%
tmp = sympy.Symbol('tmp')

# %%
dge_dT.subs({sym_fgamma:tmp}).subs({tmp: t})

# %%
print(sym_fgamma)
sym_gamma

# %%
(5.0 + 74420000.0*(numpy.exp(6100.0/T) - 1)**(-2.0)/T/T)

# %%
x = 6100.0/T

expx = numpy.exp(x)

gammaH2 = 2.0/(5.0+ 2.0*x*x*expx/(expx-1)/(expx-1)) + 1
gammaH2[numpy.isnan(gammaH2)] = 1.4
gammaH2[gammaH2<1.2] = 1.4

# %%
len(gammaH2)

# %%
gammaH2 = sympy.Function('gammaH2T')(T)

# %%
sym_dgammaH2_dT = diff(gammaH2,T)

# %%
kkk = sympy.Symbol('dgH2_dT')

# %%
gammaH2

# %%
ddd = diff(gammaH2 + expr,T)

# %%
ddd.subs({sym_dgammaH2_dT: kkk})

# %%
primordial.species_gamma(sp, temp=False)

# %%
word = ['a','b', 'ba', 'bca','bda','bdca']

# %%
def longestChain(words):
    set_of_words = set(words)
    max_length = 0
    
    for word in words:
        length = len(word)
        if length > max_length:
            max_length = hello(word, 0, words)
    return max_length
            
def hello(word, count, words):
    length = len(word)
    empty_list = [count]
    for i in range(length):
        w = word[:i] + word[i+1:]
        if w in words:
            empty_list.append(hello(w, count+1, words))
    return max(empty_list)

# %%
word = ["a",'b','ba','bca','bda','bdca']

# %%
def longestChain(words):
    set_of_words = set(words)
    max_length = 0
    
    for word in words:
        length = len(word)
        if length > max_length:
            max_length = hello(word, 0, set_of_words)
    return max_length + 1
            
def hello(word, count, set_of_words):
    length = len(word)
    empty_list = [count]
    for i in range(length):
        w = word[:i] + word[i+1:]
        if w in set_of_words:
            empty_list.append(hello(w, count+1, set_of_words))
    return max(empty_list)

# %%
longestChain(['b','ab','ac','1435','143','14','4'])

# %%
def longestChain(words):
    set_of_words = set(words)
    max_length = 0
    string_chain = {}
    
    for word in words:
        length = len(word)
        if length > max_length:
            max_length = hello(word, set_of_words, string_chain)
    return max_length
            
def hello(word, count, set_of_words, string_chain):
    if word not in string_chain:
        m = 1
        for i in range(len(word)):
            w = word[:i] + word[i+1:]
            if w != [] and w in set_of_words:
                count = hello(w, set_of_words, string_chain)
                m = max(m, 1 + count)
        string_chain[word] = m
            
    return string_chain[word]

# %%
def longestChain(words):
    set_of_words = set(words) # Storing list of words in a set for efficient lookup
    max_length = 0 # Maximum length of string chain encountered yet
    string_chain = {} # Remembering string_chain length of strings already encountered
    count = 1 # Initial value for string chain length
    
    for word in words:
        print(string_chain)
        max_length = max(max_length, memoized_length(word, count, set_of_words, string_chain))
    
    return max_length
            
def memoized_length(word, count, set_of_words, string_chain): 
    """
    Depth first search with memoization
    """
    if word in string_chain:
        return count + string_chain[word] 
    else:
        length = len(word)
        depth_list = [count]
        for i in range(length):
            w = word[:i] + word[i+1:]
            if w and w in set_of_words:
                depth_list.append(memoized_length(w, count + 1, set_of_words, string_chain))
        string_chain[word] = max(depth_list) - count
            
    return max(depth_list) # Maximum depth of the tree

# %%
primordial.interpolate_species_gamma(sp)

# %% [raw]
# sp = species_registry['H2_2']

# %%
sorted

# %%
primordial.interpolate_gamma_species_named
