# %%
import os
os.environ['YT_DEST'] = '/home/kwoksun2/anaconda2/pkgs/yt-3.3.5-np111py27_2/'
import numpy as np
from dengo.chemical_network import \
    ChemicalNetwork, \
    reaction_registry, \
    cooling_registry, species_registry
import dengo.primordial_rates, dengo.primordial_cooling
from dengo.chemistry_constants import tiny, kboltz, mh
import yt
import numpy

import matplotlib.pyplot as plt

import pyximport
pyximport.install(setup_args={"include_dirs":np.get_include()},
                      reload_support=True, inplace=True)

# %%
def equil_values(init_values, primordial, t =3.16e12, niter= 1e6, full_output = False):
    
    # !rm sunny*
    
    primordial.write_solver("sunny", output_dir = ".",
                            init_values=init_values,
                            input_is_number=False)

    sunny_solver_run = pyximport.load_module("sunny_solver_run",
                                "sunny_solver_run.pyx",
                                build_inplace = True, pyxbuild_dir = "_dengo_temp")
    rv, rv_int = sunny_solver_run.run_sunny(init_values, t, niter=niter) ;
    
    mask = rv_int['successful']
    
    if full_output:
        return rv_int, 0
    else:
        return rv_int['H_1'][:, mask][:,-1] / init_values['density'], rv_int['t'][mask][-1]

# %%
def Init_values(temperature, density, fH):
    X = 0.75

    # initialize and setup the network
    dengo.primordial_rates.setup_primordial()
    primordial = ChemicalNetwork()

    for i in range(23):
        try: 
            primordial.add_reaction("k{0:02d}".format(i+1))
        except:
            pass
    
    
    primordial.init_temperature((1e0, 1e5))

    tiny = 1e-10

    # init_array are is in fractional abundances
    init_array = density
    init_values = dict()

    init_values["H_1"]     = fH* X * init_array    
    init_values['H_2']     =  X *tiny* init_array
    init_values["H_m0"]     = X *tiny* init_array

    init_values["H2_1"]     = (1.0-fH) *X* init_array
    init_values["H2_2"]     = tiny *X* init_array

    init_values["He_1"] = ( 1.0 - X )*init_array
    init_values["He_2"] = ( 1.0 - X )*tiny*init_array
    init_values["He_3"] = ( 1.0 - X )*tiny*init_array

    # now everything in mass density
    init_values = primordial.convert_to_mass_density(init_values)
    init_values['de'] = primordial.calculate_free_electrons(init_values)
    # one signle value: again mass density
    init_values['density'] = primordial.calculate_total_density(init_values)
    number_density = primordial.calculate_number_density(init_values)

    # set up initial temperatures values used to define ge
    init_values['T'] = temperature

    # calculate ge (very crudely, no H2 help here)
    gamma = 5.0/3.0
    init_values['ge'] = ((temperature * number_density * kboltz)
                         / (init_values['density'] * mh * (gamma - 1)))
    return init_values, primordial

# %%
def main(fH, temp, den , full_output = False):
    
    
    temp = temp.flatten()
    den = den.flatten()
    
    h_array = numpy.zeros((len(temp), len(den)))
    t_array = numpy.zeros((len(den)))
    
    h_array = []
    t_array = []
    
    print(den)
    for iden, den_arr in enumerate(den):
        
        den_arr = numpy.ones((len(temp)))*den_arr
        
        init_values, primordial = Init_values(temp, den_arr, fH)
        h_array_now, t_array_now = equil_values(init_values, primordial, full_output = full_output)
        
        h_array.append(h_array_now)
        t_array.append(t_array_now)
        
    return h_array, t_array

# %%
result_H = []
result_t = []

for fH in numpy.logspace(-3, -1.0e-5, 3):
    print(fH)
    
    dendim = 32
    tempdim = 32
    
    temp = numpy.linspace(1e2,5e3, tempdim)
    den = numpy.logspace(10,18, dendim)
    
    temp_mesh, den_mesh = numpy.meshgrid(temp,den)
    
    try:
        nowH,nowt = main(fH, temp, den)
        nowH = nowH.reshape((tempdim, dendim))
        result_H.append(nowH)
        result_t.append(nowt)
    except:
        nowH = numpy.zeros((tempdim,dendim))
        result_H.append(nowH)
        result_t.append(numpy.array([0]))
    plt.pcolor(temp_mesh, den_mesh, numpy.log10(nowH))
    plt.yscale('log')
    
    plt.colorbar()
    plt.show()
    
    numpy.save('fH_array={}.npy'.format(fH), result_H )
# Out:
# 0.001
# [  1.00000000e+10   1.81160919e+10   3.28192787e+10   5.94557071e+10
#    1.07710506e+11   1.95129342e+11   3.53498111e+11   6.40400427e+11
#    1.16015530e+12   2.10174801e+12   3.80754602e+12   6.89778538e+12
#    1.24960914e+13   2.26380341e+13   4.10112707e+13   7.42963951e+13
#    1.34596032e+14   2.43835410e+14   4.41734470e+14   8.00250228e+14
#    1.44974067e+15   2.62636353e+15   4.75794431e+15   8.61953566e+15
#    1.56152301e+16   2.82886943e+16   5.12480588e+16   9.28414545e+16
#    1.68192432e+17   3.04698957e+17   5.51995432e+17   1.00000000e+18]
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_2 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log10
# 0.0316224125331
# [  1.00000000e+10   1.81160919e+10   3.28192787e+10   5.94557071e+10
#    1.07710506e+11   1.95129342e+11   3.53498111e+11   6.40400427e+11
#    1.16015530e+12   2.10174801e+12   3.80754602e+12   6.89778538e+12
#    1.24960914e+13   2.26380341e+13   4.10112707e+13   7.42963951e+13
#    1.34596032e+14   2.43835410e+14   4.41734470e+14   8.00250228e+14
#    1.44974067e+15   2.62636353e+15   4.75794431e+15   8.61953566e+15
#    1.56152301e+16   2.82886943e+16   5.12480588e+16   9.28414545e+16
#    1.68192432e+17   3.04698957e+17   5.51995432e+17   1.00000000e+18]
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_2 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-99e558b0e38b> in <module>()
#      22         result_H.append(nowH)
#      23         result_t.append(numpy.array([0]))
# ---> 24     plt.pcolor(temp_mesh, den_mesh, numpy.log10(nowH))
#      25     plt.yscale('log')
#      26
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in pcolor(*args, **kwargs)
#    3210 @_autogen_docstring(Axes.pcolor)
#    3211 def pcolor(*args, **kwargs):
# -> 3212     ax = gca()
#    3213     # Deprecated: allow callers to override the hold state
#    3214     # by passing hold=True|False
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in gca(**kwargs)
#     948     matplotlib.figure.Figure.gca : The figure's gca method.
#     949     """
# --> 950     return gcf().gca(**kwargs)
#     951
#     952 # More ways of creating axes:
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in gca(self, **kwargs)
#    1367
#    1368         # no axes found, so create one which spans the figure
# -> 1369         return self.add_subplot(1, 1, 1, **kwargs)
#    1370
#    1371     def sca(self, a):
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1019                     self._axstack.remove(ax)
#    1020
# -> 1021             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1022
#    1023         self._axstack.add(key, a)
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     527
#     528         # this call may differ for non-sep axes, e.g., polar
# --> 529         self._init_axis()
#     530         if axisbg is not None and facecolor is not None:
#     531             raise TypeError('Both axisbg and facecolor are not None. '
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _init_axis(self)
#     621         "move this out of __init__ because non-separable axes don't use it"
#     622         self.xaxis = maxis.XAxis(self)
# --> 623         self.spines['bottom'].register_axis(self.xaxis)
#     624         self.spines['top'].register_axis(self.xaxis)
#     625         self.yaxis = maxis.YAxis(self)
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/spines.pyc in register_axis(self, axis)
#     161         self.axis = axis
#     162         if self.axis is not None:
# --> 163             self.axis.cla()
#     164         self.stale = True
#     165
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     773
#     774         self.majorTicks.extend([self._get_tick(major=True)])
# --> 775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#     777         self._lastNumMinorTicks = 1
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
# --> 152         self.gridline = self._get_gridline()
#     153
#     154         self.label1 = self._get_text1()
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_gridline(self)
#     446                           linewidth=rcParams['grid.linewidth'],
#     447                           alpha=rcParams['grid.alpha'],
# --> 448                           markersize=0)
#     449         l.set_transform(self.axes.get_xaxis_transform(which='grid'))
#     450         l.get_path()._interpolation_steps = GRIDLINE_INTERPOLATION_STEPS
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     352             antialiased = rcParams['lines.antialiased']
#     353         if dash_capstyle is None:
# --> 354             dash_capstyle = rcParams['lines.dash_capstyle']
#     355         if dash_joinstyle is None:
#     356             dash_joinstyle = rcParams['lines.dash_joinstyle']
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in __getitem__(self, key)
#     939             key = alt_key
#     940
# --> 941         elif key in _deprecated_ignore_map:
#     942             alt = _deprecated_ignore_map[key]
#     943             warnings.warn(self.msg_depr_ignore % (key, alt))
#
# KeyboardInterrupt:

# %%
for ifH, fH in enumerate(numpy.logspace(-3, -1.0e-5, 3)):    

    plt.pcolor(den_mesh, temp_mesh, numpy.log10(result_H[ifH]) )
    plt.xscale('log')
    plt.title('initial fH = {}'.format(fH, ))
    plt.colorbar()
    plt.show()

# %%
result_tarr = numpy.array(result_t).transpose()
plt.plot(den, result_tarr)
plt.xscale('log')
plt.show()

# %%
import imageio
images = []


result_H = numpy.load('H_aray_1e5.npy')
result_t = numpy.load('t_aray_1e5.npy')
dendim = 32
tempdim = 32
    
temp = numpy.linspace(1e2,5e3, tempdim)
den = numpy.logspace(10,20, dendim)
    
temp, den = numpy.meshgrid(temp,den)

for ifH, fH in enumerate(numpy.logspace(-3, 0, 5)):
    print(result_t[ifH])
    print(fH)
    
    plt.clf()
    plt.title('Starting with f(H) = {0:f}, ending at {1:f} s'.format(fH, result_t[ifH]))
    plt.pcolor(den, temp, numpy.log10(result_H[ifH]).transpose())
    plt.xscale('log')
    plt.xlabel('Density (cm**-3)')
    plt.ylabel('Tempereature (K)')
    if ifH <= 0.5:
        plt.colorbar()
    plt.savefig('fH={0}.png'.format(fH))
    
    images.append(imageio.imread('fH={0}.png'.format(fH)))

imageio.mimsave('fH.gif', images)

# %%
from IPython.display import Image
Image('fH={}.png'.format(numpy.logspace(-3, 0, 5)[0]))

# %%
result_H = []
result_t = []

for fH in numpy.logspace(-3, 0, 5):
    print(fH)
    
    dendim = 32
    tempdim = 32
    
    temp = numpy.linspace(1e2,5e3, tempdim)
    den = numpy.logspace(10,20, dendim)
    
    temp, den = numpy.meshgrid(temp,den)

    
    try:
        nowH,nowt = main(fH, temp, den)
        nowH = nowH.reshape((tempdim, dendim))
        result_H.append(nowH)
        result_t.append(nowt)
    except:
        nowH = numpy.zeros((tempdim,dendim))
        result_H.append(nowH)
        result_t.append(numpy.array([0]))
    plt.pcolor(temp, den, numpy.log10(nowH))
    plt.yscale('log')
    
    plt.colorbar()
    plt.show()

# %%
temp = numpy.linspace(100,5000,100)
den = 1e15

# %%
init, network = Init_values(temp,den, 1.0)
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_2 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1

# %%
result_H = []
result_t = []


    
dendim = 3.0
tempdim = 3.0
    
temp = numpy.linspace(1.0e2,5.0e3, tempdim)
den = numpy.logspace(14.0,16.0, dendim)

print(temp,den)
temp_mesh, den_mesh = numpy.meshgrid(temp,den)
    
nowH, nowt = main( 0.99, temp, den, full_output = True)

result_H.append(nowH)
result_t.append(nowt)
# Out:
# (array([  100.,  2550.,  5000.]), array([  1.00000000e+14,   1.00000000e+15,   1.00000000e+16]))
# [  1.00000000e+14   1.00000000e+15   1.00000000e+16]
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_2 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# End in 370 iterations: 3.16000e+12 / 3.16000e+12 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_2 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# Successful iteration[ 1000]: (9.560e+01) 9.487e+04 / 3.160e+12
# Successful iteration[ 2000]: (8.710e+01) 1.595e+05 / 3.160e+12
# Successful iteration[ 3000]: (7.935e+01) 2.234e+05 / 3.160e+12
# Successful iteration[ 4000]: (7.229e+01) 2.883e+05 / 3.160e+12
# Successful iteration[ 5000]: (6.586e+01) 3.527e+05 / 3.160e+12
# Successful iteration[ 6000]: (6.000e+01) 4.169e+05 / 3.160e+12
# Successful iteration[ 8000]: (1.096e+02) 5.460e+05 / 3.160e+12
# Successful iteration[ 9000]: (9.982e+01) 6.109e+05 / 3.160e+12
# Successful iteration[ 10000]: (9.094e+01) 6.750e+05 / 3.160e+12
# Successful iteration[ 11000]: (8.285e+01) 7.394e+05 / 3.160e+12
# Successful iteration[ 12000]: (7.548e+01) 8.044e+05 / 3.160e+12
# Successful iteration[ 13000]: (6.877e+01) 8.690e+05 / 3.160e+12
# Successful iteration[ 14000]: (6.265e+01) 9.338e+05 / 3.160e+12
# Successful iteration[ 15000]: (5.708e+01) 9.977e+05 / 3.160e+12
# Successful iteration[ 16000]: (5.200e+01) 1.063e+06 / 3.160e+12
# Successful iteration[ 17000]: (1.042e+02) 1.128e+06 / 3.160e+12
# Successful iteration[ 18000]: (9.495e+01) 1.192e+06 / 3.160e+12
# Successful iteration[ 20000]: (7.881e+01) 1.321e+06 / 3.160e+12
# Successful iteration[ 21000]: (7.180e+01) 1.386e+06 / 3.160e+12
# Successful iteration[ 22000]: (6.541e+01) 1.451e+06 / 3.160e+12
# Successful iteration[ 23000]: (5.959e+01) 1.515e+06 / 3.160e+12
# Successful iteration[ 26000]: (9.914e+01) 1.710e+06 / 3.160e+12
# Successful iteration[ 27000]: (4.106e+01) 1.774e+06 / 3.160e+12
# Successful iteration[ 28000]: (8.229e+01) 1.840e+06 / 3.160e+12
# Successful iteration[ 29000]: (7.497e+01) 1.905e+06 / 3.160e+12
# Successful iteration[ 30000]: (6.830e+01) 1.969e+06 / 3.160e+12
# Successful iteration[ 31000]: (6.222e+01) 2.034e+06 / 3.160e+12
# Successful iteration[ 32000]: (5.669e+01) 2.100e+06 / 3.160e+12
# Successful iteration[ 35000]: (9.431e+01) 2.293e+06 / 3.160e+12
# Successful iteration[ 36000]: (8.592e+01) 2.358e+06 / 3.160e+12
# Successful iteration[ 37000]: (7.828e+01) 2.423e+06 / 3.160e+12
# Successful iteration[ 38000]: (7.131e+01) 2.487e+06 / 3.160e+12
# Successful iteration[ 40000]: (5.919e+01) 2.617e+06 / 3.160e+12
# Successful iteration[ 41000]: (5.392e+01) 2.682e+06 / 3.160e+12
# Successful iteration[ 43000]: (9.847e+01) 2.810e+06 / 3.160e+12
# Successful iteration[ 44000]: (8.971e+01) 2.875e+06 / 3.160e+12
# Successful iteration[ 45000]: (8.173e+01) 2.940e+06 / 3.160e+12
# Successful iteration[ 46000]: (7.446e+01) 3.005e+06 / 3.160e+12
# Successful iteration[ 47000]: (6.784e+01) 3.069e+06 / 3.160e+12
# Successful iteration[ 49000]: (5.630e+01) 3.200e+06 / 3.160e+12
# Successful iteration[ 50000]: (5.130e+01) 3.264e+06 / 3.160e+12
# Successful iteration[ 52000]: (4.258e+01) 3.394e+06 / 3.160e+12
# Successful iteration[ 53000]: (8.533e+01) 3.459e+06 / 3.160e+12
# Successful iteration[ 54000]: (7.774e+01) 3.523e+06 / 3.160e+12
# Successful iteration[ 55000]: (7.083e+01) 3.588e+06 / 3.160e+12
# Successful iteration[ 57000]: (5.879e+01) 3.718e+06 / 3.160e+12
# Successful iteration[ 58000]: (5.356e+01) 3.783e+06 / 3.160e+12
# Successful iteration[ 59000]: (4.879e+01) 3.846e+06 / 3.160e+12
# Successful iteration[ 61000]: (8.910e+01) 3.976e+06 / 3.160e+12
# Successful iteration[ 62000]: (8.117e+01) 4.041e+06 / 3.160e+12
# Successful iteration[ 63000]: (7.395e+01) 4.105e+06 / 3.160e+12
# Successful iteration[ 65000]: (6.138e+01) 4.236e+06 / 3.160e+12
# Successful iteration[ 66000]: (5.592e+01) 4.300e+06 / 3.160e+12
# Successful iteration[ 67000]: (5.095e+01) 4.364e+06 / 3.160e+12
# Successful iteration[ 68000]: (1.021e+02) 4.429e+06 / 3.160e+12
# Successful iteration[ 70000]: (8.475e+01) 4.559e+06 / 3.160e+12
# Successful iteration[ 71000]: (7.721e+01) 4.623e+06 / 3.160e+12
# Successful iteration[ 72000]: (7.035e+01) 4.688e+06 / 3.160e+12
# Successful iteration[ 74000]: (5.839e+01) 4.817e+06 / 3.160e+12
# Successful iteration[ 75000]: (5.319e+01) 4.882e+06 / 3.160e+12
# Successful iteration[ 76000]: (1.066e+02) 4.946e+06 / 3.160e+12
# Successful iteration[ 78000]: (8.849e+01) 5.076e+06 / 3.160e+12
# Successful iteration[ 79000]: (8.062e+01) 5.141e+06 / 3.160e+12
# Successful iteration[ 80000]: (7.345e+01) 5.205e+06 / 3.160e+12
# Successful iteration[ 81000]: (6.692e+01) 5.270e+06 / 3.160e+12
# Successful iteration[ 82000]: (6.096e+01) 5.334e+06 / 3.160e+12
# Successful iteration[ 83000]: (1.222e+02) 5.399e+06 / 3.160e+12
# Successful iteration[ 84000]: (5.060e+01) 5.464e+06 / 3.160e+12
# Successful iteration[ 86000]: (9.240e+01) 5.594e+06 / 3.160e+12
# Successful iteration[ 87000]: (8.418e+01) 5.658e+06 / 3.160e+12
# Successful iteration[ 88000]: (7.669e+01) 5.723e+06 / 3.160e+12
# Successful iteration[ 89000]: (6.987e+01) 5.788e+06 / 3.160e+12
# Successful iteration[ 91000]: (5.799e+01) 5.917e+06 / 3.160e+12
# Successful iteration[ 92000]: (5.283e+01) 5.981e+06 / 3.160e+12
# Successful iteration[ 93000]: (4.813e+01) 6.046e+06 / 3.160e+12
# Successful iteration[ 95000]: (8.789e+01) 6.175e+06 / 3.160e+12
# Successful iteration[ 96000]: (8.007e+01) 6.240e+06 / 3.160e+12
# Successful iteration[ 97000]: (7.295e+01) 6.304e+06 / 3.160e+12
# Successful iteration[ 98000]: (6.646e+01) 6.369e+06 / 3.160e+12
# Successful iteration[ 99000]: (6.055e+01) 6.433e+06 / 3.160e+12
# Successful iteration[ 100000]: (5.516e+01) 6.497e+06 / 3.160e+12
# Successful iteration[ 101000]: (1.106e+02) 6.563e+06 / 3.160e+12
# Successful iteration[ 103000]: (9.177e+01) 6.691e+06 / 3.160e+12
# Successful iteration[ 104000]: (8.361e+01) 6.756e+06 / 3.160e+12
# Successful iteration[ 105000]: (7.617e+01) 6.821e+06 / 3.160e+12
# Successful iteration[ 106000]: (6.939e+01) 6.886e+06 / 3.160e+12
# Successful iteration[ 107000]: (6.322e+01) 6.950e+06 / 3.160e+12
# Successful iteration[ 108000]: (5.760e+01) 7.014e+06 / 3.160e+12
# Successful iteration[ 109000]: (5.247e+01) 7.080e+06 / 3.160e+12
# Successful iteration[ 111000]: (9.582e+01) 7.208e+06 / 3.160e+12
# Successful iteration[ 112000]: (8.729e+01) 7.272e+06 / 3.160e+12
# Successful iteration[ 113000]: (7.953e+01) 7.337e+06 / 3.160e+12
# Successful iteration[ 114000]: (7.245e+01) 7.402e+06 / 3.160e+12
# Successful iteration[ 115000]: (6.601e+01) 7.466e+06 / 3.160e+12
# Successful iteration[ 116000]: (6.014e+01) 7.530e+06 / 3.160e+12
# Successful iteration[ 117000]: (5.479e+01) 7.595e+06 / 3.160e+12
# Successful iteration[ 118000]: (4.991e+01) 7.660e+06 / 3.160e+12
# Successful iteration[ 119000]: (1.000e+02) 7.724e+06 / 3.160e+12
# Successful iteration[ 120000]: (9.115e+01) 7.789e+06 / 3.160e+12
# Successful iteration[ 121000]: (8.304e+01) 7.854e+06 / 3.160e+12
# Successful iteration[ 122000]: (7.565e+01) 7.918e+06 / 3.160e+12
# Successful iteration[ 123000]: (6.892e+01) 7.982e+06 / 3.160e+12
# Successful iteration[ 124000]: (6.279e+01) 8.047e+06 / 3.160e+12
# Successful iteration[ 126000]: (1.147e+02) 8.177e+06 / 3.160e+12
# Successful iteration[ 127000]: (1.045e+02) 8.242e+06 / 3.160e+12
# Successful iteration[ 128000]: (9.517e+01) 8.306e+06 / 3.160e+12
# Successful iteration[ 129000]: (8.670e+01) 8.371e+06 / 3.160e+12
# Successful iteration[ 130000]: (7.899e+01) 8.436e+06 / 3.160e+12
# Successful iteration[ 131000]: (7.196e+01) 8.500e+06 / 3.160e+12
# Successful iteration[ 132000]: (6.556e+01) 8.564e+06 / 3.160e+12
# Successful iteration[ 133000]: (5.973e+01) 8.630e+06 / 3.160e+12
# Successful iteration[ 135000]: (4.958e+01) 8.758e+06 / 3.160e+12
# Successful iteration[ 137000]: (9.053e+01) 8.888e+06 / 3.160e+12
# Successful iteration[ 138000]: (8.247e+01) 8.952e+06 / 3.160e+12
# Successful iteration[ 139000]: (7.514e+01) 9.017e+06 / 3.160e+12
# Successful iteration[ 140000]: (6.845e+01) 9.081e+06 / 3.160e+12
# Successful iteration[ 141000]: (6.236e+01) 9.146e+06 / 3.160e+12
# Successful iteration[ 142000]: (5.682e+01) 9.211e+06 / 3.160e+12
# Successful iteration[ 144000]: (4.716e+01) 9.340e+06 / 3.160e+12
# Successful iteration[ 145000]: (9.452e+01) 9.405e+06 / 3.160e+12
# Successful iteration[ 146000]: (8.611e+01) 9.470e+06 / 3.160e+12
# Successful iteration[ 147000]: (7.845e+01) 9.535e+06 / 3.160e+12
# Successful iteration[ 148000]: (7.147e+01) 9.599e+06 / 3.160e+12
# Successful iteration[ 149000]: (6.512e+01) 9.665e+06 / 3.160e+12
# Successful iteration[ 150000]: (5.932e+01) 9.730e+06 / 3.160e+12
# Successful iteration[ 151000]: (5.405e+01) 9.794e+06 / 3.160e+12
# Successful iteration[ 153000]: (4.486e+01) 9.923e+06 / 3.160e+12
# Successful iteration[ 154000]: (8.991e+01) 9.988e+06 / 3.160e+12
# Successful iteration[ 155000]: (8.191e+01) 1.005e+07 / 3.160e+12
# Successful iteration[ 156000]: (7.463e+01) 1.012e+07 / 3.160e+12
# Successful iteration[ 157000]: (6.799e+01) 1.018e+07 / 3.160e+12
# Successful iteration[ 158000]: (6.194e+01) 1.025e+07 / 3.160e+12
# Successful iteration[ 159000]: (5.643e+01) 1.031e+07 / 3.160e+12
# Successful iteration[ 160000]: (5.141e+01) 1.038e+07 / 3.160e+12
# Successful iteration[ 161000]: (1.030e+02) 1.044e+07 / 3.160e+12
# Successful iteration[ 162000]: (9.388e+01) 1.051e+07 / 3.160e+12
# Successful iteration[ 164000]: (7.792e+01) 1.063e+07 / 3.160e+12
# Successful iteration[ 165000]: (7.099e+01) 1.070e+07 / 3.160e+12
# Successful iteration[ 166000]: (6.467e+01) 1.076e+07 / 3.160e+12
# Successful iteration[ 167000]: (1.296e+02) 1.083e+07 / 3.160e+12
# Successful iteration[ 168000]: (5.368e+01) 1.089e+07 / 3.160e+12
# Successful iteration[ 169000]: (4.890e+01) 1.096e+07 / 3.160e+12
# Successful iteration[ 170000]: (9.802e+01) 1.102e+07 / 3.160e+12
# Successful iteration[ 171000]: (8.930e+01) 1.109e+07 / 3.160e+12
# Successful iteration[ 172000]: (8.136e+01) 1.115e+07 / 3.160e+12
# Successful iteration[ 173000]: (7.412e+01) 1.122e+07 / 3.160e+12
# Successful iteration[ 174000]: (6.753e+01) 1.128e+07 / 3.160e+12
# Successful iteration[ 175000]: (6.152e+01) 1.135e+07 / 3.160e+12
# Successful iteration[ 176000]: (5.605e+01) 1.141e+07 / 3.160e+12
# Successful iteration[ 177000]: (1.123e+02) 1.148e+07 / 3.160e+12
# Successful iteration[ 178000]: (4.652e+01) 1.154e+07 / 3.160e+12
# Successful iteration[ 179000]: (9.324e+01) 1.161e+07 / 3.160e+12
# Successful iteration[ 180000]: (8.495e+01) 1.167e+07 / 3.160e+12
# Successful iteration[ 181000]: (7.739e+01) 1.174e+07 / 3.160e+12
# Successful iteration[ 183000]: (6.423e+01) 1.187e+07 / 3.160e+12
# Successful iteration[ 184000]: (5.852e+01) 1.193e+07 / 3.160e+12
# Successful iteration[ 185000]: (1.173e+02) 1.200e+07 / 3.160e+12
# Successful iteration[ 186000]: (4.857e+01) 1.206e+07 / 3.160e+12
# Successful iteration[ 187000]: (4.425e+01) 1.212e+07 / 3.160e+12
# Successful iteration[ 188000]: (8.869e+01) 1.219e+07 / 3.160e+12
# Successful iteration[ 189000]: (8.080e+01) 1.225e+07 / 3.160e+12
# Successful iteration[ 190000]: (7.362e+01) 1.232e+07 / 3.160e+12
# Successful iteration[ 191000]: (6.707e+01) 1.238e+07 / 3.160e+12
# Successful iteration[ 192000]: (6.110e+01) 1.245e+07 / 3.160e+12
# Successful iteration[ 193000]: (5.567e+01) 1.251e+07 / 3.160e+12
# Successful iteration[ 194000]: (1.116e+02) 1.258e+07 / 3.160e+12
# Successful iteration[ 195000]: (4.620e+01) 1.264e+07 / 3.160e+12
# Successful iteration[ 196000]: (9.261e+01) 1.271e+07 / 3.160e+12
# Successful iteration[ 198000]: (7.686e+01) 1.284e+07 / 3.160e+12
# Successful iteration[ 199000]: (7.003e+01) 1.290e+07 / 3.160e+12
# Successful iteration[ 200000]: (6.380e+01) 1.296e+07 / 3.160e+12
# Successful iteration[ 202000]: (5.295e+01) 1.309e+07 / 3.160e+12
# Successful iteration[ 203000]: (1.061e+02) 1.316e+07 / 3.160e+12
# Successful iteration[ 205000]: (8.809e+01) 1.329e+07 / 3.160e+12
# Successful iteration[ 206000]: (8.025e+01) 1.335e+07 / 3.160e+12
# Successful iteration[ 207000]: (7.312e+01) 1.342e+07 / 3.160e+12
# Successful iteration[ 208000]: (6.661e+01) 1.348e+07 / 3.160e+12
# Successful iteration[ 210000]: (5.529e+01) 1.361e+07 / 3.160e+12
# Successful iteration[ 211000]: (5.037e+01) 1.368e+07 / 3.160e+12
# Successful iteration[ 212000]: (4.589e+01) 1.374e+07 / 3.160e+12
# Successful iteration[ 214000]: (8.379e+01) 1.387e+07 / 3.160e+12
# Successful iteration[ 215000]: (7.634e+01) 1.394e+07 / 3.160e+12
# Successful iteration[ 216000]: (6.955e+01) 1.400e+07 / 3.160e+12
# Successful iteration[ 217000]: (6.336e+01) 1.406e+07 / 3.160e+12
# Successful iteration[ 219000]: (5.259e+01) 1.419e+07 / 3.160e+12
# Successful iteration[ 222000]: (8.749e+01) 1.439e+07 / 3.160e+12
# Successful iteration[ 223000]: (7.971e+01) 1.445e+07 / 3.160e+12
# Successful iteration[ 224000]: (7.262e+01) 1.452e+07 / 3.160e+12
# Successful iteration[ 225000]: (6.616e+01) 1.458e+07 / 3.160e+12
# Successful iteration[ 226000]: (6.027e+01) 1.465e+07 / 3.160e+12
# Successful iteration[ 227000]: (5.491e+01) 1.471e+07 / 3.160e+12
# Successful iteration[ 229000]: (1.003e+02) 1.484e+07 / 3.160e+12
# Successful iteration[ 230000]: (9.135e+01) 1.491e+07 / 3.160e+12
# Successful iteration[ 231000]: (8.323e+01) 1.497e+07 / 3.160e+12
# Successful iteration[ 232000]: (7.582e+01) 1.503e+07 / 3.160e+12
# Successful iteration[ 233000]: (6.908e+01) 1.510e+07 / 3.160e+12
# Successful iteration[ 234000]: (6.293e+01) 1.516e+07 / 3.160e+12
# Successful iteration[ 235000]: (5.733e+01) 1.523e+07 / 3.160e+12
# Successful iteration[ 237000]: (4.759e+01) 1.536e+07 / 3.160e+12
# Successful iteration[ 238000]: (9.538e+01) 1.542e+07 / 3.160e+12
# Successful iteration[ 239000]: (8.690e+01) 1.549e+07 / 3.160e+12
# Successful iteration[ 240000]: (7.917e+01) 1.555e+07 / 3.160e+12
# Successful iteration[ 241000]: (7.213e+01) 1.562e+07 / 3.160e+12
# Successful iteration[ 242000]: (6.571e+01) 1.568e+07 / 3.160e+12
# Successful iteration[ 243000]: (5.986e+01) 1.575e+07 / 3.160e+12
# Successful iteration[ 245000]: (1.093e+02) 1.588e+07 / 3.160e+12
# Successful iteration[ 246000]: (9.959e+01) 1.594e+07 / 3.160e+12
# Successful iteration[ 247000]: (9.073e+01) 1.601e+07 / 3.160e+12
# Successful iteration[ 248000]: (8.266e+01) 1.607e+07 / 3.160e+12
# Successful iteration[ 249000]: (7.531e+01) 1.613e+07 / 3.160e+12
# Successful iteration[ 250000]: (6.861e+01) 1.620e+07 / 3.160e+12
# Successful iteration[ 251000]: (6.251e+01) 1.626e+07 / 3.160e+12
# Successful iteration[ 252000]: (5.695e+01) 1.633e+07 / 3.160e+12
# Successful iteration[ 253000]: (5.188e+01) 1.639e+07 / 3.160e+12
# Successful iteration[ 254000]: (1.040e+02) 1.646e+07 / 3.160e+12
# Successful iteration[ 255000]: (9.473e+01) 1.652e+07 / 3.160e+12
# Successful iteration[ 256000]: (8.631e+01) 1.659e+07 / 3.160e+12
# Successful iteration[ 257000]: (7.863e+01) 1.665e+07 / 3.160e+12
# Successful iteration[ 258000]: (7.164e+01) 1.672e+07 / 3.160e+12
# Successful iteration[ 259000]: (6.526e+01) 1.678e+07 / 3.160e+12
# Successful iteration[ 260000]: (5.946e+01) 1.685e+07 / 3.160e+12
# Successful iteration[ 261000]: (5.417e+01) 1.691e+07 / 3.160e+12
# Successful iteration[ 263000]: (9.891e+01) 1.704e+07 / 3.160e+12
# Successful iteration[ 264000]: (9.011e+01) 1.711e+07 / 3.160e+12
# Successful iteration[ 265000]: (8.210e+01) 1.717e+07 / 3.160e+12
# Successful iteration[ 266000]: (7.480e+01) 1.723e+07 / 3.160e+12
# Successful iteration[ 267000]: (6.814e+01) 1.730e+07 / 3.160e+12
# Successful iteration[ 268000]: (6.208e+01) 1.736e+07 / 3.160e+12
# Successful iteration[ 269000]: (5.656e+01) 1.743e+07 / 3.160e+12
# Successful iteration[ 272000]: (9.409e+01) 1.762e+07 / 3.160e+12
# Successful iteration[ 273000]: (8.572e+01) 1.769e+07 / 3.160e+12
# Successful iteration[ 274000]: (7.810e+01) 1.775e+07 / 3.160e+12
# Successful iteration[ 275000]: (7.115e+01) 1.782e+07 / 3.160e+12
# Successful iteration[ 276000]: (6.482e+01) 1.788e+07 / 3.160e+12
# Successful iteration[ 277000]: (5.905e+01) 1.794e+07 / 3.160e+12
# Successful iteration[ 278000]: (5.380e+01) 1.801e+07 / 3.160e+12
# Successful iteration[ 279000]: (4.901e+01) 1.808e+07 / 3.160e+12
# Successful iteration[ 280000]: (9.824e+01) 1.814e+07 / 3.160e+12
# Successful iteration[ 281000]: (8.950e+01) 1.820e+07 / 3.160e+12
# Successful iteration[ 282000]: (8.154e+01) 1.827e+07 / 3.160e+12
# Successful iteration[ 283000]: (7.429e+01) 1.833e+07 / 3.160e+12
# Successful iteration[ 284000]: (6.768e+01) 1.840e+07 / 3.160e+12
# Successful iteration[ 285000]: (6.166e+01) 1.846e+07 / 3.160e+12
# Successful iteration[ 286000]: (1.236e+02) 1.853e+07 / 3.160e+12
# Successful iteration[ 287000]: (5.118e+01) 1.859e+07 / 3.160e+12
# Successful iteration[ 288000]: (4.662e+01) 1.866e+07 / 3.160e+12
# Successful iteration[ 289000]: (9.345e+01) 1.872e+07 / 3.160e+12
# Successful iteration[ 290000]: (8.514e+01) 1.879e+07 / 3.160e+12
# Successful iteration[ 291000]: (7.756e+01) 1.885e+07 / 3.160e+12
# Successful iteration[ 292000]: (7.066e+01) 1.892e+07 / 3.160e+12
# Successful iteration[ 293000]: (6.438e+01) 1.898e+07 / 3.160e+12
# Successful iteration[ 294000]: (5.865e+01) 1.905e+07 / 3.160e+12
# Successful iteration[ 298000]: (8.889e+01) 1.933e+07 / 3.160e+12
# Successful iteration[ 299000]: (8.099e+01) 1.940e+07 / 3.160e+12
# Successful iteration[ 300000]: (7.378e+01) 1.948e+07 / 3.160e+12
# Successful iteration[ 301000]: (6.722e+01) 1.955e+07 / 3.160e+12
# Successful iteration[ 302000]: (6.124e+01) 1.962e+07 / 3.160e+12
# Successful iteration[ 303000]: (5.579e+01) 1.970e+07 / 3.160e+12
# Successful iteration[ 304000]: (1.118e+02) 1.977e+07 / 3.160e+12
# Successful iteration[ 305000]: (4.631e+01) 1.985e+07 / 3.160e+12
# Successful iteration[ 306000]: (2.042e+02) 1.992e+07 / 3.160e+12
# Successful iteration[ 307000]: (8.456e+01) 2.000e+07 / 3.160e+12
# Successful iteration[ 308000]: (7.704e+01) 2.008e+07 / 3.160e+12
# Successful iteration[ 309000]: (7.018e+01) 2.016e+07 / 3.160e+12
# Successful iteration[ 312000]: (5.307e+01) 2.040e+07 / 3.160e+12
# Successful iteration[ 313000]: (1.064e+02) 2.048e+07 / 3.160e+12
# Successful iteration[ 314000]: (4.405e+01) 2.056e+07 / 3.160e+12
# Successful iteration[ 315000]: (8.829e+01) 2.064e+07 / 3.160e+12
# Successful iteration[ 316000]: (8.044e+01) 2.072e+07 / 3.160e+12
# Successful iteration[ 317000]: (7.328e+01) 2.080e+07 / 3.160e+12
# Successful iteration[ 318000]: (6.676e+01) 2.088e+07 / 3.160e+12
# Successful iteration[ 320000]: (5.541e+01) 2.105e+07 / 3.160e+12
# Successful iteration[ 321000]: (1.111e+02) 2.113e+07 / 3.160e+12
# Successful iteration[ 322000]: (4.599e+01) 2.122e+07 / 3.160e+12
# Successful iteration[ 323000]: (9.218e+01) 2.130e+07 / 3.160e+12
# Successful iteration[ 324000]: (8.398e+01) 2.139e+07 / 3.160e+12
# Successful iteration[ 326000]: (6.971e+01) 2.156e+07 / 3.160e+12
# Successful iteration[ 327000]: (6.351e+01) 2.164e+07 / 3.160e+12
# Successful iteration[ 328000]: (5.786e+01) 2.173e+07 / 3.160e+12
# Successful iteration[ 330000]: (1.056e+02) 2.191e+07 / 3.160e+12
# Successful iteration[ 331000]: (9.625e+01) 2.199e+07 / 3.160e+12
# Successful iteration[ 332000]: (8.769e+01) 2.208e+07 / 3.160e+12
# Successful iteration[ 333000]: (7.989e+01) 2.217e+07 / 3.160e+12
# Successful iteration[ 334000]: (7.278e+01) 2.226e+07 / 3.160e+12
# Successful iteration[ 335000]: (6.631e+01) 2.235e+07 / 3.160e+12
# Successful iteration[ 337000]: (1.211e+02) 2.252e+07 / 3.160e+12
# Successful iteration[ 338000]: (1.103e+02) 2.261e+07 / 3.160e+12
# Successful iteration[ 340000]: (9.156e+01) 2.279e+07 / 3.160e+12
# Successful iteration[ 341000]: (8.341e+01) 2.288e+07 / 3.160e+12
# Successful iteration[ 342000]: (1.672e+02) 2.297e+07 / 3.160e+12
# Successful iteration[ 343000]: (6.923e+01) 2.306e+07 / 3.160e+12
# Successful iteration[ 344000]: (6.308e+01) 2.316e+07 / 3.160e+12
# Successful iteration[ 345000]: (5.746e+01) 2.325e+07 / 3.160e+12
# Successful iteration[ 346000]: (1.152e+02) 2.334e+07 / 3.160e+12
# Successful iteration[ 347000]: (1.049e+02) 2.343e+07 / 3.160e+12
# Successful iteration[ 348000]: (2.103e+02) 2.352e+07 / 3.160e+12
# Successful iteration[ 349000]: (8.709e+01) 2.361e+07 / 3.160e+12
# Successful iteration[ 350000]: (7.935e+01) 2.370e+07 / 3.160e+12
# Successful iteration[ 351000]: (7.229e+01) 2.379e+07 / 3.160e+12
# Successful iteration[ 352000]: (6.586e+01) 2.388e+07 / 3.160e+12
# Successful iteration[ 353000]: (6.000e+01) 2.398e+07 / 3.160e+12
# Successful iteration[ 354000]: (5.466e+01) 2.406e+07 / 3.160e+12
# Successful iteration[ 355000]: (1.096e+02) 2.416e+07 / 3.160e+12
# Successful iteration[ 356000]: (9.981e+01) 2.425e+07 / 3.160e+12
# Successful iteration[ 357000]: (9.094e+01) 2.434e+07 / 3.160e+12
# Successful iteration[ 358000]: (8.285e+01) 2.443e+07 / 3.160e+12
# Successful iteration[ 361000]: (1.378e+02) 2.471e+07 / 3.160e+12
# Successful iteration[ 362000]: (1.256e+02) 2.480e+07 / 3.160e+12
# Successful iteration[ 363000]: (1.144e+02) 2.490e+07 / 3.160e+12
# Successful iteration[ 364000]: (1.042e+02) 2.499e+07 / 3.160e+12
# Successful iteration[ 365000]: (9.495e+01) 2.508e+07 / 3.160e+12
# Successful iteration[ 366000]: (8.650e+01) 2.517e+07 / 3.160e+12
# Successful iteration[ 367000]: (7.881e+01) 2.527e+07 / 3.160e+12
# Successful iteration[ 369000]: (1.439e+02) 2.546e+07 / 3.160e+12
# Successful iteration[ 370000]: (1.311e+02) 2.556e+07 / 3.160e+12
# Successful iteration[ 371000]: (1.194e+02) 2.565e+07 / 3.160e+12
# Successful iteration[ 372000]: (1.088e+02) 2.575e+07 / 3.160e+12
# Successful iteration[ 373000]: (9.914e+01) 2.584e+07 / 3.160e+12
# Successful iteration[ 374000]: (9.032e+01) 2.594e+07 / 3.160e+12
# Successful iteration[ 375000]: (8.228e+01) 2.604e+07 / 3.160e+12
# Successful iteration[ 376000]: (7.496e+01) 2.613e+07 / 3.160e+12
# Successful iteration[ 377000]: (1.503e+02) 2.623e+07 / 3.160e+12
# Successful iteration[ 378000]: (1.369e+02) 2.633e+07 / 3.160e+12
# Successful iteration[ 379000]: (2.744e+02) 2.643e+07 / 3.160e+12
# Successful iteration[ 380000]: (1.136e+02) 2.653e+07 / 3.160e+12
# Successful iteration[ 382000]: (9.430e+01) 2.674e+07 / 3.160e+12
# Successful iteration[ 383000]: (8.591e+01) 2.683e+07 / 3.160e+12
# Successful iteration[ 384000]: (7.827e+01) 2.693e+07 / 3.160e+12
# Successful iteration[ 385000]: (3.451e+02) 2.703e+07 / 3.160e+12
# Successful iteration[ 386000]: (1.429e+02) 2.713e+07 / 3.160e+12
# Successful iteration[ 387000]: (1.302e+02) 2.723e+07 / 3.160e+12
# Successful iteration[ 388000]: (1.186e+02) 2.734e+07 / 3.160e+12
# Successful iteration[ 389000]: (1.081e+02) 2.744e+07 / 3.160e+12
# Successful iteration[ 390000]: (2.166e+02) 2.754e+07 / 3.160e+12
# Successful iteration[ 391000]: (8.970e+01) 2.764e+07 / 3.160e+12
# Successful iteration[ 392000]: (8.172e+01) 2.775e+07 / 3.160e+12
# Successful iteration[ 393000]: (1.638e+02) 2.785e+07 / 3.160e+12
# Successful iteration[ 394000]: (1.492e+02) 2.796e+07 / 3.160e+12
# Successful iteration[ 396000]: (1.239e+02) 2.817e+07 / 3.160e+12
# Successful iteration[ 397000]: (1.128e+02) 2.828e+07 / 3.160e+12
# Successful iteration[ 398000]: (1.028e+02) 2.838e+07 / 3.160e+12
# Successful iteration[ 399000]: (9.366e+01) 2.848e+07 / 3.160e+12
# Successful iteration[ 400000]: (8.533e+01) 2.859e+07 / 3.160e+12
# Successful iteration[ 401000]: (7.774e+01) 2.870e+07 / 3.160e+12
# Successful iteration[ 402000]: (1.558e+02) 2.881e+07 / 3.160e+12
# Successful iteration[ 403000]: (1.420e+02) 2.891e+07 / 3.160e+12
# Successful iteration[ 404000]: (1.293e+02) 2.902e+07 / 3.160e+12
# Successful iteration[ 405000]: (2.592e+02) 2.912e+07 / 3.160e+12
# Successful iteration[ 406000]: (1.073e+02) 2.923e+07 / 3.160e+12
# Successful iteration[ 407000]: (9.779e+01) 2.933e+07 / 3.160e+12
# Successful iteration[ 408000]: (8.909e+01) 2.944e+07 / 3.160e+12
# Successful iteration[ 410000]: (1.627e+02) 2.966e+07 / 3.160e+12
# Successful iteration[ 411000]: (6.737e+01) 2.977e+07 / 3.160e+12
# Successful iteration[ 412000]: (1.350e+02) 2.988e+07 / 3.160e+12
# Successful iteration[ 413000]: (5.592e+01) 2.999e+07 / 3.160e+12
# Successful iteration[ 414000]: (5.094e+01) 3.011e+07 / 3.160e+12
# Successful iteration[ 415000]: (1.021e+02) 3.022e+07 / 3.160e+12
# Successful iteration[ 417000]: (8.475e+01) 3.044e+07 / 3.160e+12
# Successful iteration[ 418000]: (1.699e+02) 3.055e+07 / 3.160e+12
# Successful iteration[ 419000]: (1.548e+02) 3.066e+07 / 3.160e+12
# Successful iteration[ 420000]: (3.102e+02) 3.078e+07 / 3.160e+12
# Successful iteration[ 421000]: (1.284e+02) 3.089e+07 / 3.160e+12
# Successful iteration[ 422000]: (1.170e+02) 3.100e+07 / 3.160e+12
# Successful iteration[ 423000]: (2.345e+02) 3.111e+07 / 3.160e+12
# Successful iteration[ 424000]: (9.713e+01) 3.123e+07 / 3.160e+12
# Successful iteration[ 427000]: (1.616e+02) 3.157e+07 / 3.160e+12
# Successful iteration[ 428000]: (1.472e+02) 3.169e+07 / 3.160e+12
# Successful iteration[ 429000]: (1.341e+02) 3.181e+07 / 3.160e+12
# Successful iteration[ 430000]: (1.222e+02) 3.192e+07 / 3.160e+12
# Successful iteration[ 431000]: (1.113e+02) 3.204e+07 / 3.160e+12
# Successful iteration[ 432000]: (1.014e+02) 3.216e+07 / 3.160e+12
# Successful iteration[ 433000]: (9.239e+01) 3.228e+07 / 3.160e+12
# Successful iteration[ 435000]: (7.669e+01) 3.251e+07 / 3.160e+12
# Successful iteration[ 436000]: (1.537e+02) 3.263e+07 / 3.160e+12
# Successful iteration[ 437000]: (1.400e+02) 3.275e+07 / 3.160e+12
# Successful iteration[ 438000]: (1.276e+02) 3.287e+07 / 3.160e+12
# Successful iteration[ 439000]: (5.283e+01) 3.299e+07 / 3.160e+12
# Successful iteration[ 440000]: (1.059e+02) 3.311e+07 / 3.160e+12
# Successful iteration[ 441000]: (9.647e+01) 3.323e+07 / 3.160e+12
# Successful iteration[ 444000]: (1.605e+02) 3.359e+07 / 3.160e+12
# Successful iteration[ 445000]: (1.462e+02) 3.372e+07 / 3.160e+12
# Successful iteration[ 446000]: (6.055e+01) 3.384e+07 / 3.160e+12
# Successful iteration[ 447000]: (1.214e+02) 3.396e+07 / 3.160e+12
# Successful iteration[ 448000]: (1.106e+02) 3.408e+07 / 3.160e+12
# Successful iteration[ 449000]: (2.216e+02) 3.421e+07 / 3.160e+12
# Successful iteration[ 450000]: (2.019e+02) 3.433e+07 / 3.160e+12
# Successful iteration[ 451000]: (8.360e+01) 3.445e+07 / 3.160e+12
# Successful iteration[ 452000]: (7.617e+01) 3.458e+07 / 3.160e+12
# Successful iteration[ 453000]: (1.527e+02) 3.470e+07 / 3.160e+12
# Successful iteration[ 454000]: (1.391e+02) 3.483e+07 / 3.160e+12
# Successful iteration[ 455000]: (2.788e+02) 3.495e+07 / 3.160e+12
# Successful iteration[ 456000]: (1.154e+02) 3.508e+07 / 3.160e+12
# Successful iteration[ 457000]: (1.052e+02) 3.520e+07 / 3.160e+12
# Successful iteration[ 459000]: (1.920e+02) 3.546e+07 / 3.160e+12
# Successful iteration[ 460000]: (7.953e+01) 3.558e+07 / 3.160e+12
# Successful iteration[ 461000]: (1.594e+02) 3.571e+07 / 3.160e+12
# Successful iteration[ 462000]: (1.452e+02) 3.584e+07 / 3.160e+12
# Successful iteration[ 463000]: (1.323e+02) 3.596e+07 / 3.160e+12
# Successful iteration[ 464000]: (1.205e+02) 3.609e+07 / 3.160e+12
# Successful iteration[ 465000]: (1.098e+02) 3.622e+07 / 3.160e+12
# Successful iteration[ 466000]: (1.000e+02) 3.635e+07 / 3.160e+12
# Successful iteration[ 468000]: (1.827e+02) 3.661e+07 / 3.160e+12
# Successful iteration[ 469000]: (1.664e+02) 3.674e+07 / 3.160e+12
# Successful iteration[ 470000]: (1.516e+02) 3.686e+07 / 3.160e+12
# Successful iteration[ 471000]: (1.381e+02) 3.699e+07 / 3.160e+12
# Successful iteration[ 472000]: (1.258e+02) 3.712e+07 / 3.160e+12
# Successful iteration[ 473000]: (1.147e+02) 3.725e+07 / 3.160e+12
# Successful iteration[ 475000]: (9.516e+01) 3.751e+07 / 3.160e+12
# Successful iteration[ 476000]: (1.907e+02) 3.764e+07 / 3.160e+12
# Successful iteration[ 477000]: (1.738e+02) 3.777e+07 / 3.160e+12
# Successful iteration[ 478000]: (1.583e+02) 3.790e+07 / 3.160e+12
# Successful iteration[ 480000]: (1.314e+02) 3.816e+07 / 3.160e+12
# Successful iteration[ 481000]: (1.197e+02) 3.829e+07 / 3.160e+12
# Successful iteration[ 482000]: (1.091e+02) 3.842e+07 / 3.160e+12
# Successful iteration[ 483000]: (2.186e+02) 3.855e+07 / 3.160e+12
# Successful iteration[ 484000]: (1.991e+02) 3.868e+07 / 3.160e+12
# Successful iteration[ 485000]: (1.814e+02) 3.881e+07 / 3.160e+12
# Successful iteration[ 486000]: (1.653e+02) 3.894e+07 / 3.160e+12
# Successful iteration[ 487000]: (6.845e+01) 3.907e+07 / 3.160e+12
# Successful iteration[ 488000]: (1.372e+02) 3.920e+07 / 3.160e+12
# Successful iteration[ 489000]: (1.250e+02) 3.934e+07 / 3.160e+12
# Successful iteration[ 490000]: (1.139e+02) 3.947e+07 / 3.160e+12
# Successful iteration[ 491000]: (1.037e+02) 3.960e+07 / 3.160e+12
# Successful iteration[ 493000]: (8.611e+01) 3.986e+07 / 3.160e+12
# Successful iteration[ 494000]: (1.726e+02) 4.000e+07 / 3.160e+12
# Successful iteration[ 495000]: (1.572e+02) 4.013e+07 / 3.160e+12
# Successful iteration[ 496000]: (1.432e+02) 4.027e+07 / 3.160e+12
# Successful iteration[ 497000]: (1.305e+02) 4.040e+07 / 3.160e+12
# Successful iteration[ 498000]: (1.189e+02) 4.053e+07 / 3.160e+12
# Successful iteration[ 499000]: (1.083e+02) 4.066e+07 / 3.160e+12
# Successful iteration[ 500000]: (2.171e+02) 4.080e+07 / 3.160e+12
# Successful iteration[ 501000]: (1.978e+02) 4.093e+07 / 3.160e+12
# Successful iteration[ 502000]: (1.802e+02) 4.107e+07 / 3.160e+12
# Successful iteration[ 503000]: (1.642e+02) 4.120e+07 / 3.160e+12
# Successful iteration[ 504000]: (6.799e+01) 4.134e+07 / 3.160e+12
# Successful iteration[ 505000]: (1.363e+02) 4.147e+07 / 3.160e+12
# Successful iteration[ 506000]: (1.241e+02) 4.161e+07 / 3.160e+12
# Successful iteration[ 508000]: (1.030e+02) 4.187e+07 / 3.160e+12
# Successful iteration[ 509000]: (9.387e+01) 4.201e+07 / 3.160e+12
# Successful iteration[ 511000]: (1.714e+02) 4.228e+07 / 3.160e+12
# Successful iteration[ 512000]: (1.562e+02) 4.242e+07 / 3.160e+12
# Successful iteration[ 513000]: (1.423e+02) 4.255e+07 / 3.160e+12
# Successful iteration[ 514000]: (1.296e+02) 4.269e+07 / 3.160e+12
# Successful iteration[ 515000]: (1.181e+02) 4.282e+07 / 3.160e+12
# Successful iteration[ 516000]: (1.076e+02) 4.296e+07 / 3.160e+12
# Successful iteration[ 517000]: (9.801e+01) 4.310e+07 / 3.160e+12
# Successful iteration[ 518000]: (1.965e+02) 4.324e+07 / 3.160e+12
# Successful iteration[ 519000]: (1.790e+02) 4.338e+07 / 3.160e+12
# Successful iteration[ 521000]: (1.486e+02) 4.366e+07 / 3.160e+12
# Successful iteration[ 522000]: (1.353e+02) 4.380e+07 / 3.160e+12
# Successful iteration[ 523000]: (1.233e+02) 4.393e+07 / 3.160e+12
# Successful iteration[ 524000]: (1.123e+02) 4.407e+07 / 3.160e+12
# Successful iteration[ 525000]: (1.023e+02) 4.421e+07 / 3.160e+12
# Successful iteration[ 528000]: (1.702e+02) 4.462e+07 / 3.160e+12
# Successful iteration[ 529000]: (1.551e+02) 4.476e+07 / 3.160e+12
# Successful iteration[ 531000]: (1.287e+02) 4.504e+07 / 3.160e+12
# Successful iteration[ 532000]: (1.173e+02) 4.518e+07 / 3.160e+12
# Successful iteration[ 533000]: (2.351e+02) 4.532e+07 / 3.160e+12
# Successful iteration[ 534000]: (9.735e+01) 4.546e+07 / 3.160e+12
# Successful iteration[ 537000]: (1.619e+02) 4.586e+07 / 3.160e+12
# Successful iteration[ 538000]: (1.475e+02) 4.600e+07 / 3.160e+12
# Successful iteration[ 539000]: (1.344e+02) 4.614e+07 / 3.160e+12
# Successful iteration[ 540000]: (1.225e+02) 4.628e+07 / 3.160e+12
# Successful iteration[ 541000]: (1.116e+02) 4.642e+07 / 3.160e+12
# Successful iteration[ 542000]: (1.016e+02) 4.656e+07 / 3.160e+12
# Successful iteration[ 544000]: (1.856e+02) 4.684e+07 / 3.160e+12
# Successful iteration[ 545000]: (3.720e+02) 4.698e+07 / 3.160e+12
# Successful iteration[ 546000]: (3.389e+02) 4.713e+07 / 3.160e+12
# Successful iteration[ 547000]: (1.403e+02) 4.727e+07 / 3.160e+12
# Successful iteration[ 548000]: (1.279e+02) 4.742e+07 / 3.160e+12
# Successful iteration[ 549000]: (2.563e+02) 4.756e+07 / 3.160e+12
# Successful iteration[ 550000]: (2.335e+02) 4.770e+07 / 3.160e+12
# Successful iteration[ 552000]: (8.809e+01) 4.798e+07 / 3.160e+12
# Successful iteration[ 554000]: (1.608e+02) 4.826e+07 / 3.160e+12
# Successful iteration[ 555000]: (1.465e+02) 4.841e+07 / 3.160e+12
# Successful iteration[ 557000]: (1.216e+02) 4.869e+07 / 3.160e+12
# Successful iteration[ 558000]: (1.108e+02) 4.883e+07 / 3.160e+12
# Successful iteration[ 560000]: (9.197e+01) 4.912e+07 / 3.160e+12
# Successful iteration[ 562000]: (7.634e+01) 4.941e+07 / 3.160e+12
# Successful iteration[ 563000]: (1.530e+02) 4.955e+07 / 3.160e+12
# Successful iteration[ 564000]: (1.394e+02) 4.969e+07 / 3.160e+12
# Successful iteration[ 566000]: (1.157e+02) 4.998e+07 / 3.160e+12
# Successful iteration[ 568000]: (2.113e+02) 5.026e+07 / 3.160e+12
# Successful iteration[ 569000]: (1.925e+02) 5.040e+07 / 3.160e+12
# Successful iteration[ 570000]: (1.754e+02) 5.054e+07 / 3.160e+12
# Successful iteration[ 571000]: (1.598e+02) 5.068e+07 / 3.160e+12
# Successful iteration[ 572000]: (1.455e+02) 5.081e+07 / 3.160e+12
# Successful iteration[ 573000]: (1.326e+02) 5.096e+07 / 3.160e+12
# Successful iteration[ 577000]: (2.010e+02) 5.151e+07 / 3.160e+12
# Successful iteration[ 578000]: (1.831e+02) 5.165e+07 / 3.160e+12
# Successful iteration[ 579000]: (1.668e+02) 5.180e+07 / 3.160e+12
# Successful iteration[ 580000]: (3.343e+02) 5.193e+07 / 3.160e+12
# Successful iteration[ 581000]: (1.384e+02) 5.208e+07 / 3.160e+12
# Successful iteration[ 582000]: (1.261e+02) 5.222e+07 / 3.160e+12
# Successful iteration[ 583000]: (1.149e+02) 5.236e+07 / 3.160e+12
# Successful iteration[ 584000]: (2.303e+02) 5.251e+07 / 3.160e+12
# Successful iteration[ 585000]: (2.098e+02) 5.265e+07 / 3.160e+12
# Successful iteration[ 586000]: (1.912e+02) 5.280e+07 / 3.160e+12
# Successful iteration[ 587000]: (1.742e+02) 5.293e+07 / 3.160e+12
# Successful iteration[ 588000]: (7.212e+01) 5.308e+07 / 3.160e+12
# Successful iteration[ 589000]: (3.180e+02) 5.322e+07 / 3.160e+12
# Successful iteration[ 590000]: (1.317e+02) 5.337e+07 / 3.160e+12
# Successful iteration[ 591000]: (1.200e+02) 5.350e+07 / 3.160e+12
# Successful iteration[ 594000]: (1.996e+02) 5.392e+07 / 3.160e+12
# Successful iteration[ 596000]: (1.657e+02) 5.421e+07 / 3.160e+12
# Successful iteration[ 597000]: (1.509e+02) 5.436e+07 / 3.160e+12
# Successful iteration[ 598000]: (1.375e+02) 5.450e+07 / 3.160e+12
# Successful iteration[ 599000]: (1.253e+02) 5.464e+07 / 3.160e+12
# Successful iteration[ 600000]: (1.141e+02) 5.478e+07 / 3.160e+12
# Successful iteration[ 601000]: (1.040e+02) 5.493e+07 / 3.160e+12
# Successful iteration[ 602000]: (2.084e+02) 5.507e+07 / 3.160e+12
# Successful iteration[ 603000]: (1.899e+02) 5.521e+07 / 3.160e+12
# Successful iteration[ 604000]: (1.730e+02) 5.535e+07 / 3.160e+12
# Successful iteration[ 605000]: (1.576e+02) 5.550e+07 / 3.160e+12
# Successful iteration[ 606000]: (1.436e+02) 5.564e+07 / 3.160e+12
# Successful iteration[ 607000]: (1.308e+02) 5.578e+07 / 3.160e+12
# Successful iteration[ 608000]: (2.622e+02) 5.592e+07 / 3.160e+12
# Successful iteration[ 609000]: (1.086e+02) 5.607e+07 / 3.160e+12
# Successful iteration[ 611000]: (1.982e+02) 5.634e+07 / 3.160e+12
# Successful iteration[ 612000]: (1.806e+02) 5.648e+07 / 3.160e+12
# Successful iteration[ 613000]: (1.645e+02) 5.663e+07 / 3.160e+12
# Successful iteration[ 614000]: (1.499e+02) 5.677e+07 / 3.160e+12
# Successful iteration[ 617000]: (2.494e+02) 5.720e+07 / 3.160e+12
# Successful iteration[ 618000]: (1.033e+02) 5.734e+07 / 3.160e+12
# Successful iteration[ 619000]: (2.070e+02) 5.748e+07 / 3.160e+12
# Successful iteration[ 620000]: (1.886e+02) 5.762e+07 / 3.160e+12
# Successful iteration[ 622000]: (7.114e+01) 5.791e+07 / 3.160e+12
# Successful iteration[ 623000]: (1.426e+02) 5.805e+07 / 3.160e+12
# Successful iteration[ 624000]: (1.299e+02) 5.820e+07 / 3.160e+12
# Successful iteration[ 625000]: (1.184e+02) 5.834e+07 / 3.160e+12
# Successful iteration[ 626000]: (1.078e+02) 5.848e+07 / 3.160e+12
# Successful iteration[ 627000]: (9.824e+01) 5.862e+07 / 3.160e+12
# Successful iteration[ 628000]: (1.969e+02) 5.877e+07 / 3.160e+12
# Successful iteration[ 629000]: (1.794e+02) 5.891e+07 / 3.160e+12
# Successful iteration[ 630000]: (1.634e+02) 5.905e+07 / 3.160e+12
# Successful iteration[ 632000]: (1.356e+02) 5.933e+07 / 3.160e+12
# Successful iteration[ 633000]: (1.236e+02) 5.947e+07 / 3.160e+12
# Successful iteration[ 634000]: (1.126e+02) 5.962e+07 / 3.160e+12
# Successful iteration[ 635000]: (1.026e+02) 5.976e+07 / 3.160e+12
# Successful iteration[ 636000]: (9.345e+01) 5.990e+07 / 3.160e+12
# Successful iteration[ 638000]: (7.756e+01) 6.019e+07 / 3.160e+12
# Successful iteration[ 639000]: (7.066e+01) 6.034e+07 / 3.160e+12
# Successful iteration[ 640000]: (1.416e+02) 6.048e+07 / 3.160e+12
# Successful iteration[ 641000]: (1.290e+02) 6.063e+07 / 3.160e+12
# Successful iteration[ 642000]: (1.176e+02) 6.077e+07 / 3.160e+12
# Successful iteration[ 643000]: (2.356e+02) 6.091e+07 / 3.160e+12
# Successful iteration[ 644000]: (9.757e+01) 6.106e+07 / 3.160e+12
# Successful iteration[ 646000]: (8.098e+01) 6.134e+07 / 3.160e+12
# Successful iteration[ 647000]: (7.378e+01) 6.149e+07 / 3.160e+12
# Successful iteration[ 648000]: (1.479e+02) 6.164e+07 / 3.160e+12
# Successful iteration[ 651000]: (2.460e+02) 6.207e+07 / 3.160e+12
# Successful iteration[ 652000]: (1.019e+02) 6.221e+07 / 3.160e+12
# Successful iteration[ 653000]: (2.042e+02) 6.236e+07 / 3.160e+12
# Successful iteration[ 655000]: (1.695e+02) 6.264e+07 / 3.160e+12
# Successful iteration[ 656000]: (1.544e+02) 6.279e+07 / 3.160e+12
# Successful iteration[ 657000]: (3.095e+02) 6.293e+07 / 3.160e+12
# Successful iteration[ 658000]: (1.282e+02) 6.308e+07 / 3.160e+12
# Successful iteration[ 659000]: (1.168e+02) 6.322e+07 / 3.160e+12
# Successful iteration[ 660000]: (2.340e+02) 6.337e+07 / 3.160e+12
# Successful iteration[ 661000]: (9.691e+01) 6.351e+07 / 3.160e+12
# Successful iteration[ 662000]: (8.829e+01) 6.366e+07 / 3.160e+12
# Successful iteration[ 664000]: (7.328e+01) 6.394e+07 / 3.160e+12
# Successful iteration[ 665000]: (1.469e+02) 6.409e+07 / 3.160e+12
# Successful iteration[ 666000]: (1.338e+02) 6.423e+07 / 3.160e+12
# Successful iteration[ 667000]: (1.219e+02) 6.438e+07 / 3.160e+12
# Successful iteration[ 668000]: (1.111e+02) 6.452e+07 / 3.160e+12
# Successful iteration[ 669000]: (1.012e+02) 6.467e+07 / 3.160e+12
# Successful iteration[ 670000]: (2.028e+02) 6.481e+07 / 3.160e+12
# Successful iteration[ 671000]: (8.398e+01) 6.495e+07 / 3.160e+12
# Successful iteration[ 672000]: (1.683e+02) 6.510e+07 / 3.160e+12
# Successful iteration[ 673000]: (1.533e+02) 6.524e+07 / 3.160e+12
# Successful iteration[ 674000]: (3.074e+02) 6.539e+07 / 3.160e+12
# Successful iteration[ 675000]: (1.273e+02) 6.553e+07 / 3.160e+12
# Successful iteration[ 676000]: (1.160e+02) 6.568e+07 / 3.160e+12
# Successful iteration[ 679000]: (1.929e+02) 6.611e+07 / 3.160e+12
# Successful iteration[ 680000]: (1.757e+02) 6.625e+07 / 3.160e+12
# Successful iteration[ 681000]: (1.601e+02) 6.639e+07 / 3.160e+12
# Successful iteration[ 682000]: (6.631e+01) 6.653e+07 / 3.160e+12
# Successful iteration[ 683000]: (1.329e+02) 6.667e+07 / 3.160e+12
# Successful iteration[ 684000]: (1.211e+02) 6.682e+07 / 3.160e+12
# Successful iteration[ 686000]: (2.211e+02) 6.710e+07 / 3.160e+12
# Successful iteration[ 687000]: (2.014e+02) 6.724e+07 / 3.160e+12
# Successful iteration[ 688000]: (1.835e+02) 6.739e+07 / 3.160e+12
# Successful iteration[ 689000]: (3.678e+02) 6.753e+07 / 3.160e+12
# Successful iteration[ 690000]: (1.523e+02) 6.768e+07 / 3.160e+12
# Successful iteration[ 691000]: (6.307e+01) 6.782e+07 / 3.160e+12
# Successful iteration[ 692000]: (1.264e+02) 6.796e+07 / 3.160e+12
# Successful iteration[ 693000]: (2.534e+02) 6.811e+07 / 3.160e+12
# Successful iteration[ 695000]: (2.103e+02) 6.839e+07 / 3.160e+12
# Successful iteration[ 696000]: (1.916e+02) 6.854e+07 / 3.160e+12
# Successful iteration[ 697000]: (1.746e+02) 6.868e+07 / 3.160e+12
# Successful iteration[ 698000]: (3.499e+02) 6.882e+07 / 3.160e+12
# Successful iteration[ 699000]: (1.449e+02) 6.897e+07 / 3.160e+12
# Successful iteration[ 700000]: (1.320e+02) 6.911e+07 / 3.160e+12
# Successful iteration[ 701000]: (1.203e+02) 6.926e+07 / 3.160e+12
# Successful iteration[ 702000]: (1.096e+02) 6.940e+07 / 3.160e+12
# Successful iteration[ 703000]: (2.196e+02) 6.955e+07 / 3.160e+12
# Successful iteration[ 704000]: (2.000e+02) 6.969e+07 / 3.160e+12
# Successful iteration[ 705000]: (1.823e+02) 6.982e+07 / 3.160e+12
# Successful iteration[ 706000]: (1.660e+02) 6.997e+07 / 3.160e+12
# Successful iteration[ 707000]: (1.513e+02) 7.011e+07 / 3.160e+12
# Successful iteration[ 712000]: (2.089e+02) 7.081e+07 / 3.160e+12
# Successful iteration[ 713000]: (1.903e+02) 7.096e+07 / 3.160e+12
# Successful iteration[ 714000]: (1.734e+02) 7.111e+07 / 3.160e+12
# Successful iteration[ 715000]: (1.579e+02) 7.125e+07 / 3.160e+12
# Successful iteration[ 717000]: (1.311e+02) 7.153e+07 / 3.160e+12
# Successful iteration[ 718000]: (1.194e+02) 7.167e+07 / 3.160e+12
# Successful iteration[ 719000]: (1.088e+02) 7.181e+07 / 3.160e+12
# Successful iteration[ 720000]: (9.913e+01) 7.195e+07 / 3.160e+12
# Successful iteration[ 721000]: (1.987e+02) 7.209e+07 / 3.160e+12
# Successful iteration[ 722000]: (1.810e+02) 7.224e+07 / 3.160e+12
# Successful iteration[ 723000]: (1.649e+02) 7.238e+07 / 3.160e+12
# Successful iteration[ 724000]: (3.305e+02) 7.252e+07 / 3.160e+12
# Successful iteration[ 725000]: (1.369e+02) 7.266e+07 / 3.160e+12
# Successful iteration[ 726000]: (1.247e+02) 7.280e+07 / 3.160e+12
# Successful iteration[ 727000]: (1.136e+02) 7.295e+07 / 3.160e+12
# Successful iteration[ 728000]: (2.277e+02) 7.309e+07 / 3.160e+12
# Successful iteration[ 729000]: (2.075e+02) 7.323e+07 / 3.160e+12
# Successful iteration[ 730000]: (8.591e+01) 7.338e+07 / 3.160e+12
# Successful iteration[ 731000]: (1.722e+02) 7.352e+07 / 3.160e+12
# Successful iteration[ 732000]: (1.569e+02) 7.367e+07 / 3.160e+12
# Successful iteration[ 733000]: (1.429e+02) 7.381e+07 / 3.160e+12
# Successful iteration[ 734000]: (1.302e+02) 7.396e+07 / 3.160e+12
# Successful iteration[ 735000]: (1.186e+02) 7.411e+07 / 3.160e+12
# Successful iteration[ 736000]: (1.081e+02) 7.424e+07 / 3.160e+12
# Successful iteration[ 737000]: (9.846e+01) 7.438e+07 / 3.160e+12
# Successful iteration[ 739000]: (1.798e+02) 7.466e+07 / 3.160e+12
# Successful iteration[ 740000]: (1.638e+02) 7.481e+07 / 3.160e+12
# Successful iteration[ 741000]: (1.492e+02) 7.494e+07 / 3.160e+12
# Successful iteration[ 742000]: (1.359e+02) 7.509e+07 / 3.160e+12
# Successful iteration[ 743000]: (1.239e+02) 7.523e+07 / 3.160e+12
# Successful iteration[ 744000]: (1.128e+02) 7.537e+07 / 3.160e+12
# Successful iteration[ 745000]: (1.028e+02) 7.551e+07 / 3.160e+12
# Successful iteration[ 746000]: (2.060e+02) 7.566e+07 / 3.160e+12
# Successful iteration[ 747000]: (1.877e+02) 7.580e+07 / 3.160e+12
# Successful iteration[ 748000]: (1.710e+02) 7.595e+07 / 3.160e+12
# Successful iteration[ 749000]: (1.558e+02) 7.609e+07 / 3.160e+12
# Successful iteration[ 750000]: (1.419e+02) 7.624e+07 / 3.160e+12
# Successful iteration[ 751000]: (2.845e+02) 7.640e+07 / 3.160e+12
# Successful iteration[ 752000]: (2.592e+02) 7.654e+07 / 3.160e+12
# Successful iteration[ 753000]: (1.073e+02) 7.669e+07 / 3.160e+12
# Successful iteration[ 754000]: (9.779e+01) 7.683e+07 / 3.160e+12
# Successful iteration[ 756000]: (3.928e+02) 7.711e+07 / 3.160e+12
# Successful iteration[ 757000]: (1.627e+02) 7.726e+07 / 3.160e+12
# Successful iteration[ 758000]: (1.482e+02) 7.740e+07 / 3.160e+12
# Successful iteration[ 759000]: (1.350e+02) 7.755e+07 / 3.160e+12
# Successful iteration[ 760000]: (2.706e+02) 7.769e+07 / 3.160e+12
# Successful iteration[ 761000]: (1.121e+02) 7.783e+07 / 3.160e+12
# Successful iteration[ 762000]: (1.021e+02) 7.798e+07 / 3.160e+12
# Successful iteration[ 764000]: (1.864e+02) 7.826e+07 / 3.160e+12
# Successful iteration[ 765000]: (1.699e+02) 7.840e+07 / 3.160e+12
# Successful iteration[ 767000]: (1.410e+02) 7.869e+07 / 3.160e+12
# Successful iteration[ 768000]: (1.284e+02) 7.883e+07 / 3.160e+12
# Successful iteration[ 769000]: (1.170e+02) 7.897e+07 / 3.160e+12
# Successful iteration[ 770000]: (2.345e+02) 7.911e+07 / 3.160e+12
# Successful iteration[ 771000]: (2.137e+02) 7.925e+07 / 3.160e+12
# Successful iteration[ 773000]: (1.774e+02) 7.953e+07 / 3.160e+12
# Successful iteration[ 774000]: (1.616e+02) 7.968e+07 / 3.160e+12
# Successful iteration[ 775000]: (1.472e+02) 7.982e+07 / 3.160e+12
# Successful iteration[ 776000]: (1.341e+02) 7.996e+07 / 3.160e+12
# Successful iteration[ 777000]: (1.222e+02) 8.010e+07 / 3.160e+12
# Successful iteration[ 778000]: (1.113e+02) 8.025e+07 / 3.160e+12
# Successful iteration[ 781000]: (1.852e+02) 8.067e+07 / 3.160e+12
# Successful iteration[ 782000]: (1.687e+02) 8.081e+07 / 3.160e+12
# Successful iteration[ 783000]: (6.986e+01) 8.096e+07 / 3.160e+12
# Successful iteration[ 784000]: (1.400e+02) 8.110e+07 / 3.160e+12
# Successful iteration[ 785000]: (2.807e+02) 8.124e+07 / 3.160e+12
# Successful iteration[ 788000]: (2.122e+02) 8.167e+07 / 3.160e+12
# Successful iteration[ 789000]: (1.933e+02) 8.181e+07 / 3.160e+12
# Successful iteration[ 790000]: (1.761e+02) 8.195e+07 / 3.160e+12
# Successful iteration[ 791000]: (1.605e+02) 8.210e+07 / 3.160e+12
# Successful iteration[ 792000]: (3.216e+02) 8.223e+07 / 3.160e+12
# Successful iteration[ 793000]: (2.930e+02) 8.237e+07 / 3.160e+12
# Successful iteration[ 794000]: (1.213e+02) 8.251e+07 / 3.160e+12
# Successful iteration[ 797000]: (2.019e+02) 8.294e+07 / 3.160e+12
# Successful iteration[ 798000]: (8.360e+01) 8.308e+07 / 3.160e+12
# Successful iteration[ 799000]: (7.616e+01) 8.323e+07 / 3.160e+12
# Successful iteration[ 800000]: (6.939e+01) 8.337e+07 / 3.160e+12
# Successful iteration[ 801000]: (1.391e+02) 8.351e+07 / 3.160e+12
# Successful iteration[ 802000]: (1.267e+02) 8.365e+07 / 3.160e+12
# Successful iteration[ 803000]: (1.154e+02) 8.380e+07 / 3.160e+12
# Successful iteration[ 804000]: (2.314e+02) 8.394e+07 / 3.160e+12
# Successful iteration[ 805000]: (2.108e+02) 8.408e+07 / 3.160e+12
# Successful iteration[ 806000]: (1.920e+02) 8.422e+07 / 3.160e+12
# Successful iteration[ 807000]: (1.749e+02) 8.437e+07 / 3.160e+12
# Successful iteration[ 808000]: (1.594e+02) 8.451e+07 / 3.160e+12
# Successful iteration[ 809000]: (1.452e+02) 8.465e+07 / 3.160e+12
# Successful iteration[ 810000]: (2.910e+02) 8.480e+07 / 3.160e+12
# Successful iteration[ 811000]: (1.205e+02) 8.495e+07 / 3.160e+12
# Successful iteration[ 812000]: (1.098e+02) 8.509e+07 / 3.160e+12
# Successful iteration[ 813000]: (2.201e+02) 8.524e+07 / 3.160e+12
# Successful iteration[ 814000]: (9.114e+01) 8.538e+07 / 3.160e+12
# Successful iteration[ 815000]: (1.827e+02) 8.552e+07 / 3.160e+12
# Successful iteration[ 816000]: (1.664e+02) 8.567e+07 / 3.160e+12
# Successful iteration[ 817000]: (1.516e+02) 8.581e+07 / 3.160e+12
# Successful iteration[ 818000]: (3.039e+02) 8.595e+07 / 3.160e+12
# Successful iteration[ 819000]: (1.258e+02) 8.610e+07 / 3.160e+12
# Successful iteration[ 820000]: (1.146e+02) 8.624e+07 / 3.160e+12
# Successful iteration[ 821000]: (1.044e+02) 8.639e+07 / 3.160e+12
# Successful iteration[ 822000]: (2.093e+02) 8.653e+07 / 3.160e+12
# Successful iteration[ 823000]: (1.907e+02) 8.667e+07 / 3.160e+12
# ...
# Successful iteration[ 722000]: (1.597e+00) 7.169e+05 / 3.160e+12
# Successful iteration[ 723000]: (1.455e+00) 7.185e+05 / 3.160e+12
# Successful iteration[ 724000]: (1.325e+00) 7.200e+05 / 3.160e+12
# Successful iteration[ 726000]: (2.420e+00) 7.232e+05 / 3.160e+12
# Successful iteration[ 727000]: (2.204e+00) 7.247e+05 / 3.160e+12
# Successful iteration[ 728000]: (2.008e+00) 7.263e+05 / 3.160e+12
# Successful iteration[ 729000]: (1.830e+00) 7.279e+05 / 3.160e+12
# Successful iteration[ 730000]: (7.577e-01) 7.295e+05 / 3.160e+12
# Successful iteration[ 731000]: (1.519e+00) 7.310e+05 / 3.160e+12
# Successful iteration[ 732000]: (1.384e+00) 7.326e+05 / 3.160e+12
# Successful iteration[ 733000]: (2.773e+00) 7.342e+05 / 3.160e+12
# Successful iteration[ 736000]: (2.097e+00) 7.389e+05 / 3.160e+12
# Successful iteration[ 737000]: (1.910e+00) 7.405e+05 / 3.160e+12
# Successful iteration[ 738000]: (1.741e+00) 7.421e+05 / 3.160e+12
# Successful iteration[ 739000]: (1.586e+00) 7.436e+05 / 3.160e+12
# Successful iteration[ 742000]: (1.199e+00) 7.484e+05 / 3.160e+12
# Successful iteration[ 743000]: (2.403e+00) 7.500e+05 / 3.160e+12
# Successful iteration[ 744000]: (2.190e+00) 7.516e+05 / 3.160e+12
# Successful iteration[ 745000]: (1.995e+00) 7.532e+05 / 3.160e+12
# Successful iteration[ 746000]: (1.817e+00) 7.548e+05 / 3.160e+12
# Successful iteration[ 747000]: (7.526e-01) 7.564e+05 / 3.160e+12
# Successful iteration[ 748000]: (6.856e-01) 7.580e+05 / 3.160e+12
# Successful iteration[ 749000]: (1.374e+00) 7.596e+05 / 3.160e+12
# Successful iteration[ 750000]: (2.754e+00) 7.612e+05 / 3.160e+12
# Successful iteration[ 752000]: (2.286e+00) 7.645e+05 / 3.160e+12
# Successful iteration[ 753000]: (2.083e+00) 7.661e+05 / 3.160e+12
# Successful iteration[ 754000]: (8.625e-01) 7.677e+05 / 3.160e+12
# Successful iteration[ 755000]: (1.729e+00) 7.693e+05 / 3.160e+12
# Successful iteration[ 756000]: (3.465e+00) 7.709e+05 / 3.160e+12
# Successful iteration[ 757000]: (1.435e+00) 7.725e+05 / 3.160e+12
# Successful iteration[ 758000]: (1.307e+00) 7.741e+05 / 3.160e+12
# Successful iteration[ 760000]: (5.251e+00) 7.773e+05 / 3.160e+12
# Successful iteration[ 761000]: (2.175e+00) 7.789e+05 / 3.160e+12
# Successful iteration[ 762000]: (1.981e+00) 7.805e+05 / 3.160e+12
# Successful iteration[ 763000]: (1.805e+00) 7.822e+05 / 3.160e+12
# Successful iteration[ 764000]: (1.644e+00) 7.838e+05 / 3.160e+12
# Successful iteration[ 766000]: (1.365e+00) 7.870e+05 / 3.160e+12
# Successful iteration[ 767000]: (1.243e+00) 7.886e+05 / 3.160e+12
# Successful iteration[ 768000]: (2.492e+00) 7.902e+05 / 3.160e+12
# Successful iteration[ 769000]: (1.032e+00) 7.918e+05 / 3.160e+12
# Successful iteration[ 770000]: (2.069e+00) 7.934e+05 / 3.160e+12
# Successful iteration[ 771000]: (1.885e+00) 7.951e+05 / 3.160e+12
# Successful iteration[ 772000]: (1.717e+00) 7.967e+05 / 3.160e+12
# Successful iteration[ 773000]: (1.564e+00) 7.983e+05 / 3.160e+12
# Successful iteration[ 774000]: (1.425e+00) 7.999e+05 / 3.160e+12
# Successful iteration[ 775000]: (1.298e+00) 8.016e+05 / 3.160e+12
# Successful iteration[ 777000]: (2.371e+00) 8.048e+05 / 3.160e+12
# Successful iteration[ 778000]: (2.160e+00) 8.064e+05 / 3.160e+12
# Successful iteration[ 779000]: (1.968e+00) 8.081e+05 / 3.160e+12
# Successful iteration[ 780000]: (1.793e+00) 8.097e+05 / 3.160e+12
# Successful iteration[ 781000]: (1.633e+00) 8.113e+05 / 3.160e+12
# Successful iteration[ 782000]: (1.488e+00) 8.129e+05 / 3.160e+12
# Successful iteration[ 783000]: (1.356e+00) 8.146e+05 / 3.160e+12
# Successful iteration[ 784000]: (1.235e+00) 8.162e+05 / 3.160e+12
# Successful iteration[ 785000]: (2.475e+00) 8.178e+05 / 3.160e+12
# Successful iteration[ 786000]: (2.255e+00) 8.194e+05 / 3.160e+12
# Successful iteration[ 787000]: (2.055e+00) 8.211e+05 / 3.160e+12
# Successful iteration[ 788000]: (1.872e+00) 8.227e+05 / 3.160e+12
# Successful iteration[ 789000]: (1.705e+00) 8.243e+05 / 3.160e+12
# Successful iteration[ 790000]: (1.554e+00) 8.260e+05 / 3.160e+12
# Successful iteration[ 791000]: (1.415e+00) 8.276e+05 / 3.160e+12
# Successful iteration[ 794000]: (2.355e+00) 8.325e+05 / 3.160e+12
# Successful iteration[ 795000]: (2.145e+00) 8.341e+05 / 3.160e+12
# Successful iteration[ 796000]: (1.954e+00) 8.357e+05 / 3.160e+12
# Successful iteration[ 797000]: (1.781e+00) 8.374e+05 / 3.160e+12
# Successful iteration[ 798000]: (1.622e+00) 8.390e+05 / 3.160e+12
# Successful iteration[ 799000]: (1.478e+00) 8.407e+05 / 3.160e+12
# Successful iteration[ 800000]: (1.346e+00) 8.423e+05 / 3.160e+12
# Successful iteration[ 802000]: (2.458e+00) 8.456e+05 / 3.160e+12
# Successful iteration[ 803000]: (2.240e+00) 8.472e+05 / 3.160e+12
# Successful iteration[ 804000]: (2.041e+00) 8.489e+05 / 3.160e+12
# Successful iteration[ 805000]: (1.859e+00) 8.505e+05 / 3.160e+12
# Successful iteration[ 806000]: (1.694e+00) 8.521e+05 / 3.160e+12
# Successful iteration[ 807000]: (1.543e+00) 8.538e+05 / 3.160e+12
# Successful iteration[ 808000]: (1.406e+00) 8.554e+05 / 3.160e+12
# Successful iteration[ 809000]: (1.281e+00) 8.570e+05 / 3.160e+12
# Successful iteration[ 810000]: (2.567e+00) 8.587e+05 / 3.160e+12
# Successful iteration[ 811000]: (2.339e+00) 8.603e+05 / 3.160e+12
# Successful iteration[ 812000]: (2.131e+00) 8.619e+05 / 3.160e+12
# Successful iteration[ 813000]: (1.941e+00) 8.636e+05 / 3.160e+12
# Successful iteration[ 814000]: (1.768e+00) 8.652e+05 / 3.160e+12
# Successful iteration[ 815000]: (1.611e+00) 8.668e+05 / 3.160e+12
# Successful iteration[ 816000]: (1.468e+00) 8.685e+05 / 3.160e+12
# Successful iteration[ 818000]: (2.680e+00) 8.717e+05 / 3.160e+12
# Successful iteration[ 819000]: (1.110e+00) 8.734e+05 / 3.160e+12
# Successful iteration[ 820000]: (2.225e+00) 8.750e+05 / 3.160e+12
# Successful iteration[ 821000]: (2.027e+00) 8.767e+05 / 3.160e+12
# Successful iteration[ 822000]: (1.846e+00) 8.783e+05 / 3.160e+12
# Successful iteration[ 823000]: (1.682e+00) 8.800e+05 / 3.160e+12
# Successful iteration[ 824000]: (1.533e+00) 8.816e+05 / 3.160e+12
# Successful iteration[ 825000]: (1.396e+00) 8.832e+05 / 3.160e+12
# Successful iteration[ 826000]: (1.272e+00) 8.849e+05 / 3.160e+12
# Successful iteration[ 827000]: (2.550e+00) 8.865e+05 / 3.160e+12
# Successful iteration[ 828000]: (2.323e+00) 8.881e+05 / 3.160e+12
# Successful iteration[ 829000]: (2.116e+00) 8.898e+05 / 3.160e+12
# Successful iteration[ 830000]: (1.928e+00) 8.914e+05 / 3.160e+12
# Successful iteration[ 831000]: (1.756e+00) 8.931e+05 / 3.160e+12
# Successful iteration[ 832000]: (1.600e+00) 8.947e+05 / 3.160e+12
# Successful iteration[ 833000]: (1.458e+00) 8.963e+05 / 3.160e+12
# Successful iteration[ 835000]: (1.210e+00) 8.996e+05 / 3.160e+12
# Successful iteration[ 836000]: (2.425e+00) 9.012e+05 / 3.160e+12
# Successful iteration[ 837000]: (2.209e+00) 9.029e+05 / 3.160e+12
# Successful iteration[ 839000]: (1.834e+00) 9.062e+05 / 3.160e+12
# Successful iteration[ 840000]: (1.671e+00) 9.078e+05 / 3.160e+12
# Successful iteration[ 841000]: (1.522e+00) 9.094e+05 / 3.160e+12
# Successful iteration[ 842000]: (1.387e+00) 9.111e+05 / 3.160e+12
# Successful iteration[ 843000]: (2.779e+00) 9.127e+05 / 3.160e+12
# Successful iteration[ 844000]: (2.532e+00) 9.144e+05 / 3.160e+12
# Successful iteration[ 845000]: (2.307e+00) 9.160e+05 / 3.160e+12
# Successful iteration[ 846000]: (9.553e-01) 9.177e+05 / 3.160e+12
# Successful iteration[ 847000]: (8.704e-01) 9.193e+05 / 3.160e+12
# Successful iteration[ 849000]: (1.589e+00) 9.226e+05 / 3.160e+12
# Successful iteration[ 851000]: (1.319e+00) 9.259e+05 / 3.160e+12
# Successful iteration[ 852000]: (1.202e+00) 9.276e+05 / 3.160e+12
# Successful iteration[ 853000]: (2.409e+00) 9.292e+05 / 3.160e+12
# Successful iteration[ 854000]: (9.975e-01) 9.309e+05 / 3.160e+12
# Successful iteration[ 855000]: (1.999e+00) 9.325e+05 / 3.160e+12
# Successful iteration[ 856000]: (8.279e-01) 9.342e+05 / 3.160e+12
# Successful iteration[ 857000]: (1.659e+00) 9.358e+05 / 3.160e+12
# Successful iteration[ 858000]: (3.326e+00) 9.375e+05 / 3.160e+12
# Successful iteration[ 859000]: (1.377e+00) 9.392e+05 / 3.160e+12
# Successful iteration[ 861000]: (2.515e+00) 9.425e+05 / 3.160e+12
# Successful iteration[ 862000]: (2.291e+00) 9.441e+05 / 3.160e+12
# Successful iteration[ 863000]: (2.087e+00) 9.458e+05 / 3.160e+12
# Successful iteration[ 864000]: (1.902e+00) 9.474e+05 / 3.160e+12
# Successful iteration[ 865000]: (1.733e+00) 9.491e+05 / 3.160e+12
# Successful iteration[ 867000]: (3.164e+00) 9.524e+05 / 3.160e+12
# Successful iteration[ 868000]: (2.882e+00) 9.541e+05 / 3.160e+12
# Successful iteration[ 870000]: (1.087e+00) 9.574e+05 / 3.160e+12
# Successful iteration[ 872000]: (1.986e+00) 9.607e+05 / 3.160e+12
# Successful iteration[ 873000]: (1.809e+00) 9.624e+05 / 3.160e+12
# Successful iteration[ 874000]: (1.648e+00) 9.641e+05 / 3.160e+12
# Successful iteration[ 875000]: (1.502e+00) 9.658e+05 / 3.160e+12
# Successful iteration[ 876000]: (1.368e+00) 9.674e+05 / 3.160e+12
# Successful iteration[ 877000]: (2.742e+00) 9.691e+05 / 3.160e+12
# Successful iteration[ 878000]: (2.498e+00) 9.707e+05 / 3.160e+12
# Successful iteration[ 879000]: (2.276e+00) 9.724e+05 / 3.160e+12
# Successful iteration[ 880000]: (2.073e+00) 9.741e+05 / 3.160e+12
# Successful iteration[ 881000]: (1.889e+00) 9.757e+05 / 3.160e+12
# Successful iteration[ 882000]: (1.721e+00) 9.774e+05 / 3.160e+12
# Successful iteration[ 883000]: (1.568e+00) 9.790e+05 / 3.160e+12
# Successful iteration[ 885000]: (1.301e+00) 9.824e+05 / 3.160e+12
# Successful iteration[ 886000]: (2.608e+00) 9.840e+05 / 3.160e+12
# Successful iteration[ 887000]: (2.376e+00) 9.857e+05 / 3.160e+12
# Successful iteration[ 888000]: (2.165e+00) 9.874e+05 / 3.160e+12
# Successful iteration[ 889000]: (1.972e+00) 9.890e+05 / 3.160e+12
# Successful iteration[ 891000]: (1.637e+00) 9.924e+05 / 3.160e+12
# Successful iteration[ 892000]: (1.491e+00) 9.940e+05 / 3.160e+12
# Successful iteration[ 893000]: (1.359e+00) 9.957e+05 / 3.160e+12
# Successful iteration[ 894000]: (2.723e+00) 9.974e+05 / 3.160e+12
# Successful iteration[ 895000]: (2.481e+00) 9.990e+05 / 3.160e+12
# Successful iteration[ 896000]: (2.260e+00) 1.001e+06 / 3.160e+12
# Successful iteration[ 897000]: (2.059e+00) 1.002e+06 / 3.160e+12
# Successful iteration[ 898000]: (1.876e+00) 1.004e+06 / 3.160e+12
# Successful iteration[ 899000]: (1.709e+00) 1.006e+06 / 3.160e+12
# Successful iteration[ 900000]: (3.426e+00) 1.007e+06 / 3.160e+12
# Successful iteration[ 901000]: (1.419e+00) 1.009e+06 / 3.160e+12
# Successful iteration[ 902000]: (1.292e+00) 1.011e+06 / 3.160e+12
# Successful iteration[ 903000]: (1.177e+00) 1.012e+06 / 3.160e+12
# Successful iteration[ 904000]: (2.360e+00) 1.014e+06 / 3.160e+12
# Successful iteration[ 905000]: (2.150e+00) 1.016e+06 / 3.160e+12
# Successful iteration[ 906000]: (8.903e-01) 1.017e+06 / 3.160e+12
# Successful iteration[ 907000]: (1.785e+00) 1.019e+06 / 3.160e+12
# Successful iteration[ 908000]: (1.626e+00) 1.021e+06 / 3.160e+12
# Successful iteration[ 909000]: (1.481e+00) 1.023e+06 / 3.160e+12
# Successful iteration[ 912000]: (1.120e+00) 1.028e+06 / 3.160e+12
# Successful iteration[ 913000]: (2.245e+00) 1.029e+06 / 3.160e+12
# Successful iteration[ 915000]: (1.863e+00) 1.033e+06 / 3.160e+12
# Successful iteration[ 916000]: (1.698e+00) 1.034e+06 / 3.160e+12
# Successful iteration[ 917000]: (1.547e+00) 1.036e+06 / 3.160e+12
# Successful iteration[ 918000]: (1.409e+00) 1.038e+06 / 3.160e+12
# Successful iteration[ 919000]: (2.824e+00) 1.039e+06 / 3.160e+12
# Successful iteration[ 920000]: (1.169e+00) 1.041e+06 / 3.160e+12
# Successful iteration[ 921000]: (2.344e+00) 1.043e+06 / 3.160e+12
# Successful iteration[ 922000]: (2.135e+00) 1.044e+06 / 3.160e+12
# Successful iteration[ 923000]: (1.945e+00) 1.046e+06 / 3.160e+12
# Successful iteration[ 924000]: (1.772e+00) 1.048e+06 / 3.160e+12
# Successful iteration[ 925000]: (1.615e+00) 1.050e+06 / 3.160e+12
# Successful iteration[ 926000]: (1.471e+00) 1.051e+06 / 3.160e+12
# Successful iteration[ 928000]: (2.686e+00) 1.055e+06 / 3.160e+12
# Successful iteration[ 929000]: (1.112e+00) 1.056e+06 / 3.160e+12
# Successful iteration[ 930000]: (2.230e+00) 1.058e+06 / 3.160e+12
# Successful iteration[ 931000]: (2.031e+00) 1.060e+06 / 3.160e+12
# Successful iteration[ 932000]: (1.851e+00) 1.062e+06 / 3.160e+12
# Successful iteration[ 933000]: (1.686e+00) 1.063e+06 / 3.160e+12
# Successful iteration[ 934000]: (1.536e+00) 1.065e+06 / 3.160e+12
# Successful iteration[ 935000]: (1.399e+00) 1.067e+06 / 3.160e+12
# Successful iteration[ 936000]: (2.805e+00) 1.068e+06 / 3.160e+12
# Successful iteration[ 937000]: (2.555e+00) 1.070e+06 / 3.160e+12
# Successful iteration[ 938000]: (2.328e+00) 1.072e+06 / 3.160e+12
# Successful iteration[ 939000]: (2.121e+00) 1.073e+06 / 3.160e+12
# Successful iteration[ 940000]: (1.932e+00) 1.075e+06 / 3.160e+12
# Successful iteration[ 941000]: (3.873e+00) 1.077e+06 / 3.160e+12
# Successful iteration[ 942000]: (1.604e+00) 1.078e+06 / 3.160e+12
# Successful iteration[ 943000]: (1.461e+00) 1.080e+06 / 3.160e+12
# Successful iteration[ 944000]: (2.929e+00) 1.082e+06 / 3.160e+12
# Successful iteration[ 945000]: (1.213e+00) 1.084e+06 / 3.160e+12
# Successful iteration[ 946000]: (2.431e+00) 1.085e+06 / 3.160e+12
# Successful iteration[ 947000]: (2.214e+00) 1.087e+06 / 3.160e+12
# Successful iteration[ 949000]: (8.355e-01) 1.090e+06 / 3.160e+12
# Successful iteration[ 950000]: (3.684e+00) 1.092e+06 / 3.160e+12
# Successful iteration[ 951000]: (1.526e+00) 1.094e+06 / 3.160e+12
# Successful iteration[ 952000]: (1.390e+00) 1.096e+06 / 3.160e+12
# Successful iteration[ 953000]: (1.266e+00) 1.097e+06 / 3.160e+12
# Successful iteration[ 954000]: (2.538e+00) 1.099e+06 / 3.160e+12
# Successful iteration[ 955000]: (2.312e+00) 1.101e+06 / 3.160e+12
# Successful iteration[ 956000]: (2.106e+00) 1.102e+06 / 3.160e+12
# Successful iteration[ 957000]: (1.919e+00) 1.104e+06 / 3.160e+12
# Successful iteration[ 959000]: (7.240e-01) 1.108e+06 / 3.160e+12
# Successful iteration[ 960000]: (3.193e+00) 1.109e+06 / 3.160e+12
# Successful iteration[ 962000]: (2.650e+00) 1.113e+06 / 3.160e+12
# Successful iteration[ 963000]: (2.414e+00) 1.114e+06 / 3.160e+12
# Successful iteration[ 964000]: (2.199e+00) 1.116e+06 / 3.160e+12
# Successful iteration[ 965000]: (2.004e+00) 1.118e+06 / 3.160e+12
# Successful iteration[ 966000]: (8.298e-01) 1.119e+06 / 3.160e+12
# Successful iteration[ 967000]: (1.663e+00) 1.121e+06 / 3.160e+12
# Successful iteration[ 968000]: (1.515e+00) 1.123e+06 / 3.160e+12
# Successful iteration[ 969000]: (6.275e-01) 1.125e+06 / 3.160e+12
# Successful iteration[ 970000]: (1.258e+00) 1.126e+06 / 3.160e+12
# Successful iteration[ 971000]: (2.521e+00) 1.128e+06 / 3.160e+12
# Successful iteration[ 973000]: (2.092e+00) 1.131e+06 / 3.160e+12
# Successful iteration[ 974000]: (8.664e-01) 1.133e+06 / 3.160e+12
# Successful iteration[ 975000]: (7.893e-01) 1.135e+06 / 3.160e+12
# Successful iteration[ 976000]: (1.582e+00) 1.136e+06 / 3.160e+12
# Successful iteration[ 977000]: (1.441e+00) 1.138e+06 / 3.160e+12
# Successful iteration[ 979000]: (2.632e+00) 1.141e+06 / 3.160e+12
# Successful iteration[ 980000]: (1.090e+00) 1.143e+06 / 3.160e+12
# Successful iteration[ 981000]: (2.184e+00) 1.145e+06 / 3.160e+12
# Successful iteration[ 982000]: (1.990e+00) 1.147e+06 / 3.160e+12
# Successful iteration[ 983000]: (1.813e+00) 1.148e+06 / 3.160e+12
# Successful iteration[ 984000]: (1.652e+00) 1.150e+06 / 3.160e+12
# Successful iteration[ 985000]: (1.505e+00) 1.152e+06 / 3.160e+12
# Successful iteration[ 987000]: (1.249e+00) 1.155e+06 / 3.160e+12
# Successful iteration[ 988000]: (2.504e+00) 1.157e+06 / 3.160e+12
# Successful iteration[ 989000]: (2.281e+00) 1.158e+06 / 3.160e+12
# Successful iteration[ 990000]: (2.078e+00) 1.160e+06 / 3.160e+12
# Successful iteration[ 991000]: (1.893e+00) 1.162e+06 / 3.160e+12
# Successful iteration[ 992000]: (1.725e+00) 1.164e+06 / 3.160e+12
# Successful iteration[ 993000]: (1.571e+00) 1.165e+06 / 3.160e+12
# Successful iteration[ 994000]: (1.432e+00) 1.167e+06 / 3.160e+12
# Successful iteration[ 995000]: (1.304e+00) 1.169e+06 / 3.160e+12
# Successful iteration[ 996000]: (2.614e+00) 1.170e+06 / 3.160e+12
# Successful iteration[ 997000]: (2.381e+00) 1.172e+06 / 3.160e+12
# Successful iteration[ 998000]: (2.170e+00) 1.174e+06 / 3.160e+12
# Successful iteration[ 999000]: (1.977e+00) 1.176e+06 / 3.160e+12
# End in 1000000 iterations: 1.17730e+06 / 3.16000e+12 (3.16000e+12)

# %%
a = result_H[0][-1]
skip_list = ['t', 'successful', 'dt']
plt.clf()
plt.figure(figsize = (8,8))
for key in a.keys():
    print(key)
    print(len(a[key]))
    b = (a[key])
    t = (a['t'])
    if key not in skip_list:       
        plt.loglog(t, b[2], label = key)

plt.loglog(t, a['dt'],label='dt')
#        plt.xlim((0 ,4.0e6))
plt.legend(loc='upper right',fontsize = 'x-small')
plt.show()
# Out:
# H_2
# 3
# H_1
# 3
# successful
# 1000000
# de
# 3
# He_1
# 3
# He_2
# 3
# He_3
# 3
# ge
# 3
# H2_2
# 3
# H2_1
# 3
# t
# 1000000
# dt
# 1000000
# H_m0
# 3
# T
# 3

# %%
print(result_H[0][-1]['t'])
# Out:
# [      0.               0.               0.         ...,  100142.959138
#   100144.13124794  100145.42056887]

# %%
plt.show()

# %%
# Vaytet et al. 2014 A&A 
# OPR 
# two phono relaxation 


# sheffer et al. 2008
# CO vs H2

# %%
def is_number(loc, s):
    if loc == 1:
        return float(s[:-1])    
    try:
        float(s)
        return float(s)
    except ValueError:
        return s
keys = ['dt', 'nchem', 'changes', 'sum tol', 'atol', 'rtol', 'value']
all_result = []
with open('output.txt', 'r') as f:
    for line in f:
        line = line.strip('\n')
        ele = line.split(' ')
        float_ele = [ is_number(loc,s) for loc, s in enumerate(ele) ]
        num = [i for i in float_ele if type(i) == numpy.float]
        all_result.append(dict(zip(keys,num)))

# %%
atol = []
rtol = []
dt = []
value = []
sum_tol = []
nchem = []
for i in all_result:
    atol.append(i['atol'])
    rtol.append(i['rtol'])
    dt.append(i['dt'])
    value.append(i['value'])
    sum_tol.append(i['sum tol'])
    nchem.append(i['nchem'])

# %%
plt.plot(atol, label='atol')
plt.plot(rtol, label='rtol')
plt.plot(dt, label='dt')
plt.plot(value, label='value')
plt.plot(sum_tol, label='sum_tol')
plt.plot(nchem)
plt.yscale('log')
plt.legend(loc ='best')
plt.show()
