# %%
import os
os.environ['YT_DEST'] = '/home/kwoksun2/anaconda2/pkgs/yt-3.3.5-np111py27_2/'
import numpy as np
from dengo.chemical_network import \
    ChemicalNetwork, \
    reaction_registry, \
    cooling_registry, species_registry
import dengo.primordial_rates, dengo.primordial_cooling
from dengo.chemistry_constants import tiny, kboltz, mh
import yt
import yt.units as u
import numpy
from IPython.display import Image
import matplotlib.pyplot as plt
import pickle
import pyximport
import matplotlib.colors as colors
import h5py
import timeit

pyximport.install(setup_args={"include_dirs":np.get_include()},
                      reload_support=True, inplace=True)
loc_pwd = "/home/kwoksun2/grackle/src/python/examples/"
def save_obj(obj, name ):
    with open(loc_pwd+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(loc_pwd + name + '.pkl', 'rb') as f:
        return pickle.load(f)
# Out:
#  using cli
#  using CLI for selections

# %%
def Init_values(temperature, density, n_species = 6):
    
    # initialize and setup the network
    dengo.primordial_rates.setup_primordial()
    primordial = ChemicalNetwork()
    
    
    if n_species == 9:
        for i in range(23):
            if (i+1) not in [0]: #, 10, 11, 17,18,19]:
                try:
                    primordial.add_reaction("k{0:02d}".format(i+1))
                except:
                    pass
    else:
        for i in range(6):
            if (i+1) not in [0]: #, 10, 11, 17,18,19]:
                try:
                    primordial.add_reaction("k{0:02d}".format(i+1))
                except:
                    pass        
        
    primordial.init_temperature((1e0, 1e5))

    tiny = 1.0e-20

    # init_array are is in fractional abundances
    init_array = density
    init_values = dict()
    
    if n_species == 6:
        # 6-species model
        init_values["He_1"]    = density * (1.0 - 0.76) /2.
        init_values["He_2"]    = density * (1.0 - 0.76) /2.      
        init_values["He_3"]    = np.array([tiny]) #density * (1.0 - 0.76) /3.        
        init_values["H_1"]     = density *  (0.76)  /2.
        init_values['H_2']     = density *  (0.76)  /2.
    else:    
        # 9-species model
        init_values["He_1"]    = density * (1.0 - 0.76) /2.0
        init_values["He_2"]    = density * (1.0 - 0.76) /2.0  
        init_values["He_3"]    = np.array([tiny])           
        init_values["H_1"]     = density *  (0.76)  /3.
        init_values['H_2']     = density *  (0.76)  /3

        init_values["H_m0"]    = np.array([tiny]) 
        init_values["H2_1"]    = density *  (0.76)  /3. 
        init_values["H2_2"]    = np.array([tiny])  
    
    # now everything in mass density
#    init_values = primordial.convert_to_mass_density(init_values)
    init_values['de'] = primordial.calculate_free_electrons(init_values)
    # one signle value: again mass density
    init_values['density'] = primordial.calculate_total_density(init_values)
    number_density = primordial.calculate_number_density(init_values)
        
    num_den = {}
    total_num_den = 0.0
    total_den = 0.0
    for sp in primordial.required_species:
        try:
            
            num_den[sp.name] = init_values[sp.name]/ sp.weight
            # total_num_den += init_values[sp.name]/ sp.weight
            if sp.name != 'de':
                total_den += init_values[sp.name]
                total_num_den += init_values[sp.name]/ sp.weight
        except:
            pass
    # mean molecular mass
    mmm = total_den/total_num_den
    mmm = init_values['density']/number_density
    # set up initial temperatures values used to define ge
    init_values['T'] = temperature

    # calculate ge (very crudely, no H2 help here)
    gamma = 5.0/3.0
    init_values['ge'] = ((temperature * number_density * kboltz)
                         / (init_values['density'] * mh * (gamma - 1)))
    
    a = init_values['ge']
    
    x = 6100.0/temperature
    gammaH2 = 2.0 / (5.0 + 2.0*x*x / (numpy.exp(x) - 1 )**2.0 ) + 1
    
    gamma_factor = primordial.gamma_factor().subs(num_den).subs({'gammaH2': gammaH2 , 'gamma': 5./3.,'T': temperature })
    
    ge  = ((temperature *  kboltz) *gamma_factor
                         / (init_values['density'] * mh  ))
    
    T = init_values['density']*ge*mh / kboltz / gamma_factor
    init_values['ge'] = numpy.array( [numpy.float64(ge)] )
    
    return init_values, primordial

# %%
init, primordial = Init_values(np.array([1000.0]), np.array([1e20]), n_species = 9)
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1

# %%
for cooling_action in cooling_registry:
    k = cooling_registry[cooling_action]
    if (k.species).issubset( primordial.required_species ):
        if cooling_action[:2] not in ['ci' ]:
            print( cooling_action, k.equation )
            primordial.add_cooling(cooling_action)
# Out:
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'brem': brem_brem[i], 'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-brem * (HII + HeII + 4.0*HeIII) * de')
# ('brem', -brem_brem[i]*de*(H_2 + He_2 + 4.0*He_3))
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'reHII': reHII_reHII[i], 'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-reHII * HII * de')
# ('reHII', -H_2*de*reHII_reHII[i])
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'reHeIII': reHeIII_reHeIII[i], 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-reHeIII * HeIII * de')
# ('reHeIII', -He_3*de*reHeIII_reHeIII[i])
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'h2lte': gloverabel08_h2lte[i], 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'gaHI': gloverabel08_gaHI[i], 'ge': ge, 'HI': H_1, 'H2_2': H2_2, 'H2_1': H2_1, 'gphdl': gloverabel08_gphdl[i], 'H_m0': H_m0, 'gael': gloverabel08_gael[i], 'H_2': H_2, 'gpldl': gloverabel08_gpldl[i], 'H_1': H_1, 'H2II': H2_2, 'gaH2': gloverabel08_gaH2[i], 'gaHe': gloverabel08_gaHe[i], 'gaHp': gloverabel08_gaHp[i], 'H2I': H2_1, 'HeII': He_2, 'HII': H_2, 'galdl': galdl, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-(H2I)*h2lte/(1.0+h2lte/galdl)')
# ('galdl', 'gaHI*HI + gaH2*H2I + gaHe*HeI + gaHp*HII + gael*de')
# --------
# ('galdl', H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i])
# ('gloverabel08', -H2_1*gloverabel08_h2lte[i]/(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0))
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'ceHI': ceHI_ceHI[i], 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-ceHI * HI * de')
# ('ceHI', -H_1*ceHI_ceHI[i]*de)
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'comp2': comp2, 'ge': ge, 'HI': H_1, 'H2_2': H2_2, 'H2_1': H2_1, 'H_m0': H_m0, 'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'T': T, 'HeI': He_1, 'comp1': comp1, 'H2I': H2_1, 'HeII': He_2, 'HII': H_2, 'z': z, 'comp_': compton_comp_[i], 'HeIII': He_3})
# ('self equation', '-(comp1)*(T - (comp2))*de')
# ('comp2', '2.73 * (1.0 + z)')
# --------
# ('comp2', 2.73*z + 2.73)
# ('z', 'z')
# --------
# ('z', z)
# ('comp1', 'comp_ * (1.0 + z)**4')
# --------
# ('comp1', compton_comp_[i]*(z + 1.0)**4)
# ('T', 'T')
# --------
# ('T', T)
# ('compton', -compton_comp_[i]*de*(z + 1.0)**4*(T - 2.73*z - 2.73))
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'nH': nH, 'ncrd1': h2formation_ncrd1[i], 'ncrd2': h2formation_ncrd2[i], 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2_2': H2_2, 'H2_1': H2_1, 'H_m0': H_m0, 'h2heatfrac': h2heatfrac, 'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'h2mcool': h2formation_h2mcool[i], 'ncrn': h2formation_ncrn[i], 'H2I': H2_1, 'HeII': He_2, 'HII': H_2, 'h2mheat': h2formation_h2mheat[i], 'HeI': He_1, 'HeIII': He_3})
# ('self equation', 'h2heatfrac*(h2mheat*HI*HI*HI - h2mcool*H2I*HI)')
# ('nH', 'nH')
# --------
# ('nH', nH)
# ('h2heatfrac', ' (1.0 + ncrn *nH / (HI * ncrd1 + H2I * ncrd2))**(-1) ')
# --------
# ('h2heatfrac', 1/(h2formation_ncrn[i]*nH/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0))
# ('h2formation', (-H2_1*H_1*h2formation_h2mcool[i] + H_1**3*h2formation_h2mheat[i])/(h2formation_ncrn[i]*nH/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0))
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'reHeII2': reHeII2_reHeII2[i], 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-reHeII2 * HeII * de')
# ('reHeII2', -He_2*de*reHeII2_reHeII2[i])
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'reHeII1': reHeII1_reHeII1[i], 'HII': H_2, 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-reHeII1 * HeII * de')
# ('reHeII1', -He_2*de*reHeII1_reHeII1[i])
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'ciHeIS': ciHeIS_ciHeIS[i], 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-ciHeIS*HeII*de**2')
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ceHeII': ceHeII_ceHeII[i], 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-ceHeII * HeII * de')
# ('ceHeII', -He_2*ceHeII_ceHeII[i]*de)
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'ciHI': ciHI_ciHI[i], 'HII': H_2, 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-ciHI*HI*de')
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'ceHeI': ceHeI_ceHeI[i], 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-ceHeI * HeII * de**2')
# ('ceHeI', -He_2*ceHeI_ceHeI[i]*de**2)
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'gammah': gammah_gammah[i], 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '0.0*gammah * HI * HII')
# ('gammah', 0)
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'cieco': cie_cooling_cieco[i], 'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'ndensity': ndensity, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', ' - cieco * H2I * ndensity ')
# ('ndensity', 'ndensity')
# --------
# ('ndensity', ndensity)
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'ciHeI': ciHeI_ciHeI[i], 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-ciHeI*HeI*de')
# {'HII': H_2}
# {'HI': H_1}
# {'HeI': He_1}
# {'HeII': He_2}
# {'HeIII': He_3}
# {'H2II': H2_2}
# {'H2I': H2_1}
# ('symbols', {'ciHeII': ciHeII_ciHeII[i], 'H_2': H_2, 'H_1': H_1, 'H2II': H2_2, 'de': de, 'He_1': He_1, 'He_2': He_2, 'He_3': He_3, 'ge': ge, 'HI': H_1, 'H2I': H2_1, 'H2_2': H2_2, 'H2_1': H2_1, 'HeII': He_2, 'HII': H_2, 'H_m0': H_m0, 'HeI': He_1, 'HeIII': He_3})
# ('self equation', '-ciHeII*HeII*de')

# %%
primordial.cooling_actions
# Out:
# {'brem': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3a90>,
#  'ceHI': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3790>,
#  'ceHeI': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3810>,
#  'ceHeII': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3850>,
#  'compton': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3b10>,
#  'gammah': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3b50>,
#  'gloverabel08': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3ad0>,
#  'h2formation': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3b90>,
#  'reHII': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3990>,
#  'reHeII1': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff39d0>,
#  'reHeII2': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3a10>,
#  'reHeIII': <dengo.reaction_classes.CoolingAction at 0x7f31d9ff3a50>}

# %%
for i in primordial.required_species:
    print(i.name)
    print(primordial.print_JacTimesVec_component(i))
    print('-----------------')
# Out:
# H2_1
# d_H2_1_dy_y = -k11[i]*H2_1*v9 - k12[i]*H2_1*v8 + v0*(-k11[i]*H_2 - k12[i]*de - k13[i]*H_1 + k21[i]*pow(H_1, 2) - 2*k23[i]*H2_1) + v1*(k10[i]*H_1 + k19[i]*H_m0) + v4*(k08[i]*H_1 + k19[i]*H2_2) + v7*(k08[i]*H_m0 + k10[i]*H2_2 - k13[i]*H2_1 + 2*k21[i]*H2_1*H_1 + 3*k22[i]*pow(H_1, 2));
# -----------------
# H2_2
# d_H2_2_dy_y = k11[i]*H_2*v0 - k18[i]*H2_2*v8 + v1*(-k10[i]*H_1 - k18[i]*de - k19[i]*H_m0) + v4*(k17[i]*H_2 - k19[i]*H2_2) + v7*(k09[i]*H_2 - k10[i]*H2_2) + v9*(k09[i]*H_1 + k11[i]*H2_1 + k17[i]*H_m0);
# -----------------
# ge
# d_ge_dy_y = -H2_1*gloverabel08_gaHe[i]*pow(gloverabel08_h2lte[i], 2)*v3/(mdensity*pow(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0, 2)*pow(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i], 2)) + v0*(-H2_1*gloverabel08_gaH2[i]*pow(gloverabel08_h2lte[i], 2)/(pow(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0, 2)*pow(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i], 2)) - H_1*h2formation_h2mcool[i]/(h2formation_ncrn[i]*nH/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0) - gloverabel08_h2lte[i]/(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0) + h2formation_ncrd2[i]*h2formation_ncrn[i]*nH*(-H2_1*H_1*h2formation_h2mcool[i] + pow(H_1, 3)*h2formation_h2mheat[i])/(pow(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i], 2)*pow(h2formation_ncrn[i]*nH/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0, 2)))/mdensity + v5*(-4.0*brem_brem[i]*de - de*reHeIII_reHeIII[i])/mdensity + v6*(-brem_brem[i]*de - ceHeII_ceHeII[i]*de - ceHeI_ceHeI[i]*pow(de, 2) - de*reHeII1_reHeII1[i] - de*reHeII2_reHeII2[i])/mdensity + v7*(-H2_1*gloverabel08_gaHI[i]*pow(gloverabel08_h2lte[i], 2)/(pow(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0, 2)*pow(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i], 2)) - ceHI_ceHI[i]*de + h2formation_ncrd1[i]*h2formation_ncrn[i]*nH*(-H2_1*H_1*h2formation_h2mcool[i] + pow(H_1, 3)*h2formation_h2mheat[i])/(pow(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i], 2)*pow(h2formation_ncrn[i]*nH/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0, 2)) + (-H2_1*h2formation_h2mcool[i] + 3*pow(H_1, 2)*h2formation_h2mheat[i])/(h2formation_ncrn[i]*nH/(H2_1*h2formation_ncrd2[i] + H_1*h2formation_ncrd1[i]) + 1.0))/mdensity + v8*(-H2_1*gloverabel08_gael[i]*pow(gloverabel08_h2lte[i], 2)/(pow(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0, 2)*pow(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i], 2)) - H_1*ceHI_ceHI[i] - H_2*reHII_reHII[i] - He_2*ceHeII_ceHeII[i] - 2*He_2*ceHeI_ceHeI[i]*de - He_2*reHeII1_reHeII1[i] - He_2*reHeII2_reHeII2[i] - He_3*reHeIII_reHeIII[i] - brem_brem[i]*(H_2 + He_2 + 4.0*He_3) - compton_comp_[i]*pow(z + 1.0, 4)*(T - 2.73*z - 2.73))/mdensity + v9*(-H2_1*gloverabel08_gaHp[i]*pow(gloverabel08_h2lte[i], 2)/(pow(gloverabel08_h2lte[i]/(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i]) + 1.0, 2)*pow(H2_1*gloverabel08_gaH2[i] + H_1*gloverabel08_gaHI[i] + H_2*gloverabel08_gaHp[i] + He_1*gloverabel08_gaHe[i] + de*gloverabel08_gael[i], 2)) - brem_brem[i]*de - de*reHII_reHII[i])/mdensity;
# -----------------
# He_1
# d_He_1_dy_y = -k03[i]*de*v3 + k04[i]*de*v6 + v8*(-k03[i]*He_1 + k04[i]*He_2);
# -----------------
# H_m0
# d_H_m0_dy_y = -k19[i]*H_m0*v1 + v4*(-k08[i]*H_1 - k14[i]*de - k15[i]*H_1 - k16[i]*H_2 - k17[i]*H_2 - k19[i]*H2_2) + v7*(k07[i]*de - k08[i]*H_m0 - k15[i]*H_m0) + v8*(k07[i]*H_1 - k14[i]*H_m0) + v9*(-k16[i]*H_m0 - k17[i]*H_m0);
# -----------------
# He_3
# d_He_3_dy_y = k05[i]*de*v6 - k06[i]*de*v5 + v8*(k05[i]*He_2 - k06[i]*He_3);
# -----------------
# He_2
# d_He_2_dy_y = k03[i]*de*v3 + k06[i]*de*v5 + v6*(-k04[i]*de - k05[i]*de) + v8*(k03[i]*He_1 - k04[i]*He_2 - k05[i]*He_2 + k06[i]*He_3);
# -----------------
# H_1
# d_H_1_dy_y = v0*(k11[i]*H_2 + 2*k12[i]*de + 2*k13[i]*H_1 - 2*k21[i]*pow(H_1, 2) + 4*k23[i]*H2_1) + v1*(-k10[i]*H_1 + 2*k18[i]*de + k19[i]*H_m0) + v4*(-k08[i]*H_1 + k14[i]*de + k15[i]*H_1 + 2*k16[i]*H_2 + k19[i]*H2_2) + v7*(-k01[i]*de - k07[i]*de - k08[i]*H_m0 - k09[i]*H_2 - k10[i]*H2_2 + 2*k13[i]*H2_1 + k15[i]*H_m0 - 4*k21[i]*H2_1*H_1 - 6*k22[i]*pow(H_1, 2)) + v8*(-k01[i]*H_1 + k02[i]*H_2 - k07[i]*H_1 + 2*k12[i]*H2_1 + k14[i]*H_m0 + 2*k18[i]*H2_2) + v9*(k02[i]*de - k09[i]*H_1 + k11[i]*H2_1 + 2*k16[i]*H_m0);
# -----------------
# de
# d_de_dy_y = k03[i]*de*v3 - k06[i]*de*v5 - k18[i]*de*v1 + v4*(k08[i]*H_1 + k14[i]*de + k15[i]*H_1 + k17[i]*H_2) + v6*(-k04[i]*de + k05[i]*de) + v7*(k01[i]*de - k07[i]*de + k08[i]*H_m0 + k15[i]*H_m0) + v8*(k01[i]*H_1 - k02[i]*H_2 + k03[i]*He_1 - k04[i]*He_2 + k05[i]*He_2 - k06[i]*He_3 - k07[i]*H_1 + k14[i]*H_m0 - k18[i]*H2_2) + v9*(-k02[i]*de + k17[i]*H_m0);
# -----------------
# H_2
# d_H_2_dy_y = k10[i]*H_1*v1 - k11[i]*H_2*v0 + v4*(-k16[i]*H_2 - k17[i]*H_2) + v7*(k01[i]*de - k09[i]*H_2 + k10[i]*H2_2) + v8*(k01[i]*H_1 - k02[i]*H_2) + v9*(-k02[i]*de - k09[i]*H_1 - k11[i]*H2_1 - k16[i]*H_m0 - k17[i]*H_m0);
# -----------------

# %%
# %%time
primordial.write_solver("sundials_onestep", output_dir = ".",
                           solver_template = "sundials_onestep",
                           ode_solver_source = "cvodes_solver_onestep.C",
                            init_values=init,
                            input_is_number=False)
sundials_onestep_run = pyximport.load_module("sundials_onestep_run",
                            "sundials_onestep_solver_run.pyx",
                            build_inplace = True, pyxbuild_dir = "_dengo_temp")
# Out:
# CPU times: user 1.03 s, sys: 422 ms, total: 1.45 s
# Wall time: 10.8 s

# %%
# %%time
primordial.write_solver("sunny", output_dir = ".",
                            init_values=init,
                            input_is_number=False)

sunny_solver_run = pyximport.load_module("sunny_solver_run",
                                "sunny_solver_run.pyx",
                                build_inplace = True, pyxbuild_dir = "_dengo_temp")
# Out:
# CPU times: user 578 ms, sys: 203 ms, total: 781 ms
# Wall time: 9.33 s

# %%
def calc_fftime(den):
    mu = 1.0
    rho = mu* u.mass_hydrogen *den *(u.cm**-3)
    tff = numpy.sqrt(1.0 / u.G / rho).in_units('s')
    return tff

# %%
def time_taken_sundials(Tdim = 50 ,Ddim = 50 ,total_t = 1e10, n_species=6):
    time_taken = []
    success = []
    
    HI_arr = []
    HII_arr = []
    HeI_arr = []
    HeII_arr = []
    HeIII_arr = []
    de_arr = []
    ge_arr = []
    T_arr = []
    total_t_arr = []

    temp_list = numpy.logspace(2,4,Tdim)
    den_list  = numpy.logspace(0,18,Ddim)
    
    temp_2d, den_2d = numpy.meshgrid(temp_list,den_list)
    den_temp_pair2d = numpy.dstack( (temp_2d,den_2d)  )

    den_temp_pair2d = ( numpy.reshape(den_temp_pair2d, (Tdim*Ddim,2) )  )

    temp_arr = []
    den_arr = []
    
    # initialize data dictionary
    init, primordial = Init_values(np.array([1000]), np.array([1e10]), n_species = n_species)
    rv, rv_int_sundials = sundials_onestep_run.run_sundials_onestep(init, total_t, niter=1e5)
    data_dict = {}
    for sp in rv_int_sundials.keys():
        data_dict[sp] = []
        
    
    for temp, den in den_temp_pair2d:
        
        # initial conditions for a given temperature and density
        init, primordial = Init_values(np.array([temp]), np.array([den]), n_species = n_species)
        total_t = calc_fftime(den).v
        # Calculate the time it takes
        tic=timeit.default_timer()
        rv, rv_int_sundials = sundials_onestep_run.run_sundials_onestep(init, total_t, niter=2e5)
        toc=timeit.default_timer()
        time_taken.append(toc - tic)

        temp_arr.append(temp)
        den_arr.append(den)

        flag = rv_int_sundials['successful']
        try:
            final_t = rv_int_sundials['t'][flag][-1]
        except:
            final_t = 0.0
        success.append(final_t)
        total_t_arr.append(total_t)
        for sp in rv_int_sundials.keys():
            if sp not in ["successful", 'dt', 't']:
                data_dict[sp].append( rv_int_sundials[sp][0][flag][-1] )
            else:
                data_dict[sp].append( rv_int_sundials[sp][flag][-1] )
    success = numpy.array(success)
    time_taken = numpy.array(time_taken)
    total_t_arr = numpy.array(total_t_arr)
    temp_arr = numpy.array(temp_arr)
    den_arr = numpy.array(den_arr)
    
    filename = 'sundials_final_%d.hdf5' %(n_species)
    try:
        f = h5py.File(filename, 'w')
    except:
        f = h5py.File(filename)
        f.close()
        f = h5py.File(filename, 'w')
    for key in data_dict.keys():
        dset = f.create_dataset(key, data = data_dict[key])
    dset = f.create_dataset( "density", data = den_arr )
    dset = f.create_dataset( "temperature", data = temp_arr )
    dset = f.create_dataset( "success", data = success )
    dset = f.create_dataset( "time_taken", data = time_taken)
    dset = f.create_dataset( "total_t", data = total_t_arr)
    
    dset = f.create_dataset( "Tdim", data = (Tdim))
    dset = f.create_dataset( "Ddim", data = (Ddim))
    
    f.close()
    
    return success, time_taken, temp_arr, den_arr, filename

# %%
# filename = 'sundials_final_%d.hdf5' %(9)
# import os
# os.system('rm {}'.format(filename))



niter = 1
Tdim = 20
Ddim = 20
total_t = 1e10

success, time_taken, temp_arr, den_arr, filename_sun = time_taken_sundials(Tdim = Tdim ,
                                                                           Ddim = Ddim ,
                                                                           total_t = total_t,
                                                                           n_species=9)
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+03
# Successful iteration[  100]: (2.215e+04) 2.436e+05 / 1.000e+10
# Successful iteration[  200]: (3.052e+08) 3.357e+09 / 1.000e+10
# End in 213 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+02
# Successful iteration[    0]: (1.496e+10) 1.496e+10 / 2.992e+15
# Successful iteration[  100]: (2.062e+14) 2.268e+15 / 2.992e+15
# End in 104 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.274E+02
# Successful iteration[    0]: (1.496e+10) 1.496e+10 / 2.992e+15
# Successful iteration[  100]: (2.062e+14) 2.268e+15 / 2.992e+15
# End in 104 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.624E+02
# Successful iteration[    0]: (1.496e+10) 1.496e+10 / 2.992e+15
# Successful iteration[  100]: (2.062e+14) 2.268e+15 / 2.992e+15
# End in 104 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.069E+02
# Successful iteration[  100]: (9.371e+13) 1.031e+15 / 2.992e+15
# End in 113 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.637E+02
# Successful iteration[  100]: (9.371e+13) 1.031e+15 / 2.992e+15
# End in 113 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.360E+02
# Successful iteration[  100]: (9.371e+13) 1.031e+15 / 2.992e+15
# End in 113 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 4.281E+02
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 5.456E+02
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 6.952E+02
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 8.859E+02
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.129E+03
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.438E+03
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.833E+03
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.336E+03
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.976E+03
# Successful iteration[  100]: (1.936e+13) 2.130e+14 / 2.992e+15
# End in 129 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.793E+03
# Successful iteration[  100]: (1.936e+13) 2.130e+14 / 2.992e+15
# End in 129 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 4.833E+03
# Successful iteration[  100]: (1.936e+13) 2.130e+14 / 2.992e+15
# End in 129 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 6.158E+03
# Successful iteration[  100]: (8.801e+12) 9.680e+13 / 2.992e+15
# End in 137 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 7.848E+03
# Successful iteration[  100]: (8.801e+12) 9.685e+13 / 2.992e+15
# End in 137 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+04
# Successful iteration[  100]: (8.801e+12) 9.685e+13 / 2.992e+15
# End in 137 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+02
# Successful iteration[  100]: (3.148e+13) 3.463e+14 / 1.005e+15
# End in 113 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.274E+02
# Successful iteration[    0]: (5.026e+09) 5.026e+09 / 1.005e+15
# Successful iteration[  100]: (6.927e+13) 7.619e+14 / 1.005e+15
# End in 104 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.624E+02
# Successful iteration[    0]: (5.026e+09) 5.026e+09 / 1.005e+15
# Successful iteration[  100]: (6.927e+13) 7.619e+14 / 1.005e+15
# End in 104 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.069E+02
# Successful iteration[  100]: (3.148e+13) 3.463e+14 / 1.005e+15
# End in 113 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.637E+02
# Successful iteration[  100]: (3.148e+13) 3.463e+14 / 1.005e+15
# End in 113 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.360E+02
# Successful iteration[  100]: (1.431e+13) 1.574e+14 / 1.005e+15
# End in 121 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 4.281E+02
# Successful iteration[  100]: (1.431e+13) 1.574e+14 / 1.005e+15
# End in 121 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 5.456E+02
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 6.952E+02
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 8.859E+02
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.129E+03
# Successful iteration[  100]: (2.957e+12) 3.252e+13 / 1.005e+15
# End in 137 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.438E+03
# Successful iteration[  100]: (2.957e+12) 3.252e+13 / 1.005e+15
# End in 137 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.833E+03
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.336E+03
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.976E+03
# Successful iteration[  100]: (2.957e+12) 3.252e+13 / 1.005e+15
# End in 137 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.793E+03
# ...
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 8.859E+02
# Successful iteration[  100]: (7.550e-12) 8.251e-11 / 2.992e+06
# Successful iteration[  200]: (1.040e-07) 1.144e-06 / 2.992e+06
# Successful iteration[  300]: (1.434e-03) 1.577e-02 / 2.992e+06
# Successful iteration[  400]: (1.976e+01) 2.173e+02 / 2.992e+06
# Successful iteration[  500]: (2.694e+05) 2.992e+06 / 2.992e+06
# End in 501 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.129E+03
# Successful iteration[  100]: (3.223e-13) 3.512e-12 / 2.992e+06
# Successful iteration[  200]: (4.441e-09) 4.885e-08 / 2.992e+06
# Successful iteration[  300]: (6.120e-05) 6.732e-04 / 2.992e+06
# Successful iteration[  400]: (8.434e-01) 9.277e+00 / 2.992e+06
# Successful iteration[  500]: (1.162e+04) 1.278e+05 / 2.992e+06
# End in 535 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.438E+03
# Successful iteration[  100]: (1.376e-14) 1.493e-13 / 2.992e+06
# Successful iteration[  200]: (1.896e-10) 2.085e-09 / 2.992e+06
# Successful iteration[  300]: (2.613e-06) 2.874e-05 / 2.992e+06
# Successful iteration[  400]: (3.600e-02) 3.960e-01 / 2.992e+06
# Successful iteration[  500]: (4.961e+02) 5.458e+03 / 2.992e+06
# End in 568 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.833E+03
# Successful iteration[  100]: (2.842e-15) 3.075e-14 / 2.992e+06
# Successful iteration[  200]: (3.917e-11) 4.309e-10 / 2.992e+06
# Successful iteration[  300]: (5.398e-07) 5.938e-06 / 2.992e+06
# Successful iteration[  400]: (7.439e-03) 8.183e-02 / 2.992e+06
# Successful iteration[  500]: (1.025e+02) 1.128e+03 / 2.992e+06
# End in 584 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.336E+03
# Successful iteration[  100]: (5.873e-16) 6.330e-15 / 2.992e+06
# Successful iteration[  200]: (8.093e-12) 8.902e-11 / 2.992e+06
# Successful iteration[  300]: (1.115e-07) 1.227e-06 / 2.992e+06
# Successful iteration[  400]: (1.537e-03) 1.691e-02 / 2.992e+06
# Successful iteration[  500]: (2.118e+01) 2.330e+02 / 2.992e+06
# Successful iteration[  600]: (7.335e+04) 2.992e+06 / 2.992e+06
# End in 601 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.976E+03
# dt too small (0.000e+00 / 2.992e+06) so breaking
# End in 3 iterations: 0.00000e+00 / 2.99205e+06 (2.99205e+06)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.793E+03
# Successful iteration[  100]: (5.515e-17) 5.905e-16 / 2.992e+06
# Successful iteration[  200]: (7.601e-13) 8.361e-12 / 2.992e+06
# Successful iteration[  300]: (1.047e-08) 1.152e-07 / 2.992e+06
# Successful iteration[  400]: (1.443e-04) 1.588e-03 / 2.992e+06
# Successful iteration[  500]: (1.989e+00) 2.188e+01 / 2.992e+06
# Successful iteration[  600]: (2.741e+04) 3.015e+05 / 2.992e+06
# End in 626 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 4.833E+03
# Successful iteration[  100]: (1.140e-17) 1.213e-16 / 2.992e+06
# Successful iteration[  200]: (1.570e-13) 1.727e-12 / 2.992e+06
# Successful iteration[  300]: (2.164e-09) 2.380e-08 / 2.992e+06
# Successful iteration[  400]: (2.982e-05) 3.280e-04 / 2.992e+06
# Successful iteration[  500]: (4.110e-01) 4.521e+00 / 2.992e+06
# Successful iteration[  600]: (5.663e+03) 6.230e+04 / 2.992e+06
# End in 642 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 6.158E+03
# Successful iteration[  100]: (1.140e-17) 1.213e-16 / 2.992e+06
# Successful iteration[  200]: (1.570e-13) 1.727e-12 / 2.992e+06
# Successful iteration[  300]: (2.164e-09) 2.380e-08 / 2.992e+06
# Successful iteration[  400]: (2.982e-05) 3.280e-04 / 2.992e+06
# Successful iteration[  500]: (4.110e-01) 4.521e+00 / 2.992e+06
# Successful iteration[  600]: (5.663e+03) 6.230e+04 / 2.992e+06
# End in 642 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 7.848E+03
# Successful iteration[  100]: (1.140e-17) 1.213e-16 / 2.992e+06
# Successful iteration[  200]: (1.570e-13) 1.727e-12 / 2.992e+06
# Successful iteration[  300]: (2.164e-09) 2.380e-08 / 2.992e+06
# Successful iteration[  400]: (2.982e-05) 3.280e-04 / 2.992e+06
# Successful iteration[  500]: (4.110e-01) 4.521e+00 / 2.992e+06
# Successful iteration[  600]: (5.663e+03) 6.230e+04 / 2.992e+06
# End in 642 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+04
# Successful iteration[  100]: (5.180e-18) 5.495e-17 / 2.992e+06
# Successful iteration[  200]: (7.138e-14) 7.852e-13 / 2.992e+06
# Successful iteration[  300]: (9.837e-10) 1.082e-08 / 2.992e+06
# Successful iteration[  400]: (1.356e-05) 1.491e-04 / 2.992e+06
# Successful iteration[  500]: (1.868e-01) 2.055e+00 / 2.992e+06
# Successful iteration[  600]: (2.574e+03) 2.832e+04 / 2.992e+06
# End in 650 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)

# %%
def time_taken_be_chem(Tdim = 50 ,Ddim = 50 ,total_t = 1e10, n_species=6):
    time_taken = []
    success = []
    
    HI_arr = []
    HII_arr = []
    HeI_arr = []
    HeII_arr = []
    HeIII_arr = []
    de_arr = []
    ge_arr = []
    T_arr = []
    total_t_arr = []

    temp_list = numpy.logspace(1,4,Tdim)
    den_list  = numpy.logspace(0,16,Ddim)
    
    temp_2d, den_2d = numpy.meshgrid(temp_list,den_list)
    den_temp_pair2d = numpy.dstack( (temp_2d,den_2d)  )

    den_temp_pair2d = ( numpy.reshape(den_temp_pair2d, (Tdim*Ddim,2) )  )

    temp_arr = []
    den_arr = []
    
    # initialize data dictionary
    init, primordial = Init_values(np.array([1000]), np.array([1e10]), n_species = n_species)
    rv, rv_int_sundials = sunny_solver_run.run_sunny(init, total_t, niter=1e5)
    
    data_dict = {}
    for sp in rv_int_sundials.keys():
        data_dict[sp] = []
        
    
    for temp, den in den_temp_pair2d:
        
        # initial conditions for a given temperature and density
        init, primordial = Init_values(np.array([temp]), np.array([den]), n_species = n_species)
        total_t = calc_fftime(den).v
        # Calculate the time it takes
        tic=timeit.default_timer()
        rv, rv_int_sundials = sunny_solver_run.run_sunny(init, total_t, niter=1e5)
        toc=timeit.default_timer()
        time_taken.append(toc - tic)

        temp_arr.append(temp)
        den_arr.append(den)

        flag = rv_int_sundials['successful']
        try:
            final_t = rv_int_sundials['t'][flag][-1]
            for sp in rv_int_sundials.keys():
                if sp not in ["successful", 't', 'dt']:
                    data_dict[sp].append( rv_int_sundials[sp][0][flag][-1] )
                else:
                    data_dict[sp].append( rv_int_sundials[sp][flag][-1] )
        except:
            final_t = 0.0
            for sp in rv_int_sundials.keys():
                data_dict[sp].append( 0.0 )
        success.append(final_t)
        total_t_arr.append(total_t)
        
    success = numpy.array(success)
    time_taken = numpy.array(time_taken)
    total_t_arr = numpy.array(total_t_arr)
    
    temp_arr = numpy.array(temp_arr)
    den_arr = numpy.array(den_arr)
    
    filename = 'be_chem_final_%d_%.E.hdf5' %(n_species, total_t)
    try:
        f = h5py.File(filename, 'w')
    except:
        f = h5py.File(filename)
        f.close()
        f = h5py.File(filename, 'w')
    for key in data_dict.keys():
        dset = f.create_dataset(key, data = data_dict[key])
    dset = f.create_dataset( "density", data = den_arr )
    dset = f.create_dataset( "temperature", data = temp_arr )
    dset = f.create_dataset( "success", data = success )
    dset = f.create_dataset( "time_taken", data = time_taken)
    dset = f.create_dataset( "total_t", data = total_t_arr)
    
    dset = f.create_dataset( "Tdim", data = (Tdim))
    dset = f.create_dataset( "Ddim", data = (Ddim))
    
    f.close()
    
    return success, time_taken, temp_arr, den_arr, filename

# %%
niter = 1
Tdim = 20
Ddim = 20
total_t = 1e10

success, time_taken, temp_arr, den_arr, filename_sun = time_taken_sundials(Tdim = Tdim ,
                                                                           Ddim = Ddim ,
                                                                           total_t = total_t,
                                                                           n_species=9)
# Out:
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+03
# Successful iteration[  100]: (2.215e+04) 2.436e+05 / 1.000e+10
# Successful iteration[  200]: (3.052e+08) 3.357e+09 / 1.000e+10
# End in 213 iterations: 1.00000e+10 / 1.00000e+10 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+02
# Successful iteration[    0]: (1.496e+10) 1.496e+10 / 2.992e+15
# Successful iteration[  100]: (2.062e+14) 2.268e+15 / 2.992e+15
# End in 104 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.274E+02
# Successful iteration[    0]: (1.496e+10) 1.496e+10 / 2.992e+15
# Successful iteration[  100]: (2.062e+14) 2.268e+15 / 2.992e+15
# End in 104 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.624E+02
# Successful iteration[    0]: (1.496e+10) 1.496e+10 / 2.992e+15
# Successful iteration[  100]: (2.062e+14) 2.268e+15 / 2.992e+15
# End in 104 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.069E+02
# Successful iteration[  100]: (9.371e+13) 1.031e+15 / 2.992e+15
# End in 113 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.637E+02
# Successful iteration[  100]: (9.371e+13) 1.031e+15 / 2.992e+15
# End in 113 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.360E+02
# Successful iteration[  100]: (9.371e+13) 1.031e+15 / 2.992e+15
# End in 113 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 4.281E+02
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 5.456E+02
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 6.952E+02
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 8.859E+02
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.129E+03
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.438E+03
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.833E+03
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.336E+03
# Successful iteration[  100]: (4.260e+13) 4.685e+14 / 2.992e+15
# End in 121 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.976E+03
# Successful iteration[  100]: (1.936e+13) 2.130e+14 / 2.992e+15
# End in 129 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.793E+03
# Successful iteration[  100]: (1.936e+13) 2.130e+14 / 2.992e+15
# End in 129 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 4.833E+03
# Successful iteration[  100]: (1.936e+13) 2.130e+14 / 2.992e+15
# End in 129 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 6.158E+03
# Successful iteration[  100]: (8.801e+12) 9.680e+13 / 2.992e+15
# End in 137 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 7.848E+03
# Successful iteration[  100]: (8.801e+12) 9.685e+13 / 2.992e+15
# End in 137 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+04
# Successful iteration[  100]: (8.801e+12) 9.685e+13 / 2.992e+15
# End in 137 iterations: 2.99205e+15 / 2.99205e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+02
# Successful iteration[  100]: (3.148e+13) 3.463e+14 / 1.005e+15
# End in 113 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.274E+02
# Successful iteration[    0]: (5.026e+09) 5.026e+09 / 1.005e+15
# Successful iteration[  100]: (6.927e+13) 7.619e+14 / 1.005e+15
# End in 104 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.624E+02
# Successful iteration[    0]: (5.026e+09) 5.026e+09 / 1.005e+15
# Successful iteration[  100]: (6.927e+13) 7.619e+14 / 1.005e+15
# End in 104 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.069E+02
# Successful iteration[  100]: (3.148e+13) 3.463e+14 / 1.005e+15
# End in 113 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.637E+02
# Successful iteration[  100]: (3.148e+13) 3.463e+14 / 1.005e+15
# End in 113 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.360E+02
# Successful iteration[  100]: (1.431e+13) 1.574e+14 / 1.005e+15
# End in 121 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 4.281E+02
# Successful iteration[  100]: (1.431e+13) 1.574e+14 / 1.005e+15
# End in 121 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 5.456E+02
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 6.952E+02
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 8.859E+02
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.129E+03
# Successful iteration[  100]: (2.957e+12) 3.252e+13 / 1.005e+15
# End in 137 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.438E+03
# Successful iteration[  100]: (2.957e+12) 3.252e+13 / 1.005e+15
# End in 137 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.833E+03
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.336E+03
# Successful iteration[  100]: (6.505e+12) 7.155e+13 / 1.005e+15
# End in 129 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.976E+03
# Successful iteration[  100]: (2.957e+12) 3.252e+13 / 1.005e+15
# End in 137 iterations: 1.00527e+15 / 1.00527e+15 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.793E+03
# ...
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.438E+03
# Successful iteration[  100]: (1.376e-14) 1.493e-13 / 2.992e+06
# Successful iteration[  200]: (1.896e-10) 2.085e-09 / 2.992e+06
# Successful iteration[  300]: (2.613e-06) 2.874e-05 / 2.992e+06
# Successful iteration[  400]: (3.600e-02) 3.960e-01 / 2.992e+06
# Successful iteration[  500]: (4.961e+02) 5.458e+03 / 2.992e+06
# End in 568 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.833E+03
# Successful iteration[  100]: (2.842e-15) 3.075e-14 / 2.992e+06
# Successful iteration[  200]: (3.917e-11) 4.309e-10 / 2.992e+06
# Successful iteration[  300]: (5.398e-07) 5.938e-06 / 2.992e+06
# Successful iteration[  400]: (7.439e-03) 8.183e-02 / 2.992e+06
# Successful iteration[  500]: (1.025e+02) 1.128e+03 / 2.992e+06
# End in 584 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.336E+03
# Successful iteration[  100]: (5.873e-16) 6.330e-15 / 2.992e+06
# Successful iteration[  200]: (8.093e-12) 8.902e-11 / 2.992e+06
# Successful iteration[  300]: (1.115e-07) 1.227e-06 / 2.992e+06
# Successful iteration[  400]: (1.537e-03) 1.691e-02 / 2.992e+06
# Successful iteration[  500]: (2.118e+01) 2.330e+02 / 2.992e+06
# Successful iteration[  600]: (7.335e+04) 2.992e+06 / 2.992e+06
# End in 601 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 2.976E+03
# dt too small (0.000e+00 / 2.992e+06) so breaking
# End in 3 iterations: 0.00000e+00 / 2.99205e+06 (2.99205e+06)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 3.793E+03
# Successful iteration[  100]: (5.515e-17) 5.905e-16 / 2.992e+06
# Successful iteration[  200]: (7.601e-13) 8.361e-12 / 2.992e+06
# Successful iteration[  300]: (1.047e-08) 1.152e-07 / 2.992e+06
# Successful iteration[  400]: (1.443e-04) 1.588e-03 / 2.992e+06
# Successful iteration[  500]: (1.989e+00) 2.188e+01 / 2.992e+06
# Successful iteration[  600]: (2.741e+04) 3.015e+05 / 2.992e+06
# End in 626 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 4.833E+03
# Successful iteration[  100]: (1.140e-17) 1.213e-16 / 2.992e+06
# Successful iteration[  200]: (1.570e-13) 1.727e-12 / 2.992e+06
# Successful iteration[  300]: (2.164e-09) 2.380e-08 / 2.992e+06
# Successful iteration[  400]: (2.982e-05) 3.280e-04 / 2.992e+06
# Successful iteration[  500]: (4.110e-01) 4.521e+00 / 2.992e+06
# Successful iteration[  600]: (5.663e+03) 6.230e+04 / 2.992e+06
# End in 642 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 6.158E+03
# Successful iteration[  100]: (1.140e-17) 1.213e-16 / 2.992e+06
# Successful iteration[  200]: (1.570e-13) 1.727e-12 / 2.992e+06
# Successful iteration[  300]: (2.164e-09) 2.380e-08 / 2.992e+06
# Successful iteration[  400]: (2.982e-05) 3.280e-04 / 2.992e+06
# Successful iteration[  500]: (4.110e-01) 4.521e+00 / 2.992e+06
# Successful iteration[  600]: (5.663e+03) 6.230e+04 / 2.992e+06
# End in 642 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 7.848E+03
# Successful iteration[  100]: (1.140e-17) 1.213e-16 / 2.992e+06
# Successful iteration[  200]: (1.570e-13) 1.727e-12 / 2.992e+06
# Successful iteration[  300]: (2.164e-09) 2.380e-08 / 2.992e+06
# Successful iteration[  400]: (2.982e-05) 3.280e-04 / 2.992e+06
# Successful iteration[  500]: (4.110e-01) 4.521e+00 / 2.992e+06
# Successful iteration[  600]: (5.663e+03) 6.230e+04 / 2.992e+06
# End in 642 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# Adding reaction: k01 : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: k02 : 1*H_2 + 1*de => 1*H_1
# Adding reaction: k03 : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: k04 : 1*He_2 + 1*de => 1*He_1
# Adding reaction: k05 : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: k06 : 1*He_3 + 1*de => 1*He_2
# Adding reaction: k07 : 1*H_1 + 1*de => 1*H_m0
# Adding reaction: k08 : 1*H_m0 + 1*H_1 => 1*H2_1 + 1*de
# Adding reaction: k09 : 1*H_1 + 1*H_2 => 1*H2_2
# Adding reaction: k10 : 1*H2_2 + 1*H_1 => 1*H2_1 + 1*H_2
# Adding reaction: k11 : 1*H2_1 + 1*H_2 => 1*H2_2 + 1*H_1
# Adding reaction: k12 : 1*H2_1 + 1*de => 2*H_1 + 1*de
# Adding reaction: k13 : 1*H2_1 + 1*H_1 => 3*H_1
# Adding reaction: k14 : 1*H_m0 + 1*de => 1*H_1 + 2*de
# Adding reaction: k15 : 1*H_m0 + 1*H_1 => 2*H_1 + 1*de
# Adding reaction: k16 : 1*H_m0 + 1*H_2 => 2*H_1
# Adding reaction: k17 : 1*H_m0 + 1*H_2 => 1*H2_2 + 1*de
# Adding reaction: k18 : 1*H2_2 + 1*de => 2*H_1
# Adding reaction: k19 : 1*H2_2 + 1*H_m0 => 1*H_1 + 1*H2_1
# Adding reaction: k21 : 2*H_1 + 1*H2_1 => 2*H2_1
# Adding reaction: k22 : 2*H_1 + 1*H_1 => 1*H2_1 + 1*H_1
# Adding reaction: k23 : 1*H2_1 + 1*H2_1 => 2*H_1 + 1*H2_1
# initial  temperature: 1.000E+04
# Successful iteration[  100]: (5.180e-18) 5.495e-17 / 2.992e+06
# Successful iteration[  200]: (7.138e-14) 7.852e-13 / 2.992e+06
# Successful iteration[  300]: (9.837e-10) 1.082e-08 / 2.992e+06
# Successful iteration[  400]: (1.356e-05) 1.491e-04 / 2.992e+06
# Successful iteration[  500]: (1.868e-01) 2.055e+00 / 2.992e+06
# Successful iteration[  600]: (2.574e+03) 2.832e+04 / 2.992e+06
# End in 650 iterations: 2.99205e+06 / 2.99205e+06 (0.00000e+00)
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-37-964915005577> in <module>()
#       7                                                                            Ddim = Ddim ,
#       8                                                                            total_t = total_t,
# ----> 9                                                                            n_species=9)
#
# <ipython-input-19-17053ccbbee3> in time_taken_sundials(Tdim, Ddim, total_t, n_species)
#      69         f = h5py.File(filename)
#      70         f.close()
# ---> 71         f = h5py.File(filename, 'w')
#      72     for key in data_dict.keys():
#      73         dset = f.create_dataset(key, data = data_dict[key])
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/h5py/_hl/files.pyc in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     269
#     270                 fapl = make_fapl(driver, libver, **kwds)
# --> 271                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     272
#     273                 if swmr_support:
#
# /home/kwoksun2/anaconda2/lib/python2.7/site-packages/h5py/_hl/files.pyc in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     105         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     106     elif mode == 'w':
# --> 107         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     108     elif mode == 'a':
#     109         # Open in append mode (read/write).
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/feedstock_root/build_artefacts/h5py_1491364442174/work/h5py-2.7.0/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/feedstock_root/build_artefacts/h5py_1491364442174/work/h5py-2.7.0/h5py/_objects.c:2804)()
#
# h5py/h5f.pyx in h5py.h5f.create (/feedstock_root/build_artefacts/h5py_1491364442174/work/h5py-2.7.0/h5py/h5f.c:2290)()
#
# IOError: Unable to create file (Unable to truncate a file which is already open)

# %%
f = h5py.File(filename_sun,'r')

Tdim = f['Tdim'].value
Ddim = f['Ddim'].value
print(Tdim, Ddim)
temp_arr = f['temperature'].value
den_arr = f['density'].value
success = f['success'].value
time_taken = f['time_taken'].value
total_t = f['total_t'].value
f.close()

logmin_temp, logmax_temp = numpy.log10(temp_arr.min()), numpy.log10(temp_arr.max())
logmin_den , logmax_den  = numpy.log10(den_arr.min()) , numpy.log10(den_arr.max())

dlogtemp = ( logmax_temp - logmin_temp )/ Tdim /2.0
dlogden  = ( logmax_den  - logmin_den )/ Ddim / 2.0
temp_arr = numpy.logspace( logmin_temp - dlogtemp , logmax_temp + dlogtemp , Tdim + 1 )
den_arr  = numpy.logspace( logmin_den - dlogden, logmax_den + dlogden, Ddim + 1 )

plot_performance(Tdim, Ddim, temp_arr,den_arr, success, time_taken, title="sundials", log=True,total_t = total_t)
# Out:
# (20, 20)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-aa4571f36370> in <module>()
#      19 den_arr  = numpy.logspace( logmin_den - dlogden, logmax_den + dlogden, Ddim + 1 )
#      20
# ---> 21 plot_performance(Tdim, Ddim, temp_arr,den_arr, success, time_taken, title="sundials", log=True,total_t = total_t)
#
# <ipython-input-48-87b5a7acccb6> in plot_performance(Tdim, Ddim, temp_arr, den_arr, success, time_taken, title, performance, log, total_t)
#      22         fig, ax = plt.subplots(1,2, figsize = (16,8))
#      23
# ---> 24         pcm = ax[0].pcolor( temp_2d, den_2d, time_run_mat/total_t)
#      25         fig.colorbar(pcm, ax=ax[0], extend='max')
#      26
#
# ValueError: operands could not be broadcast together with shapes (20,20) (400,)

# %%
niter = 1
Tdim = 20
Ddim = 20
total_t = 1e5
9
final_success = numpy.zeros((Tdim*Ddim))
final_time_taken = numpy.zeros((Tdim*Ddim))
for i in range(niter):
    success, time_taken, temp_arr, den_arr, filename = time_taken_be_chem(Tdim = Tdim ,Ddim = Ddim ,total_t = total_t,n_species=9)
    final_success += success
    final_time_taken += time_taken

final_success /= niter
final_time_taken /= niter

# %%
f = h5py.File(filename,'r')

Tdim = f['Tdim'].value
Ddim = f['Ddim'].value
den_arr = f['density'].value
success = f['success'].value
time_taken = f['time_taken'].value
f.close()

logmin_temp, logmax_temp = numpy.log10(temp_arr.min()), numpy.log10(temp_arr.max())
logmin_den , logmax_den  = numpy.log10(den_arr.min()) , numpy.log10(den_arr.max())

dlogtemp = ( logmax_temp - logmin_temp )/ Tdim /2.0
dlogden  = ( logmax_den  - logmin_den )/ Ddim / 2.0
temp_arr = numpy.logspace( logmin_temp - dlogtemp , logmax_temp + dlogtemp , Tdim + 1 )
den_arr  = numpy.logspace( logmin_den - dlogden, logmax_den + dlogden, Ddim + 1 )

plot_performance(Tdim, Ddim, temp_arr,den_arr, success, time_taken)

# %%
def plot_performance(Tdim, Ddim, temp_arr,den_arr, success, time_taken, title=None, performance=True, log=True, total_t = total_t):

    success = numpy.array(success)
    time_run = numpy.copy(success)
    i1 = success >= total_t*(0.9)
    i2 = ~i1
    
    success[i1] = 1
    success[i2] = 0

    success_mat = success.reshape((Ddim,Tdim))
    total_t_mat = total_t.reshape((Ddim,Tdim))

#     temp_2d = temp_arr.reshape(Ddim + 1,Tdim + 1)
#     den_2d = den_arr.reshape(Ddim + 1,Tdim + 1)
    
    temp_2d, den_2d = numpy.meshgrid(temp_arr, den_arr)
    
    time_taken_mat = numpy.array(time_taken).reshape((Ddim,Tdim))
    time_run_mat = numpy.array(time_run).reshape((Ddim,Tdim))
    
    if performance:
        fig, ax = plt.subplots(1,2, figsize = (16,8))
        
        pcm = ax[0].pcolor( temp_2d, den_2d, time_run_mat/total_t_mat)
        fig.colorbar(pcm, ax=ax[0], extend='max')


        ax[0].set_xscale('log')
        ax[0].set_yscale('log')
        ax[0].set_xlabel('Temperature (K)')
        ax[0].set_ylabel('Density ($cm^{-3}$)')
        
        if log:
            pcm = ax[1].pcolor( temp_2d, den_2d, time_taken_mat,
                              norm=colors.LogNorm(vmin=time_taken_mat.min(), vmax=time_taken_mat.max()))
        else:
            pcm = ax[1].pcolor( temp_2d, den_2d, time_taken_mat)
        fig.colorbar(pcm, ax=ax[1], extend='max')

        ax[1].set_xscale('log')
        ax[1].set_yscale('log')
        ax[1].set_xlabel('Temperature (K)')
        ax[1].set_ylabel('Density ($cm^{-3}$)')
        if title != None:
            ax[0].set_title(title+' time evolved ')
            ax[1].set_title(title+' run time')

        plt.show()
    else:
        fig, ax = plt.subplots(1,1, figsize = (8,8))
        if log:
            pcm = ax.pcolor( temp_2d, den_2d, time_taken_mat,
                              norm=colors.LogNorm(vmin=time_taken_mat.min(), vmax=time_taken_mat.max()))
        else:        
            pcm = ax.pcolor( temp_2d, den_2d, time_taken_mat)
        fig.colorbar(pcm, ax=ax, extend='max')

        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlabel('Temperature (K)')
        ax.set_ylabel('Density ($cm^{-3}$)')
        if title != None:
            ax.set_title(title+' abundances')

        plt.show()

# %%
f_sun = h5py.File(filename_sun,'r')

Tdim = f_sun['Tdim'].value
Ddim = f_sun['Ddim'].value
den_arr = f_sun['density'].value
success = f_sun['success'].value

logmin_temp, logmax_temp = numpy.log10(temp_arr.min()), numpy.log10(temp_arr.max())
logmin_den , logmax_den  = numpy.log10(den_arr.min()) , numpy.log10(den_arr.max())

dlogtemp = ( logmax_temp - logmin_temp )/ Tdim /2.0
dlogden  = ( logmax_den  - logmin_den )/ Ddim / 2.0
temp_arr = numpy.logspace( logmin_temp - dlogtemp , logmax_temp + dlogtemp , Tdim + 1 )
den_arr  = numpy.logspace( logmin_den - dlogden, logmax_den + dlogden, Ddim + 1 )

for species in f_sun.keys():
    if species not in ["Ddim", "Tdim","dt","success",'t']:
        abundance = f_sun[species].value
        print(species)
        plot_performance(Tdim, Ddim, temp_arr,den_arr, success, abundance, title=species, performance = False)    
f_sun.close()
f_be.close()
# Out:
# H2_1
# H2_2
# H_1
# H_2
# H_m0
# He_1
# He_2
# He_3
# T
# de
# density
# ge
# successful
# temperature
# time_taken
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-792b9ac6321a> in <module>()
#      20         plot_performance(Tdim, Ddim, temp_arr,den_arr, success, abundance, title=species, performance = False)
#      21 f_sun.close()
# ---> 22 f_be.close()
#
# NameError: name 'f_be' is not defined

# %%
print(filename_sun)
print(filename)

# %%
# !cp sundials_final_9_1E+10.hdf5 /home/kwoksun2/grackle/src/python/examples/sundials_final_9_1E+10.hdf5
# !cp be_chem_final_9_1E+05.hdf5 /home/kwoksun2/grackle/src/python/examples/be_chem_final_9_1E+05.hdf5

# %%
den = 1e15
temp_arr = []
den_arr =[]
success = []

all_data = []
time_taken = []

for temp in numpy.logspace(1,4,10):
    data_dict = {} 
    for sp in rv_int_sundials.keys():
        data_dict[sp] = []
    
    # initial conditions for a given temperature and density
    init, primordial = Init_values(np.array([temp]), np.array([den]), n_species = 9)
    # Calculate the time it takes
    tic=timeit.default_timer()
    rv, rv_int_sundials = sundials_onestep_run.run_sundials_onestep(init, 1e5, niter=1e4)
    toc=timeit.default_timer()
    time_taken.append(toc - tic)

    temp_arr.append(temp)
    den_arr.append(den)

    flag = rv_int_sundials['successful']
    try:
        final_t = rv_int_sundials['t'][flag][-1]
    except:
        final_t = 0.0
    success.append(final_t)

    for sp in rv_int_sundials.keys():
        if sp not in ["successful", 'dt', 't']:
            data_dict[sp].append( rv_int_sundials[sp][0][flag][-1] )
        else:
            data_dict[sp].append( rv_int_sundials[sp][flag][-1] )
    all_data.append(data_dict)

# %%
success

# %%
den_arr[0]/1e15

# %%
time_taken

# %%
f = h5py.File(filename_sun)
f.keys()

# %%
filename_sun

# %%
filename_sun

# %%
(numpy.logspace(0,20,20)/6158482110660254.0)[:-4]

# %%
1e16/6158482110660254.0

# %%
dengo.primordial_rates.setup_primordial()
primordial = ChemicalNetwork()


primordial.add_reaction('k13')
primordial.add_reaction('k22')

primordial.init_temperature((1e0, 1e5))

tiny = 1.0e-20

# init_array are is in fractional abundances
density = 1e10
init_values = dict()


init_values["He_1"]    = density * (1.0 - 0.76) /2.0
init_values["He_2"]    = density * (1.0 - 0.76) /2.0 #np.array([tiny]) #density * (1.0 - 0.76) /3.      
init_values["He_3"]    = np.array([tiny]) #density * (1.0 - 0.76) /3.          
init_values["H_1"]     = density *  (0.76)  /3.
init_values['H_2']     = density *  (0.76)  /3

init_values["H_m0"]    = np.array([tiny]) #density *  (0.76)  /4.
init_values["H2_1"]    = density *  (0.76)  /3. #density *  (0.76)  /3. #density *  (0.76)  /3.
init_values["H2_2"]    = np.array([tiny]) # density *  (0.76)  /5.

# %%
for i in primordial.required_species:
    print(primordial.print_ccode(i))

# %%
k13 = primordial.reactions['k13']

# %%
k13.

# %%
k13.net_change('H_1')

# %%
from sympy import *

# %%
fraction(4,3)

# %%
reaction_registry

# %%
primordial = ChemicalNetwork()

primordial.add_reaction('k13')
primordial.add_reaction('k22')
k22 = primordial.reactions['k22']

# %%
for i in primordial.required_species:
    print(primordial.print_ccode(i))

# %%
(0.5* k22.coeff_fn(aaa)* nH**2 ) / 1e9

# %%
class my_network:
    def __init__(self, T):
        self.T = T
        self.threebody = 4

# %%
aaa = my_network(500.0)
nH = (0.76*1e10)**2
