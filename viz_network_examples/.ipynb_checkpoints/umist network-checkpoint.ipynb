# %%
import networkx as nx
import matplotlib.pyplot as plt

from dengo import chemical_network
from dengo.chemical_network import \
    ChemicalNetwork, \
    reaction_registry, \
    cooling_registry, species_registry
import dengo.primordial_rates, dengo.primordial_cooling
from dengo.get_rates import setup_umist_species, setup_umist_reactions

# %%
import csv, os

periodic_table_by_name = {}
periodic_table_by_number = {}

dengo_path = './'
fn = os.path.join(os.path.dirname(dengo_path),
                  "periodictabledump.csv")

with open(fn, "r") as csvfile:
    pt_reader = csv.reader(csvfile)
    for row in pt_reader:
        num = int(row[0])
        weight = float(row[1])
        full_name = row[2]
        symbol = row[3]
        periodic_table_by_name[symbol] = (num, weight, full_name)
        periodic_table_by_number[num] = (weight, symbol, full_name)

# %%
all_element = []
for i in periodic_table_by_name:
    all_element.append(i)

# %%
s, c, r = setup_umist_reactions(added_species)
umist.add_collection(s, c, r)

# %%
import os
import re
import numpy
fname = '/home/kwoksun2/dengo/dengo-project-dengo-ed14369817a2/examples'

# %%
G = nx.MultiDiGraph()

fn = os.path.join(fname, "RATE12.txt")
for line in open(fn, "r"):
    rline = re.split(":?", line)

    ele = rline[2:6]
    for sp_down in ele[1:3]:
        if sp_down == "": continue
        for sp_up in ele[3:5]:
            if sp_up == "": continue
            G.add_edge(sp_down, sp_up )

# %%
g = nx.spring_layout(G,k=5/numpy.sqrt(G.order()), iterations=200)
plt.figure(figsize=(20,20))
p = nx.draw(G,g, arrows=True,with_labels=True)

# %%
from dengo.chemical_network import \
    ChemicalNetwork, \
    reaction_registry, \
    cooling_registry
from dengo.primordial_rates import setup_primordial
import dengo.primordial_cooling
from dengo.ion_by_ion import setup_ionization
from dengo.chemistry_constants import tiny, kboltz, mh
import numpy as np
from matplotlib.pyplot import cm


ion_by_ion = ChemicalNetwork()
ion_by_ion.add_species("de")

all_elements = ["O", "C", "Si", "Mg", "N", "S", "He", "Ne", "H","Fe","de"]
color=cm.rainbow(np.linspace(0,1,len(all_elements) ))

for atom in all_elements:
    if atom != 'de':
        s, c, r = setup_ionization(atom)
        ion_by_ion.add_collection(s, c, r)
# Out:
# Adding reaction: O_9_r : 1*O_9 + 1*de => 1*O_8
# Adding reaction: O_7_r : 1*O_7 + 1*de => 1*O_6
# Adding reaction: O_4_i : 1*O_4 + 1*de => 1*O_5 + 2*de
# Adding reaction: O_8_r : 1*O_8 + 1*de => 1*O_7
# Adding reaction: O_4_r : 1*O_4 + 1*de => 1*O_3
# Adding reaction: O_6_r : 1*O_6 + 1*de => 1*O_5
# Adding reaction: O_3_r : 1*O_3 + 1*de => 1*O_2
# Adding reaction: O_5_i : 1*O_5 + 1*de => 1*O_6 + 2*de
# Adding reaction: O_6_i : 1*O_6 + 1*de => 1*O_7 + 2*de
# Adding reaction: O_1_i : 1*O_1 + 1*de => 1*O_2 + 2*de
# Adding reaction: O_8_i : 1*O_8 + 1*de => 1*O_9 + 2*de
# Adding reaction: O_2_r : 1*O_2 + 1*de => 1*O_1
# Adding reaction: O_7_i : 1*O_7 + 1*de => 1*O_8 + 2*de
# Adding reaction: O_2_i : 1*O_2 + 1*de => 1*O_3 + 2*de
# Adding reaction: O_3_i : 1*O_3 + 1*de => 1*O_4 + 2*de
# Adding reaction: O_5_r : 1*O_5 + 1*de => 1*O_4
# Adding reaction: C_4_r : 1*C_4 + 1*de => 1*C_3
# Adding reaction: C_2_i : 1*C_2 + 1*de => 1*C_3 + 2*de
# Adding reaction: C_5_i : 1*C_5 + 1*de => 1*C_6 + 2*de
# Adding reaction: C_6_i : 1*C_6 + 1*de => 1*C_7 + 2*de
# Adding reaction: C_3_i : 1*C_3 + 1*de => 1*C_4 + 2*de
# Adding reaction: C_3_r : 1*C_3 + 1*de => 1*C_2
# Adding reaction: C_6_r : 1*C_6 + 1*de => 1*C_5
# Adding reaction: C_7_r : 1*C_7 + 1*de => 1*C_6
# Adding reaction: C_5_r : 1*C_5 + 1*de => 1*C_4
# Adding reaction: C_2_r : 1*C_2 + 1*de => 1*C_1
# Adding reaction: C_4_i : 1*C_4 + 1*de => 1*C_5 + 2*de
# Adding reaction: C_1_i : 1*C_1 + 1*de => 1*C_2 + 2*de
# Adding reaction: Si_11_r : 1*Si_11 + 1*de => 1*Si_10
# Adding reaction: Si_12_i : 1*Si_12 + 1*de => 1*Si_13 + 2*de
# Adding reaction: Si_5_i : 1*Si_5 + 1*de => 1*Si_6 + 2*de
# Adding reaction: Si_10_r : 1*Si_10 + 1*de => 1*Si_9
# Adding reaction: Si_5_r : 1*Si_5 + 1*de => 1*Si_4
# Adding reaction: Si_12_r : 1*Si_12 + 1*de => 1*Si_11
# Adding reaction: Si_10_i : 1*Si_10 + 1*de => 1*Si_11 + 2*de
# Adding reaction: Si_11_i : 1*Si_11 + 1*de => 1*Si_12 + 2*de
# Adding reaction: Si_6_i : 1*Si_6 + 1*de => 1*Si_7 + 2*de
# Adding reaction: Si_9_i : 1*Si_9 + 1*de => 1*Si_10 + 2*de
# Adding reaction: Si_7_r : 1*Si_7 + 1*de => 1*Si_6
# Adding reaction: Si_4_r : 1*Si_4 + 1*de => 1*Si_3
# Adding reaction: Si_13_r : 1*Si_13 + 1*de => 1*Si_12
# Adding reaction: Si_1_i : 1*Si_1 + 1*de => 1*Si_2 + 2*de
# Adding reaction: Si_8_i : 1*Si_8 + 1*de => 1*Si_9 + 2*de
# Adding reaction: Si_13_i : 1*Si_13 + 1*de => 1*Si_14 + 2*de
# Adding reaction: Si_4_i : 1*Si_4 + 1*de => 1*Si_5 + 2*de
# Adding reaction: Si_8_r : 1*Si_8 + 1*de => 1*Si_7
# Adding reaction: Si_7_i : 1*Si_7 + 1*de => 1*Si_8 + 2*de
# Adding reaction: Si_9_r : 1*Si_9 + 1*de => 1*Si_8
# Adding reaction: Si_6_r : 1*Si_6 + 1*de => 1*Si_5
# Adding reaction: Si_3_i : 1*Si_3 + 1*de => 1*Si_4 + 2*de
# Adding reaction: Si_2_i : 1*Si_2 + 1*de => 1*Si_3 + 2*de
# Adding reaction: Si_2_r : 1*Si_2 + 1*de => 1*Si_1
# Adding reaction: Si_3_r : 1*Si_3 + 1*de => 1*Si_2
# Adding reaction: Si_15_r : 1*Si_15 + 1*de => 1*Si_14
# Adding reaction: Si_14_r : 1*Si_14 + 1*de => 1*Si_13
# Adding reaction: Si_14_i : 1*Si_14 + 1*de => 1*Si_15 + 2*de
# Adding reaction: Mg_2_r : 1*Mg_2 + 1*de => 1*Mg_1
# Adding reaction: Mg_2_i : 1*Mg_2 + 1*de => 1*Mg_3 + 2*de
# Adding reaction: Mg_8_r : 1*Mg_8 + 1*de => 1*Mg_7
# Adding reaction: Mg_9_r : 1*Mg_9 + 1*de => 1*Mg_8
# Adding reaction: Mg_6_r : 1*Mg_6 + 1*de => 1*Mg_5
# Adding reaction: Mg_6_i : 1*Mg_6 + 1*de => 1*Mg_7 + 2*de
# Adding reaction: Mg_9_i : 1*Mg_9 + 1*de => 1*Mg_10 + 2*de
# Adding reaction: Mg_1_i : 1*Mg_1 + 1*de => 1*Mg_2 + 2*de
# Adding reaction: Mg_8_i : 1*Mg_8 + 1*de => 1*Mg_9 + 2*de
# Adding reaction: Mg_5_r : 1*Mg_5 + 1*de => 1*Mg_4
# Adding reaction: Mg_12_r : 1*Mg_12 + 1*de => 1*Mg_11
# Adding reaction: Mg_4_i : 1*Mg_4 + 1*de => 1*Mg_5 + 2*de
# Adding reaction: Mg_3_r : 1*Mg_3 + 1*de => 1*Mg_2
# Adding reaction: Mg_7_i : 1*Mg_7 + 1*de => 1*Mg_8 + 2*de
# Adding reaction: Mg_3_i : 1*Mg_3 + 1*de => 1*Mg_4 + 2*de
# Adding reaction: Mg_7_r : 1*Mg_7 + 1*de => 1*Mg_6
# Adding reaction: Mg_4_r : 1*Mg_4 + 1*de => 1*Mg_3
# Adding reaction: Mg_12_i : 1*Mg_12 + 1*de => 1*Mg_13 + 2*de
# Adding reaction: Mg_5_i : 1*Mg_5 + 1*de => 1*Mg_6 + 2*de
# Adding reaction: Mg_13_r : 1*Mg_13 + 1*de => 1*Mg_12
# Adding reaction: Mg_10_i : 1*Mg_10 + 1*de => 1*Mg_11 + 2*de
# Adding reaction: Mg_11_i : 1*Mg_11 + 1*de => 1*Mg_12 + 2*de
# Adding reaction: Mg_11_r : 1*Mg_11 + 1*de => 1*Mg_10
# Adding reaction: Mg_10_r : 1*Mg_10 + 1*de => 1*Mg_9
# Adding reaction: N_6_i : 1*N_6 + 1*de => 1*N_7 + 2*de
# Adding reaction: N_7_r : 1*N_7 + 1*de => 1*N_6
# Adding reaction: N_2_i : 1*N_2 + 1*de => 1*N_3 + 2*de
# Adding reaction: N_3_r : 1*N_3 + 1*de => 1*N_2
# Adding reaction: N_8_r : 1*N_8 + 1*de => 1*N_7
# Adding reaction: N_4_r : 1*N_4 + 1*de => 1*N_3
# Adding reaction: N_5_i : 1*N_5 + 1*de => 1*N_6 + 2*de
# Adding reaction: N_1_i : 1*N_1 + 1*de => 1*N_2 + 2*de
# Adding reaction: N_5_r : 1*N_5 + 1*de => 1*N_4
# Adding reaction: N_4_i : 1*N_4 + 1*de => 1*N_5 + 2*de
# Adding reaction: N_7_i : 1*N_7 + 1*de => 1*N_8 + 2*de
# Adding reaction: N_6_r : 1*N_6 + 1*de => 1*N_5
# Adding reaction: N_3_i : 1*N_3 + 1*de => 1*N_4 + 2*de
# Adding reaction: N_2_r : 1*N_2 + 1*de => 1*N_1
# Adding reaction: S_11_i : 1*S_11 + 1*de => 1*S_12 + 2*de
# Adding reaction: S_11_r : 1*S_11 + 1*de => 1*S_10
# Adding reaction: S_1_i : 1*S_1 + 1*de => 1*S_2 + 2*de
# Adding reaction: S_3_r : 1*S_3 + 1*de => 1*S_2
# Adding reaction: S_12_i : 1*S_12 + 1*de => 1*S_13 + 2*de
# Adding reaction: S_13_r : 1*S_13 + 1*de => 1*S_12
# Adding reaction: S_10_r : 1*S_10 + 1*de => 1*S_9
# Adding reaction: S_2_r : 1*S_2 + 1*de => 1*S_1
# Adding reaction: S_15_i : 1*S_15 + 1*de => 1*S_16 + 2*de
# Adding reaction: S_2_i : 1*S_2 + 1*de => 1*S_3 + 2*de
# Adding reaction: S_10_i : 1*S_10 + 1*de => 1*S_11 + 2*de
# Adding reaction: S_15_r : 1*S_15 + 1*de => 1*S_14
# Adding reaction: S_3_i : 1*S_3 + 1*de => 1*S_4 + 2*de
# Adding reaction: S_13_i : 1*S_13 + 1*de => 1*S_14 + 2*de
# Adding reaction: S_12_r : 1*S_12 + 1*de => 1*S_11
# Adding reaction: S_7_r : 1*S_7 + 1*de => 1*S_6
# Adding reaction: S_16_i : 1*S_16 + 1*de => 1*S_17 + 2*de
# Adding reaction: S_4_i : 1*S_4 + 1*de => 1*S_5 + 2*de
# Adding reaction: S_14_r : 1*S_14 + 1*de => 1*S_13
# Adding reaction: S_9_r : 1*S_9 + 1*de => 1*S_8
# Adding reaction: S_6_r : 1*S_6 + 1*de => 1*S_5
# Adding reaction: S_4_r : 1*S_4 + 1*de => 1*S_3
# Adding reaction: S_16_r : 1*S_16 + 1*de => 1*S_15
# Adding reaction: S_6_i : 1*S_6 + 1*de => 1*S_7 + 2*de
# Adding reaction: S_9_i : 1*S_9 + 1*de => 1*S_10 + 2*de
# Adding reaction: S_14_i : 1*S_14 + 1*de => 1*S_15 + 2*de
# Adding reaction: S_17_r : 1*S_17 + 1*de => 1*S_16
# Adding reaction: S_7_i : 1*S_7 + 1*de => 1*S_8 + 2*de
# Adding reaction: S_5_r : 1*S_5 + 1*de => 1*S_4
# Adding reaction: S_8_i : 1*S_8 + 1*de => 1*S_9 + 2*de
# Adding reaction: S_5_i : 1*S_5 + 1*de => 1*S_6 + 2*de
# Adding reaction: S_8_r : 1*S_8 + 1*de => 1*S_7
# Adding reaction: He_1_i : 1*He_1 + 1*de => 1*He_2 + 2*de
# Adding reaction: He_2_i : 1*He_2 + 1*de => 1*He_3 + 2*de
# Adding reaction: He_3_r : 1*He_3 + 1*de => 1*He_2
# Adding reaction: He_2_r : 1*He_2 + 1*de => 1*He_1
# Adding reaction: Ne_7_r : 1*Ne_7 + 1*de => 1*Ne_6
# Adding reaction: Ne_9_r : 1*Ne_9 + 1*de => 1*Ne_8
# Adding reaction: Ne_3_r : 1*Ne_3 + 1*de => 1*Ne_2
# Adding reaction: Ne_2_i : 1*Ne_2 + 1*de => 1*Ne_3 + 2*de
# Adding reaction: Ne_6_r : 1*Ne_6 + 1*de => 1*Ne_5
# Adding reaction: Ne_8_r : 1*Ne_8 + 1*de => 1*Ne_7
# Adding reaction: Ne_11_r : 1*Ne_11 + 1*de => 1*Ne_10
# Adding reaction: Ne_5_i : 1*Ne_5 + 1*de => 1*Ne_6 + 2*de
# Adding reaction: Ne_2_r : 1*Ne_2 + 1*de => 1*Ne_1
# Adding reaction: Ne_8_i : 1*Ne_8 + 1*de => 1*Ne_9 + 2*de
# Adding reaction: Ne_1_i : 1*Ne_1 + 1*de => 1*Ne_2 + 2*de
# Adding reaction: Ne_10_r : 1*Ne_10 + 1*de => 1*Ne_9
# Adding reaction: Ne_5_r : 1*Ne_5 + 1*de => 1*Ne_4
# Adding reaction: Ne_9_i : 1*Ne_9 + 1*de => 1*Ne_10 + 2*de
# Adding reaction: Ne_4_i : 1*Ne_4 + 1*de => 1*Ne_5 + 2*de
# Adding reaction: Ne_7_i : 1*Ne_7 + 1*de => 1*Ne_8 + 2*de
# Adding reaction: Ne_4_r : 1*Ne_4 + 1*de => 1*Ne_3
# Adding reaction: Ne_6_i : 1*Ne_6 + 1*de => 1*Ne_7 + 2*de
# Adding reaction: Ne_10_i : 1*Ne_10 + 1*de => 1*Ne_11 + 2*de
# Adding reaction: Ne_3_i : 1*Ne_3 + 1*de => 1*Ne_4 + 2*de
# Adding reaction: H_2_r : 1*H_2 + 1*de => 1*H_1
# Adding reaction: H_1_i : 1*H_1 + 1*de => 1*H_2 + 2*de
# Adding reaction: Fe_5_i : 1*Fe_5 + 1*de => 1*Fe_6 + 2*de
# Adding reaction: Fe_4_r : 1*Fe_4 + 1*de => 1*Fe_3
# Adding reaction: Fe_7_r : 1*Fe_7 + 1*de => 1*Fe_6
# Adding reaction: Fe_3_r : 1*Fe_3 + 1*de => 1*Fe_2
# Adding reaction: Fe_23_r : 1*Fe_23 + 1*de => 1*Fe_22
# Adding reaction: Fe_2_i : 1*Fe_2 + 1*de => 1*Fe_3 + 2*de
# Adding reaction: Fe_23_i : 1*Fe_23 + 1*de => 1*Fe_24 + 2*de
# Adding reaction: Fe_7_i : 1*Fe_7 + 1*de => 1*Fe_8 + 2*de
# Adding reaction: Fe_2_r : 1*Fe_2 + 1*de => 1*Fe_1
# Adding reaction: Fe_4_i : 1*Fe_4 + 1*de => 1*Fe_5 + 2*de
# Adding reaction: Fe_5_r : 1*Fe_5 + 1*de => 1*Fe_4
# Adding reaction: Fe_11_r : 1*Fe_11 + 1*de => 1*Fe_10
# Adding reaction: Fe_18_r : 1*Fe_18 + 1*de => 1*Fe_17
# Adding reaction: Fe_10_i : 1*Fe_10 + 1*de => 1*Fe_11 + 2*de
# Adding reaction: Fe_1_i : 1*Fe_1 + 1*de => 1*Fe_2 + 2*de
# Adding reaction: Fe_19_r : 1*Fe_19 + 1*de => 1*Fe_18
# Adding reaction: Fe_16_r : 1*Fe_16 + 1*de => 1*Fe_15
# Adding reaction: Fe_16_i : 1*Fe_16 + 1*de => 1*Fe_17 + 2*de
# Adding reaction: Fe_3_i : 1*Fe_3 + 1*de => 1*Fe_4 + 2*de
# Adding reaction: Fe_10_r : 1*Fe_10 + 1*de => 1*Fe_9
# Adding reaction: Fe_18_i : 1*Fe_18 + 1*de => 1*Fe_19 + 2*de
# Adding reaction: Fe_11_i : 1*Fe_11 + 1*de => 1*Fe_12 + 2*de
# Adding reaction: Fe_15_r : 1*Fe_15 + 1*de => 1*Fe_14
# Adding reaction: Fe_25_r : 1*Fe_25 + 1*de => 1*Fe_24
# Adding reaction: Fe_14_i : 1*Fe_14 + 1*de => 1*Fe_15 + 2*de
# Adding reaction: Fe_12_r : 1*Fe_12 + 1*de => 1*Fe_11
# Adding reaction: Fe_26_i : 1*Fe_26 + 1*de => 1*Fe_27 + 2*de
# Adding reaction: Fe_24_r : 1*Fe_24 + 1*de => 1*Fe_23
# Adding reaction: Fe_13_r : 1*Fe_13 + 1*de => 1*Fe_12
# Adding reaction: Fe_19_i : 1*Fe_19 + 1*de => 1*Fe_20 + 2*de
# Adding reaction: Fe_17_i : 1*Fe_17 + 1*de => 1*Fe_18 + 2*de
# Adding reaction: Fe_13_i : 1*Fe_13 + 1*de => 1*Fe_14 + 2*de
# Adding reaction: Fe_24_i : 1*Fe_24 + 1*de => 1*Fe_25 + 2*de
# Adding reaction: Fe_17_r : 1*Fe_17 + 1*de => 1*Fe_16
# Adding reaction: Fe_27_r : 1*Fe_27 + 1*de => 1*Fe_26
# Adding reaction: Fe_12_i : 1*Fe_12 + 1*de => 1*Fe_13 + 2*de
# Adding reaction: Fe_14_r : 1*Fe_14 + 1*de => 1*Fe_13
# Adding reaction: Fe_25_i : 1*Fe_25 + 1*de => 1*Fe_26 + 2*de
# Adding reaction: Fe_15_i : 1*Fe_15 + 1*de => 1*Fe_16 + 2*de
# Adding reaction: Fe_26_r : 1*Fe_26 + 1*de => 1*Fe_25
# Adding reaction: Fe_9_i : 1*Fe_9 + 1*de => 1*Fe_10 + 2*de
# Adding reaction: Fe_8_r : 1*Fe_8 + 1*de => 1*Fe_7
# Adding reaction: Fe_21_r : 1*Fe_21 + 1*de => 1*Fe_20
# Adding reaction: Fe_22_i : 1*Fe_22 + 1*de => 1*Fe_23 + 2*de
# Adding reaction: Fe_6_i : 1*Fe_6 + 1*de => 1*Fe_7 + 2*de
# Adding reaction: Fe_20_r : 1*Fe_20 + 1*de => 1*Fe_19
# Adding reaction: Fe_6_r : 1*Fe_6 + 1*de => 1*Fe_5
# Adding reaction: Fe_22_r : 1*Fe_22 + 1*de => 1*Fe_21
# Adding reaction: Fe_20_i : 1*Fe_20 + 1*de => 1*Fe_21 + 2*de
# Adding reaction: Fe_8_i : 1*Fe_8 + 1*de => 1*Fe_9 + 2*de
# Adding reaction: Fe_9_r : 1*Fe_9 + 1*de => 1*Fe_8
# Adding reaction: Fe_21_i : 1*Fe_21 + 1*de => 1*Fe_22 + 2*de

# %%
G = nx.MultiDiGraph()

for reaction in ion_by_ion.reactions:
    r = ion_by_ion.reactions[reaction]
    down_species  = r.down_species
    up_species  = r.up_species    
    for d_sp in down_species:
        for u_sp in up_species:
            dname = d_sp.name
            uname = u_sp.name
            
            nd = dname
            nu = uname
            cd = ""
            cu = ""
            
            
            G.add_node(nd+cd)
            G.add_node(nu+cu)
            
#             try:
#                 nd, c = dname.split('_')
#                 cd = write_roman(int(c))
#             except:
#                 nd = dname
#                 cd = ""
#             try:
#                 nu, cu = uname.split('_')
#                 cu = write_roman(int(c))
#             except:
#                 nu = uname
#                 cu = ""
            G.add_edge( nd+cd , nu+cu )

# %%
    
from matplotlib.pyplot import cm

ele_to_color = {}

for i, ele in enumerate(all_elements):
        ele_to_color[ele] = color[i]
color_map = []
for node in G:
        try:
            n, c = node.split('_')
        except:
            n = "de"
        color_map.append( ele_to_color[n] )
pos = nx.spring_layout(G)
plt.figure(figsize=(10,10))
p = nx.draw(G, pos,node_color = color_map, with_labels=True, arrows=True)

# %%
from collections import OrderedDict

def write_roman(num):

    roman = OrderedDict()
    roman[1000] = "M"
    roman[900] = "CM"
    roman[500] = "D"
    roman[400] = "CD"
    roman[100] = "C"
    roman[90] = "XC"
    roman[50] = "L"
    roman[40] = "XL"
    roman[10] = "X"
    roman[9] = "IX"
    roman[5] = "V"
    roman[4] = "IV"
    roman[1] = "I"

    def roman_num(num):
        for r in roman.keys():
            x, y = divmod(num, r)
            yield roman[r] * x
            num -= (r * x)
            if num > 0:
                roman_num(num)
            else:
                break
    return "".join([a for a in roman_num(num)])
